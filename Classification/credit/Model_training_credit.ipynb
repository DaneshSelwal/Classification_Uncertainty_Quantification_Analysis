# %% [markdown]
# # 1.0 — Setup & Imports
#
# Mount Google Drive and import all required standard, scientific, and deep-learning libraries.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ── Standard library ──────────────────────────────────────────────────────────
import os
import glob
import json
import time
import random
from pathlib import Path

# ── Scientific / data ─────────────────────────────────────────────────────────
import numpy as np
import pandas as pd

# ── Visualisation ─────────────────────────────────────────────────────────────
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch

# ── Deep learning ─────────────────────────────────────────────────────────────
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# ── ML utilities ──────────────────────────────────────────────────────────────
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score, cohen_kappa_score, confusion_matrix,
    classification_report, f1_score, log_loss
)

# ── Excel export ──────────────────────────────────────────────────────────────
from openpyxl import Workbook
from openpyxl.styles import Font, PatternFill, Alignment, Border, Side
from openpyxl.utils import get_column_letter
from openpyxl.drawing.image import Image as XLImage

sns.set_style('whitegrid')
print('TensorFlow:', tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# # 2.0 — Configuration
#
# All paths, seeds, dataset geometry, training hyperparameters, and per-architecture configs in one place. **Edit only this section between experiments.**

# %%
# ── Reproducibility ───────────────────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# ── Directory layout ──────────────────────────────────────────────────────────
PROJECT_ROOT = Path('/content/drive/My Drive/Classification')
DATA_DIR     = PROJECT_ROOT / 'data'
MODEL_DIR    = PROJECT_ROOT / 'credit' / 'models'
RESULTS_DIR  = PROJECT_ROOT / 'credit' / 'results'
ENSEMBLE_DIR = PROJECT_ROOT / 'ensemble' / 'models' / 'ensembles'

MODEL_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
PLOT_DIR = RESULTS_DIR / 'training_plots'
PLOT_DIR.mkdir(parents=True, exist_ok=True)

DATA_FILE  = DATA_DIR / 'data.csv'
LABEL_FILE = DATA_DIR / 'ref.csv'

# ── Dataset geometry ──────────────────────────────────────────────────────────
H, W, B     = 330, 307, 6   # height, width, spectral bands
PATCH_SIZE  = 9
INNER_PATCH = 3             # tokenisation patch size for GFNet / ViT

# ── Split ratios ──────────────────────────────────────────────────────────────
TRAIN_PERCENT        = 0.75
VAL_SPLIT_FROM_TRAIN = 0.20

# ── Training hyperparameters ──────────────────────────────────────────────────
BATCH_SIZE    = 128
EPOCHS        = 100
LEARNING_RATE = 3e-4
DROPOUT_RATE  = 0.25

TRAIN_CFG = {
    'label_smoothing': 0.05,
    'weight_decay':    1e-4,
    'clipnorm':        1.0,
    'cosine_alpha':    0.05,
}

# ── Architecture configs ──────────────────────────────────────────────────────
ALEXNET_CFG = {
    'conv_filters': [96, 256, 384, 384, 256],
    'dense_units':  [4096, 1024, 256, 32],
}
GFNET_CFG = {
    'hidden_dim': 512,
    'num_blocks': 5,
    'mlp_ratio':  4,
}
VIT_CFG = {
    'projection_dim':     256,
    'num_heads':          4,
    'transformer_layers': 12,
    'mlp_multiplier':     2,
    'head_units':         [512, 256, 128, 64],
}

# ── AlexNet legacy recipe (keeps uncertainty recovery reproducible) ────────────
ALEXNET_LEGACY_SPLIT_SEED    = 10
ALEXNET_LEGACY_TRAIN_PERCENT = 0.75
ALEXNET_LR_START = 0.01
ALEXNET_LR_MAX   = 0.02
ALEXNET_LR_MIN   = 0.005

# ── Sanity print ──────────────────────────────────────────────────────────────
print('Data   :', DATA_FILE)
print('Labels :', LABEL_FILE)
print('Models :', MODEL_DIR)
print('Results:', RESULTS_DIR)
# Out:
# Data   : /content/drive/My Drive/Classification/data/data.csv
# Labels : /content/drive/My Drive/Classification/data/ref.csv
# Models : /content/drive/My Drive/Classification/credit/models
# Results: /content/drive/My Drive/Classification/credit/results

# %% [markdown]
# # 3.0 — Data Loading & Patch Extraction
#
# Reads the multispectral CSV rasters, applies per-band min-max normalisation, extracts fixed-size spatial patches centred on every labelled pixel, and builds both the standard and AlexNet-legacy train/test splits.

# %% [markdown]
# ## 3.1 — Helper Functions

# %%
def load_multispectral_6band(data_path, label_path, height, width, bands):
    """Read CSV rasters, reshape to (H, W, B), and apply per-band min-max normalisation."""
    x = pd.read_csv(data_path).to_numpy(dtype=np.float32).reshape(height, width, bands)
    y = pd.read_csv(label_path).to_numpy(dtype=np.int32).reshape(height, width)

    x_norm = np.empty_like(x, dtype=np.float32)
    for b in range(bands):
        band = x[:, :, b]
        b_min, b_max = np.min(band), np.max(band)
        x_norm[:, :, b] = (band - b_min) / max(b_max - b_min, 1e-8)
    return x_norm, y


def extract_labeled_patches(x, y, patch_size=9):
    """Extract spatial patches centred on every labelled (y > 0) pixel."""
    pad   = patch_size // 2
    x_pad = np.pad(x, ((pad, pad), (pad, pad), (0, 0)), mode='edge')

    coords  = np.argwhere(y > 0)
    patches = np.empty((len(coords), patch_size, patch_size, x.shape[-1]), dtype=np.float32)
    labels  = np.empty((len(coords),), dtype=np.int32)

    for i, (r, c) in enumerate(coords):
        patches[i] = x_pad[r:r + patch_size, c:c + patch_size, :]
        labels[i]  = int(y[r, c]) - 1   # 1-indexed → 0-indexed

    return patches, labels, coords

# %% [markdown]
# ## 3.2 — Load Image & Extract Patches

# %%
print('Loading multispectral image...')
x_img, y_img = load_multispectral_6band(DATA_FILE, LABEL_FILE, H, W, B)

print('Extracting patches...')
X, y, coords = extract_labeled_patches(x_img, y_img, PATCH_SIZE)

num_classes = int(np.unique(y).size)
input_shape = (PATCH_SIZE, PATCH_SIZE, B)

print(f'Image  : {x_img.shape}  |  Labels : {y_img.shape}')
print(f'Patches: {X.shape}  |  Classes: {num_classes}')
# Out:
# Loading multispectral image...
# Extracting patches...
# Image  : (330, 307, 6)  |  Labels : (330, 307)
# Patches: (17239, 9, 9, 6)  |  Classes: 7

# %% [markdown]
# ## 3.3 — Train / Validation / Test Split
#
# Two independent splits are created: a **standard split** (shared by GFNet and ViT) and an **AlexNet legacy split** (separate seed to preserve reproducibility of uncertainty recovery).

# %%
# ── Standard split (GFNet & ViT) ──────────────────────────────────────────────
x_train_full, x_test, y_train_full, y_test = train_test_split(
    X, y, train_size=TRAIN_PERCENT, random_state=SEED, stratify=y
)
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full,
    test_size=VAL_SPLIT_FROM_TRAIN, random_state=SEED, stratify=y_train_full
)

y_train_cat = keras.utils.to_categorical(y_train, num_classes)
y_val_cat   = keras.utils.to_categorical(y_val,   num_classes)
y_test_cat  = keras.utils.to_categorical(y_test,  num_classes)

print(f'Train : {x_train.shape}  Val : {x_val.shape}  Test : {x_test.shape}')

# ── AlexNet legacy split (separate seed for uncertainty recovery) ──────────────
x_train_alex, x_test_alex, y_train_alex, y_test_alex = train_test_split(
    X, y,
    train_size=ALEXNET_LEGACY_TRAIN_PERCENT,
    random_state=ALEXNET_LEGACY_SPLIT_SEED,
    stratify=y
)
y_train_alex_cat = keras.utils.to_categorical(y_train_alex, num_classes)
y_test_alex_cat  = keras.utils.to_categorical(y_test_alex,  num_classes)

print(f'AlexNet  Train : {x_train_alex.shape}  Test : {x_test_alex.shape}')
# Out:
# Train : (10343, 9, 9, 6)  Val : (2586, 9, 9, 6)  Test : (4310, 9, 9, 6)
# AlexNet  Train : (12929, 9, 9, 6)  Test : (4310, 9, 9, 6)

# %% [markdown]
# # 4.0 — Model Definitions
#
# Defines all three single-head base architectures (AlexNet CNN, GFNet, ViT with U-Net skip connections) plus the shared custom Keras layers used by GFNet and ViT.

# %% [markdown]
# ## 4.1 — Shared Custom Keras Layers
#
# Four serialisable custom layers: patch extraction, positional encoding (with and without CLS token), and the frequency-domain Global Filter layer used in GFNet.

# %%
@tf.keras.utils.register_keras_serializable()
class PatchExtractor(layers.Layer):
    """Extract non-overlapping patches from a spatial image tensor."""

    def __init__(self, patch_size=3, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding='VALID',
        )
        batch       = tf.shape(images)[0]
        num_patches = tf.shape(patches)[1] * tf.shape(patches)[2]
        patch_dim   = tf.shape(patches)[-1]
        return tf.reshape(patches, [batch, num_patches, patch_dim])

    def get_config(self):
        cfg = super().get_config()
        cfg.update({'patch_size': self.patch_size})
        return cfg


@tf.keras.utils.register_keras_serializable()
class PatchPositionEncoder(layers.Layer):
    """Linear projection + learnable position embedding (no CLS token)."""

    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches    = num_patches
        self.projection_dim = projection_dim
        self.projection         = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patches):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        return self.projection(patches) + self.position_embedding(positions)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({'num_patches': self.num_patches, 'projection_dim': self.projection_dim})
        return cfg


@tf.keras.utils.register_keras_serializable()
class PatchEncoderWithCLS(layers.Layer):
    """Linear projection + learnable position embedding WITH a prepended CLS token."""

    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches    = num_patches
        self.projection_dim = projection_dim
        self.projection         = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches + 1, output_dim=projection_dim
        )

    def build(self, input_shape):
        self.cls_token = self.add_weight(
            name='cls_token', shape=(1, 1, self.projection_dim),
            initializer='zeros', trainable=True
        )
        super().build(input_shape)

    def call(self, patches):
        batch      = tf.shape(patches)[0]
        patch_proj = self.projection(patches)
        cls_tokens = tf.repeat(self.cls_token, repeats=batch, axis=0)
        x          = tf.concat([cls_tokens, patch_proj], axis=1)
        positions  = tf.range(start=0, limit=self.num_patches + 1, delta=1)
        return x + self.position_embedding(positions)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({'num_patches': self.num_patches, 'projection_dim': self.projection_dim})
        return cfg


@tf.keras.utils.register_keras_serializable()
class GlobalFilterLayer(layers.Layer):
    """Learnable complex-valued filter applied in the 2-D frequency domain."""

    def __init__(self, token_side, **kwargs):
        super().__init__(**kwargs)
        self.token_side = token_side

    def build(self, input_shape):
        channels = int(input_shape[-1])
        self.w_real = self.add_weight(
            name='w_real', shape=(self.token_side, self.token_side, channels),
            initializer='glorot_uniform', trainable=True
        )
        self.w_imag = self.add_weight(
            name='w_imag', shape=(self.token_side, self.token_side, channels),
            initializer='zeros', trainable=True
        )
        super().build(input_shape)

    def call(self, x):
        batch    = tf.shape(x)[0]
        channels = tf.shape(x)[-1]
        x_2d       = tf.reshape(x, [batch, self.token_side, self.token_side, channels])
        x_fft      = tf.signal.fft2d(tf.cast(x_2d, tf.complex64))
        w_complex  = tf.complex(self.w_real, self.w_imag)
        x_filtered = x_fft * w_complex
        x_spatial  = tf.math.real(tf.signal.ifft2d(x_filtered))
        return tf.reshape(x_spatial, [batch, self.token_side * self.token_side, channels])

    def get_config(self):
        cfg = super().get_config()
        cfg.update({'token_side': self.token_side})
        return cfg

# %% [markdown]
# ## 4.2 — AlexNet CNN

# %%
def build_alexnet(input_shape, num_classes, dropout_rate=0.25, cfg=None):
    """Build a single-head AlexNet-style CNN with configurable conv and dense units."""
    cfg = cfg or ALEXNET_CFG

    inputs = keras.Input(shape=input_shape)
    x = inputs

    for i, filters in enumerate(cfg['conv_filters'], start=1):
        x = layers.Conv2D(filters, (3, 3), activation='relu',
                          padding='same', name=f'alex_conv_{i}')(x)

    x = layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2),
                            padding='same', name='alex_pool')(x)
    x = layers.Flatten(name='alex_flatten')(x)

    fc_names   = ['alex_fc1', 'alex_fc2', 'alex_fc3', 'alex_fc4']
    drop_names = ['TRAIN_DROPOUT_1', 'TRAIN_DROPOUT_2', 'TRAIN_DROPOUT_3', None]

    for units, fc_name, drop_name in zip(cfg['dense_units'], fc_names, drop_names):
        x = layers.Dense(units, activation='relu', name=fc_name)(x)
        if drop_name:
            x = layers.Dropout(dropout_rate, name=drop_name)(x)

    outputs = layers.Dense(num_classes, activation='softmax', name='alex_logits')(x)
    return keras.Model(inputs, outputs, name='AlexNet_SingleHead')

# %% [markdown]
# ## 4.3 — Global Filter Network (GFNet)

# %%
def gf_block(x, token_side, dim, mlp_ratio=4, dropout_rate=0.25, name_prefix='gf'):
    """One GFNet block: Global Filter → LayerNorm → MLP → residual add."""
    y = layers.LayerNormalization(name=f'{name_prefix}_ln1')(x)
    y = GlobalFilterLayer(token_side, name=f'{name_prefix}_gfilter')(y)
    y = layers.LayerNormalization(name=f'{name_prefix}_ln2')(y)
    y = layers.Dense(dim * mlp_ratio, activation=tf.keras.activations.gelu,
                     name=f'{name_prefix}_mlp1')(y)
    y = layers.Dropout(dropout_rate, name=f'{name_prefix}_drop1')(y)
    y = layers.Dense(dim, activation=tf.keras.activations.gelu,
                     name=f'{name_prefix}_mlp2')(y)
    y = layers.Dropout(dropout_rate, name=f'{name_prefix}_drop2')(y)
    return layers.Add(name=f'{name_prefix}_add')([x, y])


def build_gfnet(input_shape, num_classes, inner_patch=3,
                hidden_dim=512, num_blocks=5, mlp_ratio=4, dropout_rate=0.25):
    """Build a single-head Global Filter Network over tokenised image patches."""
    num_patches = (input_shape[0] // inner_patch) * (input_shape[1] // inner_patch)
    token_side  = int(np.sqrt(num_patches))

    inputs = keras.Input(shape=input_shape)
    x = PatchExtractor(inner_patch, name='gf_patch_extractor')(inputs)
    x = PatchPositionEncoder(num_patches, hidden_dim, name='gf_patch_encoder')(x)
    x = layers.Dropout(dropout_rate, name='TRAIN_DROPOUT_1')(x)

    for i in range(num_blocks):
        x = gf_block(x, token_side, hidden_dim, mlp_ratio,
                     dropout_rate, name_prefix=f'gf_block_{i+1}')

    x = layers.Dropout(dropout_rate, name='TRAIN_DROPOUT_2')(x)
    x = layers.LayerNormalization(name='gf_final_ln')(x)
    x = layers.GlobalAveragePooling1D(name='gf_gap')(x)
    x = layers.Flatten(name='gf_flatten')(x)
    x = layers.Dropout(dropout_rate, name='TRAIN_DROPOUT_3')(x)
    outputs = layers.Dense(num_classes, activation='softmax', name='gf_logits')(x)

    return keras.Model(inputs, outputs, name='GFNet_SingleHead')

# %% [markdown]
# ## 4.4 — Vision Transformer with U-Net Skip Connections

# %%
def transformer_block(x, num_heads, projection_dim, mlp_dim, dropout_rate, name_prefix):
    """Standard pre-LN transformer block: Multi-Head Attention + MLP with residual adds."""
    y = layers.LayerNormalization(epsilon=1e-6, name=f'{name_prefix}_ln1')(x)
    y = layers.MultiHeadAttention(
        num_heads=num_heads, key_dim=projection_dim,
        dropout=dropout_rate, name=f'{name_prefix}_mha'
    )(y, y)
    x = layers.Add(name=f'{name_prefix}_add1')([y, x])

    y = layers.LayerNormalization(epsilon=1e-6, name=f'{name_prefix}_ln2')(x)
    y = layers.Dense(mlp_dim, activation=tf.keras.activations.gelu,
                     name=f'{name_prefix}_mlp1')(y)
    y = layers.Dropout(dropout_rate, name=f'{name_prefix}_drop1')(y)
    y = layers.Dense(projection_dim, activation=tf.keras.activations.gelu,
                     name=f'{name_prefix}_mlp2')(y)
    y = layers.Dropout(dropout_rate, name=f'{name_prefix}_drop2')(y)
    return layers.Add(name=f'{name_prefix}_add2')([y, x])


def build_vit_unet_singlehead(
    input_shape, num_classes, inner_patch=3,
    projection_dim=256, num_heads=4, transformer_layers=12,
    mlp_multiplier=2, dropout_rate=0.25, head_units=(512, 256, 128, 64)
):
    """Build a single-head ViT with encoder-decoder skip connections (U-Net style)."""
    num_patches = (input_shape[0] // inner_patch) * (input_shape[1] // inner_patch)

    inputs = keras.Input(shape=input_shape)
    x = PatchExtractor(inner_patch, name='vit_patch_extractor')(inputs)
    x = PatchEncoderWithCLS(num_patches, projection_dim, name='vit_patch_encoder')(x)

    block_list = []
    for i in range(transformer_layers):
        x = transformer_block(
            x, num_heads=num_heads, projection_dim=projection_dim,
            mlp_dim=projection_dim * mlp_multiplier,
            dropout_rate=0.1, name_prefix=f'vit_block_{i+1}'
        )
        if i <= transformer_layers // 2:
            block_list.append(x)
        else:
            x = layers.Add(name=f'vit_skip_add_{i+1}')(
                [x, block_list[transformer_layers - i - 1]]
            )

    x         = layers.Dropout(dropout_rate, name='TRAIN_DROPOUT_1')(x)
    x         = layers.LayerNormalization(epsilon=1e-6, name='vit_cls_norm')(x)
    cls_token = layers.Lambda(lambda t: t[:, 0, :], name='vit_cls_token')(x)

    drop_slots = ['TRAIN_DROPOUT_3', None, 'TRAIN_DROPOUT_5', 'TRAIN_DROPOUT_6']
    head_names = ['vit_head_1', 'vit_head_2', 'vit_head_3', 'vit_head_4']
    y = cls_token
    for units, hname, dname in zip(head_units, head_names, drop_slots):
        y = layers.Dense(units, activation=tf.keras.activations.gelu, name=hname)(y)
        if dname:
            y = layers.Dropout(dropout_rate, name=dname)(y)

    outputs = layers.Dense(num_classes, activation='softmax', name='vit_logits')(y)
    return keras.Model(inputs, outputs, name='ViT_UNet_SingleHead')

# %% [markdown]
# # 5.0 — Training Helpers
#
# Utility functions for calibration metrics, optimiser construction, and the formatted Excel report writer.

# %% [markdown]
# ## 5.1 — Calibration Metrics

# %%
def multiclass_brier_score(y_onehot, y_prob):
    """Compute the multiclass Brier score (mean squared probability error)."""
    return float(np.mean(np.sum((y_prob - y_onehot) ** 2, axis=1)))


def expected_calibration_error(y_true, y_prob, n_bins=15):
    """Compute Expected Calibration Error (ECE) using equal-width confidence bins."""
    confidences = np.max(y_prob, axis=1)
    predictions = np.argmax(y_prob, axis=1)
    correct     = (predictions == y_true).astype(np.float32)
    bin_edges   = np.linspace(0.0, 1.0, n_bins + 1)
    ece = 0.0
    for i in range(n_bins):
        lo, hi = bin_edges[i], bin_edges[i + 1]
        in_bin = (confidences >= lo) & (
            confidences <= hi if i == n_bins - 1 else confidences < hi
        )
        prop = np.mean(in_bin)
        if prop > 0:
            ece += np.abs(np.mean(correct[in_bin]) - np.mean(confidences[in_bin])) * prop
    return float(ece)

# %% [markdown]
# ## 5.2 — Optimiser & LR Schedule

# %%
def make_adamw_optimizer(num_train_samples):
    """Build a cosine-decay AdamW optimiser (used for GFNet and ViT)."""
    steps_per_epoch = int(np.ceil(num_train_samples / BATCH_SIZE))
    decay_steps     = max(1, steps_per_epoch * EPOCHS)
    lr_schedule = keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=LEARNING_RATE,
        decay_steps=decay_steps,
        alpha=TRAIN_CFG['cosine_alpha'],
    )
    return keras.optimizers.AdamW(
        learning_rate=lr_schedule,
        weight_decay=TRAIN_CFG['weight_decay'],
        clipnorm=TRAIN_CFG['clipnorm'],
    )


def _alexnet_legacy_lr(epoch):
    """Cosine LR schedule oscillating between ALEXNET_LR_MIN and ALEXNET_LR_MAX."""
    if EPOCHS <= 1:
        return ALEXNET_LR_START
    phase        = np.pi * epoch / (EPOCHS - 1)
    cosine_decay = 0.5 * (1.0 + np.cos(phase))
    return float((ALEXNET_LR_MAX - ALEXNET_LR_MIN) * cosine_decay + ALEXNET_LR_MIN)

# %% [markdown]
# ## 5.3 — Excel Report Helpers
#
# Style constants and helper functions for writing DataFrames and plots into a formatted `.xlsx` workbook.

# %%
# ── Style constants ───────────────────────────────────────────────────────────
_HDR_FILL   = PatternFill('solid', start_color='1F4E79')
_ALT_FILL   = PatternFill('solid', start_color='D6E4F0')
_HDR_FONT   = Font(name='Arial', bold=True, color='FFFFFF', size=11)
_BODY_FONT  = Font(name='Arial', size=10)
_TITLE_FONT = Font(name='Arial', bold=True, size=13)
_CENTER     = Alignment(horizontal='center', vertical='center', wrap_text=True)
_LEFT       = Alignment(horizontal='left',   vertical='center')
_THIN_SIDE  = Side(style='thin', color='AAAAAA')
_THIN_BORDER = Border(
    left=_THIN_SIDE, right=_THIN_SIDE, top=_THIN_SIDE, bottom=_THIN_SIDE
)


def _style_header_row(ws, row, col_start, col_end):
    """Apply dark-blue header styling to a worksheet row range."""
    for c in range(col_start, col_end + 1):
        cell = ws.cell(row=row, column=c)
        cell.fill      = _HDR_FILL
        cell.font      = _HDR_FONT
        cell.alignment = _CENTER
        cell.border    = _THIN_BORDER


def _style_data_rows(ws, row_start, row_end, col_start, col_end):
    """Apply alternating-row fill and border to a worksheet data range."""
    for r in range(row_start, row_end + 1):
        fill = _ALT_FILL if r % 2 == 0 else PatternFill()
        for c in range(col_start, col_end + 1):
            cell = ws.cell(row=r, column=c)
            cell.font      = _BODY_FONT
            cell.fill      = fill
            cell.alignment = _LEFT
            cell.border    = _THIN_BORDER


def _write_df_to_sheet(ws, df, start_row=1, start_col=1, title=None):
    """Write a DataFrame into a worksheet with headers, alternating rows, and auto-width columns."""
    r = start_row
    if title:
        cell = ws.cell(row=r, column=start_col, value=title)
        cell.font      = _TITLE_FONT
        cell.alignment = _LEFT
        ws.merge_cells(
            start_row=r, start_column=start_col,
            end_row=r, end_column=start_col + len(df.columns) - 1
        )
        r += 1

    # Header row
    for j, col_name in enumerate(df.columns, start=start_col):
        ws.cell(row=r, column=j, value=col_name)
    _style_header_row(ws, r, start_col, start_col + len(df.columns) - 1)
    r += 1

    # Data rows
    data_start = r
    for _, row_data in df.iterrows():
        for j, val in enumerate(row_data, start=start_col):
            ws.cell(row=r, column=j,
                    value=round(float(val), 6)
                    if isinstance(val, (float, np.floating)) else val)
        r += 1
    _style_data_rows(ws, data_start, r - 1, start_col, start_col + len(df.columns) - 1)

    # Auto column width
    for j, col_name in enumerate(df.columns, start=start_col):
        max_len = max(
            len(str(col_name)),
            max((len(str(ws.cell(row=row, column=j).value or ''))
                 for row in range(data_start, r)), default=0)
        )
        ws.column_dimensions[get_column_letter(j)].width = min(max_len + 4, 40)

    return r  # next free row

# %% [markdown]
# ## 5.4 — Excel Report Builder
#
# Assembles the full `CREDIT_Results.xlsx` workbook with four sheets: Training Summary, Evaluation Summary, Confusion Matrices, and Plots.

# %%
def create_credit_excel_report(
    results_dir,
    train_summary_df,
    eval_summary_df,
    credit_artifacts_dict,
    plot_paths           # list of (label_str, image_path_str)
):
    """
    Create CREDIT_Results.xlsx with four sheets:
      Sheet 1 — Training Summary
      Sheet 2 — Evaluation Summary
      Sheet 3 — Confusion Matrices (per model, side by side)
      Sheet 4 — Plots (one image per row)
    """
    xlsx_path = Path(results_dir) / 'CREDIT_Results.xlsx'
    wb = Workbook()

    # ── Sheet 1: Training Summary ──────────────────────────────────────────────
    ws1 = wb.active
    ws1.title = 'Training Summary'
    ws1.row_dimensions[1].height = 30
    _write_df_to_sheet(ws1, train_summary_df,
                       start_row=1, title='CREDIT — Training Uncertainty Summary')

    # ── Sheet 2: Evaluation Summary ────────────────────────────────────────────
    ws2 = wb.create_sheet('Evaluation Summary')
    _write_df_to_sheet(ws2, eval_summary_df,
                       start_row=1, title='CREDIT — Full Evaluation Metrics')

    # ── Sheet 3: Confusion Matrices ────────────────────────────────────────────
    ws3 = wb.create_sheet('Confusion Matrices')
    col_cursor = 1
    for mname, art in credit_artifacts_dict.items():
        cm    = art['confusion_matrix']
        rep   = art['report']
        n_cls = cm.shape[0]

        # Title
        cell = ws3.cell(row=1, column=col_cursor,
                        value=f'{mname} — Confusion Matrix')
        cell.font = _TITLE_FONT
        ws3.merge_cells(start_row=1, start_column=col_cursor,
                        end_row=1, end_column=col_cursor + n_cls)

        # Column headers (Predicted)
        ws3.cell(row=2, column=col_cursor,
                 value='True \\ Pred').font = Font(bold=True, name='Arial')
        for j in range(n_cls):
            c = ws3.cell(row=2, column=col_cursor + 1 + j, value=f'C{j+1}')
            c.font      = Font(bold=True, name='Arial', color='FFFFFF')
            c.fill      = _HDR_FILL
            c.alignment = _CENTER

        # Data rows
        for i in range(n_cls):
            ws3.cell(row=3 + i, column=col_cursor,
                     value=f'C{i+1}').font = Font(bold=True, name='Arial')
            for j in range(n_cls):
                val  = int(cm[i, j])
                cell = ws3.cell(row=3 + i, column=col_cursor + 1 + j, value=val)
                cell.alignment = _CENTER
                cell.border    = _THIN_BORDER
                if i == j:  # diagonal → green
                    cell.fill = PatternFill('solid', start_color='C6EFCE')
                    cell.font = Font(name='Arial', bold=True, color='276221')
                else:
                    cell.font = _BODY_FONT

        # Per-class F1 from classification report
        f1_row = 3 + n_cls + 1
        ws3.cell(row=f1_row, column=col_cursor,
                 value='Per-Class F1').font = Font(bold=True, name='Arial')
        for j in range(n_cls):
            key = str(j)
            f1  = rep.get(key, {}).get('f1-score', '')
            ws3.cell(row=f1_row, column=col_cursor + 1 + j,
                     value=round(f1, 4) if f1 != '' else '').font = _BODY_FONT

        col_cursor += n_cls + 3   # gap between model tables

    # ── Sheet 4: Plots ─────────────────────────────────────────────────────────
    ws4 = wb.create_sheet('Plots')
    title_cell = ws4.cell(row=1, column=1, value='CREDIT — All Output Plots')
    title_cell.font = Font(name='Arial', bold=True, size=14)

    img_row = 3
    for label, img_path in plot_paths:
        if not Path(img_path).exists():
            continue
        ws4.cell(row=img_row, column=1,
                 value=label).font = Font(name='Arial', bold=True, size=11)
        img_row += 1

        xl_img = XLImage(img_path)
        orig_w, orig_h = xl_img.width, xl_img.height
        target_w = 900
        scale         = target_w / orig_w if orig_w > 0 else 1
        xl_img.width  = int(orig_w * scale)
        xl_img.height = int(orig_h * scale)

        cell_addr = f'A{img_row}'
        ws4.add_image(xl_img, cell_addr)
        # openpyxl row height is in points; 1pt ≈ 0.75px
        ws4.row_dimensions[img_row].height = xl_img.height * 0.75
        img_row += int(xl_img.height / 15) + 3

    wb.save(xlsx_path)
    print(f'\n✅ Excel report saved → {xlsx_path}')
    return str(xlsx_path)

# %% [markdown]
# # 6.0 — CREDIT Distillation
#
# Generates soft targets from the pre-trained ensemble teachers, builds a dual-head student for each architecture, and trains it via KL divergence (aleatoric head) + MSE (epistemic head).

# %% [markdown]
# ## 6.1 — Soft Target Generation
#
# Loads each ensemble teacher, runs inference over the training data, and derives CREDIT targets: `p_star` (normalised per-class minimum — aleatoric proxy) and `delta_p` (per-class prediction spread — epistemic proxy).

# %%
def get_ensemble_paths(model_name):
    """Locate ensemble teacher weights using three fallback search patterns."""
    # Primary: standardised location
    pattern = str(ENSEMBLE_DIR / f'{model_name}_ens_*_final.keras')
    paths   = glob.glob(pattern)

    # Fallback 1: sub-folder style
    if not paths:
        pattern = str(
            ENSEMBLE_DIR / f'ensembles_{model_name}' / f'{model_name}_ens_*_final.keras'
        )
        paths = glob.glob(pattern)

    # Fallback 2: old Credit/models location
    if not paths:
        pattern = str(MODEL_DIR / f'{model_name}_ens_*_final.keras')
        paths   = glob.glob(pattern)

    return sorted(paths)


def generate_credit_targets(ensemble_paths, x_data, batch_size=128):
    """
    Run each teacher over x_data and derive CREDIT interval targets.

    Returns:
        p_star_true  : (N, C) normalised per-class minimum  (aleatoric proxy)
        delta_p_true : (N, C) per-class prediction spread   (epistemic proxy)
    """
    all_preds = []
    for path in ensemble_paths:
        print(f'  Loading teacher: {path}')
        model = tf.keras.models.load_model(path, compile=False, safe_mode=False)
        all_preds.append(model.predict(x_data, batch_size=batch_size, verbose=1))
        del model
        tf.keras.backend.clear_session()

    stacked = tf.stack(all_preds, axis=0)   # (M, N, C)
    p_min   = tf.reduce_min(stacked, axis=0)  # (N, C)
    p_max   = tf.reduce_max(stacked, axis=0)  # (N, C)

    delta_p_true = p_max - p_min
    p_star_true  = p_min / (tf.reduce_sum(p_min, axis=-1, keepdims=True) + 1e-12)
    return p_star_true, delta_p_true

# %% [markdown]
# ## 6.2 — CREDIT Student (Dual-Head)
#
# Wraps any single-head base architecture with two output heads: a softmax head for the aleatoric belief (`p_star`) and a sigmoid head for the epistemic spread (`delta_p`).

# %%
def build_credit_student(base_builder_func, num_classes):
    """
    Attach CREDIT dual-output heads to any single-head base architecture.

    Args:
        base_builder_func: Zero-argument callable that returns a Keras model.
        num_classes:       Number of target classes.

    Returns:
        A Keras model with outputs [p_star (softmax), delta_p (sigmoid)].
    """
    base_model = base_builder_func()
    features   = base_model.layers[-2].output   # penultimate feature tensor

    p_star  = layers.Dense(num_classes, activation='softmax',  name='p_star' )(features)
    delta_p = layers.Dense(num_classes, activation='sigmoid',  name='delta_p')(features)

    return tf.keras.Model(
        inputs=base_model.input,
        outputs=[p_star, delta_p],
        name='CREDIT_Student'
    )

# %% [markdown]
# ## 6.3 — Model Builder Registry
#
# Centralised registry mapping model names to zero-argument builder lambdas.

# %%
model_builders = {
    'AlexNet_CNN': lambda: build_alexnet(
        input_shape, num_classes,
        dropout_rate=DROPOUT_RATE, cfg=ALEXNET_CFG
    ),
    'GFNet': lambda: build_gfnet(
        input_shape, num_classes,
        inner_patch=INNER_PATCH,
        hidden_dim=GFNET_CFG['hidden_dim'],
        num_blocks=GFNET_CFG['num_blocks'],
        mlp_ratio=GFNET_CFG['mlp_ratio'],
        dropout_rate=DROPOUT_RATE
    ),
    'ViT_UNet': lambda: build_vit_unet_singlehead(
        input_shape, num_classes,
        inner_patch=INNER_PATCH,
        projection_dim=VIT_CFG['projection_dim'],
        num_heads=VIT_CFG['num_heads'],
        transformer_layers=VIT_CFG['transformer_layers'],
        mlp_multiplier=VIT_CFG['mlp_multiplier'],
        dropout_rate=DROPOUT_RATE,
        head_units=tuple(VIT_CFG['head_units'])
    ),
}

# %% [markdown]
# ## 6.4 — Training Loop
#
# For each architecture: locate ensemble teachers → generate soft targets → build `tf.data` pipelines → build and compile the CREDIT student → train with `ModelCheckpoint` → compute a quick post-training uncertainty summary.

# %%
train_results = []

for model_name, builder in model_builders.items():
    print(f"\n{'='*25} CREDIT Distillation: {model_name} {'='*25}")

    # ── 1. Locate ensemble teachers ────────────────────────────────────────────
    ensemble_paths = get_ensemble_paths(model_name)
    if len(ensemble_paths) == 0:
        print('  No ensemble models found — skipping.')
        continue
    if len(ensemble_paths) < 5:
        print(f'  Warning: only {len(ensemble_paths)} ensemble models found (expected 5).')

    # ── 2. Select correct data split ───────────────────────────────────────────
    x_tr, x_te = (
        (x_train_alex, x_test_alex) if model_name == 'AlexNet_CNN'
        else (x_train, x_test)
    )

    # ── 3. Generate soft targets ───────────────────────────────────────────────
    print('  Generating training targets...')
    p_star_tr, delta_p_tr = generate_credit_targets(ensemble_paths, x_tr)

    print('  Generating test targets...')
    p_star_te, delta_p_te = generate_credit_targets(ensemble_paths, x_te)

    # ── 4. Build tf.data pipelines ─────────────────────────────────────────────
    train_ds = (
        tf.data.Dataset
        .from_tensor_slices((x_tr, (p_star_tr, delta_p_tr)))
        .shuffle(1024).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    )
    test_ds = (
        tf.data.Dataset
        .from_tensor_slices((x_te, (p_star_te, delta_p_te)))
        .batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    )

    # ── 5. Build & compile student ─────────────────────────────────────────────
    tf.keras.backend.clear_session()
    student = build_credit_student(builder, num_classes)

    optimizer = (
        keras.optimizers.Adagrad(learning_rate=ALEXNET_LR_START)
        if model_name == 'AlexNet_CNN'
        else keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    )

    student.compile(
        optimizer=optimizer,
        loss={
            'p_star':  tf.keras.losses.KLDivergence(),
            'delta_p': tf.keras.losses.MeanSquaredError(),
        },
        loss_weights={'p_star': 1.0, 'delta_p': 0.5},   # lambda = 0.5
    )

    # ── 6. Train ───────────────────────────────────────────────────────────────
    best_path = MODEL_DIR / f'{model_name}_CREDIT_best.keras'
    callbacks = [
        keras.callbacks.ModelCheckpoint(
            filepath=str(best_path), monitor='val_loss',
            mode='min', save_best_only=True, verbose=1
        )
    ]

    t0 = time.perf_counter()
    student.fit(
        train_ds, validation_data=test_ds,
        epochs=EPOCHS, callbacks=callbacks, verbose=1
    )
    train_time = time.perf_counter() - t0

    # ── 7. Post-training uncertainty summary ───────────────────────────────────
    student.load_weights(best_path)
    p_star_pred, delta_p_pred = student.predict(x_te, batch_size=BATCH_SIZE)

    au = -np.sum(p_star_pred * np.log(p_star_pred + 1e-12), axis=-1)
    eu =  np.mean(delta_p_pred, axis=-1)
    tu =  au + eu

    train_results.append({
        'Model':          model_name,
        'Mean_AU':        np.mean(au),
        'Mean_EU':        np.mean(eu),
        'Mean_TU':        np.mean(tu),
        'Train_Time_sec': train_time,
    })

# ── Save training uncertainty summary ─────────────────────────────────────────
summary_df   = pd.DataFrame(train_results)
summary_path = RESULTS_DIR / 'credit_train_uncertainty_summary.csv'
summary_df.to_csv(summary_path, index=False)
print(f'\nSaved training summary → {summary_path}')
print(summary_df)

# Stash for the final Excel report
_credit_train_summary_df = summary_df.copy()
# Out:
# ========================= CREDIT Distillation: AlexNet_CNN =========================
#   Generating training targets...
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/AlexNet_CNN_ens_1_final.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/AlexNet_CNN_ens_2_final.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/AlexNet_CNN_ens_3_final.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/AlexNet_CNN_ens_4_final.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/AlexNet_CNN_ens_5_final.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step
#   Generating test targets...
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/AlexNet_CNN_ens_1_final.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/AlexNet_CNN_ens_2_final.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/AlexNet_CNN_ens_3_final.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/AlexNet_CNN_ens_4_final.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/AlexNet_CNN_ens_5_final.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# Epoch 1/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - delta_p_loss: 0.2305 - loss: 1.8107 - p_star_loss: 1.6954
# Epoch 1: val_loss improved from None to 3.91657, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 25s 132ms/step - delta_p_loss: 0.1947 - loss: 1.6100 - p_star_loss: 1.5066 - val_delta_p_loss: 0.0598 - val_loss: 3.9166 - val_p_star_loss: 3.8814
# Epoch 2/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 0.1211 - loss: 1.5158 - p_star_loss: 1.4552
# Epoch 2: val_loss improved from 3.91657 to 1.33250, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - delta_p_loss: 0.0873 - loss: 1.2408 - p_star_loss: 1.1980 - val_delta_p_loss: 0.0240 - val_loss: 1.3325 - val_p_star_loss: 1.3197
# Epoch 3/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 0.0405 - loss: 1.1032 - p_star_loss: 1.0829
# Epoch 3: val_loss did not improve from 1.33250
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - delta_p_loss: 0.0329 - loss: 1.0526 - p_star_loss: 1.0522 - val_delta_p_loss: 0.0534 - val_loss: 1.5129 - val_p_star_loss: 1.4858
# Epoch 4/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 0.0350 - loss: 1.0626 - p_star_loss: 1.0451
# Epoch 4: val_loss did not improve from 1.33250
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 0.0244 - loss: 0.9867 - p_star_loss: 0.9711 - val_delta_p_loss: 0.0047 - val_loss: 1.6031 - val_p_star_loss: 1.6004
# Epoch 5/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 0.0130 - loss: 0.9505 - p_star_loss: 0.9440
# Epoch 5: val_loss did not improve from 1.33250
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - delta_p_loss: 0.0113 - loss: 0.9047 - p_star_loss: 0.9022 - val_delta_p_loss: 0.0032 - val_loss: 3.9784 - val_p_star_loss: 3.9781
# Epoch 6/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 0.0293 - loss: 1.3419 - p_star_loss: 1.3272
# Epoch 6: val_loss improved from 1.33250 to 0.91503, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - delta_p_loss: 0.0166 - loss: 1.0549 - p_star_loss: 1.0364 - val_delta_p_loss: 0.0061 - val_loss: 0.9150 - val_p_star_loss: 0.9110
# Epoch 7/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 0.0067 - loss: 0.8829 - p_star_loss: 0.8796
# Epoch 7: val_loss did not improve from 0.91503
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 0.0061 - loss: 0.8506 - p_star_loss: 0.8601 - val_delta_p_loss: 0.0031 - val_loss: 7.1887 - val_p_star_loss: 7.1848
# Epoch 8/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 0.0252 - loss: 1.2748 - p_star_loss: 1.2623
# Epoch 8: val_loss improved from 0.91503 to 0.76410, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 121ms/step - delta_p_loss: 0.0181 - loss: 0.9325 - p_star_loss: 0.9144 - val_delta_p_loss: 0.0085 - val_loss: 0.7641 - val_p_star_loss: 0.7593
# Epoch 9/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 0.0071 - loss: 0.7877 - p_star_loss: 0.7842
# Epoch 9: val_loss improved from 0.76410 to 0.70021, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - delta_p_loss: 0.0060 - loss: 0.7607 - p_star_loss: 0.7504 - val_delta_p_loss: 0.0051 - val_loss: 0.7002 - val_p_star_loss: 0.6972
# Epoch 10/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - delta_p_loss: 0.0040 - loss: 0.6914 - p_star_loss: 0.6894
# Epoch 10: val_loss did not improve from 0.70021
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - delta_p_loss: 0.0035 - loss: 0.6640 - p_star_loss: 0.6584 - val_delta_p_loss: 0.0055 - val_loss: 1.7017 - val_p_star_loss: 1.6985
# Epoch 11/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - delta_p_loss: 0.0042 - loss: 0.7705 - p_star_loss: 0.7685
# Epoch 11: val_loss improved from 0.70021 to 0.54599, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 105ms/step - delta_p_loss: 0.0037 - loss: 0.6334 - p_star_loss: 0.6256 - val_delta_p_loss: 0.0035 - val_loss: 0.5460 - val_p_star_loss: 0.5443
# Epoch 12/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 0.0029 - loss: 0.5541 - p_star_loss: 0.5526
# Epoch 12: val_loss did not improve from 0.54599
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 0.0028 - loss: 0.5403 - p_star_loss: 0.5435 - val_delta_p_loss: 0.0018 - val_loss: 3.1735 - val_p_star_loss: 3.1709
# Epoch 13/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 0.0057 - loss: 0.7962 - p_star_loss: 0.7934
# Epoch 13: val_loss did not improve from 0.54599
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - delta_p_loss: 0.0036 - loss: 0.5745 - p_star_loss: 0.5730 - val_delta_p_loss: 0.0021 - val_loss: 0.6669 - val_p_star_loss: 0.6664
# Epoch 14/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - delta_p_loss: 0.0021 - loss: 0.5029 - p_star_loss: 0.5019
# Epoch 14: val_loss improved from 0.54599 to 0.40154, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - delta_p_loss: 0.0020 - loss: 0.4700 - p_star_loss: 0.4645 - val_delta_p_loss: 0.0019 - val_loss: 0.4015 - val_p_star_loss: 0.4014
# Epoch 15/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 0.0015 - loss: 0.4288 - p_star_loss: 0.4280
# Epoch 15: val_loss did not improve from 0.40154
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 0.0015 - loss: 0.4093 - p_star_loss: 0.4053 - val_delta_p_loss: 0.0020 - val_loss: 0.5003 - val_p_star_loss: 0.4994
# Epoch 16/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 0.0014 - loss: 0.4128 - p_star_loss: 0.4121
# Epoch 16: val_loss improved from 0.40154 to 0.33098, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 110ms/step - delta_p_loss: 0.0013 - loss: 0.3854 - p_star_loss: 0.3811 - val_delta_p_loss: 0.0016 - val_loss: 0.3310 - val_p_star_loss: 0.3309
# Epoch 17/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 0.0010 - loss: 0.3664 - p_star_loss: 0.3659
# Epoch 17: val_loss improved from 0.33098 to 0.28976, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 17: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - delta_p_loss: 0.0011 - loss: 0.3626 - p_star_loss: 0.3586 - val_delta_p_loss: 0.0018 - val_loss: 0.2898 - val_p_star_loss: 0.2897
# Epoch 18/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 0.0010 - loss: 0.3435 - p_star_loss: 0.3430
# Epoch 18: val_loss did not improve from 0.28976
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - delta_p_loss: 9.7603e-04 - loss: 0.3352 - p_star_loss: 0.3326 - val_delta_p_loss: 0.0013 - val_loss: 1.6860 - val_p_star_loss: 1.6849
# Epoch 19/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - delta_p_loss: 0.0013 - loss: 0.4514 - p_star_loss: 0.4507
# Epoch 19: val_loss improved from 0.28976 to 0.28072, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 19: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - delta_p_loss: 9.9890e-04 - loss: 0.3324 - p_star_loss: 0.3286 - val_delta_p_loss: 0.0016 - val_loss: 0.2807 - val_p_star_loss: 0.2809
# Epoch 20/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 0.0017 - loss: 0.3577 - p_star_loss: 0.3569
# Epoch 20: val_loss did not improve from 0.28072
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - delta_p_loss: 0.0030 - loss: 0.4221 - p_star_loss: 0.4186 - val_delta_p_loss: 0.0034 - val_loss: 1.6301 - val_p_star_loss: 1.6283
# Epoch 21/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - delta_p_loss: 0.0015 - loss: 0.3838 - p_star_loss: 0.3831
# Epoch 21: val_loss improved from 0.28072 to 0.26409, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 21: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 108ms/step - delta_p_loss: 0.0011 - loss: 0.3029 - p_star_loss: 0.2996 - val_delta_p_loss: 0.0014 - val_loss: 0.2641 - val_p_star_loss: 0.2642
# Epoch 22/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 6.4732e-04 - loss: 0.2624 - p_star_loss: 0.2621
# Epoch 22: val_loss did not improve from 0.26409
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 5.6709e-04 - loss: 0.2522 - p_star_loss: 0.2509 - val_delta_p_loss: 0.0012 - val_loss: 0.3565 - val_p_star_loss: 0.3567
# Epoch 23/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 3.9402e-04 - loss: 0.2517 - p_star_loss: 0.2515
# Epoch 23: val_loss improved from 0.26409 to 0.24447, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 23: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 108ms/step - delta_p_loss: 3.9690e-04 - loss: 0.2350 - p_star_loss: 0.2327 - val_delta_p_loss: 0.0013 - val_loss: 0.2445 - val_p_star_loss: 0.2450
# Epoch 24/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 4.7666e-04 - loss: 0.2682 - p_star_loss: 0.2680
# Epoch 24: val_loss improved from 0.24447 to 0.17792, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 24: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - delta_p_loss: 4.4117e-04 - loss: 0.2408 - p_star_loss: 0.2382 - val_delta_p_loss: 0.0012 - val_loss: 0.1779 - val_p_star_loss: 0.1782
# Epoch 25/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 3.7189e-04 - loss: 0.2107 - p_star_loss: 0.2105
# Epoch 25: val_loss improved from 0.17792 to 0.16505, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 25: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - delta_p_loss: 4.4600e-04 - loss: 0.2313 - p_star_loss: 0.2290 - val_delta_p_loss: 0.0013 - val_loss: 0.1651 - val_p_star_loss: 0.1651
# Epoch 26/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 5.0322e-04 - loss: 0.2077 - p_star_loss: 0.2074
# Epoch 26: val_loss did not improve from 0.16505
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 4.4731e-04 - loss: 0.2040 - p_star_loss: 0.2021 - val_delta_p_loss: 0.0011 - val_loss: 0.3828 - val_p_star_loss: 0.3838
# Epoch 27/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - delta_p_loss: 3.7193e-04 - loss: 0.1949 - p_star_loss: 0.1947
# Epoch 27: val_loss did not improve from 0.16505
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - delta_p_loss: 3.2164e-04 - loss: 0.1751 - p_star_loss: 0.1735 - val_delta_p_loss: 0.0011 - val_loss: 0.2164 - val_p_star_loss: 0.2166
# Epoch 28/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 2.8789e-04 - loss: 0.1806 - p_star_loss: 0.1804
# Epoch 28: val_loss improved from 0.16505 to 0.12141, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 28: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - delta_p_loss: 2.9893e-04 - loss: 0.1666 - p_star_loss: 0.1649 - val_delta_p_loss: 0.0011 - val_loss: 0.1214 - val_p_star_loss: 0.1217
# Epoch 29/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 2.8354e-04 - loss: 0.1667 - p_star_loss: 0.1666
# Epoch 29: val_loss did not improve from 0.12141
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - delta_p_loss: 2.9884e-04 - loss: 0.1597 - p_star_loss: 0.1580 - val_delta_p_loss: 0.0012 - val_loss: 0.1419 - val_p_star_loss: 0.1416
# Epoch 30/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 2.9233e-04 - loss: 0.1525 - p_star_loss: 0.1524
# Epoch 30: val_loss improved from 0.12141 to 0.11542, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 30: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 13s 126ms/step - delta_p_loss: 2.9421e-04 - loss: 0.1543 - p_star_loss: 0.1529 - val_delta_p_loss: 0.0012 - val_loss: 0.1154 - val_p_star_loss: 0.1153
# Epoch 31/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 2.7346e-04 - loss: 0.1398 - p_star_loss: 0.1396
# Epoch 31: val_loss improved from 0.11542 to 0.10342, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 31: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - delta_p_loss: 2.5919e-04 - loss: 0.1412 - p_star_loss: 0.1397 - val_delta_p_loss: 0.0012 - val_loss: 0.1034 - val_p_star_loss: 0.1037
# Epoch 32/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 2.3658e-04 - loss: 0.1278 - p_star_loss: 0.1277
# Epoch 32: val_loss did not improve from 0.10342
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - delta_p_loss: 2.4908e-04 - loss: 0.1277 - p_star_loss: 0.1267 - val_delta_p_loss: 0.0011 - val_loss: 0.1834 - val_p_star_loss: 0.1840
# Epoch 33/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - delta_p_loss: 2.6488e-04 - loss: 0.1368 - p_star_loss: 0.1367
# Epoch 33: val_loss improved from 0.10342 to 0.08427, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 33: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - delta_p_loss: 2.6791e-04 - loss: 0.1299 - p_star_loss: 0.1285 - val_delta_p_loss: 0.0011 - val_loss: 0.0843 - val_p_star_loss: 0.0843
# Epoch 34/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - delta_p_loss: 2.1473e-04 - loss: 0.1133 - p_star_loss: 0.1131
# Epoch 34: val_loss did not improve from 0.08427
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - delta_p_loss: 2.2299e-04 - loss: 0.1225 - p_star_loss: 0.1211 - val_delta_p_loss: 0.0012 - val_loss: 0.1046 - val_p_star_loss: 0.1045
# Epoch 35/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - delta_p_loss: 2.3793e-04 - loss: 0.1181 - p_star_loss: 0.1179
# Epoch 35: val_loss did not improve from 0.08427
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - delta_p_loss: 2.1664e-04 - loss: 0.1091 - p_star_loss: 0.1080 - val_delta_p_loss: 0.0011 - val_loss: 0.0901 - val_p_star_loss: 0.0904
# Epoch 36/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - delta_p_loss: 1.7910e-04 - loss: 0.0956 - p_star_loss: 0.0955
# Epoch 36: val_loss did not improve from 0.08427
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - delta_p_loss: 1.7560e-04 - loss: 0.0999 - p_star_loss: 0.0988 - val_delta_p_loss: 0.0011 - val_loss: 0.0969 - val_p_star_loss: 0.0973
# Epoch 37/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 1.9258e-04 - loss: 0.1029 - p_star_loss: 0.1028
# Epoch 37: val_loss did not improve from 0.08427
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - delta_p_loss: 1.8886e-04 - loss: 0.0972 - p_star_loss: 0.0990 - val_delta_p_loss: 0.0010 - val_loss: 0.7050 - val_p_star_loss: 0.7026
# Epoch 38/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 1.8432e-04 - loss: 0.2134 - p_star_loss: 0.2133
# Epoch 38: val_loss did not improve from 0.08427
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 1.7608e-04 - loss: 0.1181 - p_star_loss: 0.1168 - val_delta_p_loss: 0.0011 - val_loss: 0.0932 - val_p_star_loss: 0.0937
# Epoch 39/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 1.2716e-04 - loss: 0.0830 - p_star_loss: 0.0829
# Epoch 39: val_loss did not improve from 0.08427
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 1.1155e-04 - loss: 0.0749 - p_star_loss: 0.0741 - val_delta_p_loss: 0.0011 - val_loss: 0.0909 - val_p_star_loss: 0.0912
# Epoch 40/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 1.1487e-04 - loss: 0.0820 - p_star_loss: 0.0819
# Epoch 40: val_loss did not improve from 0.08427
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - delta_p_loss: 1.1127e-04 - loss: 0.0756 - p_star_loss: 0.0748 - val_delta_p_loss: 0.0011 - val_loss: 0.1055 - val_p_star_loss: 0.1055
# Epoch 41/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 1.1766e-04 - loss: 0.0820 - p_star_loss: 0.0819
# Epoch 41: val_loss improved from 0.08427 to 0.06813, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 41: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - delta_p_loss: 1.4984e-04 - loss: 0.1107 - p_star_loss: 0.1096 - val_delta_p_loss: 0.0012 - val_loss: 0.0681 - val_p_star_loss: 0.0679
# Epoch 42/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 1.8567e-04 - loss: 0.0729 - p_star_loss: 0.0728
# Epoch 42: val_loss did not improve from 0.06813
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 1.5042e-04 - loss: 0.0650 - p_star_loss: 0.0652 - val_delta_p_loss: 0.0010 - val_loss: 0.5588 - val_p_star_loss: 0.5609
# Epoch 43/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 1.2192e-04 - loss: 0.0980 - p_star_loss: 0.0979
# Epoch 43: val_loss did not improve from 0.06813
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - delta_p_loss: 1.1795e-04 - loss: 0.0681 - p_star_loss: 0.0674 - val_delta_p_loss: 0.0010 - val_loss: 0.0725 - val_p_star_loss: 0.0721
# Epoch 44/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - delta_p_loss: 1.1521e-04 - loss: 0.0689 - p_star_loss: 0.0689
# Epoch 44: val_loss improved from 0.06813 to 0.06113, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 44: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - delta_p_loss: 1.8866e-04 - loss: 0.0994 - p_star_loss: 0.0983 - val_delta_p_loss: 0.0012 - val_loss: 0.0611 - val_p_star_loss: 0.0606
# Epoch 45/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 2.3407e-04 - loss: 0.0605 - p_star_loss: 0.0604
# Epoch 45: val_loss did not improve from 0.06113
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 1.7445e-04 - loss: 0.0533 - p_star_loss: 0.0527 - val_delta_p_loss: 0.0010 - val_loss: 0.1637 - val_p_star_loss: 0.1638
# Epoch 46/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 1.1841e-04 - loss: 0.0715 - p_star_loss: 0.0714
# Epoch 46: val_loss improved from 0.06113 to 0.03696, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 46: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 111ms/step - delta_p_loss: 9.7068e-05 - loss: 0.0498 - p_star_loss: 0.0493 - val_delta_p_loss: 0.0010 - val_loss: 0.0370 - val_p_star_loss: 0.0365
# Epoch 47/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 7.1569e-05 - loss: 0.0489 - p_star_loss: 0.0489
# Epoch 47: val_loss did not improve from 0.03696
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 7.2178e-05 - loss: 0.0471 - p_star_loss: 0.0468 - val_delta_p_loss: 0.0010 - val_loss: 0.0826 - val_p_star_loss: 0.0826
# Epoch 48/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 7.8309e-05 - loss: 0.0638 - p_star_loss: 0.0638
# Epoch 48: val_loss improved from 0.03696 to 0.03228, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 48: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 113ms/step - delta_p_loss: 7.1641e-05 - loss: 0.0483 - p_star_loss: 0.0478 - val_delta_p_loss: 0.0010 - val_loss: 0.0323 - val_p_star_loss: 0.0319
# Epoch 49/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 0.0026 - loss: 0.4045 - p_star_loss: 0.4032
# Epoch 49: val_loss did not improve from 0.03228
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 0.0019 - loss: 0.2514 - p_star_loss: 0.2491 - val_delta_p_loss: 0.0012 - val_loss: 0.0964 - val_p_star_loss: 0.0957
# Epoch 50/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 2.3049e-04 - loss: 0.0590 - p_star_loss: 0.0589
# Epoch 50: val_loss did not improve from 0.03228
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - delta_p_loss: 1.8336e-04 - loss: 0.0484 - p_star_loss: 0.0479 - val_delta_p_loss: 0.0011 - val_loss: 0.0511 - val_p_star_loss: 0.0507
# Epoch 51/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - delta_p_loss: 1.1994e-04 - loss: 0.0520 - p_star_loss: 0.0520
# Epoch 51: val_loss did not improve from 0.03228
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - delta_p_loss: 1.2566e-04 - loss: 0.0475 - p_star_loss: 0.0470 - val_delta_p_loss: 0.0011 - val_loss: 0.0331 - val_p_star_loss: 0.0327
# Epoch 52/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - delta_p_loss: 1.0576e-04 - loss: 0.0409 - p_star_loss: 0.0409
# Epoch 52: val_loss did not improve from 0.03228
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - delta_p_loss: 9.3856e-05 - loss: 0.0367 - p_star_loss: 0.0363 - val_delta_p_loss: 0.0010 - val_loss: 0.0512 - val_p_star_loss: 0.0506
# Epoch 53/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - delta_p_loss: 6.0529e-05 - loss: 0.0413 - p_star_loss: 0.0412
# Epoch 53: val_loss did not improve from 0.03228
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - delta_p_loss: 5.8404e-05 - loss: 0.0341 - p_star_loss: 0.0337 - val_delta_p_loss: 0.0010 - val_loss: 0.0373 - val_p_star_loss: 0.0368
# Epoch 54/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 4.7510e-05 - loss: 0.0301 - p_star_loss: 0.0300
# Epoch 54: val_loss did not improve from 0.03228
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 4.4422e-05 - loss: 0.0287 - p_star_loss: 0.0284 - val_delta_p_loss: 0.0010 - val_loss: 0.0639 - val_p_star_loss: 0.0634
# Epoch 55/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 9.4657e-05 - loss: 0.0874 - p_star_loss: 0.0873
# Epoch 55: val_loss improved from 0.03228 to 0.02636, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 55: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - delta_p_loss: 8.4571e-05 - loss: 0.0478 - p_star_loss: 0.0473 - val_delta_p_loss: 0.0010 - val_loss: 0.0264 - val_p_star_loss: 0.0257
# Epoch 56/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 5.4237e-05 - loss: 0.0218 - p_star_loss: 0.0218
# Epoch 56: val_loss did not improve from 0.02636
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - delta_p_loss: 5.5374e-05 - loss: 0.0239 - p_star_loss: 0.0236 - val_delta_p_loss: 0.0011 - val_loss: 0.0858 - val_p_star_loss: 0.0858
# Epoch 57/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - delta_p_loss: 6.4980e-05 - loss: 0.0445 - p_star_loss: 0.0444
# Epoch 57: val_loss did not improve from 0.02636
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - delta_p_loss: 6.6093e-05 - loss: 0.0502 - p_star_loss: 0.0496 - val_delta_p_loss: 0.0015 - val_loss: 0.9735 - val_p_star_loss: 0.9718
# Epoch 58/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 2.7587e-04 - loss: 0.0888 - p_star_loss: 0.0886
# Epoch 58: val_loss did not improve from 0.02636
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - delta_p_loss: 1.8235e-04 - loss: 0.0415 - p_star_loss: 0.0410 - val_delta_p_loss: 0.0011 - val_loss: 0.0276 - val_p_star_loss: 0.0274
# Epoch 59/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 8.2500e-05 - loss: 0.0250 - p_star_loss: 0.0249
# Epoch 59: val_loss improved from 0.02636 to 0.01986, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 59: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - delta_p_loss: 7.7506e-05 - loss: 0.0229 - p_star_loss: 0.0228 - val_delta_p_loss: 0.0010 - val_loss: 0.0199 - val_p_star_loss: 0.0194
# Epoch 60/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - delta_p_loss: 5.2674e-05 - loss: 0.0164 - p_star_loss: 0.0163
# Epoch 60: val_loss improved from 0.01986 to 0.01672, saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
#
# Epoch 60: finished saving model to /content/drive/My Drive/Classification/credit/models/AlexNet_CNN_CREDIT_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - delta_p_loss: 5.2300e-05 - loss: 0.0180 - p_star_loss: 0.0178 - val_delta_p_loss: 0.0010 - val_loss: 0.0167 - val_p_star_loss: 0.0163
# Epoch 61/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 4.8548e-05 - loss: 0.0161 - p_star_loss: 0.0161
# Epoch 61: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - delta_p_loss: 4.7516e-05 - loss: 0.0156 - p_star_loss: 0.0320 - val_delta_p_loss: 0.0010 - val_loss: 14.3855 - val_p_star_loss: 14.3889
# Epoch 62/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - delta_p_loss: 1.9689e-04 - loss: 13.4294 - p_star_loss: 13.4293
# Epoch 62: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - delta_p_loss: 1.7496e-04 - loss: 13.4429 - p_star_loss: 13.4689 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 63/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 4.6851e-05 - loss: 13.3572 - p_star_loss: 13.3572
# Epoch 63: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - delta_p_loss: 6.3148e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 64/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 2.0496e-05 - loss: 13.3965 - p_star_loss: 13.3965
# Epoch 64: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - delta_p_loss: 6.3138e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 65/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 1.9999e-05 - loss: 13.4079 - p_star_loss: 13.4079
# Epoch 65: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 1.3394e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 66/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 1.4946e-06 - loss: 13.3826 - p_star_loss: 13.3826
# Epoch 66: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 1.1556e-06 - loss: 13.4427 - p_star_loss: 13.3119 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 67/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 2.6649e-05 - loss: 13.3575 - p_star_loss: 13.3575
# Epoch 67: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 2.1817e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 68/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 6.9615e-06 - loss: 13.4115 - p_star_loss: 13.4115
# Epoch 68: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 4.2985e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 69/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 7.1671e-06 - loss: 13.3993 - p_star_loss: 13.3993
# Epoch 69: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 1.6764e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 70/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 2.2098e-05 - loss: 13.4105 - p_star_loss: 13.4105
# Epoch 70: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 2.0178e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 71/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 4.7252e-06 - loss: 13.3767 - p_star_loss: 13.3767
# Epoch 71: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 7.8399e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 72/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 2.4114e-06 - loss: 13.3472 - p_star_loss: 13.3472
# Epoch 72: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 1.5009e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 73/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 2.1413e-06 - loss: 13.3968 - p_star_loss: 13.3968
# Epoch 73: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 1.4803e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 74/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 1.6110e-05 - loss: 13.3419 - p_star_loss: 13.3419
# Epoch 74: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - delta_p_loss: 1.1984e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 75/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 6.7295e-06 - loss: 13.4060 - p_star_loss: 13.4060
# Epoch 75: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 1.2047e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 76/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 1.2534e-06 - loss: 13.4046 - p_star_loss: 13.4046
# Epoch 76: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 1.1050e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 77/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 1.6839e-05 - loss: 13.3275 - p_star_loss: 13.3275
# Epoch 77: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - delta_p_loss: 1.2624e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 78/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 2.7426e-06 - loss: 13.3881 - p_star_loss: 13.3881
# Epoch 78: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 2.0468e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 79/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 9.7289e-06 - loss: 13.3810 - p_star_loss: 13.3810
# Epoch 79: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 4.9618e-06 - loss: 13.4427 - p_star_loss: 13.3119 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 80/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 9.0758e-06 - loss: 13.4198 - p_star_loss: 13.4198
# Epoch 80: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 1.1440e-05 - loss: 13.4427 - p_star_loss: 13.3119 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 81/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 2.9867e-06 - loss: 13.4046 - p_star_loss: 13.4046
# Epoch 81: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 1.1554e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 82/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 2.5172e-06 - loss: 13.3951 - p_star_loss: 13.3951
# Epoch 82: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 2.0097e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 83/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 4.8449e-06 - loss: 13.4037 - p_star_loss: 13.4037
# Epoch 83: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 2.3472e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 84/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 3.1825e-06 - loss: 13.3842 - p_star_loss: 13.3842
# Epoch 84: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 1.2054e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 85/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 1.7363e-06 - loss: 13.3734 - p_star_loss: 13.3734
# Epoch 85: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 1.1066e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 86/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 1.6454e-06 - loss: 13.3963 - p_star_loss: 13.3963
# Epoch 86: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 1.1061e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 87/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - delta_p_loss: 1.8149e-06 - loss: 13.4335 - p_star_loss: 13.4335
# Epoch 87: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - delta_p_loss: 1.1050e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 88/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 1.0055e-05 - loss: 13.4220 - p_star_loss: 13.4220
# Epoch 88: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 1.2151e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 89/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 2.3047e-06 - loss: 13.3719 - p_star_loss: 13.3719
# Epoch 89: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 65ms/step - delta_p_loss: 1.2432e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 90/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 1.8194e-05 - loss: 13.3734 - p_star_loss: 13.3734
# Epoch 90: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 1.1821e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 91/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 8.6131e-06 - loss: 13.3925 - p_star_loss: 13.3925
# Epoch 91: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 1.4038e-05 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 92/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 1.6114e-06 - loss: 13.3815 - p_star_loss: 13.3815
# Epoch 92: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - delta_p_loss: 1.1076e-06 - loss: 13.4427 - p_star_loss: 13.3119 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 93/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 1.6165e-06 - loss: 13.4137 - p_star_loss: 13.4137
# Epoch 93: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 1.1439e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 94/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - delta_p_loss: 1.9142e-06 - loss: 13.3906 - p_star_loss: 13.3906
# Epoch 94: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - delta_p_loss: 1.8656e-06 - loss: 13.4427 - p_star_loss: 13.3119 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 95/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 1.8950e-06 - loss: 13.4158 - p_star_loss: 13.4158
# Epoch 95: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 1.1291e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 96/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 1.4652e-06 - loss: 13.4058 - p_star_loss: 13.4058
# Epoch 96: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 1.1661e-06 - loss: 13.4427 - p_star_loss: 13.3119 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 97/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 5.8186e-06 - loss: 13.3793 - p_star_loss: 13.3793
# Epoch 97: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 5.2052e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 98/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - delta_p_loss: 1.6013e-06 - loss: 13.3562 - p_star_loss: 13.3562
# Epoch 98: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 1.1051e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 99/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - delta_p_loss: 8.5516e-06 - loss: 13.4035 - p_star_loss: 13.4034
# Epoch 99: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - delta_p_loss: 6.2157e-06 - loss: 13.4427 - p_star_loss: 13.3119 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# Epoch 100/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - delta_p_loss: 1.5410e-06 - loss: 13.4150 - p_star_loss: 13.4150
# Epoch 100: val_loss did not improve from 0.01672
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - delta_p_loss: 1.1051e-06 - loss: 13.4427 - p_star_loss: 13.4687 - val_delta_p_loss: 0.0010 - val_loss: 13.4376 - val_p_star_loss: 13.4341
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step
#
# ========================= CREDIT Distillation: GFNet =========================
#   Generating training targets...
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/GFNet_ens_1_final.keras
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:424: UserWarning: `build()` was called on layer 'gf_patch_encoder', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/GFNet_ens_2_final.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/GFNet_ens_3_final.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/GFNet_ens_4_final.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/GFNet_ens_5_final.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step
#   Generating test targets...
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/GFNet_ens_1_final.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/GFNet_ens_2_final.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/GFNet_ens_3_final.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/GFNet_ens_4_final.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step
#   Loading teacher: /content/drive/My Drive/Classification/ensemble/models/ensembles/GFNet_ens_5_final.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step
# Epoch 1/100
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - delta_p_loss: 0.0464 - loss: 1.6834 - p_star_loss: 1.6602
# Epoch 1: val_loss improved from None to 0.97922, saving model to /content/drive/My Drive/Classification/credit/models/GFNet_CREDIT_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Classification/credit/models/GFNet_CREDIT_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 50s 320ms/step - delta_p_loss: 0.0166 - loss: 1.2302 - p_star_loss: 1.2210 - val_delta_p_loss: 0.0020 - val_loss: 0.9792 - val_p_star_loss: 0.9788
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - delta_p_loss: 0.0041 - loss: 0.7518 - p_star_loss: 0.7498
# Epoch 2: val_loss improved from 0.97922 to 0.52412, saving model to /content/drive/My Drive/Classification/credit/models/GFNet_CREDIT_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Classification/credit/models/GFNet_CREDIT_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - delta_p_loss: 0.0034 - loss: 0.7009 - p_star_loss: 0.6989 - val_delta_p_loss: 0.0016 - val_loss: 0.5241 - val_p_star_loss: 0.5249
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - delta_p_loss: 0.0018 - loss: 0.5299 - p_star_loss: 0.5290
# Epoch 3: val_loss improved from 0.52412 to 0.41209, saving model to /content/drive/My Drive/Classification/credit/models/GFNet_CREDIT_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Classification/credit/models/GFNet_CREDIT_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 103ms/step - delta_p_loss: 0.0017 - loss: 0.5091 - p_star_loss: 0.5079 - val_delta_p_loss: 0.0016 - val_loss: 0.4121 - val_p_star_loss: 0.4123
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - delta_p_loss: 0.0015 - loss: 0.4494 - p_star_loss: 0.4486
# Epoch 4: val_loss improved from 0.41209 to 0.39221, saving model to /content/drive/My Drive/Classification/credit/models/GFNet_CREDIT_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Classification/credit/models/GFNet_CREDIT_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - delta_p_loss: 0.0013 - loss: 0.4347 - p_star_loss: 0.4341 - val_delta_p_loss: 0.0015 - val_loss: 0.3922 - val_p_star_loss: 0.3931
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - delta_p_loss: 0.0010 - loss: 0.3720 - p_star_loss: 0.3715
# ...
# Epoch 56: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 142ms/step - delta_p_loss: 3.6159e-04 - loss: 0.0627 - p_star_loss: 0.0625 - val_delta_p_loss: 0.0036 - val_loss: 0.0454 - val_p_star_loss: 0.0444
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 2.7486e-04 - loss: 0.0425 - p_star_loss: 0.0424
# Epoch 57: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - delta_p_loss: 2.7649e-04 - loss: 0.0411 - p_star_loss: 0.0409 - val_delta_p_loss: 0.0036 - val_loss: 0.0418 - val_p_star_loss: 0.0408
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 2.7598e-04 - loss: 0.0413 - p_star_loss: 0.0412
# Epoch 58: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 2.9643e-04 - loss: 0.0421 - p_star_loss: 0.0420 - val_delta_p_loss: 0.0036 - val_loss: 0.0470 - val_p_star_loss: 0.0457
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 3.0902e-04 - loss: 0.0397 - p_star_loss: 0.0396
# Epoch 59: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 2.9512e-04 - loss: 0.0464 - p_star_loss: 0.0462 - val_delta_p_loss: 0.0036 - val_loss: 0.0692 - val_p_star_loss: 0.0676
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 3.2735e-04 - loss: 0.0673 - p_star_loss: 0.0672
# Epoch 60: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - delta_p_loss: 3.1236e-04 - loss: 0.0740 - p_star_loss: 0.0738 - val_delta_p_loss: 0.0036 - val_loss: 0.0408 - val_p_star_loss: 0.0396
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - delta_p_loss: 2.8341e-04 - loss: 0.0406 - p_star_loss: 0.0405
# Epoch 61: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - delta_p_loss: 2.9457e-04 - loss: 0.0467 - p_star_loss: 0.0465 - val_delta_p_loss: 0.0036 - val_loss: 0.0463 - val_p_star_loss: 0.0451
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 2.6399e-04 - loss: 0.0472 - p_star_loss: 0.0471
# Epoch 62: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - delta_p_loss: 3.1538e-04 - loss: 0.0698 - p_star_loss: 0.0699 - val_delta_p_loss: 0.0036 - val_loss: 0.0795 - val_p_star_loss: 0.0785
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - delta_p_loss: 3.0629e-04 - loss: 0.0571 - p_star_loss: 0.0570
# Epoch 63: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - delta_p_loss: 2.6619e-04 - loss: 0.0529 - p_star_loss: 0.0527 - val_delta_p_loss: 0.0036 - val_loss: 0.0830 - val_p_star_loss: 0.0816
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - delta_p_loss: 2.6652e-04 - loss: 0.0573 - p_star_loss: 0.0571
# Epoch 64: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 146ms/step - delta_p_loss: 2.4985e-04 - loss: 0.0523 - p_star_loss: 0.0525 - val_delta_p_loss: 0.0036 - val_loss: 0.0849 - val_p_star_loss: 0.0832
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 2.5304e-04 - loss: 0.0505 - p_star_loss: 0.0504
# Epoch 65: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - delta_p_loss: 2.3722e-04 - loss: 0.0493 - p_star_loss: 0.0493 - val_delta_p_loss: 0.0036 - val_loss: 0.0746 - val_p_star_loss: 0.0732
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 2.3996e-04 - loss: 0.0504 - p_star_loss: 0.0503
# Epoch 66: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 142ms/step - delta_p_loss: 2.4135e-04 - loss: 0.0470 - p_star_loss: 0.0470 - val_delta_p_loss: 0.0036 - val_loss: 0.0504 - val_p_star_loss: 0.0488
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 1.8362e-04 - loss: 0.0370 - p_star_loss: 0.0369
# Epoch 67: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 1.9495e-04 - loss: 0.0413 - p_star_loss: 0.0413 - val_delta_p_loss: 0.0036 - val_loss: 0.0555 - val_p_star_loss: 0.0542
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 2.6737e-04 - loss: 0.0585 - p_star_loss: 0.0583
# Epoch 68: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 2.8483e-04 - loss: 0.0809 - p_star_loss: 0.0809 - val_delta_p_loss: 0.0036 - val_loss: 0.0978 - val_p_star_loss: 0.0970
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 3.1811e-04 - loss: 0.0709 - p_star_loss: 0.0708
# Epoch 69: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 2.4803e-04 - loss: 0.0672 - p_star_loss: 0.0671 - val_delta_p_loss: 0.0036 - val_loss: 0.0888 - val_p_star_loss: 0.0872
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 3.1549e-04 - loss: 0.0891 - p_star_loss: 0.0889
# Epoch 70: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 2.7160e-04 - loss: 0.0689 - p_star_loss: 0.0687 - val_delta_p_loss: 0.0036 - val_loss: 0.0436 - val_p_star_loss: 0.0421
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - delta_p_loss: 1.7455e-04 - loss: 0.0434 - p_star_loss: 0.0433
# Epoch 71: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - delta_p_loss: 1.9555e-04 - loss: 0.0550 - p_star_loss: 0.0549 - val_delta_p_loss: 0.0036 - val_loss: 0.0492 - val_p_star_loss: 0.0476
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 1.8114e-04 - loss: 0.0497 - p_star_loss: 0.0496
# Epoch 72: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 1.8007e-04 - loss: 0.0518 - p_star_loss: 0.0517 - val_delta_p_loss: 0.0036 - val_loss: 0.0509 - val_p_star_loss: 0.0500
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - delta_p_loss: 1.4941e-04 - loss: 0.0490 - p_star_loss: 0.0489
# Epoch 73: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - delta_p_loss: 1.5816e-04 - loss: 0.0466 - p_star_loss: 0.0466 - val_delta_p_loss: 0.0036 - val_loss: 0.0545 - val_p_star_loss: 0.0533
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 1.5239e-04 - loss: 0.0511 - p_star_loss: 0.0510
# Epoch 74: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - delta_p_loss: 1.7052e-04 - loss: 0.0586 - p_star_loss: 0.0585 - val_delta_p_loss: 0.0036 - val_loss: 0.0478 - val_p_star_loss: 0.0467
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 1.4434e-04 - loss: 0.0481 - p_star_loss: 0.0480
# Epoch 75: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 1.4572e-04 - loss: 0.0481 - p_star_loss: 0.0480 - val_delta_p_loss: 0.0036 - val_loss: 0.0789 - val_p_star_loss: 0.0781
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - delta_p_loss: 1.9361e-04 - loss: 0.0718 - p_star_loss: 0.0717
# Epoch 76: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 145ms/step - delta_p_loss: 1.9902e-04 - loss: 0.0718 - p_star_loss: 0.0716 - val_delta_p_loss: 0.0036 - val_loss: 0.0552 - val_p_star_loss: 0.0540
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - delta_p_loss: 1.6773e-04 - loss: 0.0500 - p_star_loss: 0.0499
# Epoch 77: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - delta_p_loss: 1.5983e-04 - loss: 0.0442 - p_star_loss: 0.0441 - val_delta_p_loss: 0.0036 - val_loss: 0.0711 - val_p_star_loss: 0.0699
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 2.0597e-04 - loss: 0.0858 - p_star_loss: 0.0857
# Epoch 78: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 2.1815e-04 - loss: 0.0968 - p_star_loss: 0.0968 - val_delta_p_loss: 0.0036 - val_loss: 0.0854 - val_p_star_loss: 0.0838
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 2.2466e-04 - loss: 0.1063 - p_star_loss: 0.1061
# Epoch 79: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 2.7647e-04 - loss: 0.1387 - p_star_loss: 0.1385 - val_delta_p_loss: 0.0036 - val_loss: 0.0988 - val_p_star_loss: 0.0971
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 2.3000e-04 - loss: 0.0949 - p_star_loss: 0.0948
# Epoch 80: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 1.9135e-04 - loss: 0.0939 - p_star_loss: 0.0937 - val_delta_p_loss: 0.0036 - val_loss: 0.0710 - val_p_star_loss: 0.0692
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - delta_p_loss: 1.7326e-04 - loss: 0.0813 - p_star_loss: 0.0812
# Epoch 81: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - delta_p_loss: 1.6421e-04 - loss: 0.0854 - p_star_loss: 0.0853 - val_delta_p_loss: 0.0036 - val_loss: 0.0600 - val_p_star_loss: 0.0582
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 1.3185e-04 - loss: 0.0644 - p_star_loss: 0.0643
# Epoch 82: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 142ms/step - delta_p_loss: 1.3323e-04 - loss: 0.0603 - p_star_loss: 0.0602 - val_delta_p_loss: 0.0036 - val_loss: 0.0418 - val_p_star_loss: 0.0402
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 1.2614e-04 - loss: 0.0422 - p_star_loss: 0.0422
# Epoch 83: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 21s 142ms/step - delta_p_loss: 1.2013e-04 - loss: 0.0441 - p_star_loss: 0.0440 - val_delta_p_loss: 0.0036 - val_loss: 0.0509 - val_p_star_loss: 0.0493
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - delta_p_loss: 1.2016e-04 - loss: 0.0423 - p_star_loss: 0.0422
# Epoch 84: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - delta_p_loss: 1.0712e-04 - loss: 0.0406 - p_star_loss: 0.0406 - val_delta_p_loss: 0.0036 - val_loss: 0.0462 - val_p_star_loss: 0.0445
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - delta_p_loss: 8.7706e-05 - loss: 0.0374 - p_star_loss: 0.0373
# Epoch 85: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 145ms/step - delta_p_loss: 8.5292e-05 - loss: 0.0329 - p_star_loss: 0.0329 - val_delta_p_loss: 0.0036 - val_loss: 0.0478 - val_p_star_loss: 0.0467
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 9.2934e-05 - loss: 0.0415 - p_star_loss: 0.0415
# Epoch 86: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 9.8479e-05 - loss: 0.0472 - p_star_loss: 0.0471 - val_delta_p_loss: 0.0036 - val_loss: 0.0508 - val_p_star_loss: 0.0496
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 1.0021e-04 - loss: 0.0355 - p_star_loss: 0.0354
# Epoch 87: val_loss did not improve from 0.03959
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 9.8992e-05 - loss: 0.0343 - p_star_loss: 0.0342 - val_delta_p_loss: 0.0036 - val_loss: 0.0500 - val_p_star_loss: 0.0488
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 1.0356e-04 - loss: 0.0490 - p_star_loss: 0.0490
# Epoch 88: val_loss improved from 0.03959 to 0.03177, saving model to /content/drive/My Drive/Classification/credit/models/ViT_UNet_CREDIT_best.keras
#
# Epoch 88: finished saving model to /content/drive/My Drive/Classification/credit/models/ViT_UNet_CREDIT_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 167ms/step - delta_p_loss: 8.8337e-05 - loss: 0.0438 - p_star_loss: 0.0437 - val_delta_p_loss: 0.0036 - val_loss: 0.0318 - val_p_star_loss: 0.0304
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - delta_p_loss: 7.3435e-05 - loss: 0.0321 - p_star_loss: 0.0320
# Epoch 89: val_loss did not improve from 0.03177
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - delta_p_loss: 7.9617e-05 - loss: 0.0336 - p_star_loss: 0.0335 - val_delta_p_loss: 0.0036 - val_loss: 0.0449 - val_p_star_loss: 0.0435
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - delta_p_loss: 8.1777e-05 - loss: 0.0303 - p_star_loss: 0.0303
# Epoch 90: val_loss did not improve from 0.03177
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - delta_p_loss: 8.7474e-05 - loss: 0.0313 - p_star_loss: 0.0312 - val_delta_p_loss: 0.0036 - val_loss: 0.0417 - val_p_star_loss: 0.0405
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 1.0119e-04 - loss: 0.0423 - p_star_loss: 0.0423
# Epoch 91: val_loss did not improve from 0.03177
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - delta_p_loss: 9.3139e-05 - loss: 0.0468 - p_star_loss: 0.0468 - val_delta_p_loss: 0.0036 - val_loss: 0.0862 - val_p_star_loss: 0.0851
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 9.9350e-05 - loss: 0.0660 - p_star_loss: 0.0660
# Epoch 92: val_loss did not improve from 0.03177
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 142ms/step - delta_p_loss: 1.0109e-04 - loss: 0.0616 - p_star_loss: 0.0615 - val_delta_p_loss: 0.0036 - val_loss: 0.0479 - val_p_star_loss: 0.0466
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 7.4217e-05 - loss: 0.0337 - p_star_loss: 0.0336
# Epoch 93: val_loss did not improve from 0.03177
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 7.1394e-05 - loss: 0.0298 - p_star_loss: 0.0298 - val_delta_p_loss: 0.0036 - val_loss: 0.0593 - val_p_star_loss: 0.0577
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 8.3324e-05 - loss: 0.0321 - p_star_loss: 0.0320
# Epoch 94: val_loss did not improve from 0.03177
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 7.8697e-05 - loss: 0.0335 - p_star_loss: 0.0335 - val_delta_p_loss: 0.0036 - val_loss: 0.0467 - val_p_star_loss: 0.0454
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 1.0899e-04 - loss: 0.0406 - p_star_loss: 0.0405
# Epoch 95: val_loss did not improve from 0.03177
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - delta_p_loss: 9.3872e-05 - loss: 0.0366 - p_star_loss: 0.0365 - val_delta_p_loss: 0.0036 - val_loss: 0.0567 - val_p_star_loss: 0.0560
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - delta_p_loss: 1.0047e-04 - loss: 0.0733 - p_star_loss: 0.0733
# Epoch 96: val_loss did not improve from 0.03177
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - delta_p_loss: 1.2415e-04 - loss: 0.0929 - p_star_loss: 0.0928 - val_delta_p_loss: 0.0036 - val_loss: 0.0556 - val_p_star_loss: 0.0546
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 8.3952e-05 - loss: 0.0520 - p_star_loss: 0.0520
# Epoch 97: val_loss did not improve from 0.03177
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - delta_p_loss: 8.0156e-05 - loss: 0.0446 - p_star_loss: 0.0446 - val_delta_p_loss: 0.0036 - val_loss: 0.0412 - val_p_star_loss: 0.0400
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - delta_p_loss: 8.2572e-05 - loss: 0.0407 - p_star_loss: 0.0406
# Epoch 98: val_loss did not improve from 0.03177
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 142ms/step - delta_p_loss: 8.7006e-05 - loss: 0.0494 - p_star_loss: 0.0493 - val_delta_p_loss: 0.0036 - val_loss: 0.0574 - val_p_star_loss: 0.0557
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - delta_p_loss: 6.8095e-05 - loss: 0.0434 - p_star_loss: 0.0434
# Epoch 99: val_loss did not improve from 0.03177
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - delta_p_loss: 6.5115e-05 - loss: 0.0480 - p_star_loss: 0.0479 - val_delta_p_loss: 0.0036 - val_loss: 0.0466 - val_p_star_loss: 0.0458
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - delta_p_loss: 7.0391e-05 - loss: 0.0426 - p_star_loss: 0.0425
# Epoch 100: val_loss did not improve from 0.03177
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - delta_p_loss: 6.6617e-05 - loss: 0.0402 - p_star_loss: 0.0401 - val_delta_p_loss: 0.0036 - val_loss: 0.0401 - val_p_star_loss: 0.0389
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step
#
# Saved training summary → /content/drive/My Drive/Classification/credit/results/credit_train_uncertainty_summary.csv
#          Model   Mean_AU   Mean_EU   Mean_TU  Train_Time_sec
# 0  AlexNet_CNN  0.030099  0.001598  0.031697      748.142700
# 1        GFNet  0.015346  0.000142  0.015488      777.072614
# 2     ViT_UNet  0.222933  0.002971  0.225904     1426.796464

# %% [markdown]
# # 7.0 — Evaluation
#
# Loads the best saved CREDIT student weights for each architecture and computes a full suite of classification and calibration metrics — no re-training.

# %% [markdown]
# ## 7.1 — Load, Predict & Compute Metrics

# %%
eval_results     = []
credit_artifacts = {}

for model_name, builder in model_builders.items():
    best_path = MODEL_DIR / f'{model_name}_CREDIT_best.keras'

    if not best_path.exists():
        print(f'  [{model_name}] No saved weights at {best_path} — skipping.')
        continue

    print(f"\n{'='*25} Evaluating: {model_name} {'='*25}")
    tf.keras.backend.clear_session()

    student = build_credit_student(builder, num_classes)
    student.load_weights(best_path)

    # Select the correct test split for this architecture
    if model_name == 'AlexNet_CNN':
        x_te, y_te_true, y_te_cat = x_test_alex, y_test_alex, y_test_alex_cat
    else:
        x_te, y_te_true, y_te_cat = x_test, y_test, y_test_cat

    p_star_pred, delta_p_pred = student.predict(x_te, batch_size=BATCH_SIZE)

    au = -np.sum(p_star_pred * np.log(p_star_pred + 1e-12), axis=-1)
    eu =  np.mean(delta_p_pred, axis=-1)
    tu =  au + eu

    y_pred = np.argmax(p_star_pred, axis=-1)

    credit_artifacts[model_name] = {
        'confusion_matrix': confusion_matrix(y_te_true, y_pred),
        'report':           classification_report(
            y_te_true, y_pred, output_dict=True, zero_division=0
        ),
    }

    eval_results.append({
        'Model':         model_name,
        'Test_Accuracy': float(accuracy_score(y_te_true, y_pred)),
        'Macro_F1':      float(f1_score(y_te_true, y_pred, average='macro')),
        'Cohen_Kappa':   float(cohen_kappa_score(y_te_true, y_pred)),
        'Test_NLL':      float(log_loss(y_te_true, p_star_pred,
                                        labels=np.arange(num_classes))),
        'Test_Brier':    float(multiclass_brier_score(y_te_cat, p_star_pred)),
        'Test_ECE':      float(expected_calibration_error(
            y_te_true, p_star_pred, n_bins=15)),
        'Mean_AU':       float(np.mean(au)),
        'Mean_EU':       float(np.mean(eu)),
        'Mean_TU':       float(np.mean(tu)),
    })

eval_df = pd.DataFrame(eval_results)
eval_df.to_csv(RESULTS_DIR / 'credit_evaluation_summary.csv', index=False)
print('\n--- CREDIT Evaluation Summary ---')
print(eval_df.to_string(index=False))

# Stash for the final Excel report
_credit_eval_df        = eval_df.copy()
_credit_artifacts_dict = credit_artifacts
# Out:
# ========================= Evaluating: AlexNet_CNN =========================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step
#
# ========================= Evaluating: GFNet =========================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step
#
# ========================= Evaluating: ViT_UNet =========================
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step
#
# --- CREDIT Evaluation Summary ---
#       Model  Test_Accuracy  Macro_F1  Cohen_Kappa  Test_NLL  Test_Brier  Test_ECE  Mean_AU  Mean_EU  Mean_TU
# AlexNet_CNN       0.993735  0.988747     0.991509  0.018714    0.009854  0.005480 0.030099 0.001598 0.031697
#       GFNet       0.997216  0.996466     0.996224  0.011738    0.005115  0.002387 0.015346 0.000142 0.015488
#    ViT_UNet       0.993271  0.991132     0.990876  0.054809    0.012058  0.034371 0.222933 0.002971 0.225904

# %% [markdown]
# ## 7.2 — Confusion Matrices
#
# Renders and saves a side-by-side confusion matrix heatmap for every evaluated model.

# %%
if credit_artifacts:
    class_ticks = [str(i + 1) for i in range(num_classes)]
    n_models    = len(credit_artifacts)
    fig, axes   = plt.subplots(1, n_models, figsize=(7 * n_models, 5.5))
    if n_models == 1:
        axes = [axes]

    for ax, (mname, art) in zip(axes, credit_artifacts.items()):
        sns.heatmap(
            art['confusion_matrix'], annot=True, fmt='d', cmap='Blues',
            xticklabels=class_ticks, yticklabels=class_ticks, cbar=False, ax=ax
        )
        ax.set_title(f'{mname} — CREDIT\nConfusion Matrix', fontsize=13)
        ax.set_xlabel('Predicted Class')
        ax.set_ylabel('True Class')

    plt.tight_layout()
    save_path = RESULTS_DIR / 'credit_confusion_matrices.png'
    plt.savefig(save_path, dpi=220, bbox_inches='tight')
    print(f'Saved → {save_path}')
    plt.show()
# Out:
# Saved → /content/drive/My Drive/Classification/credit/results/credit_confusion_matrices.png

# %% [markdown]
# # 8.0 — Spatial Uncertainty Mapping
#
# Runs full-scene inference for each CREDIT student and produces a 3×4 figure showing: the base prediction map, binary certain/uncertain masks, grey-overlay maps, and per-class pixel-count bar charts — all for the aleatoric, epistemic, and total uncertainty channels.

# %% [markdown]
# ## 8.1 — Extract Full-Scene Patch Array

# %%
print('Extracting full-scene patch array (all H×W pixels)...')
pad   = PATCH_SIZE // 2
x_pad = np.pad(x_img, ((pad, pad), (pad, pad), (0, 0)), mode='edge')

scene_patches = np.empty((H * W, PATCH_SIZE, PATCH_SIZE, B), dtype=np.float32)
for idx, (r, c) in enumerate(
    [(r, c) for r in range(H) for c in range(W)]
):
    scene_patches[idx] = x_pad[r:r + PATCH_SIZE, c:c + PATCH_SIZE, :]

print(f'Scene patch tensor: {scene_patches.shape}')
# Out:
# Extracting full-scene patch array (all H×W pixels)...
# Scene patch tensor: (101310, 9, 9, 6)

# %% [markdown]
# ## 8.2 — Spatial Map Generator
#
# Defines the function that produces and saves the 3×4 uncertainty figure for a given student model.

# %%
CLASS_COLORS = [
    '#0000FF', '#00FF00', '#FF0000', '#00FFFF',
    '#FF00FF', '#FFFF00', '#A52A2A', '#FFA500',
    '#7FFF00', '#8A2BE2',
]


def generate_spatial_credit_maps(
    model_name, student_model, scene_pixels,
    H, W, au_thresh=0.5, eu_thresh=0.2, tu_thresh=0.7
):
    """
    Run full-scene inference and save a 3×4 spatial uncertainty figure.

    Panel layout (rows × cols):
      Row 0: Base prediction | AU binary | EU binary | TU binary
      Row 1: AU grey overlay | EU grey overlay | TU grey overlay | (blank)
      Row 2: AU bar chart   | EU bar chart   | TU bar chart   | (blank)
    """
    print(f'  Inferring full scene for {model_name}...')
    p_star_scene, delta_p_scene = student_model.predict(
        scene_pixels, batch_size=2048, verbose=1
    )
    p_star_scene = np.clip(p_star_scene, 1e-12, 1.0)
    n_cls = p_star_scene.shape[-1]

    au_scene = -np.sum(p_star_scene * np.log(p_star_scene), axis=-1)
    eu_scene =  np.mean(delta_p_scene, axis=-1)
    tu_scene =  au_scene + eu_scene

    pred_map = np.argmax(p_star_scene, axis=-1).reshape(H, W)
    au_mask  = (au_scene.reshape(H, W) > au_thresh).astype(int)
    eu_mask  = (eu_scene.reshape(H, W) > eu_thresh).astype(int)
    tu_mask  = (tu_scene.reshape(H, W) > tu_thresh).astype(int)

    combined_au = np.where(au_mask == 1, n_cls, pred_map)
    combined_eu = np.where(eu_mask == 1, n_cls, pred_map)
    combined_tu = np.where(tu_mask == 1, n_cls, pred_map)

    cmap_base   = ListedColormap(CLASS_COLORS[:n_cls])
    cmap_unc    = ListedColormap(CLASS_COLORS[:n_cls] + ['#808080'])
    cmap_binary = ListedColormap(['#FFFF00', '#001F3F'])

    bar_lbls = [f'Class {i}' for i in range(n_cls)] + ['Uncertain']
    bar_cols = CLASS_COLORS[:n_cls] + ['#808080']

    fig, axes = plt.subplots(3, 4, figsize=(38, 26))
    fig.suptitle(
        f'{model_name} — CREDIT Uncertainty Maps (Absolute Thresholds)',
        fontsize=24, fontweight='bold', y=0.99
    )

    # ── Row 0: Base prediction + 3 binary maps ─────────────────────────────────
    axes[0, 0].imshow(pred_map, cmap=cmap_base, vmin=0, vmax=n_cls - 1)
    axes[0, 0].set_title('Base Prediction Map', fontsize=15)
    axes[0, 0].axis('off')

    binary_specs = [
        (axes[0, 1], au_mask, f'Aleatoric (AU > {au_thresh})'),
        (axes[0, 2], eu_mask, f'Epistemic (EU > {eu_thresh})'),
        (axes[0, 3], tu_mask, f'Total     (TU > {tu_thresh})'),
    ]
    for ax, mask, label in binary_specs:
        ax.imshow(mask, cmap=cmap_binary, vmin=0, vmax=1)
        ax.set_title(f'Certain vs Uncertain\n{label}', fontsize=15, pad=10)
        ax.axis('off')
        ax.legend(
            handles=[
                Patch(facecolor='#FFFF00', label='Certain'),
                Patch(facecolor='#001F3F', label='Uncertain'),
            ],
            loc='upper left',
            bbox_to_anchor=(0.0, -0.02),
            borderaxespad=0,
            fontsize=11,
            framealpha=0.9,
            ncol=2
        )

    # ── Row 1: Grey overlay maps ────────────────────────────────────────────────
    overlay_specs = [
        (axes[1, 0], combined_au, f'Aleatoric (AU > {au_thresh})'),
        (axes[1, 1], combined_eu, f'Epistemic (EU > {eu_thresh})'),
        (axes[1, 2], combined_tu, f'Total     (TU > {tu_thresh})'),
    ]
    for ax, combined, label in overlay_specs:
        ax.imshow(combined, cmap=cmap_unc, vmin=0, vmax=n_cls)
        ax.set_title(f'Grey Overlay — {label}', fontsize=15, pad=10)
        ax.axis('off')
    axes[1, 3].axis('off')

    # ── Row 2: Pixel-count bar charts ───────────────────────────────────────────
    bar_specs = [
        (axes[2, 0], combined_au, f'Aleatoric (AU > {au_thresh})'),
        (axes[2, 1], combined_eu, f'Epistemic (EU > {eu_thresh})'),
        (axes[2, 2], combined_tu, f'Total     (TU > {tu_thresh})'),
    ]
    for ax, combined, label in bar_specs:
        uniq, cnt = np.unique(combined, return_counts=True)
        c_dict    = {int(k): int(v) for k, v in zip(uniq, cnt)}
        bar_vals  = [c_dict.get(i, 0) for i in range(n_cls + 1)]
        ax.bar(bar_lbls, bar_vals, color=bar_cols, edgecolor='black')
        ax.set_title(f'Pixel Counts — {label}', fontsize=15, pad=10)
        ax.tick_params(axis='x', rotation=45, labelsize=11)
        ax.set_ylabel('Pixel Count', fontsize=12)
        max_val = max(bar_vals, default=1)
        for i, v in enumerate(bar_vals):
            ax.text(i, v + max_val * 0.01,
                    f'{v:,}', ha='center', va='bottom',
                    fontweight='bold', fontsize=9)
        ax.set_ylim(0, max_val * 1.12)
    axes[2, 3].axis('off')

    plt.tight_layout(rect=[0, 0.03, 1, 0.98])
    save_path = RESULTS_DIR / f'{model_name}_CREDIT_spatial_maps.png'
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    print(f'  Saved → {save_path}')
    plt.show()

# %% [markdown]
# ## 8.3 — Run Spatial Mapping for All Models

# %%
for model_name, builder in model_builders.items():
    best_path = MODEL_DIR / f'{model_name}_CREDIT_best.keras'
    if not best_path.exists():
        print(f'[{model_name}] No weights found — skipping spatial maps.')
        continue

    tf.keras.backend.clear_session()
    student = build_credit_student(builder, num_classes)
    student.load_weights(best_path)

    generate_spatial_credit_maps(
        model_name, student, scene_patches, H, W,
        au_thresh=0.5, eu_thresh=0.2, tu_thresh=0.7
    )
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 9.0 — Excel Report Export
#
# Collects all saved plot paths (confusion matrices, spatial uncertainty maps, and any training-curve PNGs) and writes the final `CREDIT_Results.xlsx` workbook.

# %%
# ── Collect all plot paths ─────────────────────────────────────────────────────
_plot_entries = []

# Confusion matrix image
_cm_path = str(RESULTS_DIR / 'credit_confusion_matrices.png')
_plot_entries.append(('Confusion Matrices (all models)', _cm_path))

# Per-model spatial uncertainty maps
for _mname in model_builders:
    _sp_path = str(RESULTS_DIR / f'{_mname}_CREDIT_spatial_maps.png')
    _plot_entries.append((f'{_mname} — Spatial Uncertainty Maps', _sp_path))

# Any additional training-curve PNGs saved to PLOT_DIR
for _p in sorted(PLOT_DIR.glob('*.png')):
    _plot_entries.append((_p.stem.replace('_', ' ').title(), str(_p)))

# ── Write the workbook ─────────────────────────────────────────────────────────
create_credit_excel_report(
    results_dir           = RESULTS_DIR,
    train_summary_df      = _credit_train_summary_df,
    eval_summary_df       = _credit_eval_df,
    credit_artifacts_dict = _credit_artifacts_dict,
    plot_paths            = _plot_entries,
)
# Out:
# ✅ Excel report saved → /content/drive/My Drive/Classification/credit/results/CREDIT_Results.xlsx
# '/content/drive/My Drive/Classification/credit/results/CREDIT_Results.xlsx'
