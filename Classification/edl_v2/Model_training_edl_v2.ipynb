# %% [markdown]
# # 1.0 — Setup & Imports
# Mount Google Drive and import all required standard, third-party, and ML libraries.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Standard library
import io
import json
import os
import random
import time
from pathlib import Path

# Third-party – data / viz
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.colors import ListedColormap
from openpyxl import Workbook, load_workbook
from openpyxl.drawing.image import Image as XLImage
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    cohen_kappa_score,
    confusion_matrix,
    f1_score,
    log_loss,
)
from sklearn.model_selection import train_test_split

# TensorFlow / Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers

sns.set_style("whitegrid")
print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# # 2.0 — Configuration
# All hyper-parameters, paths, and architecture configs are defined here. Change values in this single cell to reconfigure the whole notebook.

# %%
# ── Reproducibility ──────────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# ── Paths ─────────────────────────────────────────────────────────────
MODEL_DIR   = Path("/content/drive/My Drive/Classification/edl_v2/models")
RESULTS_DIR = Path("/content/drive/My Drive/Classification/edl_v2/results")
MODEL_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
PLOT_DIR    = RESULTS_DIR / "training_plots"
PLOT_DIR.mkdir(parents=True, exist_ok=True)
VIS_DIR     = RESULTS_DIR / "scene_visualizations"
VIS_DIR.mkdir(parents=True, exist_ok=True)

DATA_DIR   = Path("/content/drive/My Drive/Classification/data")
DATA_FILE  = DATA_DIR / "data.csv"
LABEL_FILE = DATA_DIR / "ref.csv"

# ── Dataset geometry ──────────────────────────────────────────────────
H, W, B    = 330, 307, 6          # height, width, bands
PATCH_SIZE  = 9
INNER_PATCH = 3                   # tokenisation patch size for GFNet / ViT

# ── Train / val / test splits ─────────────────────────────────────────
TRAIN_PERCENT          = 0.75
VAL_SPLIT_FROM_TRAIN   = 0.20

# ── Training ──────────────────────────────────────────────────────────
BATCH_SIZE    = 128
EPOCHS        = 100
LEARNING_RATE = 3e-4
DROPOUT_RATE  = 0.25
CAPACITY_PRESET = "legacy_arch"

TRAIN_CFG = {
    "label_smoothing": 0.05,   # retained for reference only; unused with the EDL loss
    "weight_decay":    1e-4,
    "clipnorm":        1.0,
    "cosine_alpha":    0.05,
}

# ── EDL fix: extra damping on the KL term, on top of epoch-based annealing ────
# The first EDL run collapsed (every model converged to a uniform 1/7 output on every
# pixel) because the KL term could grow far larger than the cross-entropy term. We now
# use the PROPER, bounded Dirichlet KL divergence (see 5.1 below) and additionally scale
# it down by KL_LAMBDA as a safety margin. Increase toward 1.0 only if evidence still
# looks too weak once this run completes.
KL_LAMBDA = 0.1

# ── AlexNet legacy recipe (reproduces original single-head results) ────
ALEXNET_LEGACY_SPLIT_SEED   = 10
ALEXNET_LEGACY_TRAIN_PERCENT = 0.75
ALEXNET_LR_START = 0.01
ALEXNET_LR_MAX   = 0.02
ALEXNET_LR_MIN   = 0.005

# ── Architecture configs ──────────────────────────────────────────────
ALEXNET_CFG = {
    "conv_filters": [96, 256, 384, 384, 256],
    "dense_units":  [4096, 1024, 256, 32],
}

GFNET_CFG = {"hidden_dim": 512, "num_blocks": 5, "mlp_ratio": 4}
VIT_CFG   = {
    "projection_dim":    256,
    "num_heads":         4,
    "transformer_layers": 12,
    "mlp_multiplier":    2,
    "head_units":        [512, 256, 128, 64],
}

# Fallback configs used when Colab runs out of memory
GFNET_FALLBACK_CFG = {"hidden_dim": 384, "num_blocks": 4, "mlp_ratio": 4}
VIT_FALLBACK_CFG   = {
    "projection_dim":    192,
    "num_heads":         4,
    "transformer_layers": 8,
    "mlp_multiplier":    2,
    "head_units":        [384, 192, 96, 64],
}

# ── Visualisation palette ─────────────────────────────────────────────
CLASS_COLOR_BASE = [
    "#0000FF", "#00FF00", "#FF0000", "#00FFFF", "#FF00FF",
    "#FFFF00", "#A52A2A", "#FFA500", "#7FFF00", "#8A2BE2",
]
BACKGROUND_COLOR  = "#000000"
VIS_EXCEL_PATH    = VIS_DIR / "initial_classification_maps.xlsx"

print("Data file:    ", DATA_FILE)
print("Label file:   ", LABEL_FILE)
print("Model dir:    ", MODEL_DIR)
print("Results dir:  ", RESULTS_DIR)
print("Plot dir:     ", PLOT_DIR)
print("Arch preset:  ", CAPACITY_PRESET)
# Out:
# Data file:     /content/drive/My Drive/Classification/data/data.csv
# Label file:    /content/drive/My Drive/Classification/data/ref.csv
# Model dir:     /content/drive/My Drive/Classification/edl_v2/models
# Results dir:   /content/drive/My Drive/Classification/edl_v2/results
# Plot dir:      /content/drive/My Drive/Classification/edl_v2/results/training_plots
# Arch preset:   legacy_arch

# %% [markdown]
# # 3.0 — Data Loading & Preprocessing
# Load the raw multispectral CSV files, apply per-band min-max normalisation, extract labelled patches, and create stratified train / val / test splits.

# %% [markdown]
# ## 3.1 — Loading and patch extraction helpers

# %%
def load_multispectral_6band(data_path, label_path, height, width, bands):
    """Load multispectral data and reference labels; normalise each band to [0, 1]."""
    x = pd.read_csv(data_path).to_numpy(dtype=np.float32).reshape(height, width, bands)
    y = pd.read_csv(label_path).to_numpy(dtype=np.int32).reshape(height, width)

    x_norm = np.empty_like(x, dtype=np.float32)
    for b in range(bands):
        band     = x[:, :, b]
        band_min = np.min(band)
        band_max = np.max(band)
        denom    = max(band_max - band_min, 1e-8)
        x_norm[:, :, b] = (band - band_min) / denom

    return x_norm, y


def extract_labeled_patches(x, y, patch_size=9):
    """Extract (patch_size × patch_size) spatial patches around every labelled pixel."""
    pad   = patch_size // 2
    x_pad = np.pad(x, ((pad, pad), (pad, pad), (0, 0)), mode="edge")

    coords  = np.argwhere(y > 0)
    patches = np.empty((coords.shape[0], patch_size, patch_size, x.shape[-1]), dtype=np.float32)
    labels  = np.empty((coords.shape[0],), dtype=np.int32)

    for i, (r, c) in enumerate(coords):
        patches[i] = x_pad[r:r + patch_size, c:c + patch_size, :]
        labels[i]  = int(y[r, c]) - 1  # convert class IDs to 0..C-1

    return patches, labels, coords

# %% [markdown]
# ## 3.2 — Load data and create splits

# %%
x_img, y_img = load_multispectral_6band(DATA_FILE, LABEL_FILE, H, W, B)
X, y, coords = extract_labeled_patches(x_img, y_img, PATCH_SIZE)

num_classes = int(np.unique(y).size)
input_shape = (PATCH_SIZE, PATCH_SIZE, B)

print("x_img:", x_img.shape, "  y_img:", y_img.shape)
print("Labelled samples:", X.shape[0])
print("Patch tensor:    ", X.shape)
print("Num classes:     ", num_classes)
# Out:
# x_img: (330, 307, 6)   y_img: (330, 307)
# Labelled samples: 17239
# Patch tensor:     (17239, 9, 9, 6)
# Num classes:      7

# %%
# Primary stratified split used by GFNet and ViT
x_train_full, x_test, y_train_full, y_test = train_test_split(
    X, y,
    train_size=TRAIN_PERCENT,
    random_state=SEED,
    stratify=y,
)
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full,
    test_size=VAL_SPLIT_FROM_TRAIN,
    random_state=SEED,
    stratify=y_train_full,
)

y_train_cat = keras.utils.to_categorical(y_train, num_classes)
y_val_cat   = keras.utils.to_categorical(y_val,   num_classes)
y_test_cat  = keras.utils.to_categorical(y_test,  num_classes)

print("Train:", x_train.shape, y_train.shape)
print("Val:  ", x_val.shape,   y_val.shape)
print("Test: ", x_test.shape,  y_test.shape)
# Out:
# Train: (10343, 9, 9, 6) (10343,)
# Val:   (2586, 9, 9, 6) (2586,)
# Test:  (4310, 9, 9, 6) (4310,)

# %%
# AlexNet legacy split — matches the original single-head notebook for
# uncertainty recovery (different seed and no val split)
x_train_alex, x_test_alex, y_train_alex, y_test_alex = train_test_split(
    X, y,
    train_size=ALEXNET_LEGACY_TRAIN_PERCENT,
    random_state=ALEXNET_LEGACY_SPLIT_SEED,
    stratify=y,
)
y_train_alex_cat = keras.utils.to_categorical(y_train_alex, num_classes)
y_test_alex_cat  = keras.utils.to_categorical(y_test_alex,  num_classes)

print("AlexNet Train:", x_train_alex.shape, y_train_alex.shape)
print("AlexNet Test: ", x_test_alex.shape,  y_test_alex.shape)
# Out:
# AlexNet Train: (12929, 9, 9, 6) (12929,)
# AlexNet Test:  (4310, 9, 9, 6) (4310,)

# %% [markdown]
# # 4.0 — Model Definitions
# Defines three single-head architectures: AlexNet-based CNN, Global Filter Network (GFNet), and Vision Transformer (ViT with U-Net style skip connections). Custom Keras layers are registered for serialisation.

# %% [markdown]
# ## 4.1 — Shared custom Keras layers (PatchExtractor, PatchPositionEncoder, PatchEncoderWithCLS)

# %%
@tf.keras.utils.register_keras_serializable()
class PatchExtractor(layers.Layer):
    """Extract non-overlapping spatial patches from an image tensor."""

    def __init__(self, patch_size=3, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        patches     = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        batch       = tf.shape(images)[0]
        num_patches = tf.shape(patches)[1] * tf.shape(patches)[2]
        patch_dim   = tf.shape(patches)[-1]
        return tf.reshape(patches, [batch, num_patches, patch_dim])

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"patch_size": self.patch_size})
        return cfg


@tf.keras.utils.register_keras_serializable()
class PatchPositionEncoder(layers.Layer):
    """Project patches to embedding dim and add learned positional embeddings."""

    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches      = num_patches
        self.projection_dim   = projection_dim
        self.projection       = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)

    def call(self, patches):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        return self.projection(patches) + self.position_embedding(positions)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"num_patches": self.num_patches, "projection_dim": self.projection_dim})
        return cfg


@tf.keras.utils.register_keras_serializable()
class PatchEncoderWithCLS(layers.Layer):
    """Project patches and prepend a learnable [CLS] token with positional embeddings."""

    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches      = num_patches
        self.projection_dim   = projection_dim
        self.projection       = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(input_dim=num_patches + 1, output_dim=projection_dim)

    def build(self, input_shape):
        self.cls_token = self.add_weight(
            name="cls_token",
            shape=(1, 1, self.projection_dim),
            initializer="zeros",
            trainable=True,
        )
        super().build(input_shape)

    def call(self, patches):
        batch      = tf.shape(patches)[0]
        patch_proj = self.projection(patches)
        cls_tokens = tf.repeat(self.cls_token, repeats=batch, axis=0)
        x          = tf.concat([cls_tokens, patch_proj], axis=1)
        positions  = tf.range(start=0, limit=self.num_patches + 1, delta=1)
        return x + self.position_embedding(positions)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"num_patches": self.num_patches, "projection_dim": self.projection_dim})
        return cfg

# %% [markdown]
# ### Evidential output activation
# For Evidential Deep Learning the final layer must output non-negative *evidence* rather than a softmax probability. We keep the architecture otherwise identical (same single final `Dense` layer, same layer count, so penultimate-layer feature extraction used elsewhere is unaffected) and only swap the activation function: `alpha = softplus(logits) + 1`. `alpha` is the Dirichlet concentration parameter per class; it is always ≥ 1 and is *not* normalised to sum to 1 (unlike softmax).

# %%
@tf.keras.utils.register_keras_serializable()
def evidence_activation(logits):
    """Map raw logits to Dirichlet alpha parameters: alpha = softplus(logits) + 1.

    softplus(.) guarantees non-negative 'evidence'; adding 1 gives the alpha used to
    parameterise a Dirichlet distribution over the class-probability simplex (Sensoy et al., 2018).
    """
    return tf.math.softplus(logits) + 1.0

# %% [markdown]
# ## 4.2 — AlexNet-based CNN

# %%
def build_alexnet(input_shape, num_classes, dropout_rate=0.25, cfg=None):
    """Build an AlexNet-inspired CNN with five conv layers and four dense layers."""
    cfg = cfg or ALEXNET_CFG

    inputs = keras.Input(shape=input_shape)
    x      = inputs
    for i, filters in enumerate(cfg["conv_filters"], start=1):
        x = layers.Conv2D(filters, (3, 3), activation="relu", padding="same", name=f"alex_conv_{i}")(x)

    x = layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same", name="alex_pool")(x)
    x = layers.Flatten(name="alex_flatten")(x)

    dense_units = cfg["dense_units"]
    x = layers.Dense(dense_units[0], activation="relu", name="alex_fc1")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)
    x = layers.Dense(dense_units[1], activation="relu", name="alex_fc2")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_2")(x)
    x = layers.Dense(dense_units[2], activation="relu", name="alex_fc3")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(x)
    x = layers.Dense(dense_units[3], activation="relu", name="alex_fc4")(x)

    outputs = layers.Dense(num_classes, activation=evidence_activation, name="alex_logits")(x)
    return keras.Model(inputs, outputs, name="AlexNet_SingleHead")

# %% [markdown]
# ## 4.3 — Global Filter Network (GFNet)

# %%
@tf.keras.utils.register_keras_serializable()
class GlobalFilterLayer(layers.Layer):
    """Apply learnable complex-valued filters in the 2-D frequency domain."""

    def __init__(self, token_side, **kwargs):
        super().__init__(**kwargs)
        self.token_side = token_side

    def build(self, input_shape):
        channels    = int(input_shape[-1])
        self.w_real = self.add_weight(
            name="w_real",
            shape=(self.token_side, self.token_side, channels),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.w_imag = self.add_weight(
            name="w_imag",
            shape=(self.token_side, self.token_side, channels),
            initializer="zeros",
            trainable=True,
        )
        super().build(input_shape)

    def call(self, x):
        batch      = tf.shape(x)[0]
        channels   = tf.shape(x)[-1]
        x_2d       = tf.reshape(x, [batch, self.token_side, self.token_side, channels])
        x_fft      = tf.signal.fft2d(tf.cast(x_2d, tf.complex64))
        w_complex  = tf.complex(self.w_real, self.w_imag)
        x_filtered = x_fft * w_complex
        x_spatial  = tf.math.real(tf.signal.ifft2d(x_filtered))
        return tf.reshape(x_spatial, [batch, self.token_side * self.token_side, channels])

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"token_side": self.token_side})
        return cfg


def gf_block(x, token_side, dim, mlp_ratio=4, dropout_rate=0.25, name_prefix="gf"):
    """Single GFNet residual block: global filter followed by a two-layer MLP."""
    # Legacy block style: one residual add after filter + MLP branch
    y = layers.LayerNormalization(name=f"{name_prefix}_ln1")(x)
    y = GlobalFilterLayer(token_side, name=f"{name_prefix}_gfilter")(y)
    y = layers.LayerNormalization(name=f"{name_prefix}_ln2")(y)
    y = layers.Dense(dim * mlp_ratio, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp1")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop1")(y)
    y = layers.Dense(dim, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp2")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop2")(y)
    return layers.Add(name=f"{name_prefix}_add")([x, y])


def build_gfnet(input_shape, num_classes, inner_patch=3, hidden_dim=512,
                num_blocks=5, mlp_ratio=4, dropout_rate=0.25):
    """Build a Global Filter Network (GFNet) single-head classifier."""
    num_patches = (input_shape[0] // inner_patch) * (input_shape[1] // inner_patch)
    token_side  = int(np.sqrt(num_patches))

    inputs = keras.Input(shape=input_shape)
    x      = PatchExtractor(inner_patch, name="gf_patch_extractor")(inputs)
    x      = PatchPositionEncoder(num_patches, hidden_dim, name="gf_patch_encoder")(x)
    x      = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)

    for i in range(num_blocks):
        x = gf_block(x, token_side, hidden_dim, mlp_ratio, dropout_rate, name_prefix=f"gf_block_{i+1}")

    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_2")(x)
    x = layers.LayerNormalization(name="gf_final_ln")(x)
    x = layers.GlobalAveragePooling1D(name="gf_gap")(x)
    x = layers.Flatten(name="gf_flatten")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(x)

    outputs = layers.Dense(num_classes, activation=evidence_activation, name="gf_logits")(x)
    return keras.Model(inputs, outputs, name="GFNet_SingleHead")

# %% [markdown]
# ## 4.4 — Vision Transformer with U-Net style skip connections

# %%
def transformer_block(x, num_heads, projection_dim, mlp_dim, dropout_rate, name_prefix):
    """Standard pre-LN transformer block with multi-head attention and a GELU MLP."""
    y = layers.LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_ln1")(x)
    y = layers.MultiHeadAttention(
        num_heads=num_heads, key_dim=projection_dim,
        dropout=dropout_rate, name=f"{name_prefix}_mha",
    )(y, y)
    x = layers.Add(name=f"{name_prefix}_add1")([y, x])

    y = layers.LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_ln2")(x)
    y = layers.Dense(mlp_dim, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp1")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop1")(y)
    y = layers.Dense(projection_dim, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp2")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop2")(y)
    return layers.Add(name=f"{name_prefix}_add2")([y, x])


def build_vit_unet_singlehead(
    input_shape, num_classes, inner_patch=3,
    projection_dim=256, num_heads=4, transformer_layers=12,
    mlp_multiplier=2, dropout_rate=0.25, head_units=(512, 256, 128, 64),
):
    """Build a ViT single-head classifier with U-Net style encoder–decoder skip connections."""
    num_patches = (input_shape[0] // inner_patch) * (input_shape[1] // inner_patch)

    inputs = keras.Input(shape=input_shape)
    x      = PatchExtractor(inner_patch, name="vit_patch_extractor")(inputs)
    x      = PatchEncoderWithCLS(num_patches, projection_dim, name="vit_patch_encoder")(x)

    block_list = []
    for i in range(transformer_layers):
        x = transformer_block(
            x, num_heads=num_heads, projection_dim=projection_dim,
            mlp_dim=projection_dim * mlp_multiplier,
            dropout_rate=0.1, name_prefix=f"vit_block_{i+1}",
        )
        if i <= transformer_layers // 2:
            block_list.append(x)
        else:
            x = layers.Add(name=f"vit_skip_add_{i+1}")([x, block_list[transformer_layers - i - 1]])

    x         = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)
    x         = layers.LayerNormalization(epsilon=1e-6, name="vit_cls_norm")(x)
    cls_token = layers.Lambda(lambda t: t[:, 0, :], name="vit_cls_token")(x)

    y = layers.Dense(head_units[0], activation=tf.keras.activations.gelu, name="vit_head_1")(cls_token)
    y = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(y)
    y = layers.Dense(head_units[1], activation=tf.keras.activations.gelu, name="vit_head_2")(y)
    y = layers.Dense(head_units[2], activation=tf.keras.activations.gelu, name="vit_head_3")(y)
    y = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_5")(y)
    y = layers.Dense(head_units[3], activation=tf.keras.activations.gelu, name="vit_head_4")(y)
    y = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_6")(y)

    outputs = layers.Dense(num_classes, activation=evidence_activation, name="vit_logits")(y)
    return keras.Model(inputs, outputs, name="ViT_UNet_SingleHead")

# %% [markdown]
# # 5.0 — Training & Evaluation Helpers
# Optimiser factory, learning-rate schedule, calibration metrics (Brier score, ECE), and the main `train_save_evaluate` function.

# %% [markdown]
# ## 5.1 — Evidential Deep Learning (EDL) loss
# Trains the model to output Dirichlet concentration parameters (`alpha`, produced by the `evidence_activation` final layer above) instead of a plain softmax distribution. The loss has two parts: an expected cross-entropy term that pushes `alpha` of the *correct* class up, and a KL-divergence regulariser that penalises the model for accumulating evidence on *incorrect* classes -- gradually phased in via an epoch-based annealing coefficient so early training is not destabilised (Sensoy et al., 2018). Because a standard `loss=...` argument to `model.compile()` has no way to see the current epoch number, `EDLAnnealer` is a small callback that writes the epoch into a shared `tf.Variable` that the loss closure reads from.

# %%
class EDLAnnealer(keras.callbacks.Callback):
    """Writes the current epoch number into a shared tf.Variable each epoch, so the EDL loss's
    KL-annealing coefficient can be computed inside a standard compile()-style loss function."""

    def __init__(self, epoch_variable):
        super().__init__()
        self.epoch_variable = epoch_variable

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_variable.assign(float(epoch))


def make_edl_loss(epoch_variable, total_epochs, num_classes, sparse=False, kl_lambda=0.1):
    """Build an EDL loss closure. `y_pred` here is `alpha` (see evidence_activation above),
    NOT a softmax probability vector.

    Fix vs. the first EDL run: uses the PROPER Dirichlet KL divergence
    KL( Dir(alpha_tilde) || Dir(1,...,1) ) instead of the earlier unbounded
    sum(lgamma(alpha_tilde)) approximation, and applies an extra kl_lambda damping factor
    on top of epoch-based annealing. The earlier version let the KL term grow far larger
    than the cross-entropy term, which is why every model collapsed to a uniform 1/7
    output on every pixel (zero evidence for every class, everywhere).
    """
    total_epochs_f = tf.cast(total_epochs, tf.float32)
    num_classes_f  = tf.cast(num_classes, tf.float32)

    def loss_fn(y_true, y_pred):
        alpha = y_pred
        S     = tf.reduce_sum(alpha, axis=-1, keepdims=True)

        if sparse:
            y_true_oh = tf.one_hot(tf.cast(y_true, tf.int32), depth=num_classes)
        else:
            y_true_oh = y_true

        # Expected cross-entropy: pushes alpha of the true class up
        loss_ce = tf.reduce_sum(y_true_oh * (tf.math.log(S) - tf.math.log(alpha)), axis=-1)

        # Proper (bounded) KL divergence: KL( Dir(alpha_tilde) || Dir(1,...,1) )
        # alpha_tilde 'removes' the true class's evidence (fixes it at 1) so only
        # non-target evidence is penalised.
        alpha_tilde = y_true_oh + (1.0 - y_true_oh) * alpha
        S_tilde     = tf.reduce_sum(alpha_tilde, axis=-1, keepdims=True)

        term1 = (
            tf.math.lgamma(tf.squeeze(S_tilde, axis=-1))
            - tf.math.lgamma(num_classes_f)
            - tf.reduce_sum(tf.math.lgamma(alpha_tilde), axis=-1)
        )
        term2 = tf.reduce_sum(
            (alpha_tilde - 1.0) * (tf.math.digamma(alpha_tilde) - tf.math.digamma(S_tilde)),
            axis=-1,
        )
        kl_proper = term1 + term2

        annealing_coef = tf.minimum(1.0, epoch_variable / (total_epochs_f / 2.0))
        kl_div = kl_lambda * annealing_coef * kl_proper

        return loss_ce + kl_div

    return loss_fn


def alpha_to_probs(alpha):
    """Convert Dirichlet alpha output to the expected class probabilities: p_hat = alpha / S."""
    alpha = np.asarray(alpha, dtype=np.float64)
    return alpha / alpha.sum(axis=-1, keepdims=True)

# %% [markdown]
# ## 5.2 — Calibration metrics

# %%
def multiclass_brier_score(y_onehot, y_prob):
    """Compute the multiclass Brier score (mean squared error over probability vectors)."""
    return float(np.mean(np.sum((y_prob - y_onehot) ** 2, axis=1)))


def expected_calibration_error(y_true, y_prob, n_bins=15):
    """Compute Expected Calibration Error (ECE) with equal-width confidence bins."""
    confidences = np.max(y_prob, axis=1)
    predictions = np.argmax(y_prob, axis=1)
    correct     = (predictions == y_true).astype(np.float32)
    bin_edges   = np.linspace(0.0, 1.0, n_bins + 1)
    ece         = 0.0

    for i in range(n_bins):
        lo, hi = bin_edges[i], bin_edges[i + 1]
        in_bin = (confidences >= lo) & (confidences <= hi if i == n_bins - 1 else confidences < hi)
        prop   = np.mean(in_bin)
        if prop > 0:
            ece += np.abs(np.mean(correct[in_bin]) - np.mean(confidences[in_bin])) * prop

    return float(ece)

# %% [markdown]
# ## 5.3 — Optimiser factory

# %%
def make_optimizer(num_train_samples):
    """Build an AdamW optimiser with a cosine-decay learning-rate schedule."""
    steps_per_epoch = int(np.ceil(num_train_samples / BATCH_SIZE))
    decay_steps     = max(1, steps_per_epoch * EPOCHS)
    lr_schedule     = keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=LEARNING_RATE,
        decay_steps=decay_steps,
        alpha=TRAIN_CFG["cosine_alpha"],
    )
    return keras.optimizers.AdamW(
        learning_rate=lr_schedule,
        weight_decay=TRAIN_CFG["weight_decay"],
        clipnorm=TRAIN_CFG["clipnorm"],
    )


def _alexnet_legacy_lr(epoch):
    """Cosine LR schedule for AlexNet, matching the original single-head script."""
    if EPOCHS <= 1:
        return ALEXNET_LR_START
    phase        = np.pi * epoch / (EPOCHS - 1)
    cosine_decay = 0.5 * (1.0 + np.cos(phase))
    return float((ALEXNET_LR_MAX - ALEXNET_LR_MIN) * cosine_decay + ALEXNET_LR_MIN)

# %% [markdown]
# ## 5.4 — Main training, saving, and evaluation function

# %%
def train_save_evaluate(model_name, model_builder, capacity_tag="max"):
    """Compile, train, save (best + final), and evaluate a single-head model.

    Returns a metrics dict, per-class classification report, confusion matrix,
    and the raw Keras history dict.
    """
    tf.keras.backend.clear_session()
    model     = model_builder()
    best_path  = MODEL_DIR / f"{model_name}_best.keras"
    final_path = MODEL_DIR / f"{model_name}_final.keras"

    # Shared epoch counter for the EDL loss's KL-annealing coefficient (see 5.1 above)
    edl_epoch_var = tf.Variable(0.0, trainable=False, dtype=tf.float32, name=f"{model_name}_edl_epoch")

    # AlexNet uses a legacy Adagrad + cosine LR schedule to match the original
    # single-head script for downstream uncertainty analysis.
    if model_name == "AlexNet_CNN":
        model.compile(
            optimizer=keras.optimizers.Adagrad(learning_rate=ALEXNET_LR_START, clipnorm=TRAIN_CFG["clipnorm"]),
            loss=make_edl_loss(edl_epoch_var, EPOCHS, num_classes, sparse=True, kl_lambda=KL_LAMBDA),
            metrics=["accuracy"],
        )
        callbacks = [
            keras.callbacks.ModelCheckpoint(
                filepath=str(best_path), monitor="val_accuracy",
                mode="max", save_best_only=True, verbose=1,
            ),
            keras.callbacks.LearningRateScheduler(_alexnet_legacy_lr, verbose=0),
            EDLAnnealer(edl_epoch_var),
        ]
        x_tr, y_tr         = x_train_alex, y_train_alex
        x_va, y_va         = x_test_alex,  y_test_alex
        x_te, y_te, y_te_cat = x_test_alex, y_test_alex, y_test_alex_cat
        x_eval, y_eval, y_eval_cat = x_test_alex, y_test_alex, y_test_alex_cat
        fit_shuffle        = False
    else:
        # GFNet and ViT use AdamW + cosine decay with label smoothing
        model.compile(
            optimizer=make_optimizer(len(x_train)),
            loss=make_edl_loss(edl_epoch_var, EPOCHS, num_classes, sparse=False, kl_lambda=KL_LAMBDA),
            metrics=["accuracy"],
        )
        callbacks = [
            keras.callbacks.ModelCheckpoint(
                filepath=str(best_path), monitor="val_loss",
                mode="min", save_best_only=True, verbose=1,
            ),
            EDLAnnealer(edl_epoch_var),
        ]
        x_tr, y_tr         = x_train, y_train_cat
        x_va, y_va         = x_val,   y_val_cat
        x_te, y_te, y_te_cat = x_test, y_test, y_test_cat
        x_eval, y_eval, y_eval_cat = x_val, y_val, y_val_cat
        fit_shuffle        = True

    train_start = time.perf_counter()
    history_obj = model.fit(
        x_tr, y_tr,
        validation_data=(x_va, y_va),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=callbacks,
        verbose=1,
        shuffle=fit_shuffle,
    )
    train_time_sec = float(time.perf_counter() - train_start)

    epochs_ran = int(len(history_obj.history.get("loss", [])))
    if epochs_ran != EPOCHS:
        print(f"WARNING: {model_name} ran {epochs_ran} epochs, expected {EPOCHS}.")
    else:
        print(f"{model_name} completed full training: {epochs_ran}/{EPOCHS} epochs.")

    model.save(final_path)

    # Model output is alpha (Dirichlet concentration), not a softmax probability --
    # convert to the expected probability p_hat = alpha / S before any downstream metric
    # (log-loss, Brier score, ECE, classification report) touches it.
    y_eval_prob = alpha_to_probs(model.predict(x_eval, batch_size=BATCH_SIZE, verbose=0))
    y_test_prob = alpha_to_probs(model.predict(x_te,   batch_size=BATCH_SIZE, verbose=0))
    y_test_pred = np.argmax(y_test_prob, axis=1)

    report = classification_report(y_te, y_test_pred, output_dict=True, zero_division=0)
    cm     = confusion_matrix(y_te, y_test_pred)

    row = {
        "model":            model_name,
        "capacity_tag":     capacity_tag,
        "test_accuracy":    float(accuracy_score(y_te, y_test_pred)),
        "kappa":            float(cohen_kappa_score(y_te, y_test_pred)),
        "macro_f1":         float(f1_score(y_te, y_test_pred, average="macro")),
        "weighted_f1":      float(f1_score(y_te, y_test_pred, average="weighted")),
        "val_nll":          float(log_loss(y_eval, y_eval_prob, labels=np.arange(num_classes))),
        "test_nll":         float(log_loss(y_te,   y_test_prob, labels=np.arange(num_classes))),
        "val_brier":        multiclass_brier_score(y_eval_cat, y_eval_prob),
        "test_brier":       multiclass_brier_score(y_te_cat,   y_test_prob),
        "test_ece_15bin":   expected_calibration_error(y_te, y_test_prob, n_bins=15),
        "epochs_configured": int(EPOCHS),
        "epochs_ran":       epochs_ran,
        "train_time_sec":   train_time_sec,
        "best_model_path":  str(best_path),
        "final_model_path": str(final_path),
    }
    return row, report, cm, history_obj.history

# %% [markdown]
# # 6.0 — Model Training
# Build factory lambdas, then loop over all three architectures. OOM errors on GFNet and ViT automatically retry with reduced fallback configs.

# %%
def build_gfnet_with_cfg(cfg):
    """Instantiate GFNet from a config dict."""
    return build_gfnet(
        input_shape, num_classes,
        inner_patch=INNER_PATCH,
        hidden_dim=cfg["hidden_dim"],
        num_blocks=cfg["num_blocks"],
        mlp_ratio=cfg["mlp_ratio"],
        dropout_rate=DROPOUT_RATE,
    )


def build_vit_with_cfg(cfg):
    """Instantiate ViT-UNet from a config dict."""
    return build_vit_unet_singlehead(
        input_shape, num_classes,
        inner_patch=INNER_PATCH,
        projection_dim=cfg["projection_dim"],
        num_heads=cfg["num_heads"],
        transformer_layers=cfg["transformer_layers"],
        mlp_multiplier=cfg["mlp_multiplier"],
        dropout_rate=DROPOUT_RATE,
        head_units=tuple(cfg["head_units"]),
    )


model_builders = {
    "AlexNet_CNN": lambda: build_alexnet(input_shape, num_classes,
                                         dropout_rate=DROPOUT_RATE, cfg=ALEXNET_CFG),
    "GFNet":       lambda: build_gfnet_with_cfg(GFNET_CFG),
    "ViT_UNet":    lambda: build_vit_with_cfg(VIT_CFG),
}

# %%
results_rows   = []
model_artifacts = {}

for model_name, builder in model_builders.items():
    print(f"\n{'=' * 25} Training {model_name} ({CAPACITY_PRESET}) {'=' * 25}")

    try:
        row, report, cm, history = train_save_evaluate(model_name, builder,
                                                       capacity_tag=CAPACITY_PRESET)
    except tf.errors.ResourceExhaustedError:
        # Automatically retry with a smaller fallback config to handle Colab OOM
        if model_name == "GFNet":
            print("OOM on GFNet legacy config. Retrying with fallback config.")
            tf.keras.backend.clear_session()
            row, report, cm, history = train_save_evaluate(
                model_name, lambda: build_gfnet_with_cfg(GFNET_FALLBACK_CFG),
                capacity_tag="fallback",
            )
        elif model_name == "ViT_UNet":
            print("OOM on ViT_UNet legacy config. Retrying with fallback config.")
            tf.keras.backend.clear_session()
            row, report, cm, history = train_save_evaluate(
                model_name, lambda: build_vit_with_cfg(VIT_FALLBACK_CFG),
                capacity_tag="fallback",
            )
        else:
            raise

    results_rows.append(row)
    model_artifacts[model_name] = {"report": report, "confusion_matrix": cm, "history": history}

summary_df = (
    pd.DataFrame(results_rows)
    .sort_values("test_accuracy", ascending=False)
    .reset_index(drop=True)
)
summary_df
# Out:
# ========================= Training AlexNet_CNN (legacy_arch) =========================
# Epoch 1/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.3766 - loss: 1.9127
# Epoch 1: val_accuracy improved from None to 0.42413, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 37s 192ms/step - accuracy: 0.4153 - loss: 1.8307 - val_accuracy: 0.4241 - val_loss: 1.6149 - learning_rate: 0.0200
# Epoch 2/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4276 - loss: 1.4975
# Epoch 2: val_accuracy improved from 0.42413 to 0.56079, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.4730 - loss: 1.4044 - val_accuracy: 0.5608 - val_loss: 1.2625 - learning_rate: 0.0200
# Epoch 3/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5562 - loss: 1.2532
# Epoch 3: val_accuracy improved from 0.56079 to 0.59814, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.5620 - loss: 1.2201 - val_accuracy: 0.5981 - val_loss: 1.1083 - learning_rate: 0.0200
# Epoch 4/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5743 - loss: 1.1688
# Epoch 4: val_accuracy improved from 0.59814 to 0.60418, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.5794 - loss: 1.1399 - val_accuracy: 0.6042 - val_loss: 1.0509 - learning_rate: 0.0200
# Epoch 5/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5863 - loss: 1.1040
# Epoch 5: val_accuracy improved from 0.60418 to 0.61090, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.5959 - loss: 1.0794 - val_accuracy: 0.6109 - val_loss: 1.0411 - learning_rate: 0.0199
# Epoch 6/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6012 - loss: 1.0526
# Epoch 6: val_accuracy improved from 0.61090 to 0.63619, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.6088 - loss: 1.0346 - val_accuracy: 0.6362 - val_loss: 0.9841 - learning_rate: 0.0199
# Epoch 7/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6187 - loss: 1.0201
# Epoch 7: val_accuracy did not improve from 0.63619
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.6241 - loss: 1.0018 - val_accuracy: 0.6290 - val_loss: 1.0639 - learning_rate: 0.0199
# Epoch 8/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6360 - loss: 0.9931
# Epoch 8: val_accuracy improved from 0.63619 to 0.67193, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.6461 - loss: 0.9746 - val_accuracy: 0.6719 - val_loss: 0.9676 - learning_rate: 0.0198
# Epoch 9/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6619 - loss: 0.9646
# Epoch 9: val_accuracy did not improve from 0.67193
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.6718 - loss: 0.9483 - val_accuracy: 0.6703 - val_loss: 0.9650 - learning_rate: 0.0198
# Epoch 10/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6923 - loss: 0.9270
# Epoch 10: val_accuracy improved from 0.67193 to 0.69490, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 119ms/step - accuracy: 0.7017 - loss: 0.9050 - val_accuracy: 0.6949 - val_loss: 0.9141 - learning_rate: 0.0197
# Epoch 11/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7190 - loss: 0.8965
# Epoch 11: val_accuracy improved from 0.69490 to 0.75383, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.7265 - loss: 0.8716 - val_accuracy: 0.7538 - val_loss: 0.8324 - learning_rate: 0.0196
# Epoch 12/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7308 - loss: 0.8640
# Epoch 12: val_accuracy did not improve from 0.75383
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.7387 - loss: 0.8386 - val_accuracy: 0.7311 - val_loss: 0.8517 - learning_rate: 0.0195
# Epoch 13/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7507 - loss: 0.8255
# Epoch 13: val_accuracy did not improve from 0.75383
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7546 - loss: 0.8025 - val_accuracy: 0.7490 - val_loss: 0.8028 - learning_rate: 0.0195
# Epoch 14/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7614 - loss: 0.7924
# Epoch 14: val_accuracy did not improve from 0.75383
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.7651 - loss: 0.7723 - val_accuracy: 0.7506 - val_loss: 0.7871 - learning_rate: 0.0194
# Epoch 15/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7720 - loss: 0.7642
# Epoch 15: val_accuracy improved from 0.75383 to 0.79165, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 15: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 84ms/step - accuracy: 0.7750 - loss: 0.7468 - val_accuracy: 0.7916 - val_loss: 0.7120 - learning_rate: 0.0193
# Epoch 16/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7861 - loss: 0.7351
# Epoch 16: val_accuracy improved from 0.79165 to 0.80626, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.7899 - loss: 0.7138 - val_accuracy: 0.8063 - val_loss: 0.6724 - learning_rate: 0.0192
# Epoch 17/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7931 - loss: 0.7076
# Epoch 17: val_accuracy did not improve from 0.80626
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8012 - loss: 0.6813 - val_accuracy: 0.7791 - val_loss: 0.7646 - learning_rate: 0.0191
# Epoch 18/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8074 - loss: 0.6745
# Epoch 18: val_accuracy improved from 0.80626 to 0.81717, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 18: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 17s 133ms/step - accuracy: 0.8131 - loss: 0.6482 - val_accuracy: 0.8172 - val_loss: 0.6137 - learning_rate: 0.0189
# Epoch 19/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8119 - loss: 0.6428
# Epoch 19: val_accuracy improved from 0.81717 to 0.84942, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 19: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 18s 109ms/step - accuracy: 0.8201 - loss: 0.6127 - val_accuracy: 0.8494 - val_loss: 0.5349 - learning_rate: 0.0188
# Epoch 20/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8268 - loss: 0.6104
# Epoch 20: val_accuracy did not improve from 0.84942
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8325 - loss: 0.5885 - val_accuracy: 0.8276 - val_loss: 0.6155 - learning_rate: 0.0187
# Epoch 21/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8356 - loss: 0.5801
# Epoch 21: val_accuracy improved from 0.84942 to 0.85638, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 21: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 106ms/step - accuracy: 0.8437 - loss: 0.5561 - val_accuracy: 0.8564 - val_loss: 0.5325 - learning_rate: 0.0185
# Epoch 22/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8413 - loss: 0.5553
# Epoch 22: val_accuracy did not improve from 0.85638
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8500 - loss: 0.5324 - val_accuracy: 0.8429 - val_loss: 0.5640 - learning_rate: 0.0184
# Epoch 23/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8525 - loss: 0.5363
# Epoch 23: val_accuracy improved from 0.85638 to 0.87146, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 23: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.8569 - loss: 0.5099 - val_accuracy: 0.8715 - val_loss: 0.4816 - learning_rate: 0.0182
# Epoch 24/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8591 - loss: 0.5150
# Epoch 24: val_accuracy did not improve from 0.87146
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8648 - loss: 0.4942 - val_accuracy: 0.8566 - val_loss: 0.5131 - learning_rate: 0.0181
# Epoch 25/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8646 - loss: 0.4884
# Epoch 25: val_accuracy improved from 0.87146 to 0.87610, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 25: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 115ms/step - accuracy: 0.8721 - loss: 0.4677 - val_accuracy: 0.8761 - val_loss: 0.4729 - learning_rate: 0.0179
# Epoch 26/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8725 - loss: 0.4738
# Epoch 26: val_accuracy did not improve from 0.87610
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8756 - loss: 0.4542 - val_accuracy: 0.8617 - val_loss: 0.4922 - learning_rate: 0.0178
# Epoch 27/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8707 - loss: 0.4696
# Epoch 27: val_accuracy improved from 0.87610 to 0.88306, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 27: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 110ms/step - accuracy: 0.8788 - loss: 0.4452 - val_accuracy: 0.8831 - val_loss: 0.4172 - learning_rate: 0.0176
# Epoch 28/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8754 - loss: 0.4429
# Epoch 28: val_accuracy improved from 0.88306 to 0.88585, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 28: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.8810 - loss: 0.4249 - val_accuracy: 0.8858 - val_loss: 0.4332 - learning_rate: 0.0174
# Epoch 29/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8843 - loss: 0.4289
# Epoch 29: val_accuracy did not improve from 0.88585
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8887 - loss: 0.4066 - val_accuracy: 0.8777 - val_loss: 0.4525 - learning_rate: 0.0172
# Epoch 30/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8858 - loss: 0.4187
# Epoch 30: val_accuracy improved from 0.88585 to 0.88840, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 30: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - accuracy: 0.8913 - loss: 0.4017 - val_accuracy: 0.8884 - val_loss: 0.4092 - learning_rate: 0.0170
# Epoch 31/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8894 - loss: 0.4112
# Epoch 31: val_accuracy improved from 0.88840 to 0.90348, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 31: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.8940 - loss: 0.3893 - val_accuracy: 0.9035 - val_loss: 0.3492 - learning_rate: 0.0169
# Epoch 32/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8953 - loss: 0.3848
# Epoch 32: val_accuracy did not improve from 0.90348
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.8991 - loss: 0.3726 - val_accuracy: 0.8937 - val_loss: 0.3750 - learning_rate: 0.0167
# Epoch 33/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8956 - loss: 0.3777
# Epoch 33: val_accuracy did not improve from 0.90348
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.8999 - loss: 0.3649 - val_accuracy: 0.8984 - val_loss: 0.3676 - learning_rate: 0.0165
# Epoch 34/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9007 - loss: 0.3615
# Epoch 34: val_accuracy improved from 0.90348 to 0.90974, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 34: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 92ms/step - accuracy: 0.9033 - loss: 0.3498 - val_accuracy: 0.9097 - val_loss: 0.3202 - learning_rate: 0.0162
# Epoch 35/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9014 - loss: 0.3533
# Epoch 35: val_accuracy did not improve from 0.90974
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9058 - loss: 0.3401 - val_accuracy: 0.9042 - val_loss: 0.3449 - learning_rate: 0.0160
# Epoch 36/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9079 - loss: 0.3326
# Epoch 36: val_accuracy improved from 0.90974 to 0.91624, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 36: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 115ms/step - accuracy: 0.9104 - loss: 0.3288 - val_accuracy: 0.9162 - val_loss: 0.2997 - learning_rate: 0.0158
# Epoch 37/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9070 - loss: 0.3261
# Epoch 37: val_accuracy did not improve from 0.91624
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 16s 73ms/step - accuracy: 0.9097 - loss: 0.3239 - val_accuracy: 0.9056 - val_loss: 0.3201 - learning_rate: 0.0156
# Epoch 38/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9070 - loss: 0.3266
# Epoch 38: val_accuracy did not improve from 0.91624
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9119 - loss: 0.3171 - val_accuracy: 0.9151 - val_loss: 0.3132 - learning_rate: 0.0154
# Epoch 39/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9100 - loss: 0.3196
# Epoch 39: val_accuracy did not improve from 0.91624
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9147 - loss: 0.3073 - val_accuracy: 0.9130 - val_loss: 0.2950 - learning_rate: 0.0152
# Epoch 40/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9140 - loss: 0.3116
# Epoch 40: val_accuracy did not improve from 0.91624
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9170 - loss: 0.2992 - val_accuracy: 0.9155 - val_loss: 0.2992 - learning_rate: 0.0150
# Epoch 41/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9182 - loss: 0.2945
# Epoch 41: val_accuracy improved from 0.91624 to 0.91671, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 41: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9193 - loss: 0.2904 - val_accuracy: 0.9167 - val_loss: 0.2872 - learning_rate: 0.0147
# Epoch 42/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9180 - loss: 0.2940
# Epoch 42: val_accuracy did not improve from 0.91671
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9196 - loss: 0.2893 - val_accuracy: 0.9125 - val_loss: 0.3212 - learning_rate: 0.0145
# Epoch 43/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9188 - loss: 0.2868
# Epoch 43: val_accuracy improved from 0.91671 to 0.92552, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 43: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 117ms/step - accuracy: 0.9230 - loss: 0.2766 - val_accuracy: 0.9255 - val_loss: 0.2534 - learning_rate: 0.0143
# Epoch 44/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9229 - loss: 0.2698
# Epoch 44: val_accuracy did not improve from 0.92552
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9237 - loss: 0.2684 - val_accuracy: 0.9220 - val_loss: 0.2725 - learning_rate: 0.0140
# Epoch 45/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9256 - loss: 0.2671
# Epoch 45: val_accuracy did not improve from 0.92552
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9268 - loss: 0.2611 - val_accuracy: 0.9209 - val_loss: 0.2758 - learning_rate: 0.0138
# Epoch 46/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9252 - loss: 0.2643
# Epoch 46: val_accuracy improved from 0.92552 to 0.92947, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 46: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 15s 147ms/step - accuracy: 0.9288 - loss: 0.2525 - val_accuracy: 0.9295 - val_loss: 0.2437 - learning_rate: 0.0136
# Epoch 47/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9265 - loss: 0.2572
# Epoch 47: val_accuracy did not improve from 0.92947
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9296 - loss: 0.2495 - val_accuracy: 0.9290 - val_loss: 0.2404 - learning_rate: 0.0133
# Epoch 48/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9294 - loss: 0.2444
# Epoch 48: val_accuracy improved from 0.92947 to 0.93086, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 48: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 113ms/step - accuracy: 0.9312 - loss: 0.2410 - val_accuracy: 0.9309 - val_loss: 0.2318 - learning_rate: 0.0131
# Epoch 49/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9278 - loss: 0.2446
# Epoch 49: val_accuracy did not improve from 0.93086
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9309 - loss: 0.2372 - val_accuracy: 0.9306 - val_loss: 0.2278 - learning_rate: 0.0129
# Epoch 50/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9280 - loss: 0.2461
# Epoch 50: val_accuracy improved from 0.93086 to 0.93155, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 50: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 108ms/step - accuracy: 0.9310 - loss: 0.2372 - val_accuracy: 0.9316 - val_loss: 0.2298 - learning_rate: 0.0126
# Epoch 51/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9322 - loss: 0.2347
# Epoch 51: val_accuracy improved from 0.93155 to 0.93480, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 51: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9344 - loss: 0.2286 - val_accuracy: 0.9348 - val_loss: 0.2197 - learning_rate: 0.0124
# Epoch 52/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9304 - loss: 0.2360
# Epoch 52: val_accuracy improved from 0.93480 to 0.93666, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 52: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.9340 - loss: 0.2270 - val_accuracy: 0.9367 - val_loss: 0.2011 - learning_rate: 0.0121
# Epoch 53/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9339 - loss: 0.2206
# Epoch 53: val_accuracy did not improve from 0.93666
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9359 - loss: 0.2161 - val_accuracy: 0.9343 - val_loss: 0.2223 - learning_rate: 0.0119
# Epoch 54/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9326 - loss: 0.2239
# Epoch 54: val_accuracy did not improve from 0.93666
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9362 - loss: 0.2141 - val_accuracy: 0.9251 - val_loss: 0.2799 - learning_rate: 0.0117
# Epoch 55/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9341 - loss: 0.2195
# Epoch 55: val_accuracy did not improve from 0.93666
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9362 - loss: 0.2128 - val_accuracy: 0.9348 - val_loss: 0.2115 - learning_rate: 0.0114
# Epoch 56/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9339 - loss: 0.2174
# Epoch 56: val_accuracy improved from 0.93666 to 0.94014, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 56: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.9379 - loss: 0.2070 - val_accuracy: 0.9401 - val_loss: 0.1924 - learning_rate: 0.0112
# Epoch 57/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9355 - loss: 0.2091
# Epoch 57: val_accuracy did not improve from 0.94014
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9385 - loss: 0.2019 - val_accuracy: 0.9350 - val_loss: 0.2112 - learning_rate: 0.0110
# Epoch 58/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9358 - loss: 0.2086
# Epoch 58: val_accuracy did not improve from 0.94014
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9391 - loss: 0.1999 - val_accuracy: 0.9387 - val_loss: 0.1885 - learning_rate: 0.0107
# Epoch 59/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9361 - loss: 0.2050
# Epoch 59: val_accuracy did not improve from 0.94014
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9402 - loss: 0.1931 - val_accuracy: 0.9383 - val_loss: 0.1998 - learning_rate: 0.0105
# Epoch 60/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9359 - loss: 0.2038
# Epoch 60: val_accuracy improved from 0.94014 to 0.94037, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 60: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 96ms/step - accuracy: 0.9397 - loss: 0.1961 - val_accuracy: 0.9404 - val_loss: 0.1889 - learning_rate: 0.0103
# Epoch 61/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9388 - loss: 0.1901
# Epoch 61: val_accuracy did not improve from 0.94037
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9408 - loss: 0.1860 - val_accuracy: 0.9339 - val_loss: 0.2158 - learning_rate: 0.0100
# Epoch 62/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9360 - loss: 0.2011
# Epoch 62: val_accuracy did not improve from 0.94037
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.9398 - loss: 0.1900 - val_accuracy: 0.9394 - val_loss: 0.1828 - learning_rate: 0.0098
# Epoch 63/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9383 - loss: 0.1913
# Epoch 63: val_accuracy did not improve from 0.94037
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9409 - loss: 0.1847 - val_accuracy: 0.9346 - val_loss: 0.2164 - learning_rate: 0.0096
# Epoch 64/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9391 - loss: 0.1874
# Epoch 64: val_accuracy did not improve from 0.94037
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9424 - loss: 0.1799 - val_accuracy: 0.9390 - val_loss: 0.1899 - learning_rate: 0.0094
# Epoch 65/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9397 - loss: 0.1871
# Epoch 65: val_accuracy did not improve from 0.94037
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9419 - loss: 0.1778 - val_accuracy: 0.9399 - val_loss: 0.1799 - learning_rate: 0.0092
# Epoch 66/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9403 - loss: 0.1809
# Epoch 66: val_accuracy did not improve from 0.94037
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9429 - loss: 0.1746 - val_accuracy: 0.9399 - val_loss: 0.1791 - learning_rate: 0.0090
# Epoch 67/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9414 - loss: 0.1766
# Epoch 67: val_accuracy improved from 0.94037 to 0.94084, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 67: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.9432 - loss: 0.1706 - val_accuracy: 0.9408 - val_loss: 0.1789 - learning_rate: 0.0088
# Epoch 68/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9403 - loss: 0.1797
# Epoch 68: val_accuracy improved from 0.94084 to 0.94176, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 68: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - accuracy: 0.9438 - loss: 0.1696 - val_accuracy: 0.9418 - val_loss: 0.1735 - learning_rate: 0.0085
# Epoch 69/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9410 - loss: 0.1764
# Epoch 69: val_accuracy did not improve from 0.94176
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9438 - loss: 0.1682 - val_accuracy: 0.9406 - val_loss: 0.1811 - learning_rate: 0.0083
# Epoch 70/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9423 - loss: 0.1754
# Epoch 70: val_accuracy did not improve from 0.94176
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9447 - loss: 0.1659 - val_accuracy: 0.9401 - val_loss: 0.1755 - learning_rate: 0.0081
# Epoch 71/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9414 - loss: 0.1704
# Epoch 71: val_accuracy did not improve from 0.94176
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9442 - loss: 0.1628 - val_accuracy: 0.9415 - val_loss: 0.1785 - learning_rate: 0.0080
# Epoch 72/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9416 - loss: 0.1716
# Epoch 72: val_accuracy did not improve from 0.94176
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.9442 - loss: 0.1629 - val_accuracy: 0.9411 - val_loss: 0.1763 - learning_rate: 0.0078
# Epoch 73/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9416 - loss: 0.1705
# Epoch 73: val_accuracy did not improve from 0.94176
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9449 - loss: 0.1587 - val_accuracy: 0.9404 - val_loss: 0.1753 - learning_rate: 0.0076
# Epoch 74/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9414 - loss: 0.1674
# Epoch 74: val_accuracy did not improve from 0.94176
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9453 - loss: 0.1557 - val_accuracy: 0.9411 - val_loss: 0.1677 - learning_rate: 0.0074
# Epoch 75/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9405 - loss: 0.1663
# Epoch 75: val_accuracy did not improve from 0.94176
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9442 - loss: 0.1588 - val_accuracy: 0.9411 - val_loss: 0.1727 - learning_rate: 0.0072
# Epoch 76/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9431 - loss: 0.1623
# Epoch 76: val_accuracy improved from 0.94176 to 0.94292, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 76: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 84ms/step - accuracy: 0.9462 - loss: 0.1551 - val_accuracy: 0.9429 - val_loss: 0.1719 - learning_rate: 0.0071
# Epoch 77/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9430 - loss: 0.1615
# Epoch 77: val_accuracy did not improve from 0.94292
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9459 - loss: 0.1532 - val_accuracy: 0.9429 - val_loss: 0.1653 - learning_rate: 0.0069
# Epoch 78/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9437 - loss: 0.1572
# Epoch 78: val_accuracy did not improve from 0.94292
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9466 - loss: 0.1500 - val_accuracy: 0.9429 - val_loss: 0.1624 - learning_rate: 0.0068
# Epoch 79/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9436 - loss: 0.1599
# Epoch 79: val_accuracy improved from 0.94292 to 0.94478, saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
#
# Epoch 79: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 82ms/step - accuracy: 0.9456 - loss: 0.1537 - val_accuracy: 0.9448 - val_loss: 0.1611 - learning_rate: 0.0066
# Epoch 80/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9437 - loss: 0.1567
# Epoch 80: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9464 - loss: 0.1497 - val_accuracy: 0.9418 - val_loss: 0.1644 - learning_rate: 0.0065
# Epoch 81/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9447 - loss: 0.1533
# Epoch 81: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9469 - loss: 0.1480 - val_accuracy: 0.9394 - val_loss: 0.1772 - learning_rate: 0.0063
# Epoch 82/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9440 - loss: 0.1553
# Epoch 82: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9466 - loss: 0.1483 - val_accuracy: 0.9420 - val_loss: 0.1659 - learning_rate: 0.0062
# Epoch 83/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9442 - loss: 0.1538
# Epoch 83: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.9469 - loss: 0.1474 - val_accuracy: 0.9415 - val_loss: 0.1635 - learning_rate: 0.0061
# Epoch 84/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9447 - loss: 0.1534
# Epoch 84: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9466 - loss: 0.1477 - val_accuracy: 0.9411 - val_loss: 0.1711 - learning_rate: 0.0059
# Epoch 85/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9439 - loss: 0.1534
# Epoch 85: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9464 - loss: 0.1474 - val_accuracy: 0.9420 - val_loss: 0.1689 - learning_rate: 0.0058
# Epoch 86/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9446 - loss: 0.1536
# Epoch 86: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9466 - loss: 0.1462 - val_accuracy: 0.9406 - val_loss: 0.1749 - learning_rate: 0.0057
# Epoch 87/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9449 - loss: 0.1538
# Epoch 87: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9471 - loss: 0.1463 - val_accuracy: 0.9411 - val_loss: 0.1688 - learning_rate: 0.0056
# Epoch 88/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9447 - loss: 0.1499
# Epoch 88: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9469 - loss: 0.1444 - val_accuracy: 0.9422 - val_loss: 0.1647 - learning_rate: 0.0055
# Epoch 89/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9436 - loss: 0.1527
# Epoch 89: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9465 - loss: 0.1467 - val_accuracy: 0.9418 - val_loss: 0.1591 - learning_rate: 0.0055
# Epoch 90/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9441 - loss: 0.1559
# Epoch 90: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9465 - loss: 0.1494 - val_accuracy: 0.9408 - val_loss: 0.1734 - learning_rate: 0.0054
# Epoch 91/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9447 - loss: 0.1491
# Epoch 91: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9473 - loss: 0.1452 - val_accuracy: 0.9422 - val_loss: 0.1638 - learning_rate: 0.0053
# Epoch 92/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9449 - loss: 0.1500
# Epoch 92: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.9471 - loss: 0.1443 - val_accuracy: 0.9420 - val_loss: 0.1606 - learning_rate: 0.0052
# Epoch 93/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9462 - loss: 0.1452
# Epoch 93: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9479 - loss: 0.1414 - val_accuracy: 0.9418 - val_loss: 0.1617 - learning_rate: 0.0052
# Epoch 94/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9452 - loss: 0.1502
# Epoch 94: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.9476 - loss: 0.1438 - val_accuracy: 0.9422 - val_loss: 0.1640 - learning_rate: 0.0051
# Epoch 95/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9461 - loss: 0.1451
# Epoch 95: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9474 - loss: 0.1435 - val_accuracy: 0.9415 - val_loss: 0.1670 - learning_rate: 0.0051
# Epoch 96/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9451 - loss: 0.1474
# Epoch 96: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9473 - loss: 0.1433 - val_accuracy: 0.9432 - val_loss: 0.1559 - learning_rate: 0.0051
# Epoch 97/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9443 - loss: 0.1479
# Epoch 97: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9469 - loss: 0.1440 - val_accuracy: 0.9394 - val_loss: 0.1760 - learning_rate: 0.0050
# Epoch 98/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9453 - loss: 0.1484
# Epoch 98: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9469 - loss: 0.1443 - val_accuracy: 0.9415 - val_loss: 0.1744 - learning_rate: 0.0050
# Epoch 99/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9457 - loss: 0.1475
# Epoch 99: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9477 - loss: 0.1423 - val_accuracy: 0.9422 - val_loss: 0.1615 - learning_rate: 0.0050
# Epoch 100/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9457 - loss: 0.1475
# Epoch 100: val_accuracy did not improve from 0.94478
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9476 - loss: 0.1426 - val_accuracy: 0.9429 - val_loss: 0.1563 - learning_rate: 0.0050
# AlexNet_CNN completed full training: 100/100 epochs.
#
# ========================= Training GFNet (legacy_arch) =========================
# Epoch 1/100
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.5109 - loss: 1.3005
# Epoch 1: val_loss improved from None to 0.81839, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 69s 420ms/step - accuracy: 0.5881 - loss: 1.1272 - val_accuracy: 0.7138 - val_loss: 0.8184
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7264 - loss: 0.8346
# Epoch 2: val_loss improved from 0.81839 to 0.62156, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - accuracy: 0.7510 - loss: 0.7811 - val_accuracy: 0.8113 - val_loss: 0.6216
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8219 - loss: 0.6460
# Epoch 3: val_loss improved from 0.62156 to 0.58976, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.8258 - loss: 0.6381 - val_accuracy: 0.8194 - val_loss: 0.5898
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8340 - loss: 0.6044
# Epoch 4: val_loss improved from 0.58976 to 0.49659, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - accuracy: 0.8438 - loss: 0.5830 - val_accuracy: 0.8755 - val_loss: 0.4966
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8820 - loss: 0.5078
# Epoch 5: val_loss improved from 0.49659 to 0.42633, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - accuracy: 0.8796 - loss: 0.5059 - val_accuracy: 0.8948 - val_loss: 0.4263
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8911 - loss: 0.4730
# Epoch 6: val_loss improved from 0.42633 to 0.40172, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 97ms/step - accuracy: 0.8880 - loss: 0.4776 - val_accuracy: 0.9107 - val_loss: 0.4017
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9066 - loss: 0.4351
# Epoch 7: val_loss improved from 0.40172 to 0.35853, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9023 - loss: 0.4395 - val_accuracy: 0.9234 - val_loss: 0.3585
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9237 - loss: 0.3934
# Epoch 8: val_loss did not improve from 0.35853
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9199 - loss: 0.3995 - val_accuracy: 0.9099 - val_loss: 0.3688
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9273 - loss: 0.3766
# Epoch 9: val_loss improved from 0.35853 to 0.33508, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - accuracy: 0.9262 - loss: 0.3780 - val_accuracy: 0.9254 - val_loss: 0.3351
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9311 - loss: 0.3510
# Epoch 10: val_loss improved from 0.33508 to 0.27675, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.9295 - loss: 0.3521 - val_accuracy: 0.9505 - val_loss: 0.2767
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9418 - loss: 0.3293
# Epoch 11: val_loss did not improve from 0.27675
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9380 - loss: 0.3320 - val_accuracy: 0.9424 - val_loss: 0.2914
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9405 - loss: 0.3165
# Epoch 12: val_loss improved from 0.27675 to 0.24076, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - accuracy: 0.9430 - loss: 0.3108 - val_accuracy: 0.9606 - val_loss: 0.2408
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9482 - loss: 0.2943
# Epoch 13: val_loss improved from 0.24076 to 0.22255, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 13: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 97ms/step - accuracy: 0.9460 - loss: 0.3003 - val_accuracy: 0.9667 - val_loss: 0.2225
# Epoch 14/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9581 - loss: 0.2671
# Epoch 14: val_loss did not improve from 0.22255
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.9589 - loss: 0.2660 - val_accuracy: 0.9629 - val_loss: 0.2234
# Epoch 15/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9581 - loss: 0.2500
# Epoch 15: val_loss improved from 0.22255 to 0.20424, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 15: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - accuracy: 0.9607 - loss: 0.2469 - val_accuracy: 0.9679 - val_loss: 0.2042
# Epoch 16/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9691 - loss: 0.2342
# Epoch 16: val_loss improved from 0.20424 to 0.17638, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 98ms/step - accuracy: 0.9668 - loss: 0.2355 - val_accuracy: 0.9756 - val_loss: 0.1764
# Epoch 17/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9727 - loss: 0.2257
# Epoch 17: val_loss did not improve from 0.17638
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - accuracy: 0.9734 - loss: 0.2181 - val_accuracy: 0.9695 - val_loss: 0.1927
# Epoch 18/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9677 - loss: 0.2331
# Epoch 18: val_loss did not improve from 0.17638
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9699 - loss: 0.2273 - val_accuracy: 0.9760 - val_loss: 0.1778
# Epoch 19/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9762 - loss: 0.2056
# Epoch 19: val_loss improved from 0.17638 to 0.15499, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 19: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 99ms/step - accuracy: 0.9781 - loss: 0.2001 - val_accuracy: 0.9845 - val_loss: 0.1550
# Epoch 20/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9830 - loss: 0.1836
# Epoch 20: val_loss did not improve from 0.15499
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.9805 - loss: 0.1900 - val_accuracy: 0.9803 - val_loss: 0.1552
# Epoch 21/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9780 - loss: 0.1898
# Epoch 21: val_loss did not improve from 0.15499
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9805 - loss: 0.1871 - val_accuracy: 0.9822 - val_loss: 0.1598
# Epoch 22/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9790 - loss: 0.1872
# Epoch 22: val_loss improved from 0.15499 to 0.14464, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 22: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 103ms/step - accuracy: 0.9803 - loss: 0.1839 - val_accuracy: 0.9841 - val_loss: 0.1446
# Epoch 23/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9870 - loss: 0.1652
# Epoch 23: val_loss did not improve from 0.14464
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - accuracy: 0.9844 - loss: 0.1724 - val_accuracy: 0.9811 - val_loss: 0.1539
# Epoch 24/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9822 - loss: 0.1749
# Epoch 24: val_loss improved from 0.14464 to 0.12142, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 24: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 0.9826 - loss: 0.1753 - val_accuracy: 0.9884 - val_loss: 0.1214
# Epoch 25/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9917 - loss: 0.1477
# Epoch 25: val_loss improved from 0.12142 to 0.11353, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 25: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 100ms/step - accuracy: 0.9899 - loss: 0.1496 - val_accuracy: 0.9919 - val_loss: 0.1135
# Epoch 26/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9905 - loss: 0.1456
# Epoch 26: val_loss improved from 0.11353 to 0.10882, saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
#
# Epoch 26: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 129ms/step - accuracy: 0.9896 - loss: 0.1474 - val_accuracy: 0.9938 - val_loss: 0.1088
# Epoch 27/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9925 - loss: 0.1370
# Epoch 27: val_loss did not improve from 0.10882
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 92ms/step - accuracy: 0.9902 - loss: 0.1413 - val_accuracy: 0.9853 - val_loss: 0.1281
# Epoch 28/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9873 - loss: 0.1509
# Epoch 28: val_loss did not improve from 0.10882
# ...
# Epoch 50: val_loss did not improve from 0.10355
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 164ms/step - accuracy: 0.9873 - loss: 0.0821 - val_accuracy: 0.9814 - val_loss: 0.1125
# Epoch 51/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9865 - loss: 0.0924
# Epoch 51: val_loss did not improve from 0.10355
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9860 - loss: 0.0928 - val_accuracy: 0.9807 - val_loss: 0.1223
# Epoch 52/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9896 - loss: 0.0719
# Epoch 52: val_loss did not improve from 0.10355
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 165ms/step - accuracy: 0.9891 - loss: 0.0721 - val_accuracy: 0.9814 - val_loss: 0.1043
# Epoch 53/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9827 - loss: 0.1104
# Epoch 53: val_loss improved from 0.10355 to 0.10253, saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
#
# Epoch 53: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 183ms/step - accuracy: 0.9841 - loss: 0.0998 - val_accuracy: 0.9838 - val_loss: 0.1025
# Epoch 54/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9901 - loss: 0.0645
# Epoch 54: val_loss improved from 0.10253 to 0.08851, saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
#
# Epoch 54: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 241ms/step - accuracy: 0.9888 - loss: 0.0717 - val_accuracy: 0.9872 - val_loss: 0.0885
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9912 - loss: 0.0628
# Epoch 55: val_loss did not improve from 0.08851
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.9913 - loss: 0.0620 - val_accuracy: 0.9841 - val_loss: 0.0972
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9911 - loss: 0.0665
# Epoch 56: val_loss improved from 0.08851 to 0.08297, saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
#
# Epoch 56: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 183ms/step - accuracy: 0.9906 - loss: 0.0659 - val_accuracy: 0.9857 - val_loss: 0.0830
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9899 - loss: 0.0662
# Epoch 57: val_loss improved from 0.08297 to 0.07679, saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
#
# Epoch 57: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 231ms/step - accuracy: 0.9906 - loss: 0.0634 - val_accuracy: 0.9903 - val_loss: 0.0768
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9918 - loss: 0.0600
# Epoch 58: val_loss did not improve from 0.07679
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step - accuracy: 0.9908 - loss: 0.0625 - val_accuracy: 0.9826 - val_loss: 0.1080
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9928 - loss: 0.0527
# Epoch 59: val_loss did not improve from 0.07679
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - accuracy: 0.9911 - loss: 0.0616 - val_accuracy: 0.9838 - val_loss: 0.0975
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9909 - loss: 0.0594
# Epoch 60: val_loss did not improve from 0.07679
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9915 - loss: 0.0588 - val_accuracy: 0.9884 - val_loss: 0.0795
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9949 - loss: 0.0433
# Epoch 61: val_loss did not improve from 0.07679
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.9940 - loss: 0.0490 - val_accuracy: 0.9807 - val_loss: 0.1150
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9916 - loss: 0.0525
# Epoch 62: val_loss improved from 0.07679 to 0.06880, saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
#
# Epoch 62: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9929 - loss: 0.0520 - val_accuracy: 0.9899 - val_loss: 0.0688
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9966 - loss: 0.0356
# Epoch 63: val_loss did not improve from 0.06880
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 162ms/step - accuracy: 0.9946 - loss: 0.0435 - val_accuracy: 0.9838 - val_loss: 0.1110
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9925 - loss: 0.0563
# Epoch 64: val_loss did not improve from 0.06880
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.9932 - loss: 0.0514 - val_accuracy: 0.9880 - val_loss: 0.0865
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9932 - loss: 0.0482
# Epoch 65: val_loss did not improve from 0.06880
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - accuracy: 0.9928 - loss: 0.0492 - val_accuracy: 0.9892 - val_loss: 0.0844
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9944 - loss: 0.0423
# Epoch 66: val_loss did not improve from 0.06880
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.9946 - loss: 0.0430 - val_accuracy: 0.9861 - val_loss: 0.0933
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9958 - loss: 0.0367
# Epoch 67: val_loss did not improve from 0.06880
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - accuracy: 0.9947 - loss: 0.0448 - val_accuracy: 0.9803 - val_loss: 0.1221
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9932 - loss: 0.0451
# Epoch 68: val_loss improved from 0.06880 to 0.06758, saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
#
# Epoch 68: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 183ms/step - accuracy: 0.9944 - loss: 0.0417 - val_accuracy: 0.9903 - val_loss: 0.0676
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9957 - loss: 0.0366
# Epoch 69: val_loss did not improve from 0.06758
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 165ms/step - accuracy: 0.9957 - loss: 0.0369 - val_accuracy: 0.9892 - val_loss: 0.0725
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9953 - loss: 0.0359
# Epoch 70: val_loss did not improve from 0.06758
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 165ms/step - accuracy: 0.9950 - loss: 0.0377 - val_accuracy: 0.9880 - val_loss: 0.0836
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9963 - loss: 0.0305
# Epoch 71: val_loss did not improve from 0.06758
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step - accuracy: 0.9963 - loss: 0.0318 - val_accuracy: 0.9876 - val_loss: 0.0847
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9963 - loss: 0.0317
# Epoch 72: val_loss improved from 0.06758 to 0.06454, saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
#
# Epoch 72: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 176ms/step - accuracy: 0.9964 - loss: 0.0304 - val_accuracy: 0.9919 - val_loss: 0.0645
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9980 - loss: 0.0236
# Epoch 73: val_loss did not improve from 0.06454
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.9970 - loss: 0.0289 - val_accuracy: 0.9892 - val_loss: 0.0759
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9968 - loss: 0.0291
# Epoch 74: val_loss did not improve from 0.06454
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 164ms/step - accuracy: 0.9970 - loss: 0.0284 - val_accuracy: 0.9896 - val_loss: 0.0728
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9978 - loss: 0.0247
# Epoch 75: val_loss did not improve from 0.06454
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step - accuracy: 0.9973 - loss: 0.0267 - val_accuracy: 0.9899 - val_loss: 0.0733
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9975 - loss: 0.0288
# Epoch 76: val_loss did not improve from 0.06454
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - accuracy: 0.9971 - loss: 0.0294 - val_accuracy: 0.9865 - val_loss: 0.0909
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9986 - loss: 0.0203
# Epoch 77: val_loss did not improve from 0.06454
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - accuracy: 0.9977 - loss: 0.0240 - val_accuracy: 0.9899 - val_loss: 0.0815
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9977 - loss: 0.0262
# Epoch 78: val_loss did not improve from 0.06454
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9972 - loss: 0.0291 - val_accuracy: 0.9888 - val_loss: 0.0771
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9984 - loss: 0.0209
# Epoch 79: val_loss did not improve from 0.06454
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step - accuracy: 0.9977 - loss: 0.0244 - val_accuracy: 0.9903 - val_loss: 0.0712
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9986 - loss: 0.0214
# Epoch 80: val_loss did not improve from 0.06454
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9981 - loss: 0.0230 - val_accuracy: 0.9896 - val_loss: 0.0797
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9979 - loss: 0.0258
# Epoch 81: val_loss improved from 0.06454 to 0.06154, saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
#
# Epoch 81: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - accuracy: 0.9981 - loss: 0.0229 - val_accuracy: 0.9915 - val_loss: 0.0615
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9993 - loss: 0.0163
# Epoch 82: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 163ms/step - accuracy: 0.9987 - loss: 0.0191 - val_accuracy: 0.9911 - val_loss: 0.0694
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9990 - loss: 0.0196
# Epoch 83: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 165ms/step - accuracy: 0.9983 - loss: 0.0226 - val_accuracy: 0.9915 - val_loss: 0.0707
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9988 - loss: 0.0179
# Epoch 84: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 161ms/step - accuracy: 0.9983 - loss: 0.0201 - val_accuracy: 0.9915 - val_loss: 0.0672
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9983 - loss: 0.0199
# Epoch 85: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9976 - loss: 0.0233 - val_accuracy: 0.9919 - val_loss: 0.0651
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9992 - loss: 0.0160
# Epoch 86: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9988 - loss: 0.0179 - val_accuracy: 0.9907 - val_loss: 0.0662
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9987 - loss: 0.0185
# Epoch 87: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9983 - loss: 0.0197 - val_accuracy: 0.9911 - val_loss: 0.0665
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9980 - loss: 0.0215
# Epoch 88: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9981 - loss: 0.0222 - val_accuracy: 0.9919 - val_loss: 0.0630
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9988 - loss: 0.0156
# Epoch 89: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9983 - loss: 0.0182 - val_accuracy: 0.9899 - val_loss: 0.0738
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9991 - loss: 0.0154
# Epoch 90: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.9988 - loss: 0.0165 - val_accuracy: 0.9896 - val_loss: 0.0760
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9993 - loss: 0.0146
# Epoch 91: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.9986 - loss: 0.0178 - val_accuracy: 0.9911 - val_loss: 0.0629
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9991 - loss: 0.0147
# Epoch 92: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - accuracy: 0.9986 - loss: 0.0175 - val_accuracy: 0.9896 - val_loss: 0.0727
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9993 - loss: 0.0130
# Epoch 93: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9985 - loss: 0.0172 - val_accuracy: 0.9919 - val_loss: 0.0665
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9994 - loss: 0.0140
# Epoch 94: val_loss did not improve from 0.06154
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9989 - loss: 0.0164 - val_accuracy: 0.9919 - val_loss: 0.0670
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9997 - loss: 0.0150
# Epoch 95: val_loss improved from 0.06154 to 0.05423, saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
#
# Epoch 95: finished saving model to /content/drive/My Drive/Classification/edl_v2/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 178ms/step - accuracy: 0.9989 - loss: 0.0189 - val_accuracy: 0.9934 - val_loss: 0.0542
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9995 - loss: 0.0127
# Epoch 96: val_loss did not improve from 0.05423
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 163ms/step - accuracy: 0.9992 - loss: 0.0143 - val_accuracy: 0.9903 - val_loss: 0.0684
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9998 - loss: 0.0119
# Epoch 97: val_loss did not improve from 0.05423
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 165ms/step - accuracy: 0.9996 - loss: 0.0130 - val_accuracy: 0.9903 - val_loss: 0.0737
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9983 - loss: 0.0160
# Epoch 98: val_loss did not improve from 0.05423
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9985 - loss: 0.0163 - val_accuracy: 0.9911 - val_loss: 0.0731
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9996 - loss: 0.0121
# Epoch 99: val_loss did not improve from 0.05423
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - accuracy: 0.9992 - loss: 0.0141 - val_accuracy: 0.9923 - val_loss: 0.0666
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9994 - loss: 0.0135
# Epoch 100: val_loss did not improve from 0.05423
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - accuracy: 0.9992 - loss: 0.0146 - val_accuracy: 0.9911 - val_loss: 0.0722
# ViT_UNet completed full training: 100/100 epochs.
#          model capacity_tag  test_accuracy     kappa  macro_f1  weighted_f1  \
# 0        GFNet  legacy_arch       0.996752  0.995594  0.995854     0.996746
# 1     ViT_UNet  legacy_arch       0.990719  0.987407  0.986571     0.990700
# 2  AlexNet_CNN  legacy_arch       0.942923  0.920707  0.838325     0.920195
#
#     val_nll  test_nll  val_brier  test_brier  test_ece_15bin  \
# 0  0.034930  0.041098   0.003159    0.006181        0.031866
# 1  0.052730  0.054285   0.016538    0.016895        0.002854
# 2  0.145427  0.145427   0.056300    0.056300        0.026120
#
#    epochs_configured  epochs_ran  train_time_sec  \
# 0                100         100      851.348304
# 1                100         100     1650.075184
# 2                100         100      855.469596
#
#                                      best_model_path  \
# 0  /content/drive/My Drive/Classification/edl_v2/...
# 1  /content/drive/My Drive/Classification/edl_v2/...
# 2  /content/drive/My Drive/Classification/edl_v2/...
#
#                                     final_model_path
# 0  /content/drive/My Drive/Classification/edl_v2/...
# 1  /content/drive/My Drive/Classification/edl_v2/...
# 2  /content/drive/My Drive/Classification/edl_v2/...

# %% [markdown]
# # 7.0 — Results & Metrics
# Save classification summaries to CSV / JSON, then plot training curves, cross-model bar charts, calibration proxies, and confusion matrices.

# %% [markdown]
# ## 7.1 — Save summary CSV and per-model JSON reports

# %%
summary_path = RESULTS_DIR / "classification_summary.csv"
summary_df.to_csv(summary_path, index=False)
print("Saved summary:", summary_path)

for model_name, artifact in model_artifacts.items():
    report_path = RESULTS_DIR / f"{model_name}_classification_report.json"
    with open(report_path, "w", encoding="utf-8") as f:
        json.dump(artifact["report"], f, indent=2)

print("Per-model classification reports saved to:", RESULTS_DIR)
summary_df
# Out:
# Saved summary: /content/drive/My Drive/Classification/edl_v2/results/classification_summary.csv
# Per-model classification reports saved to: /content/drive/My Drive/Classification/edl_v2/results
#          model capacity_tag  test_accuracy     kappa  macro_f1  weighted_f1  \
# 0        GFNet  legacy_arch       0.996752  0.995594  0.995854     0.996746
# 1     ViT_UNet  legacy_arch       0.990719  0.987407  0.986571     0.990700
# 2  AlexNet_CNN  legacy_arch       0.942923  0.920707  0.838325     0.920195
#
#     val_nll  test_nll  val_brier  test_brier  test_ece_15bin  \
# 0  0.034930  0.041098   0.003159    0.006181        0.031866
# 1  0.052730  0.054285   0.016538    0.016895        0.002854
# 2  0.145427  0.145427   0.056300    0.056300        0.026120
#
#    epochs_configured  epochs_ran  train_time_sec  \
# 0                100         100      851.348304
# 1                100         100     1650.075184
# 2                100         100      855.469596
#
#                                      best_model_path  \
# 0  /content/drive/My Drive/Classification/edl_v2/...
# 1  /content/drive/My Drive/Classification/edl_v2/...
# 2  /content/drive/My Drive/Classification/edl_v2/...
#
#                                     final_model_path
# 0  /content/drive/My Drive/Classification/edl_v2/...
# 1  /content/drive/My Drive/Classification/edl_v2/...
# 2  /content/drive/My Drive/Classification/edl_v2/...

# %% [markdown]
# ## 7.2 — Training curves (accuracy and loss per epoch)

# %%
for model_name, artifact in model_artifacts.items():
    hist   = artifact["history"]
    epochs = np.arange(1, len(hist["loss"]) + 1)

    fig, ax1 = plt.subplots(figsize=(12, 5))
    ax1.plot(epochs, hist["accuracy"],     color="#1f77b4", linewidth=2,   label="Train Accuracy")
    ax1.plot(epochs, hist["val_accuracy"], color="#2ca02c", linewidth=2, linestyle="--", label="Val Accuracy")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Accuracy")
    ax1.set_ylim(0, 1.0)
    ax1.grid(True, alpha=0.25)

    ax2 = ax1.twinx()
    ax2.plot(epochs, hist["loss"],     color="#111111", linewidth=1.8,   label="Train Loss")
    ax2.plot(epochs, hist["val_loss"], color="#d62728", linewidth=1.8, linestyle="--", label="Val Loss")
    ax2.set_ylabel("Loss")

    lines  = ax1.get_lines() + ax2.get_lines()
    labels = [ln.get_label() for ln in lines]
    ax1.legend(lines, labels, loc="upper right", frameon=True)
    plt.title(f"{model_name}: Accuracy / Loss vs Epoch")
    plt.tight_layout()

    curve_path = PLOT_DIR / f"{model_name}_training_curves.png"
    plt.savefig(curve_path, dpi=200, bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## 7.3 — Cross-model comparison bar charts

# %%
plot_df = summary_df[[
    "model", "test_accuracy", "macro_f1", "kappa", "train_time_sec",
    "test_nll", "test_brier", "test_ece_15bin",
]].copy()

fig, axes = plt.subplots(2, 2, figsize=(15, 9))
axes    = axes.flatten()
palette = ["#4c72b0", "#55a868", "#c44e52"]

metric_specs = [
    ("test_accuracy",  "Test Accuracy",   (0.0, 1.0), "{:.3f}"),
    ("macro_f1",       "Macro F1",        (0.0, 1.0), "{:.3f}"),
    ("kappa",          "Cohen Kappa",     (0.0, 1.0), "{:.3f}"),
    ("train_time_sec", "Train Time (sec)", None,       "{:.1f}"),
]

for ax, (col, title, ylim, fmt) in zip(axes, metric_specs):
    local = plot_df[["model", col]].copy()
    bars  = ax.bar(local["model"], local[col], color=palette[:len(local)])
    ax.set_title(title)
    ax.set_xlabel("Model")
    ax.set_ylabel(title)
    if ylim is not None:
        ax.set_ylim(*ylim)
    ax.grid(axis="y", alpha=0.25)
    for patch in bars:
        height = patch.get_height()
        xpos   = patch.get_x() + patch.get_width() / 2
        offset = (ylim[1] - ylim[0]) * 0.02 if ylim else max(local[col].max() * 0.02, 0.05)
        ax.text(xpos, height + offset, fmt.format(height), ha="center", va="bottom", fontsize=9)

plt.suptitle("Single-Head Model Comparison", y=1.02, fontsize=14)
plt.tight_layout()
comparison_path = PLOT_DIR / "model_comparison_metrics.png"
plt.savefig(comparison_path, dpi=200, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 7.4 — Calibration proxy metrics and confusion matrices

# %%
# Calibration proxy chart (lower is better for all three metrics)
fig, ax     = plt.subplots(figsize=(12, 5))
calib_cols  = ["test_nll", "test_brier", "test_ece_15bin"]
calib_df    = plot_df[["model"] + calib_cols].set_index("model")
calib_df.plot(kind="bar", ax=ax, rot=0)
ax.set_title("Uncertainty Proxy Metrics (Lower is Better)")
ax.set_ylabel("Metric Value")
ax.grid(axis="y", alpha=0.25)
plt.tight_layout()
calib_path = PLOT_DIR / "uncertainty_proxy_metrics.png"
plt.savefig(calib_path, dpi=200, bbox_inches="tight")
plt.show()

# Side-by-side confusion matrices
class_ticks = [str(i + 1) for i in range(num_classes)]
fig, axes   = plt.subplots(1, len(model_artifacts), figsize=(7 * len(model_artifacts), 5.5))
if len(model_artifacts) == 1:
    axes = [axes]

for ax, (model_name, artifact) in zip(axes, model_artifacts.items()):
    sns.heatmap(
        artifact["confusion_matrix"],
        annot=True, fmt="d", cmap="Blues",
        xticklabels=class_ticks, yticklabels=class_ticks,
        cbar=False, ax=ax,
    )
    ax.set_title(f"{model_name} Confusion Matrix")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("True")

plt.tight_layout()
cm_path = PLOT_DIR / "confusion_matrices_side_by_side.png"
plt.savefig(cm_path, dpi=220, bbox_inches="tight")
plt.show()
print("Saved confusion matrix figure:", cm_path)
print("All training plots saved to:", PLOT_DIR)
# Out:
# Saved confusion matrix figure: /content/drive/My Drive/Classification/edl_v2/results/training_plots/confusion_matrices_side_by_side.png
# All training plots saved to: /content/drive/My Drive/Classification/edl_v2/results/training_plots

# %% [markdown]
# # 8.0 — Scene Visualisation
# Load the saved best models, run dense patch-by-patch inference over the entire scene, and save classified maps as PNGs and an Excel workbook.

# %% [markdown]
# ## 8.1 — Visualisation helpers

# %%
CUSTOM_OBJECTS = {
    "PatchExtractor":      PatchExtractor,
    "PatchPositionEncoder": PatchPositionEncoder,
    "GlobalFilterLayer":   GlobalFilterLayer,
    "PatchEncoderWithCLS": PatchEncoderWithCLS,
}


def get_scene_rgb(x_img, bands):
    """Select three bands as an approximate RGB composite; clip to [0, 1]."""
    if bands >= 6:
        rgb_idx = [bands // 2 - 1, bands // 2, bands // 2 + 1]
    elif bands >= 3:
        rgb_idx = [0, 1, 2]
    else:
        raise ValueError(f"Need at least 3 bands to form RGB, got {bands}.")
    return np.clip(x_img[:, :, rgb_idx], 0.0, 1.0)


def get_display_cmap(num_classes):
    """Build a ListedColormap: index 0 = background black, 1..K = class colours."""
    return ListedColormap([BACKGROUND_COLOR] + CLASS_COLOR_BASE[:num_classes])


def predict_full_scene_labels(model, x_img, patch_size=9, batch_size=256):
    """Run dense sliding-window inference row-by-row; returns a (H, W) label map."""
    pad   = patch_size // 2
    x_pad = np.pad(x_img, ((pad, pad), (pad, pad), (0, 0)), mode="edge")
    preds = np.zeros((x_img.shape[0], x_img.shape[1]), dtype=np.int32)

    for r in range(x_img.shape[0]):
        row_patches = np.empty(
            (x_img.shape[1], patch_size, patch_size, x_img.shape[-1]),
            dtype=np.float32,
        )
        for c in range(x_img.shape[1]):
            row_patches[c] = x_pad[r:r + patch_size, c:c + patch_size, :]

        row_prob  = model.predict(row_patches, batch_size=batch_size, verbose=0)
        preds[r]  = np.argmax(row_prob, axis=1) + 1  # back to 1..K

    return preds


def load_saved_models_for_visualization(model_dir, custom_objects):
    """Attempt to load all three best models; return dicts of loaded and missing."""
    model_files = {
        "AlexNet_CNN": model_dir / "AlexNet_CNN_best.keras",
        "GFNet":       model_dir / "GFNet_best.keras",
        "ViT_UNet":    model_dir / "ViT_UNet_best.keras",
    }
    loaded, missing = {}, {}
    for model_key, model_path in model_files.items():
        if not model_path.exists():
            missing[model_key] = f"Missing file: {model_path}"
            continue
        try:
            loaded[model_key] = keras.models.load_model(
                model_path, custom_objects=custom_objects,
                compile=False, safe_mode=False,
            )
        except Exception as exc:
            missing[model_key] = f"Load failed: {exc}"
    return loaded, missing


def save_single_panel(image, title, save_path, cmap=None, vmin=None, vmax=None):
    """Save a single image panel as a high-DPI PNG."""
    fig, ax = plt.subplots(figsize=(8, 6))
    if cmap is None:
        ax.imshow(image)
    else:
        ax.imshow(image, cmap=cmap, vmin=vmin, vmax=vmax)
    ax.set_title(title, fontsize=14)
    ax.axis("off")
    fig.tight_layout()
    fig.savefig(save_path, dpi=220, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print("Saved:", save_path)


def save_combined_overview(rgb_image, y_true, pred_maps, missing_info, num_classes, save_path):
    """Save a five-panel side-by-side overview: RGB, GT, and one panel per model."""
    cmap   = get_display_cmap(num_classes)
    panels = [
        ("Approximate RGB",             rgb_image,               "rgb"),
        ("True Label Map",              y_true,                  "label"),
        ("AlexNet Initial Classification", pred_maps.get("AlexNet_CNN"), "label"),
        ("GFNet Initial Classification",   pred_maps.get("GFNet"),       "label"),
        ("ViT Initial Classification",     pred_maps.get("ViT_UNet"),    "label"),
    ]

    fig, axes = plt.subplots(1, len(panels), figsize=(30, 7), sharex=True, sharey=True)
    for ax, (title, img, kind) in zip(axes, panels):
        ax.set_title(title, fontsize=13)
        if kind == "rgb":
            ax.imshow(img)
        elif img is None:
            ax.imshow(np.zeros_like(y_true), cmap=cmap, vmin=0, vmax=num_classes)
            key = {"AlexNet": "AlexNet_CNN", "GFNet": "GFNet", "ViT": "ViT_UNet"}.get(
                next((k for k in ("AlexNet", "GFNet", "ViT") if k in title), None)
            )
            ax.text(0.5, 0.5, missing_info.get(key, "Unavailable"),
                    ha="center", va="center", fontsize=10, wrap=True, transform=ax.transAxes)
        else:
            ax.imshow(img, cmap=cmap, vmin=0, vmax=num_classes)
        ax.axis("off")

    handles = [plt.Rectangle((0, 0), 1, 1, color=BACKGROUND_COLOR, label="Background")]
    for i in range(num_classes):
        handles.append(plt.Rectangle((0, 0), 1, 1, color=CLASS_COLOR_BASE[i], label=f"Class {i+1}"))
    fig.legend(handles=handles, loc="lower center", ncol=min(num_classes + 1, 8),
               bbox_to_anchor=(0.5, -0.02), frameon=True)
    fig.tight_layout(rect=[0, 0.05, 1, 1])
    fig.savefig(save_path, dpi=220, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print("Saved:", save_path)


def save_images_to_excel(excel_path, image_paths, sheet_name="Initial_Classification_Maps"):
    """Embed PNG images into an Excel workbook at fixed anchor positions."""
    if excel_path.exists():
        wb = load_workbook(excel_path)
        if sheet_name in wb.sheetnames:
            del wb[sheet_name]
        ws = wb.create_sheet(title=sheet_name)
    else:
        wb = Workbook()
        ws = wb.active
        ws.title = sheet_name

    anchors = ["A1", "J1", "A25", "J25", "A49", "J49"]
    for path, anchor in zip(image_paths, anchors):
        if path.exists():
            img        = XLImage(str(path))
            img.anchor = anchor
            ws.add_image(img)

    wb.save(excel_path)
    print("Saved Excel workbook:", excel_path)

# %% [markdown]
# ## 8.2 — Generate and save all scene maps

# %%
scene_rgb    = get_scene_rgb(x_img, B)
display_cmap = get_display_cmap(num_classes)

loaded_models, missing_models = load_saved_models_for_visualization(MODEL_DIR, CUSTOM_OBJECTS)
prediction_maps = {}

for model_key, loaded_model in loaded_models.items():
    print(f"Generating full-scene classified image for {model_key}...")
    prediction_maps[model_key] = predict_full_scene_labels(
        loaded_model, x_img, patch_size=PATCH_SIZE, batch_size=BATCH_SIZE,
    )
    print(f"{model_key} map shape:", prediction_maps[model_key].shape)

if missing_models:
    print("Some models could not be loaded:")
    for model_key, reason in missing_models.items():
        print(f"  - {model_key}: {reason}")

# Individual PNG paths
rgb_png      = VIS_DIR / "scene_rgb.png"
gt_png       = VIS_DIR / "ground_truth_label_map.png"
alex_png     = VIS_DIR / "AlexNet_CNN_initial_classification.png"
gfnet_png    = VIS_DIR / "GFNet_initial_classification.png"
vit_png      = VIS_DIR / "ViT_UNet_initial_classification.png"
overview_png = VIS_DIR / "combined_initial_classification_overview.png"

save_single_panel(scene_rgb, "Approximate RGB", rgb_png)
save_single_panel(y_img, "Ground Truth Label Map", gt_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("AlexNet_CNN") is not None:
    save_single_panel(prediction_maps["AlexNet_CNN"], "AlexNet Initial Classification",
                      alex_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("GFNet") is not None:
    save_single_panel(prediction_maps["GFNet"], "GFNet Initial Classification",
                      gfnet_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("ViT_UNet") is not None:
    save_single_panel(prediction_maps["ViT_UNet"], "ViT Initial Classification",
                      vit_png, cmap=display_cmap, vmin=0, vmax=num_classes)

save_combined_overview(
    rgb_image=scene_rgb, y_true=y_img, pred_maps=prediction_maps,
    missing_info=missing_models, num_classes=num_classes, save_path=overview_png,
)

image_paths_for_excel = [rgb_png, gt_png, alex_png, gfnet_png, vit_png, overview_png]
save_images_to_excel(VIS_EXCEL_PATH, image_paths_for_excel, sheet_name="Initial_Classification_Maps")

print("All visualisation outputs saved to:", VIS_DIR)
