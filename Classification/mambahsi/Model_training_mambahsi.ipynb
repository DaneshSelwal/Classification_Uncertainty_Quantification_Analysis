# %% [markdown]
# # 1.0 — Setup & Imports
# Mount Google Drive and import all required standard, third-party, and ML libraries.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Standard library
import io
import json
import os
import random
import time
from pathlib import Path

# Third-party – data / viz
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.colors import ListedColormap
from openpyxl import Workbook, load_workbook
from openpyxl.drawing.image import Image as XLImage
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    cohen_kappa_score,
    confusion_matrix,
    f1_score,
    log_loss,
)
from sklearn.model_selection import train_test_split

# TensorFlow / Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers

sns.set_style("whitegrid")
print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# # 2.0 — Configuration
# All hyper-parameters, paths, and architecture configs are defined here. Change values in this single cell to reconfigure the whole notebook.

# %%
# ── Reproducibility ──────────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# ── Paths ─────────────────────────────────────────────────────────────
MODEL_DIR   = Path("/content/drive/My Drive/Classification/mambahsi/models")
RESULTS_DIR = Path("/content/drive/My Drive/Classification/mambahsi/results")
MODEL_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
PLOT_DIR    = RESULTS_DIR / "training_plots"
PLOT_DIR.mkdir(parents=True, exist_ok=True)
VIS_DIR     = RESULTS_DIR / "scene_visualizations"
VIS_DIR.mkdir(parents=True, exist_ok=True)

DATA_DIR   = Path("/content/drive/My Drive/Classification/data")
DATA_FILE  = DATA_DIR / "data.csv"
LABEL_FILE = DATA_DIR / "ref.csv"

# ── Dataset geometry ──────────────────────────────────────────────────
H, W, B    = 330, 307, 6          # height, width, bands
PATCH_SIZE  = 9
INNER_PATCH = 3                   # spatial tokenisation patch size for the SSM token sequence

# ── Train / val / test splits ─────────────────────────────────────────
TRAIN_PERCENT          = 0.75
VAL_SPLIT_FROM_TRAIN   = 0.20

# ── Training ──────────────────────────────────────────────────────────
BATCH_SIZE    = 128
EPOCHS        = 100
LEARNING_RATE = 3e-4
DROPOUT_RATE  = 0.25
CAPACITY_PRESET = "mambahsi_arch"

TRAIN_CFG = {
    "label_smoothing": 0.05,
    "weight_decay":    1e-4,
    "clipnorm":        1.0,
    "cosine_alpha":    0.05,
}

# ── AlexNet legacy recipe — kept verbatim from the original notebook per the
# "copy training loop verbatim" requirement. NOTE: this is now DEAD CODE. None
# of the three MambaHSI variants below is named "AlexNet_CNN", so the
# model_name == "AlexNet_CNN" branch inside train_save_evaluate (Section 5.3)
# never fires and these constants / x_train_alex / _alexnet_legacy_lr are
# unused. Safe to delete if you want a cleaner notebook. ───────────────
ALEXNET_LEGACY_SPLIT_SEED   = 10
ALEXNET_LEGACY_TRAIN_PERCENT = 0.75
ALEXNET_LR_START = 0.01
ALEXNET_LR_MAX   = 0.02
ALEXNET_LR_MIN   = 0.005

# ── Architecture configs ──────────────────────────────────────────────
# MambaHSI-style spatial-spectral state-space model, three capacities.
# Hyperparameter reasoning (dataset: 9x9x6 patches, ~a few thousand labelled
# samples, 7 classes — see markdown note in Section 4.3 for more detail):
#   Small — 2 SSM blocks,  state_dim=64,  hidden_dim=128, mlp_ratio=2
#   Base  — 4 SSM blocks,  state_dim=128, hidden_dim=256, mlp_ratio=4
#   Large — 6 SSM blocks,  state_dim=192, hidden_dim=384, mlp_ratio=4
MAMBAHSI_SMALL_CFG = {"inner_patch": 3, "hidden_dim": 128, "state_dim": 64,  "num_blocks": 2, "mlp_ratio": 2}
MAMBAHSI_BASE_CFG  = {"inner_patch": 3, "hidden_dim": 256, "state_dim": 128, "num_blocks": 4, "mlp_ratio": 4}
MAMBAHSI_LARGE_CFG = {"inner_patch": 3, "hidden_dim": 384, "state_dim": 192, "num_blocks": 6, "mlp_ratio": 4}

# Fallback configs used when Colab runs out of memory (mirrors the original
# GFNET_FALLBACK_CFG / VIT_FALLBACK_CFG pattern — only the two larger variants
# get a fallback, matching how the original small/simple AlexNet backbone
# never needed one).
MAMBAHSI_BASE_FALLBACK_CFG  = {"inner_patch": 3, "hidden_dim": 192, "state_dim": 96,  "num_blocks": 3, "mlp_ratio": 4}
MAMBAHSI_LARGE_FALLBACK_CFG = {"inner_patch": 3, "hidden_dim": 256, "state_dim": 128, "num_blocks": 4, "mlp_ratio": 4}

# ── Visualisation palette ─────────────────────────────────────────────
CLASS_COLOR_BASE = [
    "#0000FF", "#00FF00", "#FF0000", "#00FFFF", "#FF00FF",
    "#FFFF00", "#A52A2A", "#FFA500", "#7FFF00", "#8A2BE2",
]
BACKGROUND_COLOR  = "#000000"
VIS_EXCEL_PATH    = VIS_DIR / "initial_classification_maps.xlsx"

print("Data file:    ", DATA_FILE)
print("Label file:   ", LABEL_FILE)
print("Model dir:    ", MODEL_DIR)
print("Results dir:  ", RESULTS_DIR)
print("Plot dir:     ", PLOT_DIR)
print("Arch preset:  ", CAPACITY_PRESET)
# Out:
# Data file:     /content/drive/My Drive/Classification/data/data.csv
# Label file:    /content/drive/My Drive/Classification/data/ref.csv
# Model dir:     /content/drive/My Drive/Classification/mambahsi/models
# Results dir:   /content/drive/My Drive/Classification/mambahsi/results
# Plot dir:      /content/drive/My Drive/Classification/mambahsi/results/training_plots
# Arch preset:   mambahsi_arch

# %% [markdown]
# # 3.0 — Data Loading & Preprocessing
# Load the raw multispectral CSV files, apply per-band min-max normalisation, extract labelled patches, and create stratified train / val / test splits.

# %% [markdown]
# ## 3.1 — Loading and patch extraction helpers

# %%
def load_multispectral_6band(data_path, label_path, height, width, bands):
    """Load multispectral data and reference labels; normalise each band to [0, 1]."""
    x = pd.read_csv(data_path).to_numpy(dtype=np.float32).reshape(height, width, bands)
    y = pd.read_csv(label_path).to_numpy(dtype=np.int32).reshape(height, width)

    x_norm = np.empty_like(x, dtype=np.float32)
    for b in range(bands):
        band     = x[:, :, b]
        band_min = np.min(band)
        band_max = np.max(band)
        denom    = max(band_max - band_min, 1e-8)
        x_norm[:, :, b] = (band - band_min) / denom

    return x_norm, y


def extract_labeled_patches(x, y, patch_size=9):
    """Extract (patch_size × patch_size) spatial patches around every labelled pixel."""
    pad   = patch_size // 2
    x_pad = np.pad(x, ((pad, pad), (pad, pad), (0, 0)), mode="edge")

    coords  = np.argwhere(y > 0)
    patches = np.empty((coords.shape[0], patch_size, patch_size, x.shape[-1]), dtype=np.float32)
    labels  = np.empty((coords.shape[0],), dtype=np.int32)

    for i, (r, c) in enumerate(coords):
        patches[i] = x_pad[r:r + patch_size, c:c + patch_size, :]
        labels[i]  = int(y[r, c]) - 1  # convert class IDs to 0..C-1

    return patches, labels, coords

# %% [markdown]
# ## 3.2 — Load data and create splits

# %%
x_img, y_img = load_multispectral_6band(DATA_FILE, LABEL_FILE, H, W, B)
X, y, coords = extract_labeled_patches(x_img, y_img, PATCH_SIZE)

num_classes = int(np.unique(y).size)
input_shape = (PATCH_SIZE, PATCH_SIZE, B)

print("x_img:", x_img.shape, "  y_img:", y_img.shape)
print("Labelled samples:", X.shape[0])
print("Patch tensor:    ", X.shape)
print("Num classes:     ", num_classes)
# Out:
# x_img: (330, 307, 6)   y_img: (330, 307)
# Labelled samples: 17239
# Patch tensor:     (17239, 9, 9, 6)
# Num classes:      7

# %%
# Primary stratified split used by all three MambaHSI variants
x_train_full, x_test, y_train_full, y_test = train_test_split(
    X, y,
    train_size=TRAIN_PERCENT,
    random_state=SEED,
    stratify=y,
)
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full,
    test_size=VAL_SPLIT_FROM_TRAIN,
    random_state=SEED,
    stratify=y_train_full,
)

y_train_cat = keras.utils.to_categorical(y_train, num_classes)
y_val_cat   = keras.utils.to_categorical(y_val,   num_classes)
y_test_cat  = keras.utils.to_categorical(y_test,  num_classes)

print("Train:", x_train.shape, y_train.shape)
print("Val:  ", x_val.shape,   y_val.shape)
print("Test: ", x_test.shape,  y_test.shape)
# Out:
# Train: (10343, 9, 9, 6) (10343,)
# Val:   (2586, 9, 9, 6) (2586,)
# Test:  (4310, 9, 9, 6) (4310,)

# %%
# AlexNet legacy split — matches the original single-head notebook for
# uncertainty recovery (different seed and no val split)
x_train_alex, x_test_alex, y_train_alex, y_test_alex = train_test_split(
    X, y,
    train_size=ALEXNET_LEGACY_TRAIN_PERCENT,
    random_state=ALEXNET_LEGACY_SPLIT_SEED,
    stratify=y,
)
y_train_alex_cat = keras.utils.to_categorical(y_train_alex, num_classes)
y_test_alex_cat  = keras.utils.to_categorical(y_test_alex,  num_classes)

print("AlexNet Train:", x_train_alex.shape, y_train_alex.shape)
print("AlexNet Test: ", x_test_alex.shape,  y_test_alex.shape)
# Out:
# AlexNet Train: (12929, 9, 9, 6) (12929,)
# AlexNet Test:  (4310, 9, 9, 6) (4310,)

# %% [markdown]
# # 4.0 — Model Definitions
# Defines three capacities of a MambaHSI-style spatial-spectral state-space model (Small / Base / Large). Custom Keras layers are registered for serialisation, following the same pattern used by the backbones this replaces.

# %% [markdown]
# ## 4.1 — Shared custom Keras layers (PatchExtractor, PatchPositionEncoder)

# %%
@tf.keras.utils.register_keras_serializable()
class PatchExtractor(layers.Layer):
    """Extract non-overlapping spatial patches from an image tensor."""

    def __init__(self, patch_size=3, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        patches     = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        batch       = tf.shape(images)[0]
        num_patches = tf.shape(patches)[1] * tf.shape(patches)[2]
        patch_dim   = tf.shape(patches)[-1]
        return tf.reshape(patches, [batch, num_patches, patch_dim])

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"patch_size": self.patch_size})
        return cfg


@tf.keras.utils.register_keras_serializable()
class PatchPositionEncoder(layers.Layer):
    """Project patches to embedding dim and add learned positional embeddings."""

    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches      = num_patches
        self.projection_dim   = projection_dim
        self.projection       = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)

    def call(self, patches):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        return self.projection(patches) + self.position_embedding(positions)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"num_patches": self.num_patches, "projection_dim": self.projection_dim})
        return cfg

# %% [markdown]
# ## 4.2 — MambaHSI selective state-space layers (SpectralScanLayer, SelectiveSSMBlock)
#
# **Implementation note / simplification.** The original Mamba (Gu & Dao, 2023) selective-scan runs as a hardware-aware fused CUDA kernel with fully input-dependent (Δ, A, B, C) parameters. TensorFlow/Keras has no equivalent fused primitive, so `SpectralScanLayer` below approximates the *core idea* — input-dependent (selective) state propagation along a sequence — with a diagonal linear state-space recurrence (S4/S5-style) whose gating signal is computed from the input at every step via `tf.scan`. This is a faithful-in-spirit, not bit-exact, port of the selective-scan mechanism, and is documented again in the layer's own docstring.

# %%
@tf.keras.utils.register_keras_serializable()
class SpectralScanLayer(layers.Layer):
    """Simplified structured state-space scan (S4/S5-style diagonal linear
    recurrence) approximating Mamba's selective-scan mechanism in pure Keras ops.

    SIMPLIFICATION FROM TRUE MAMBA: the original selective-scan uses a fused
    CUDA kernel with fully input-dependent (Delta, A, B, C) parameters. There is
    no equivalent fused op in TensorFlow/Keras, so here the "selective" part is
    approximated with a single input-dependent gate applied before a per-channel
    diagonal linear recurrence, evaluated with tf.scan over the sequence axis.
    """

    def __init__(self, state_dim, **kwargs):
        super().__init__(**kwargs)
        self.state_dim = state_dim

    def build(self, input_shape):
        channels = int(input_shape[-1])
        self.in_proj   = layers.Dense(self.state_dim, name="ssm_in_proj")
        self.gate_proj = layers.Dense(self.state_dim, activation="sigmoid", name="ssm_gate_proj")
        self.log_decay = self.add_weight(
            name="log_decay", shape=(self.state_dim,),
            initializer=keras.initializers.RandomUniform(-3.0, -1.0), trainable=True,
        )
        self.out_proj = layers.Dense(channels, name="ssm_out_proj")
        super().build(input_shape)

    def call(self, x):
        # x: (batch, seq, channels)
        decay       = tf.nn.sigmoid(self.log_decay)   # (state_dim,) constrained to (0, 1)
        u           = self.in_proj(x)                  # (batch, seq, state_dim)
        gate        = self.gate_proj(x)                 # (batch, seq, state_dim) — input-dependent selection
        gated_input = u * gate

        scan_input = tf.transpose(gated_input, [1, 0, 2])  # (seq, batch, state_dim)

        def step(prev_state, cur_input):
            return decay * prev_state + cur_input

        init_state = tf.zeros_like(scan_input[0])
        states = tf.scan(step, scan_input, initializer=init_state)  # (seq, batch, state_dim)
        states = tf.transpose(states, [1, 0, 2])                     # (batch, seq, state_dim)
        return self.out_proj(states)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"state_dim": self.state_dim})
        return cfg


@tf.keras.utils.register_keras_serializable()
class SelectiveSSMBlock(layers.Layer):
    """One MambaHSI-style block: a bidirectional selective-scan (forward +
    reverse SpectralScanLayer passes, since spatial patches — unlike causal
    language sequences — benefit from non-causal context) followed by a
    two-layer GELU MLP, both wrapped in pre-LN residual connections. Mirrors
    the residual/MLP pattern used by the `gf_block` helper this replaces.
    """

    def __init__(self, state_dim, hidden_dim, mlp_ratio=4, dropout_rate=0.25, **kwargs):
        super().__init__(**kwargs)
        self.state_dim    = state_dim
        self.hidden_dim   = hidden_dim
        self.mlp_ratio    = mlp_ratio
        self.dropout_rate = dropout_rate

    def build(self, input_shape):
        self.ln1         = layers.LayerNormalization()
        self.scan_fwd     = SpectralScanLayer(self.state_dim)
        self.scan_bwd     = SpectralScanLayer(self.state_dim)
        self.merge_proj   = layers.Dense(self.hidden_dim)
        self.ln2          = layers.LayerNormalization()
        self.mlp1         = layers.Dense(self.hidden_dim * self.mlp_ratio, activation=tf.keras.activations.gelu)
        self.drop1        = layers.Dropout(self.dropout_rate)
        self.mlp2         = layers.Dense(self.hidden_dim, activation=tf.keras.activations.gelu)
        self.drop2        = layers.Dropout(self.dropout_rate)
        super().build(input_shape)

    def call(self, x, training=None):
        y   = self.ln1(x)
        fwd = self.scan_fwd(y)
        bwd = tf.reverse(self.scan_bwd(tf.reverse(y, axis=[1])), axis=[1])
        y   = self.merge_proj(tf.concat([fwd, bwd], axis=-1))
        x   = x + y

        y = self.ln2(x)
        y = self.mlp1(y)
        y = self.drop1(y, training=training)
        y = self.mlp2(y)
        y = self.drop2(y, training=training)
        return x + y

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "state_dim": self.state_dim, "hidden_dim": self.hidden_dim,
            "mlp_ratio": self.mlp_ratio, "dropout_rate": self.dropout_rate,
        })
        return cfg

# %% [markdown]
# ## 4.3 — MambaHSI backbone factory (build_mambahsi)
#
# Tokenises the `(9, 9, 6)` input patch into non-overlapping `INNER_PATCH x INNER_PATCH` spatial tokens (the same tokenisation the original GFNet/ViT backbones used), projects each token to `hidden_dim`, then processes the token sequence with a stack of `SelectiveSSMBlock` state-space blocks before global-average-pooling into a softmax head. Follows the same `build_*(input_shape, num_classes, dropout_rate=0.25, cfg=None)` calling convention as the backbones it replaces, so it plugs into `train_save_evaluate` unchanged.

# %%
def build_mambahsi(input_shape, num_classes, dropout_rate=0.25, cfg=None):
    """Build a MambaHSI-style spatial-spectral state-space classifier."""
    cfg = cfg or MAMBAHSI_BASE_CFG
    inner_patch = cfg.get("inner_patch", INNER_PATCH)
    hidden_dim  = cfg["hidden_dim"]
    state_dim   = cfg["state_dim"]
    num_blocks  = cfg["num_blocks"]
    mlp_ratio   = cfg.get("mlp_ratio", 4)
    variant_name = cfg.get("variant_name", "")

    num_patches = (input_shape[0] // inner_patch) * (input_shape[1] // inner_patch)

    inputs = keras.Input(shape=input_shape)
    x      = PatchExtractor(inner_patch, name="mamba_patch_extractor")(inputs)
    x      = PatchPositionEncoder(num_patches, hidden_dim, name="mamba_patch_encoder")(x)
    x      = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)

    for i in range(num_blocks):
        x = SelectiveSSMBlock(
            state_dim, hidden_dim, mlp_ratio, dropout_rate,
            name=f"mamba_ssm_block_{i+1}",
        )(x)

    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_2")(x)
    x = layers.LayerNormalization(name="mamba_final_ln")(x)
    x = layers.GlobalAveragePooling1D(name="mamba_gap")(x)
    x = layers.Flatten(name="mamba_flatten")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(x)

    outputs = layers.Dense(num_classes, activation="softmax", name="mamba_logits")(x)
    model_name = f"MambaHSI_{variant_name}" if variant_name else "MambaHSI_SingleHead"
    return keras.Model(inputs, outputs, name=model_name)

# %% [markdown]
# # 5.0 — Training & Evaluation Helpers
# Optimiser factory, learning-rate schedule, calibration metrics (Brier score, ECE), and the main `train_save_evaluate` function. Copied verbatim from the original notebook — see the note in Section 2.0 about the now-unused AlexNet-specific branch inside `train_save_evaluate`.

# %% [markdown]
# ## 5.1 — Calibration metrics

# %%
def multiclass_brier_score(y_onehot, y_prob):
    """Compute the multiclass Brier score (mean squared error over probability vectors)."""
    return float(np.mean(np.sum((y_prob - y_onehot) ** 2, axis=1)))


def expected_calibration_error(y_true, y_prob, n_bins=15):
    """Compute Expected Calibration Error (ECE) with equal-width confidence bins."""
    confidences = np.max(y_prob, axis=1)
    predictions = np.argmax(y_prob, axis=1)
    correct     = (predictions == y_true).astype(np.float32)
    bin_edges   = np.linspace(0.0, 1.0, n_bins + 1)
    ece         = 0.0

    for i in range(n_bins):
        lo, hi = bin_edges[i], bin_edges[i + 1]
        in_bin = (confidences >= lo) & (confidences <= hi if i == n_bins - 1 else confidences < hi)
        prop   = np.mean(in_bin)
        if prop > 0:
            ece += np.abs(np.mean(correct[in_bin]) - np.mean(confidences[in_bin])) * prop

    return float(ece)

# %% [markdown]
# ## 5.2 — Optimiser factory

# %%
def make_optimizer(num_train_samples):
    """Build an AdamW optimiser with a cosine-decay learning-rate schedule."""
    steps_per_epoch = int(np.ceil(num_train_samples / BATCH_SIZE))
    decay_steps     = max(1, steps_per_epoch * EPOCHS)
    lr_schedule     = keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=LEARNING_RATE,
        decay_steps=decay_steps,
        alpha=TRAIN_CFG["cosine_alpha"],
    )
    return keras.optimizers.AdamW(
        learning_rate=lr_schedule,
        weight_decay=TRAIN_CFG["weight_decay"],
        clipnorm=TRAIN_CFG["clipnorm"],
    )


def _alexnet_legacy_lr(epoch):
    """Cosine LR schedule for AlexNet, matching the original single-head script."""
    if EPOCHS <= 1:
        return ALEXNET_LR_START
    phase        = np.pi * epoch / (EPOCHS - 1)
    cosine_decay = 0.5 * (1.0 + np.cos(phase))
    return float((ALEXNET_LR_MAX - ALEXNET_LR_MIN) * cosine_decay + ALEXNET_LR_MIN)

# %% [markdown]
# ## 5.3 — Main training, saving, and evaluation function

# %%
def train_save_evaluate(model_name, model_builder, capacity_tag="max"):
    """Compile, train, save (best + final), and evaluate a single-head model.

    Returns a metrics dict, per-class classification report, confusion matrix,
    and the raw Keras history dict.
    """
    tf.keras.backend.clear_session()
    model     = model_builder()
    best_path  = MODEL_DIR / f"{model_name}_best.keras"
    final_path = MODEL_DIR / f"{model_name}_final.keras"

    # AlexNet uses a legacy Adagrad + cosine LR schedule to match the original
    # single-head script for downstream uncertainty analysis.
    if model_name == "AlexNet_CNN":
        model.compile(
            optimizer=keras.optimizers.Adagrad(learning_rate=ALEXNET_LR_START),
            loss="sparse_categorical_crossentropy",
            metrics=["accuracy"],
        )
        callbacks = [
            keras.callbacks.ModelCheckpoint(
                filepath=str(best_path), monitor="val_accuracy",
                mode="max", save_best_only=True, verbose=1,
            ),
            keras.callbacks.LearningRateScheduler(_alexnet_legacy_lr, verbose=0),
        ]
        x_tr, y_tr         = x_train_alex, y_train_alex
        x_va, y_va         = x_test_alex,  y_test_alex
        x_te, y_te, y_te_cat = x_test_alex, y_test_alex, y_test_alex_cat
        x_eval, y_eval, y_eval_cat = x_test_alex, y_test_alex, y_test_alex_cat
        fit_shuffle        = False
    else:
        # GFNet and ViT use AdamW + cosine decay with label smoothing
        model.compile(
            optimizer=make_optimizer(len(x_train)),
            loss=keras.losses.CategoricalCrossentropy(label_smoothing=TRAIN_CFG["label_smoothing"]),
            metrics=["accuracy"],
        )
        callbacks = [
            keras.callbacks.ModelCheckpoint(
                filepath=str(best_path), monitor="val_loss",
                mode="min", save_best_only=True, verbose=1,
            ),
        ]
        x_tr, y_tr         = x_train, y_train_cat
        x_va, y_va         = x_val,   y_val_cat
        x_te, y_te, y_te_cat = x_test, y_test, y_test_cat
        x_eval, y_eval, y_eval_cat = x_val, y_val, y_val_cat
        fit_shuffle        = True

    train_start = time.perf_counter()
    history_obj = model.fit(
        x_tr, y_tr,
        validation_data=(x_va, y_va),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=callbacks,
        verbose=1,
        shuffle=fit_shuffle,
    )
    train_time_sec = float(time.perf_counter() - train_start)

    epochs_ran = int(len(history_obj.history.get("loss", [])))
    if epochs_ran != EPOCHS:
        print(f"WARNING: {model_name} ran {epochs_ran} epochs, expected {EPOCHS}.")
    else:
        print(f"{model_name} completed full training: {epochs_ran}/{EPOCHS} epochs.")

    model.save(final_path)

    y_eval_prob = model.predict(x_eval, batch_size=BATCH_SIZE, verbose=0)
    y_test_prob = model.predict(x_te,   batch_size=BATCH_SIZE, verbose=0)
    y_test_pred = np.argmax(y_test_prob, axis=1)

    report = classification_report(y_te, y_test_pred, output_dict=True, zero_division=0)
    cm     = confusion_matrix(y_te, y_test_pred)

    row = {
        "model":            model_name,
        "capacity_tag":     capacity_tag,
        "test_accuracy":    float(accuracy_score(y_te, y_test_pred)),
        "kappa":            float(cohen_kappa_score(y_te, y_test_pred)),
        "macro_f1":         float(f1_score(y_te, y_test_pred, average="macro")),
        "weighted_f1":      float(f1_score(y_te, y_test_pred, average="weighted")),
        "val_nll":          float(log_loss(y_eval, y_eval_prob, labels=np.arange(num_classes))),
        "test_nll":         float(log_loss(y_te,   y_test_prob, labels=np.arange(num_classes))),
        "val_brier":        multiclass_brier_score(y_eval_cat, y_eval_prob),
        "test_brier":       multiclass_brier_score(y_te_cat,   y_test_prob),
        "test_ece_15bin":   expected_calibration_error(y_te, y_test_prob, n_bins=15),
        "epochs_configured": int(EPOCHS),
        "epochs_ran":       epochs_ran,
        "train_time_sec":   train_time_sec,
        "best_model_path":  str(best_path),
        "final_model_path": str(final_path),
    }
    return row, report, cm, history_obj.history

# %% [markdown]
# # 6.0 — Model Training
# Build factory lambdas, then loop over all three MambaHSI capacities. OOM errors on the Base and Large variants automatically retry with reduced fallback configs (mirrors the original GFNet/ViT fallback behaviour).

# %%
def build_mambahsi_with_cfg(cfg, variant_name):
    """Instantiate MambaHSI from a config dict, tagging it with a variant name."""
    cfg = dict(cfg)
    cfg["variant_name"] = variant_name
    return build_mambahsi(input_shape, num_classes, dropout_rate=DROPOUT_RATE, cfg=cfg)


model_builders = {
    "MambaHSI_Small": lambda: build_mambahsi_with_cfg(MAMBAHSI_SMALL_CFG, "Small"),
    "MambaHSI_Base":  lambda: build_mambahsi_with_cfg(MAMBAHSI_BASE_CFG,  "Base"),
    "MambaHSI_Large": lambda: build_mambahsi_with_cfg(MAMBAHSI_LARGE_CFG, "Large"),
}

# %%
results_rows   = []
model_artifacts = {}

for model_name, builder in model_builders.items():
    print(f"\n{'=' * 25} Training {model_name} ({CAPACITY_PRESET}) {'=' * 25}")

    try:
        row, report, cm, history = train_save_evaluate(model_name, builder,
                                                       capacity_tag=CAPACITY_PRESET)
    except tf.errors.ResourceExhaustedError:
        # Automatically retry with a smaller fallback config to handle Colab OOM
        if model_name == "MambaHSI_Base":
            print("OOM on MambaHSI_Base config. Retrying with fallback config.")
            tf.keras.backend.clear_session()
            row, report, cm, history = train_save_evaluate(
                model_name, lambda: build_mambahsi_with_cfg(MAMBAHSI_BASE_FALLBACK_CFG, "Base"),
                capacity_tag="fallback",
            )
        elif model_name == "MambaHSI_Large":
            print("OOM on MambaHSI_Large config. Retrying with fallback config.")
            tf.keras.backend.clear_session()
            row, report, cm, history = train_save_evaluate(
                model_name, lambda: build_mambahsi_with_cfg(MAMBAHSI_LARGE_FALLBACK_CFG, "Large"),
                capacity_tag="fallback",
            )
        else:
            raise

    results_rows.append(row)
    model_artifacts[model_name] = {"report": report, "confusion_matrix": cm, "history": history}

summary_df = (
    pd.DataFrame(results_rows)
    .sort_values("test_accuracy", ascending=False)
    .reset_index(drop=True)
)
summary_df
# Out:
# ========================= Training MambaHSI_Small (mambahsi_arch) =========================
# Epoch 1/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.4997 - loss: 1.4534
# Epoch 1: val_loss improved from None to 0.98082, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 48s 228ms/step - accuracy: 0.5840 - loss: 1.2163 - val_accuracy: 0.7135 - val_loss: 0.9808
# Epoch 2/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7075 - loss: 0.9338
# Epoch 2: val_loss improved from 0.98082 to 0.89044, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7180 - loss: 0.9119 - val_accuracy: 0.7444 - val_loss: 0.8904
# Epoch 3/100
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7638 - loss: 0.8136
# Epoch 3: val_loss improved from 0.89044 to 0.70357, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7719 - loss: 0.7994 - val_accuracy: 0.8554 - val_loss: 0.7036
# Epoch 4/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8228 - loss: 0.7051
# Epoch 4: val_loss improved from 0.70357 to 0.64702, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8176 - loss: 0.7096 - val_accuracy: 0.8797 - val_loss: 0.6470
# Epoch 5/100
# 79/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8438 - loss: 0.6453
# Epoch 5: val_loss improved from 0.64702 to 0.62420, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8401 - loss: 0.6490 - val_accuracy: 0.8844 - val_loss: 0.6242
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8673 - loss: 0.5998
# Epoch 6: val_loss improved from 0.62420 to 0.57482, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8665 - loss: 0.6035 - val_accuracy: 0.9006 - val_loss: 0.5748
# Epoch 7/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8848 - loss: 0.5688
# Epoch 7: val_loss improved from 0.57482 to 0.55626, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8790 - loss: 0.5760 - val_accuracy: 0.9114 - val_loss: 0.5563
# Epoch 8/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8973 - loss: 0.5404
# Epoch 8: val_loss improved from 0.55626 to 0.53721, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8917 - loss: 0.5464 - val_accuracy: 0.9165 - val_loss: 0.5372
# Epoch 9/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9054 - loss: 0.5193
# Epoch 9: val_loss improved from 0.53721 to 0.51863, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9024 - loss: 0.5246 - val_accuracy: 0.9242 - val_loss: 0.5186
# Epoch 10/100
# 75/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9101 - loss: 0.5030
# Epoch 10: val_loss improved from 0.51863 to 0.48026, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9078 - loss: 0.5078 - val_accuracy: 0.9362 - val_loss: 0.4803
# Epoch 11/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9129 - loss: 0.4912
# Epoch 11: val_loss improved from 0.48026 to 0.45651, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9139 - loss: 0.4940 - val_accuracy: 0.9459 - val_loss: 0.4565
# Epoch 12/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9245 - loss: 0.4743
# Epoch 12: val_loss did not improve from 0.45651
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9213 - loss: 0.4801 - val_accuracy: 0.9428 - val_loss: 0.4622
# Epoch 13/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9287 - loss: 0.4601
# Epoch 13: val_loss improved from 0.45651 to 0.45597, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 13: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9232 - loss: 0.4713 - val_accuracy: 0.9439 - val_loss: 0.4560
# Epoch 14/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9304 - loss: 0.4516
# Epoch 14: val_loss improved from 0.45597 to 0.43704, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9286 - loss: 0.4573 - val_accuracy: 0.9551 - val_loss: 0.4370
# Epoch 15/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9354 - loss: 0.4436
# Epoch 15: val_loss improved from 0.43704 to 0.42314, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 15: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9341 - loss: 0.4475 - val_accuracy: 0.9575 - val_loss: 0.4231
# Epoch 16/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9416 - loss: 0.4330
# Epoch 16: val_loss improved from 0.42314 to 0.40595, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9395 - loss: 0.4374 - val_accuracy: 0.9648 - val_loss: 0.4060
# Epoch 17/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9413 - loss: 0.4253
# Epoch 17: val_loss improved from 0.40595 to 0.40518, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 17: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9403 - loss: 0.4278 - val_accuracy: 0.9679 - val_loss: 0.4052
# Epoch 18/100
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9475 - loss: 0.4171
# Epoch 18: val_loss improved from 0.40518 to 0.39200, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 18: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9459 - loss: 0.4176 - val_accuracy: 0.9691 - val_loss: 0.3920
# Epoch 19/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9525 - loss: 0.4061
# Epoch 19: val_loss did not improve from 0.39200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9467 - loss: 0.4139 - val_accuracy: 0.9687 - val_loss: 0.3968
# Epoch 20/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9571 - loss: 0.3949
# Epoch 20: val_loss improved from 0.39200 to 0.38338, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 20: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9545 - loss: 0.4003 - val_accuracy: 0.9753 - val_loss: 0.3834
# Epoch 21/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9531 - loss: 0.3971
# Epoch 21: val_loss improved from 0.38338 to 0.37794, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 21: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9511 - loss: 0.3994 - val_accuracy: 0.9772 - val_loss: 0.3779
# Epoch 22/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9587 - loss: 0.3869
# Epoch 22: val_loss did not improve from 0.37794
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9557 - loss: 0.3924 - val_accuracy: 0.9745 - val_loss: 0.3863
# Epoch 23/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9607 - loss: 0.3867
# Epoch 23: val_loss improved from 0.37794 to 0.37539, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 23: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9607 - loss: 0.3866 - val_accuracy: 0.9787 - val_loss: 0.3754
# Epoch 24/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9635 - loss: 0.3774
# Epoch 24: val_loss improved from 0.37539 to 0.37040, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 24: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9627 - loss: 0.3786 - val_accuracy: 0.9834 - val_loss: 0.3704
# Epoch 25/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9684 - loss: 0.3674
# Epoch 25: val_loss improved from 0.37040 to 0.36471, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 25: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9659 - loss: 0.3706 - val_accuracy: 0.9818 - val_loss: 0.3647
# Epoch 26/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9653 - loss: 0.3700
# Epoch 26: val_loss improved from 0.36471 to 0.35616, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 26: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9653 - loss: 0.3713 - val_accuracy: 0.9865 - val_loss: 0.3562
# Epoch 27/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9699 - loss: 0.3623
# Epoch 27: val_loss did not improve from 0.35616
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9674 - loss: 0.3669 - val_accuracy: 0.9838 - val_loss: 0.3639
# Epoch 28/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9692 - loss: 0.3621
# Epoch 28: val_loss did not improve from 0.35616
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9690 - loss: 0.3635 - val_accuracy: 0.9834 - val_loss: 0.3685
# Epoch 29/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9709 - loss: 0.3566
# Epoch 29: val_loss did not improve from 0.35616
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9716 - loss: 0.3588 - val_accuracy: 0.9876 - val_loss: 0.3574
# Epoch 30/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9738 - loss: 0.3544
# Epoch 30: val_loss improved from 0.35616 to 0.35372, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 30: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9762 - loss: 0.3540 - val_accuracy: 0.9876 - val_loss: 0.3537
# Epoch 31/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9770 - loss: 0.3467
# Epoch 31: val_loss did not improve from 0.35372
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9750 - loss: 0.3496 - val_accuracy: 0.9869 - val_loss: 0.3555
# Epoch 32/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9781 - loss: 0.3491
# Epoch 32: val_loss improved from 0.35372 to 0.34834, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 32: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9776 - loss: 0.3483 - val_accuracy: 0.9880 - val_loss: 0.3483
# Epoch 33/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9778 - loss: 0.3462
# Epoch 33: val_loss did not improve from 0.34834
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9766 - loss: 0.3477 - val_accuracy: 0.9857 - val_loss: 0.3517
# Epoch 34/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9758 - loss: 0.3474
# Epoch 34: val_loss did not improve from 0.34834
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9774 - loss: 0.3469 - val_accuracy: 0.9884 - val_loss: 0.3498
# Epoch 35/100
# 75/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9824 - loss: 0.3385
# Epoch 35: val_loss improved from 0.34834 to 0.34579, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 35: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9810 - loss: 0.3410 - val_accuracy: 0.9899 - val_loss: 0.3458
# Epoch 36/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9818 - loss: 0.3358
# Epoch 36: val_loss did not improve from 0.34579
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9803 - loss: 0.3374 - val_accuracy: 0.9896 - val_loss: 0.3486
# Epoch 37/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9817 - loss: 0.3356
# Epoch 37: val_loss improved from 0.34579 to 0.33969, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 37: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9820 - loss: 0.3366 - val_accuracy: 0.9911 - val_loss: 0.3397
# Epoch 38/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9839 - loss: 0.3326
# Epoch 38: val_loss did not improve from 0.33969
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9834 - loss: 0.3348 - val_accuracy: 0.9903 - val_loss: 0.3409
# Epoch 39/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9866 - loss: 0.3254
# Epoch 39: val_loss improved from 0.33969 to 0.33789, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 39: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9841 - loss: 0.3294 - val_accuracy: 0.9927 - val_loss: 0.3379
# Epoch 40/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9879 - loss: 0.3253
# Epoch 40: val_loss improved from 0.33789 to 0.33481, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 40: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9861 - loss: 0.3295 - val_accuracy: 0.9923 - val_loss: 0.3348
# Epoch 41/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9823 - loss: 0.3315
# Epoch 41: val_loss improved from 0.33481 to 0.33438, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 41: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9850 - loss: 0.3286 - val_accuracy: 0.9927 - val_loss: 0.3344
# Epoch 42/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9877 - loss: 0.3236
# Epoch 42: val_loss improved from 0.33438 to 0.33365, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 42: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9866 - loss: 0.3240 - val_accuracy: 0.9938 - val_loss: 0.3336
# Epoch 43/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9871 - loss: 0.3234
# Epoch 43: val_loss improved from 0.33365 to 0.33320, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 43: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9868 - loss: 0.3235 - val_accuracy: 0.9923 - val_loss: 0.3332
# Epoch 44/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9884 - loss: 0.3205
# Epoch 44: val_loss did not improve from 0.33320
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9886 - loss: 0.3214 - val_accuracy: 0.9938 - val_loss: 0.3333
# Epoch 45/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9898 - loss: 0.3182
# Epoch 45: val_loss did not improve from 0.33320
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9882 - loss: 0.3206 - val_accuracy: 0.9927 - val_loss: 0.3355
# Epoch 46/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9877 - loss: 0.3196
# Epoch 46: val_loss improved from 0.33320 to 0.32749, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 46: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9894 - loss: 0.3178 - val_accuracy: 0.9938 - val_loss: 0.3275
# Epoch 47/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9906 - loss: 0.3148
# Epoch 47: val_loss did not improve from 0.32749
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9889 - loss: 0.3166 - val_accuracy: 0.9946 - val_loss: 0.3325
# Epoch 48/100
# 75/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9885 - loss: 0.3182
# Epoch 48: val_loss improved from 0.32749 to 0.32486, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 48: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9885 - loss: 0.3175 - val_accuracy: 0.9946 - val_loss: 0.3249
# Epoch 49/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9907 - loss: 0.3143
# Epoch 49: val_loss did not improve from 0.32486
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9888 - loss: 0.3161 - val_accuracy: 0.9942 - val_loss: 0.3294
# Epoch 50/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9916 - loss: 0.3113
# Epoch 50: val_loss did not improve from 0.32486
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9916 - loss: 0.3118 - val_accuracy: 0.9930 - val_loss: 0.3264
# Epoch 51/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9895 - loss: 0.3124
# Epoch 51: val_loss did not improve from 0.32486
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9903 - loss: 0.3131 - val_accuracy: 0.9950 - val_loss: 0.3252
# Epoch 52/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9925 - loss: 0.3073
# Epoch 52: val_loss did not improve from 0.32486
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9918 - loss: 0.3100 - val_accuracy: 0.9950 - val_loss: 0.3267
# Epoch 53/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9917 - loss: 0.3076
# Epoch 53: val_loss did not improve from 0.32486
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9913 - loss: 0.3093 - val_accuracy: 0.9942 - val_loss: 0.3261
# Epoch 54/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9939 - loss: 0.3054
# Epoch 54: val_loss improved from 0.32486 to 0.32467, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 54: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9925 - loss: 0.3078 - val_accuracy: 0.9942 - val_loss: 0.3247
# Epoch 55/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9924 - loss: 0.3072
# Epoch 55: val_loss improved from 0.32467 to 0.32155, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 55: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9933 - loss: 0.3070 - val_accuracy: 0.9954 - val_loss: 0.3215
# Epoch 56/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9938 - loss: 0.3048
# Epoch 56: val_loss did not improve from 0.32155
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9945 - loss: 0.3052 - val_accuracy: 0.9954 - val_loss: 0.3239
# Epoch 57/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9926 - loss: 0.3073
# Epoch 57: val_loss improved from 0.32155 to 0.32083, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 57: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9917 - loss: 0.3087 - val_accuracy: 0.9946 - val_loss: 0.3208
# Epoch 58/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9939 - loss: 0.3021
# Epoch 58: val_loss did not improve from 0.32083
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9940 - loss: 0.3038 - val_accuracy: 0.9946 - val_loss: 0.3224
# Epoch 59/100
# 79/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9939 - loss: 0.3024
# Epoch 59: val_loss did not improve from 0.32083
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9939 - loss: 0.3037 - val_accuracy: 0.9950 - val_loss: 0.3212
# Epoch 60/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9956 - loss: 0.3006
# Epoch 60: val_loss improved from 0.32083 to 0.31593, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 60: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9949 - loss: 0.3015 - val_accuracy: 0.9950 - val_loss: 0.3159
# Epoch 61/100
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9961 - loss: 0.2998
# Epoch 61: val_loss did not improve from 0.31593
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9953 - loss: 0.3016 - val_accuracy: 0.9954 - val_loss: 0.3201
# Epoch 62/100
# 75/81 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9938 - loss: 0.2995
# Epoch 62: val_loss did not improve from 0.31593
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9940 - loss: 0.3004 - val_accuracy: 0.9969 - val_loss: 0.3166
# Epoch 63/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9957 - loss: 0.2984
# Epoch 63: val_loss did not improve from 0.31593
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9950 - loss: 0.2998 - val_accuracy: 0.9965 - val_loss: 0.3176
# Epoch 64/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9947 - loss: 0.2975
# Epoch 64: val_loss did not improve from 0.31593
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9952 - loss: 0.2993 - val_accuracy: 0.9957 - val_loss: 0.3168
# Epoch 65/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9954 - loss: 0.2969
# Epoch 65: val_loss improved from 0.31593 to 0.31482, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 65: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9947 - loss: 0.2979 - val_accuracy: 0.9969 - val_loss: 0.3148
# Epoch 66/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9946 - loss: 0.2986
# Epoch 66: val_loss did not improve from 0.31482
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9952 - loss: 0.2988 - val_accuracy: 0.9973 - val_loss: 0.3161
# Epoch 67/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9966 - loss: 0.2955
# Epoch 67: val_loss did not improve from 0.31482
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9953 - loss: 0.2977 - val_accuracy: 0.9954 - val_loss: 0.3174
# Epoch 68/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9944 - loss: 0.2974
# Epoch 68: val_loss improved from 0.31482 to 0.31440, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 68: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9951 - loss: 0.2973 - val_accuracy: 0.9961 - val_loss: 0.3144
# Epoch 69/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9973 - loss: 0.2959
# Epoch 69: val_loss did not improve from 0.31440
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9970 - loss: 0.2962 - val_accuracy: 0.9973 - val_loss: 0.3146
# Epoch 70/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9954 - loss: 0.2954
# Epoch 70: val_loss did not improve from 0.31440
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9956 - loss: 0.2959 - val_accuracy: 0.9969 - val_loss: 0.3151
# Epoch 71/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9970 - loss: 0.2936
# Epoch 71: val_loss improved from 0.31440 to 0.31164, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 71: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9974 - loss: 0.2937 - val_accuracy: 0.9965 - val_loss: 0.3116
# Epoch 72/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9959 - loss: 0.2953
# Epoch 72: val_loss did not improve from 0.31164
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9964 - loss: 0.2949 - val_accuracy: 0.9973 - val_loss: 0.3153
# Epoch 73/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9962 - loss: 0.2922
# Epoch 73: val_loss did not improve from 0.31164
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9965 - loss: 0.2934 - val_accuracy: 0.9977 - val_loss: 0.3138
# Epoch 74/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9966 - loss: 0.2945
# Epoch 74: val_loss did not improve from 0.31164
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9966 - loss: 0.2937 - val_accuracy: 0.9981 - val_loss: 0.3136
# Epoch 75/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9969 - loss: 0.2930
# Epoch 75: val_loss did not improve from 0.31164
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9968 - loss: 0.2938 - val_accuracy: 0.9981 - val_loss: 0.3133
# Epoch 76/100
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9966 - loss: 0.2929
# Epoch 76: val_loss did not improve from 0.31164
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9962 - loss: 0.2940 - val_accuracy: 0.9965 - val_loss: 0.3137
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9972 - loss: 0.2914
# Epoch 77: val_loss did not improve from 0.31164
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9962 - loss: 0.2928 - val_accuracy: 0.9973 - val_loss: 0.3131
# Epoch 78/100
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9959 - loss: 0.2922
# Epoch 78: val_loss did not improve from 0.31164
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9956 - loss: 0.2926 - val_accuracy: 0.9973 - val_loss: 0.3133
# Epoch 79/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9969 - loss: 0.2908
# Epoch 79: val_loss improved from 0.31164 to 0.31115, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 79: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9965 - loss: 0.2918 - val_accuracy: 0.9981 - val_loss: 0.3111
# Epoch 80/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9977 - loss: 0.2911
# Epoch 80: val_loss did not improve from 0.31115
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9969 - loss: 0.2921 - val_accuracy: 0.9977 - val_loss: 0.3124
# Epoch 81/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9974 - loss: 0.2903
# Epoch 81: val_loss did not improve from 0.31115
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9976 - loss: 0.2908 - val_accuracy: 0.9981 - val_loss: 0.3136
# Epoch 82/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9983 - loss: 0.2905
# Epoch 82: val_loss did not improve from 0.31115
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9971 - loss: 0.2908 - val_accuracy: 0.9985 - val_loss: 0.3137
# Epoch 83/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9965 - loss: 0.2913
# Epoch 83: val_loss did not improve from 0.31115
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9970 - loss: 0.2909 - val_accuracy: 0.9973 - val_loss: 0.3139
# Epoch 84/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9955 - loss: 0.2911
# Epoch 84: val_loss did not improve from 0.31115
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9970 - loss: 0.2902 - val_accuracy: 0.9981 - val_loss: 0.3133
# Epoch 85/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9986 - loss: 0.2890
# Epoch 85: val_loss did not improve from 0.31115
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9982 - loss: 0.2897 - val_accuracy: 0.9985 - val_loss: 0.3131
# Epoch 86/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9971 - loss: 0.2887
# Epoch 86: val_loss did not improve from 0.31115
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9976 - loss: 0.2894 - val_accuracy: 0.9985 - val_loss: 0.3126
# Epoch 87/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9970 - loss: 0.2894
# Epoch 87: val_loss did not improve from 0.31115
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9971 - loss: 0.2903 - val_accuracy: 0.9981 - val_loss: 0.3129
# Epoch 88/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9964 - loss: 0.2899
# Epoch 88: val_loss did not improve from 0.31115
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9971 - loss: 0.2900 - val_accuracy: 0.9977 - val_loss: 0.3128
# Epoch 89/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9988 - loss: 0.2880
# Epoch 89: val_loss did not improve from 0.31115
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9990 - loss: 0.2878 - val_accuracy: 0.9977 - val_loss: 0.3122
# Epoch 90/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9973 - loss: 0.2892
# Epoch 90: val_loss improved from 0.31115 to 0.31111, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 90: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9974 - loss: 0.2897 - val_accuracy: 0.9981 - val_loss: 0.3111
# Epoch 91/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9971 - loss: 0.2889
# Epoch 91: val_loss did not improve from 0.31111
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9972 - loss: 0.2898 - val_accuracy: 0.9981 - val_loss: 0.3127
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9974 - loss: 0.2885
# Epoch 92: val_loss did not improve from 0.31111
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9977 - loss: 0.2896 - val_accuracy: 0.9981 - val_loss: 0.3116
# Epoch 93/100
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9981 - loss: 0.2877
# Epoch 93: val_loss improved from 0.31111 to 0.31078, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 93: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9982 - loss: 0.2886 - val_accuracy: 0.9981 - val_loss: 0.3108
# Epoch 94/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9987 - loss: 0.2881
# Epoch 94: val_loss did not improve from 0.31078
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9978 - loss: 0.2897 - val_accuracy: 0.9981 - val_loss: 0.3108
# Epoch 95/100
# 76/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9978 - loss: 0.2883
# Epoch 95: val_loss improved from 0.31078 to 0.31013, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 95: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9973 - loss: 0.2887 - val_accuracy: 0.9985 - val_loss: 0.3101
# Epoch 96/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9977 - loss: 0.2884
# Epoch 96: val_loss did not improve from 0.31013
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9978 - loss: 0.2888 - val_accuracy: 0.9985 - val_loss: 0.3117
# Epoch 97/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9977 - loss: 0.2877
# Epoch 97: val_loss did not improve from 0.31013
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9975 - loss: 0.2880 - val_accuracy: 0.9977 - val_loss: 0.3111
# Epoch 98/100
# 78/81 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9963 - loss: 0.2912
# Epoch 98: val_loss did not improve from 0.31013
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9968 - loss: 0.2905 - val_accuracy: 0.9985 - val_loss: 0.3102
# Epoch 99/100
# 77/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9975 - loss: 0.2880
# Epoch 99: val_loss did not improve from 0.31013
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9978 - loss: 0.2882 - val_accuracy: 0.9977 - val_loss: 0.3119
# Epoch 100/100
# 75/81 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9980 - loss: 0.2878
# Epoch 100: val_loss improved from 0.31013 to 0.30993, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
#
# Epoch 100: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Small_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9976 - loss: 0.2890 - val_accuracy: 0.9977 - val_loss: 0.3099
# MambaHSI_Small completed full training: 100/100 epochs.
#
# ========================= Training MambaHSI_Base (mambahsi_arch) =========================
# Epoch 1/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.4760 - loss: 1.6892
# Epoch 1: val_loss improved from None to 0.87865, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 74s 363ms/step - accuracy: 0.5687 - loss: 1.3251 - val_accuracy: 0.7208 - val_loss: 0.8786
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7359 - loss: 0.8779
# Epoch 2: val_loss improved from 0.87865 to 0.64641, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.7578 - loss: 0.8292 - val_accuracy: 0.8484 - val_loss: 0.6464
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8356 - loss: 0.6731
# Epoch 3: val_loss improved from 0.64641 to 0.62443, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.8351 - loss: 0.6699 - val_accuracy: 0.8836 - val_loss: 0.6244
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8646 - loss: 0.6037
# Epoch 4: val_loss improved from 0.62443 to 0.54179, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.8615 - loss: 0.6091 - val_accuracy: 0.9006 - val_loss: 0.5418
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8837 - loss: 0.5641
# Epoch 5: val_loss improved from 0.54179 to 0.53332, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.8831 - loss: 0.5671 - val_accuracy: 0.9130 - val_loss: 0.5333
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8827 - loss: 0.5637
# Epoch 6: val_loss improved from 0.53332 to 0.48734, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.8876 - loss: 0.5568 - val_accuracy: 0.9227 - val_loss: 0.4873
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9045 - loss: 0.5080
# Epoch 7: val_loss improved from 0.48734 to 0.46301, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9063 - loss: 0.5083 - val_accuracy: 0.9370 - val_loss: 0.4630
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9121 - loss: 0.4955
# Epoch 8: val_loss improved from 0.46301 to 0.44267, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9097 - loss: 0.5003 - val_accuracy: 0.9416 - val_loss: 0.4427
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9174 - loss: 0.4746
# Epoch 9: val_loss improved from 0.44267 to 0.43109, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.9147 - loss: 0.4806 - val_accuracy: 0.9420 - val_loss: 0.4311
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9286 - loss: 0.4496
# Epoch 10: val_loss improved from 0.43109 to 0.39964, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9298 - loss: 0.4495 - val_accuracy: 0.9578 - val_loss: 0.3996
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9386 - loss: 0.4293
# Epoch 11: val_loss did not improve from 0.39964
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.9363 - loss: 0.4326 - val_accuracy: 0.9513 - val_loss: 0.4042
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9453 - loss: 0.4205
# Epoch 12: val_loss improved from 0.39964 to 0.39299, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9448 - loss: 0.4187 - val_accuracy: 0.9606 - val_loss: 0.3930
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9528 - loss: 0.3984
# Epoch 13: val_loss improved from 0.39299 to 0.38295, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 13: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9519 - loss: 0.3985 - val_accuracy: 0.9644 - val_loss: 0.3830
# Epoch 14/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9587 - loss: 0.3838
# Epoch 14: val_loss improved from 0.38295 to 0.35672, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9588 - loss: 0.3821 - val_accuracy: 0.9764 - val_loss: 0.3567
# Epoch 15/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9637 - loss: 0.3714
# Epoch 15: val_loss did not improve from 0.35672
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.9632 - loss: 0.3748 - val_accuracy: 0.9760 - val_loss: 0.3636
# Epoch 16/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9681 - loss: 0.3620
# Epoch 16: val_loss improved from 0.35672 to 0.33482, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - accuracy: 0.9687 - loss: 0.3631 - val_accuracy: 0.9853 - val_loss: 0.3348
# Epoch 17/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9724 - loss: 0.3483
# Epoch 17: val_loss did not improve from 0.33482
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9716 - loss: 0.3515 - val_accuracy: 0.9845 - val_loss: 0.3359
# Epoch 18/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9769 - loss: 0.3418
# Epoch 18: val_loss did not improve from 0.33482
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.9761 - loss: 0.3444 - val_accuracy: 0.9814 - val_loss: 0.3394
# Epoch 19/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9760 - loss: 0.3405
# Epoch 19: val_loss improved from 0.33482 to 0.32763, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 19: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - accuracy: 0.9767 - loss: 0.3411 - val_accuracy: 0.9861 - val_loss: 0.3276
# Epoch 20/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9809 - loss: 0.3359
# Epoch 20: val_loss improved from 0.32763 to 0.31957, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 20: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - accuracy: 0.9823 - loss: 0.3313 - val_accuracy: 0.9923 - val_loss: 0.3196
# Epoch 21/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9856 - loss: 0.3210
# Epoch 21: val_loss improved from 0.31957 to 0.31194, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 21: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9856 - loss: 0.3204 - val_accuracy: 0.9934 - val_loss: 0.3119
# Epoch 22/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9867 - loss: 0.3149
# Epoch 22: val_loss did not improve from 0.31194
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.9849 - loss: 0.3206 - val_accuracy: 0.9911 - val_loss: 0.3190
# Epoch 23/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9830 - loss: 0.3184
# Epoch 23: val_loss improved from 0.31194 to 0.30976, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 23: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9858 - loss: 0.3166 - val_accuracy: 0.9927 - val_loss: 0.3098
# Epoch 24/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9861 - loss: 0.3136
# Epoch 24: val_loss did not improve from 0.30976
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.9870 - loss: 0.3150 - val_accuracy: 0.9907 - val_loss: 0.3176
# Epoch 25/100
# 80/81 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9857 - loss: 0.3156
# Epoch 25: val_loss improved from 0.30976 to 0.30395, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 25: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - accuracy: 0.9868 - loss: 0.3160 - val_accuracy: 0.9942 - val_loss: 0.3040
# Epoch 26/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9917 - loss: 0.3042
# Epoch 26: val_loss did not improve from 0.30395
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.9906 - loss: 0.3063 - val_accuracy: 0.9923 - val_loss: 0.3112
# Epoch 27/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9911 - loss: 0.3029
# Epoch 27: val_loss improved from 0.30395 to 0.30343, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 27: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.9913 - loss: 0.3029 - val_accuracy: 0.9954 - val_loss: 0.3034
# Epoch 28/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9939 - loss: 0.2952
# Epoch 28: val_loss did not improve from 0.30343
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - accuracy: 0.9944 - loss: 0.2959 - val_accuracy: 0.9930 - val_loss: 0.3054
# Epoch 29/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9935 - loss: 0.3022
# Epoch 29: val_loss did not improve from 0.30343
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.9926 - loss: 0.3025 - val_accuracy: 0.9946 - val_loss: 0.3068
# Epoch 30/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9942 - loss: 0.2963
# Epoch 30: val_loss improved from 0.30343 to 0.29862, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 30: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - accuracy: 0.9941 - loss: 0.2959 - val_accuracy: 0.9969 - val_loss: 0.2986
# Epoch 31/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9943 - loss: 0.2935
# Epoch 31: val_loss improved from 0.29862 to 0.29745, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
#
# Epoch 31: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Base_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.9949 - loss: 0.2916 - val_accuracy: 0.9957 - val_loss: 0.2975
# Epoch 32/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9964 - loss: 0.2871
# ...
# Epoch 54: val_loss did not improve from 0.27699
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - accuracy: 0.9991 - loss: 0.2658 - val_accuracy: 0.9981 - val_loss: 0.2815
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9986 - loss: 0.2660
# Epoch 55: val_loss improved from 0.27699 to 0.27683, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 55: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9990 - loss: 0.2650 - val_accuracy: 0.9977 - val_loss: 0.2768
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9992 - loss: 0.2634
# Epoch 56: val_loss improved from 0.27683 to 0.27603, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 56: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 116ms/step - accuracy: 0.9991 - loss: 0.2646 - val_accuracy: 0.9977 - val_loss: 0.2760
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9993 - loss: 0.2646
# Epoch 57: val_loss did not improve from 0.27603
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step - accuracy: 0.9989 - loss: 0.2652 - val_accuracy: 0.9954 - val_loss: 0.2816
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9992 - loss: 0.2650
# Epoch 58: val_loss did not improve from 0.27603
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9991 - loss: 0.2651 - val_accuracy: 0.9977 - val_loss: 0.2774
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.2629
# Epoch 59: val_loss improved from 0.27603 to 0.27424, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 59: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 1.0000 - loss: 0.2630 - val_accuracy: 0.9985 - val_loss: 0.2742
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9995 - loss: 0.2627
# Epoch 60: val_loss did not improve from 0.27424
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - accuracy: 0.9992 - loss: 0.2638 - val_accuracy: 0.9992 - val_loss: 0.2765
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9992 - loss: 0.2636
# Epoch 61: val_loss did not improve from 0.27424
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9986 - loss: 0.2652 - val_accuracy: 0.9988 - val_loss: 0.2783
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9989 - loss: 0.2650
# Epoch 62: val_loss did not improve from 0.27424
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 108ms/step - accuracy: 0.9993 - loss: 0.2640 - val_accuracy: 0.9973 - val_loss: 0.2761
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9997 - loss: 0.2619
# Epoch 63: val_loss improved from 0.27424 to 0.27359, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 63: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 117ms/step - accuracy: 0.9999 - loss: 0.2616 - val_accuracy: 0.9992 - val_loss: 0.2736
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9999 - loss: 0.2612
# Epoch 64: val_loss did not improve from 0.27359
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 107ms/step - accuracy: 0.9999 - loss: 0.2614 - val_accuracy: 0.9988 - val_loss: 0.2749
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9997 - loss: 0.2613
# Epoch 65: val_loss did not improve from 0.27359
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9997 - loss: 0.2613 - val_accuracy: 0.9985 - val_loss: 0.2737
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9997 - loss: 0.2610
# Epoch 66: val_loss improved from 0.27359 to 0.27358, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 66: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 118ms/step - accuracy: 0.9994 - loss: 0.2613 - val_accuracy: 0.9985 - val_loss: 0.2736
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.2602
# Epoch 67: val_loss improved from 0.27358 to 0.27143, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 67: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 1.0000 - loss: 0.2600 - val_accuracy: 0.9988 - val_loss: 0.2714
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9999 - loss: 0.2599
# Epoch 68: val_loss did not improve from 0.27143
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 17s 114ms/step - accuracy: 0.9999 - loss: 0.2599 - val_accuracy: 0.9973 - val_loss: 0.2734
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9998 - loss: 0.2602
# Epoch 69: val_loss did not improve from 0.27143
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.9999 - loss: 0.2603 - val_accuracy: 0.9985 - val_loss: 0.2725
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.2599
# Epoch 70: val_loss did not improve from 0.27143
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - accuracy: 1.0000 - loss: 0.2598 - val_accuracy: 0.9985 - val_loss: 0.2722
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.9998 - loss: 0.2599
# Epoch 71: val_loss improved from 0.27143 to 0.27116, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 71: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 117ms/step - accuracy: 0.9999 - loss: 0.2598 - val_accuracy: 0.9985 - val_loss: 0.2712
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9998 - loss: 0.2595
# Epoch 72: val_loss did not improve from 0.27116
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 100ms/step - accuracy: 0.9998 - loss: 0.2597 - val_accuracy: 0.9985 - val_loss: 0.2735
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9994 - loss: 0.2607
# Epoch 73: val_loss did not improve from 0.27116
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9997 - loss: 0.2602 - val_accuracy: 0.9981 - val_loss: 0.2721
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9998 - loss: 0.2594
# Epoch 74: val_loss improved from 0.27116 to 0.27077, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 74: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 117ms/step - accuracy: 0.9998 - loss: 0.2595 - val_accuracy: 0.9992 - val_loss: 0.2708
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.2587
# Epoch 75: val_loss improved from 0.27077 to 0.27068, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 75: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 0.2586 - val_accuracy: 0.9988 - val_loss: 0.2707
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9999 - loss: 0.2587
# Epoch 76: val_loss did not improve from 0.27068
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.9999 - loss: 0.2586 - val_accuracy: 0.9988 - val_loss: 0.2716
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.2583
# Epoch 77: val_loss did not improve from 0.27068
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 107ms/step - accuracy: 1.0000 - loss: 0.2584 - val_accuracy: 0.9985 - val_loss: 0.2716
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.2584
# Epoch 78: val_loss did not improve from 0.27068
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 110ms/step - accuracy: 1.0000 - loss: 0.2582 - val_accuracy: 0.9992 - val_loss: 0.2717
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.2580
# Epoch 79: val_loss did not improve from 0.27068
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 1.0000 - loss: 0.2582 - val_accuracy: 0.9988 - val_loss: 0.2712
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.2579
# Epoch 80: val_loss improved from 0.27068 to 0.27047, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 80: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 0.2579 - val_accuracy: 0.9988 - val_loss: 0.2705
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.2584
# Epoch 81: val_loss did not improve from 0.27047
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.9998 - loss: 0.2589 - val_accuracy: 0.9981 - val_loss: 0.2737
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9995 - loss: 0.2595
# Epoch 82: val_loss did not improve from 0.27047
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 110ms/step - accuracy: 0.9996 - loss: 0.2592 - val_accuracy: 0.9981 - val_loss: 0.2713
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 1.0000 - loss: 0.2585
# Epoch 83: val_loss did not improve from 0.27047
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - accuracy: 1.0000 - loss: 0.2582 - val_accuracy: 0.9985 - val_loss: 0.2707
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.2578
# Epoch 84: val_loss did not improve from 0.27047
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 1.0000 - loss: 0.2579 - val_accuracy: 0.9988 - val_loss: 0.2706
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.9999 - loss: 0.2582
# Epoch 85: val_loss improved from 0.27047 to 0.27025, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 85: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9999 - loss: 0.2581 - val_accuracy: 0.9988 - val_loss: 0.2702
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.2577
# Epoch 86: val_loss improved from 0.27025 to 0.26960, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 86: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.9999 - loss: 0.2580 - val_accuracy: 0.9988 - val_loss: 0.2696
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.2576
# Epoch 87: val_loss did not improve from 0.26960
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.9999 - loss: 0.2577 - val_accuracy: 0.9988 - val_loss: 0.2714
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.2577
# Epoch 88: val_loss did not improve from 0.26960
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 1.0000 - loss: 0.2577 - val_accuracy: 0.9992 - val_loss: 0.2703
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.2578
# Epoch 89: val_loss improved from 0.26960 to 0.26949, saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
#
# Epoch 89: finished saving model to /content/drive/My Drive/Classification/mambahsi/models/MambaHSI_Large_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 1.0000 - loss: 0.2577 - val_accuracy: 0.9988 - val_loss: 0.2695
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.2575
# Epoch 90: val_loss did not improve from 0.26949
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 1.0000 - loss: 0.2574 - val_accuracy: 0.9992 - val_loss: 0.2700
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.2577
# Epoch 91: val_loss did not improve from 0.26949
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - accuracy: 1.0000 - loss: 0.2577 - val_accuracy: 0.9988 - val_loss: 0.2702
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.2575
# Epoch 92: val_loss did not improve from 0.26949
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 1.0000 - loss: 0.2576 - val_accuracy: 0.9988 - val_loss: 0.2700
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9999 - loss: 0.2577
# Epoch 93: val_loss did not improve from 0.26949
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.9998 - loss: 0.2579 - val_accuracy: 0.9992 - val_loss: 0.2707
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.2575
# Epoch 94: val_loss did not improve from 0.26949
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 103ms/step - accuracy: 1.0000 - loss: 0.2575 - val_accuracy: 0.9988 - val_loss: 0.2696
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.2573
# Epoch 95: val_loss did not improve from 0.26949
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 1.0000 - loss: 0.2573 - val_accuracy: 0.9985 - val_loss: 0.2701
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.2573
# Epoch 96: val_loss did not improve from 0.26949
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step - accuracy: 1.0000 - loss: 0.2571 - val_accuracy: 0.9988 - val_loss: 0.2706
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.2572
# Epoch 97: val_loss did not improve from 0.26949
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 1.0000 - loss: 0.2572 - val_accuracy: 0.9988 - val_loss: 0.2704
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 1.0000 - loss: 0.2574
# Epoch 98: val_loss did not improve from 0.26949
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - accuracy: 0.9999 - loss: 0.2574 - val_accuracy: 0.9988 - val_loss: 0.2700
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9996 - loss: 0.2578
# Epoch 99: val_loss did not improve from 0.26949
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.9999 - loss: 0.2575 - val_accuracy: 0.9988 - val_loss: 0.2696
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.2573
# Epoch 100: val_loss did not improve from 0.26949
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 1.0000 - loss: 0.2573 - val_accuracy: 0.9992 - val_loss: 0.2699
# MambaHSI_Large completed full training: 100/100 epochs.
#             model   capacity_tag  test_accuracy     kappa  macro_f1  \
# 0   MambaHSI_Base  mambahsi_arch       0.998376  0.997798  0.998719
# 1  MambaHSI_Large  mambahsi_arch       0.998144  0.997482  0.998521
# 2  MambaHSI_Small  mambahsi_arch       0.997448  0.996539  0.997393
#
#    weighted_f1   val_nll  test_nll  val_brier  test_brier  test_ece_15bin  \
# 0     0.998375  0.023024  0.023674   0.002545    0.002787        0.020523
# 1     0.998142  0.022681  0.022995   0.002228    0.002734        0.019310
# 2     0.997447  0.022058  0.022926   0.004959    0.005357        0.017403
#
#    epochs_configured  epochs_ran  train_time_sec  \
# 0                100         100      416.761486
# 1                100         100     1033.390829
# 2                100         100      144.359482
#
#                                      best_model_path  \
# 0  /content/drive/My Drive/Classification/mambahs...
# 1  /content/drive/My Drive/Classification/mambahs...
# 2  /content/drive/My Drive/Classification/mambahs...
#
#                                     final_model_path
# 0  /content/drive/My Drive/Classification/mambahs...
# 1  /content/drive/My Drive/Classification/mambahs...
# 2  /content/drive/My Drive/Classification/mambahs...

# %% [markdown]
# # 7.0 — Results & Metrics
# Save classification summaries to CSV / JSON, then plot training curves, cross-model bar charts, calibration proxies, and confusion matrices.

# %% [markdown]
# ## 7.1 — Save summary CSV and per-model JSON reports

# %%
summary_path = RESULTS_DIR / "classification_summary.csv"
summary_df.to_csv(summary_path, index=False)
print("Saved summary:", summary_path)

for model_name, artifact in model_artifacts.items():
    report_path = RESULTS_DIR / f"{model_name}_classification_report.json"
    with open(report_path, "w", encoding="utf-8") as f:
        json.dump(artifact["report"], f, indent=2)

print("Per-model classification reports saved to:", RESULTS_DIR)
summary_df
# Out:
# Saved summary: /content/drive/My Drive/Classification/mambahsi/results/classification_summary.csv
# Per-model classification reports saved to: /content/drive/My Drive/Classification/mambahsi/results
#             model   capacity_tag  test_accuracy     kappa  macro_f1  \
# 0   MambaHSI_Base  mambahsi_arch       0.998376  0.997798  0.998719
# 1  MambaHSI_Large  mambahsi_arch       0.998144  0.997482  0.998521
# 2  MambaHSI_Small  mambahsi_arch       0.997448  0.996539  0.997393
#
#    weighted_f1   val_nll  test_nll  val_brier  test_brier  test_ece_15bin  \
# 0     0.998375  0.023024  0.023674   0.002545    0.002787        0.020523
# 1     0.998142  0.022681  0.022995   0.002228    0.002734        0.019310
# 2     0.997447  0.022058  0.022926   0.004959    0.005357        0.017403
#
#    epochs_configured  epochs_ran  train_time_sec  \
# 0                100         100      416.761486
# 1                100         100     1033.390829
# 2                100         100      144.359482
#
#                                      best_model_path  \
# 0  /content/drive/My Drive/Classification/mambahs...
# 1  /content/drive/My Drive/Classification/mambahs...
# 2  /content/drive/My Drive/Classification/mambahs...
#
#                                     final_model_path
# 0  /content/drive/My Drive/Classification/mambahs...
# 1  /content/drive/My Drive/Classification/mambahs...
# 2  /content/drive/My Drive/Classification/mambahs...

# %% [markdown]
# ## 7.2 — Training curves (accuracy and loss per epoch)

# %%
for model_name, artifact in model_artifacts.items():
    hist   = artifact["history"]
    epochs = np.arange(1, len(hist["loss"]) + 1)

    fig, ax1 = plt.subplots(figsize=(12, 5))
    ax1.plot(epochs, hist["accuracy"],     color="#1f77b4", linewidth=2,   label="Train Accuracy")
    ax1.plot(epochs, hist["val_accuracy"], color="#2ca02c", linewidth=2, linestyle="--", label="Val Accuracy")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Accuracy")
    ax1.set_ylim(0, 1.0)
    ax1.grid(True, alpha=0.25)

    ax2 = ax1.twinx()
    ax2.plot(epochs, hist["loss"],     color="#111111", linewidth=1.8,   label="Train Loss")
    ax2.plot(epochs, hist["val_loss"], color="#d62728", linewidth=1.8, linestyle="--", label="Val Loss")
    ax2.set_ylabel("Loss")

    lines  = ax1.get_lines() + ax2.get_lines()
    labels = [ln.get_label() for ln in lines]
    ax1.legend(lines, labels, loc="upper right", frameon=True)
    plt.title(f"{model_name}: Accuracy / Loss vs Epoch")
    plt.tight_layout()

    curve_path = PLOT_DIR / f"{model_name}_training_curves.png"
    plt.savefig(curve_path, dpi=200, bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## 7.3 — Cross-model comparison bar charts

# %%
plot_df = summary_df[[
    "model", "test_accuracy", "macro_f1", "kappa", "train_time_sec",
    "test_nll", "test_brier", "test_ece_15bin",
]].copy()

fig, axes = plt.subplots(2, 2, figsize=(15, 9))
axes    = axes.flatten()
palette = ["#4c72b0", "#55a868", "#c44e52"]

metric_specs = [
    ("test_accuracy",  "Test Accuracy",   (0.0, 1.0), "{:.3f}"),
    ("macro_f1",       "Macro F1",        (0.0, 1.0), "{:.3f}"),
    ("kappa",          "Cohen Kappa",     (0.0, 1.0), "{:.3f}"),
    ("train_time_sec", "Train Time (sec)", None,       "{:.1f}"),
]

for ax, (col, title, ylim, fmt) in zip(axes, metric_specs):
    local = plot_df[["model", col]].copy()
    bars  = ax.bar(local["model"], local[col], color=palette[:len(local)])
    ax.set_title(title)
    ax.set_xlabel("Model")
    ax.set_ylabel(title)
    if ylim is not None:
        ax.set_ylim(*ylim)
    ax.grid(axis="y", alpha=0.25)
    for patch in bars:
        height = patch.get_height()
        xpos   = patch.get_x() + patch.get_width() / 2
        offset = (ylim[1] - ylim[0]) * 0.02 if ylim else max(local[col].max() * 0.02, 0.05)
        ax.text(xpos, height + offset, fmt.format(height), ha="center", va="bottom", fontsize=9)

plt.suptitle("Single-Head Model Comparison", y=1.02, fontsize=14)
plt.tight_layout()
comparison_path = PLOT_DIR / "model_comparison_metrics.png"
plt.savefig(comparison_path, dpi=200, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 7.4 — Calibration proxy metrics and confusion matrices

# %%
# Calibration proxy chart (lower is better for all three metrics)
fig, ax     = plt.subplots(figsize=(12, 5))
calib_cols  = ["test_nll", "test_brier", "test_ece_15bin"]
calib_df    = plot_df[["model"] + calib_cols].set_index("model")
calib_df.plot(kind="bar", ax=ax, rot=0)
ax.set_title("Uncertainty Proxy Metrics (Lower is Better)")
ax.set_ylabel("Metric Value")
ax.grid(axis="y", alpha=0.25)
plt.tight_layout()
calib_path = PLOT_DIR / "uncertainty_proxy_metrics.png"
plt.savefig(calib_path, dpi=200, bbox_inches="tight")
plt.show()

# Side-by-side confusion matrices
class_ticks = [str(i + 1) for i in range(num_classes)]
fig, axes   = plt.subplots(1, len(model_artifacts), figsize=(7 * len(model_artifacts), 5.5))
if len(model_artifacts) == 1:
    axes = [axes]

for ax, (model_name, artifact) in zip(axes, model_artifacts.items()):
    sns.heatmap(
        artifact["confusion_matrix"],
        annot=True, fmt="d", cmap="Blues",
        xticklabels=class_ticks, yticklabels=class_ticks,
        cbar=False, ax=ax,
    )
    ax.set_title(f"{model_name} Confusion Matrix")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("True")

plt.tight_layout()
cm_path = PLOT_DIR / "confusion_matrices_side_by_side.png"
plt.savefig(cm_path, dpi=220, bbox_inches="tight")
plt.show()
print("Saved confusion matrix figure:", cm_path)
print("All training plots saved to:", PLOT_DIR)
# Out:
# Saved confusion matrix figure: /content/drive/My Drive/Classification/mambahsi/results/training_plots/confusion_matrices_side_by_side.png
# All training plots saved to: /content/drive/My Drive/Classification/mambahsi/results/training_plots

# %% [markdown]
# # 8.0 — Scene Visualisation
# Load the saved best models, run dense patch-by-patch inference over the entire scene, and save classified maps as PNGs and an Excel workbook.

# %% [markdown]
# ## 8.1 — Visualisation helpers

# %%
CUSTOM_OBJECTS = {
    "PatchExtractor":       PatchExtractor,
    "PatchPositionEncoder": PatchPositionEncoder,
    "SpectralScanLayer":    SpectralScanLayer,
    "SelectiveSSMBlock":    SelectiveSSMBlock,
}


def get_scene_rgb(x_img, bands):
    """Select three bands as an approximate RGB composite; clip to [0, 1]."""
    if bands >= 6:
        rgb_idx = [bands // 2 - 1, bands // 2, bands // 2 + 1]
    elif bands >= 3:
        rgb_idx = [0, 1, 2]
    else:
        raise ValueError(f"Need at least 3 bands to form RGB, got {bands}.")
    return np.clip(x_img[:, :, rgb_idx], 0.0, 1.0)


def get_display_cmap(num_classes):
    """Build a ListedColormap: index 0 = background black, 1..K = class colours."""
    return ListedColormap([BACKGROUND_COLOR] + CLASS_COLOR_BASE[:num_classes])


def predict_full_scene_labels(model, x_img, patch_size=9, batch_size=256):
    """Run dense sliding-window inference row-by-row; returns a (H, W) label map."""
    pad   = patch_size // 2
    x_pad = np.pad(x_img, ((pad, pad), (pad, pad), (0, 0)), mode="edge")
    preds = np.zeros((x_img.shape[0], x_img.shape[1]), dtype=np.int32)

    for r in range(x_img.shape[0]):
        row_patches = np.empty(
            (x_img.shape[1], patch_size, patch_size, x_img.shape[-1]),
            dtype=np.float32,
        )
        for c in range(x_img.shape[1]):
            row_patches[c] = x_pad[r:r + patch_size, c:c + patch_size, :]

        row_prob  = model.predict(row_patches, batch_size=batch_size, verbose=0)
        preds[r]  = np.argmax(row_prob, axis=1) + 1  # back to 1..K

    return preds


def load_saved_models_for_visualization(model_dir, custom_objects):
    """Attempt to load all three best models; return dicts of loaded and missing."""
    model_files = {
        "MambaHSI_Small": model_dir / "MambaHSI_Small_best.keras",
        "MambaHSI_Base":  model_dir / "MambaHSI_Base_best.keras",
        "MambaHSI_Large": model_dir / "MambaHSI_Large_best.keras",
    }
    loaded, missing = {}, {}
    for model_key, model_path in model_files.items():
        if not model_path.exists():
            missing[model_key] = f"Missing file: {model_path}"
            continue
        try:
            loaded[model_key] = keras.models.load_model(
                model_path, custom_objects=custom_objects,
                compile=False, safe_mode=False,
            )
        except Exception as exc:
            missing[model_key] = f"Load failed: {exc}"
    return loaded, missing


def save_single_panel(image, title, save_path, cmap=None, vmin=None, vmax=None):
    """Save a single image panel as a high-DPI PNG."""
    fig, ax = plt.subplots(figsize=(8, 6))
    if cmap is None:
        ax.imshow(image)
    else:
        ax.imshow(image, cmap=cmap, vmin=vmin, vmax=vmax)
    ax.set_title(title, fontsize=14)
    ax.axis("off")
    fig.tight_layout()
    fig.savefig(save_path, dpi=220, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print("Saved:", save_path)


def save_combined_overview(rgb_image, y_true, pred_maps, missing_info, num_classes, save_path):
    """Save a five-panel side-by-side overview: RGB, GT, and one panel per model."""
    cmap   = get_display_cmap(num_classes)
    panels = [
        ("Approximate RGB",                    rgb_image,                       "rgb"),
        ("True Label Map",                     y_true,                          "label"),
        ("MambaHSI-Small Initial Classification", pred_maps.get("MambaHSI_Small"), "label"),
        ("MambaHSI-Base Initial Classification",  pred_maps.get("MambaHSI_Base"),  "label"),
        ("MambaHSI-Large Initial Classification", pred_maps.get("MambaHSI_Large"), "label"),
    ]

    fig, axes = plt.subplots(1, len(panels), figsize=(30, 7), sharex=True, sharey=True)
    for ax, (title, img, kind) in zip(axes, panels):
        ax.set_title(title, fontsize=13)
        if kind == "rgb":
            ax.imshow(img)
        elif img is None:
            ax.imshow(np.zeros_like(y_true), cmap=cmap, vmin=0, vmax=num_classes)
            key = {
                "MambaHSI-Small": "MambaHSI_Small",
                "MambaHSI-Base":  "MambaHSI_Base",
                "MambaHSI-Large": "MambaHSI_Large",
            }.get(
                next((k for k in ("MambaHSI-Small", "MambaHSI-Base", "MambaHSI-Large") if k in title), None)
            )
            ax.text(0.5, 0.5, missing_info.get(key, "Unavailable"),
                    ha="center", va="center", fontsize=10, wrap=True, transform=ax.transAxes)
        else:
            ax.imshow(img, cmap=cmap, vmin=0, vmax=num_classes)
        ax.axis("off")

    handles = [plt.Rectangle((0, 0), 1, 1, color=BACKGROUND_COLOR, label="Background")]
    for i in range(num_classes):
        handles.append(plt.Rectangle((0, 0), 1, 1, color=CLASS_COLOR_BASE[i], label=f"Class {i+1}"))
    fig.legend(handles=handles, loc="lower center", ncol=min(num_classes + 1, 8),
               bbox_to_anchor=(0.5, -0.02), frameon=True)
    fig.tight_layout(rect=[0, 0.05, 1, 1])
    fig.savefig(save_path, dpi=220, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print("Saved:", save_path)


def save_images_to_excel(excel_path, image_paths, sheet_name="Initial_Classification_Maps"):
    """Embed PNG images into an Excel workbook at fixed anchor positions."""
    if excel_path.exists():
        wb = load_workbook(excel_path)
        if sheet_name in wb.sheetnames:
            del wb[sheet_name]
        ws = wb.create_sheet(title=sheet_name)
    else:
        wb = Workbook()
        ws = wb.active
        ws.title = sheet_name

    anchors = ["A1", "J1", "A25", "J25", "A49", "J49"]
    for path, anchor in zip(image_paths, anchors):
        if path.exists():
            img        = XLImage(str(path))
            img.anchor = anchor
            ws.add_image(img)

    wb.save(excel_path)
    print("Saved Excel workbook:", excel_path)

# %% [markdown]
# ## 8.2 — Generate and save all scene maps

# %%
scene_rgb    = get_scene_rgb(x_img, B)
display_cmap = get_display_cmap(num_classes)

loaded_models, missing_models = load_saved_models_for_visualization(MODEL_DIR, CUSTOM_OBJECTS)
prediction_maps = {}

for model_key, loaded_model in loaded_models.items():
    print(f"Generating full-scene classified image for {model_key}...")
    prediction_maps[model_key] = predict_full_scene_labels(
        loaded_model, x_img, patch_size=PATCH_SIZE, batch_size=BATCH_SIZE,
    )
    print(f"{model_key} map shape:", prediction_maps[model_key].shape)

if missing_models:
    print("Some models could not be loaded:")
    for model_key, reason in missing_models.items():
        print(f"  - {model_key}: {reason}")

# Individual PNG paths
rgb_png      = VIS_DIR / "scene_rgb.png"
gt_png       = VIS_DIR / "ground_truth_label_map.png"
small_png    = VIS_DIR / "MambaHSI_Small_initial_classification.png"
base_png     = VIS_DIR / "MambaHSI_Base_initial_classification.png"
large_png    = VIS_DIR / "MambaHSI_Large_initial_classification.png"
overview_png = VIS_DIR / "combined_initial_classification_overview.png"

save_single_panel(scene_rgb, "Approximate RGB", rgb_png)
save_single_panel(y_img, "Ground Truth Label Map", gt_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("MambaHSI_Small") is not None:
    save_single_panel(prediction_maps["MambaHSI_Small"], "MambaHSI-Small Initial Classification",
                      small_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("MambaHSI_Base") is not None:
    save_single_panel(prediction_maps["MambaHSI_Base"], "MambaHSI-Base Initial Classification",
                      base_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("MambaHSI_Large") is not None:
    save_single_panel(prediction_maps["MambaHSI_Large"], "MambaHSI-Large Initial Classification",
                      large_png, cmap=display_cmap, vmin=0, vmax=num_classes)

save_combined_overview(
    rgb_image=scene_rgb, y_true=y_img, pred_maps=prediction_maps,
    missing_info=missing_models, num_classes=num_classes, save_path=overview_png,
)

image_paths_for_excel = [rgb_png, gt_png, small_png, base_png, large_png, overview_png]
save_images_to_excel(VIS_EXCEL_PATH, image_paths_for_excel, sheet_name="Initial_Classification_Maps")

print("All visualisation outputs saved to:", VIS_DIR)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
