# %% [markdown]
# # 1.0 — Setup & Imports
# Mount Google Drive and import all required standard, third-party, and ML libraries.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Standard library
import io
import json
import os
import random
import time
from pathlib import Path

# Third-party – data / viz
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.colors import ListedColormap
from openpyxl import Workbook, load_workbook
from openpyxl.drawing.image import Image as XLImage
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    cohen_kappa_score,
    confusion_matrix,
    f1_score,
    log_loss,
)
from sklearn.model_selection import train_test_split

# TensorFlow / Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers

sns.set_style("whitegrid")
print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# # 2.0 — Configuration
# All hyper-parameters, paths, and architecture configs are defined here. Change values in this single cell to reconfigure the whole notebook.

# %%
# ── Reproducibility ──────────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# ── Paths ─────────────────────────────────────────────────────────────
MODEL_DIR   = Path("/content/drive/My Drive/Classification/edl/models")
RESULTS_DIR = Path("/content/drive/My Drive/Classification/edl/results")
MODEL_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
PLOT_DIR    = RESULTS_DIR / "training_plots"
PLOT_DIR.mkdir(parents=True, exist_ok=True)
VIS_DIR     = RESULTS_DIR / "scene_visualizations"
VIS_DIR.mkdir(parents=True, exist_ok=True)

DATA_DIR   = Path("/content/drive/My Drive/Classification/data")
DATA_FILE  = DATA_DIR / "data.csv"
LABEL_FILE = DATA_DIR / "ref.csv"

# ── Dataset geometry ──────────────────────────────────────────────────
H, W, B    = 330, 307, 6          # height, width, bands
PATCH_SIZE  = 9
INNER_PATCH = 3                   # tokenisation patch size for GFNet / ViT

# ── Train / val / test splits ─────────────────────────────────────────
TRAIN_PERCENT          = 0.75
VAL_SPLIT_FROM_TRAIN   = 0.20

# ── Training ──────────────────────────────────────────────────────────
BATCH_SIZE    = 128
EPOCHS        = 100
LEARNING_RATE = 3e-4
DROPOUT_RATE  = 0.25
CAPACITY_PRESET = "legacy_arch"

TRAIN_CFG = {
    "label_smoothing": 0.05,   # retained for reference only; unused with the EDL loss
    "weight_decay":    1e-4,
    "clipnorm":        1.0,
    "cosine_alpha":    0.05,
}

# ── AlexNet legacy recipe (reproduces original single-head results) ────
ALEXNET_LEGACY_SPLIT_SEED   = 10
ALEXNET_LEGACY_TRAIN_PERCENT = 0.75
ALEXNET_LR_START = 0.01
ALEXNET_LR_MAX   = 0.02
ALEXNET_LR_MIN   = 0.005

# ── Architecture configs ──────────────────────────────────────────────
ALEXNET_CFG = {
    "conv_filters": [96, 256, 384, 384, 256],
    "dense_units":  [4096, 1024, 256, 32],
}

GFNET_CFG = {"hidden_dim": 512, "num_blocks": 5, "mlp_ratio": 4}
VIT_CFG   = {
    "projection_dim":    256,
    "num_heads":         4,
    "transformer_layers": 12,
    "mlp_multiplier":    2,
    "head_units":        [512, 256, 128, 64],
}

# Fallback configs used when Colab runs out of memory
GFNET_FALLBACK_CFG = {"hidden_dim": 384, "num_blocks": 4, "mlp_ratio": 4}
VIT_FALLBACK_CFG   = {
    "projection_dim":    192,
    "num_heads":         4,
    "transformer_layers": 8,
    "mlp_multiplier":    2,
    "head_units":        [384, 192, 96, 64],
}

# ── Visualisation palette ─────────────────────────────────────────────
CLASS_COLOR_BASE = [
    "#0000FF", "#00FF00", "#FF0000", "#00FFFF", "#FF00FF",
    "#FFFF00", "#A52A2A", "#FFA500", "#7FFF00", "#8A2BE2",
]
BACKGROUND_COLOR  = "#000000"
VIS_EXCEL_PATH    = VIS_DIR / "initial_classification_maps.xlsx"

print("Data file:    ", DATA_FILE)
print("Label file:   ", LABEL_FILE)
print("Model dir:    ", MODEL_DIR)
print("Results dir:  ", RESULTS_DIR)
print("Plot dir:     ", PLOT_DIR)
print("Arch preset:  ", CAPACITY_PRESET)
# Out:
# Data file:     /content/drive/My Drive/Classification/data/data.csv
# Label file:    /content/drive/My Drive/Classification/data/ref.csv
# Model dir:     /content/drive/My Drive/Classification/edl/models
# Results dir:   /content/drive/My Drive/Classification/edl/results
# Plot dir:      /content/drive/My Drive/Classification/edl/results/training_plots
# Arch preset:   legacy_arch

# %% [markdown]
# # 3.0 — Data Loading & Preprocessing
# Load the raw multispectral CSV files, apply per-band min-max normalisation, extract labelled patches, and create stratified train / val / test splits.

# %% [markdown]
# ## 3.1 — Loading and patch extraction helpers

# %%
def load_multispectral_6band(data_path, label_path, height, width, bands):
    """Load multispectral data and reference labels; normalise each band to [0, 1]."""
    x = pd.read_csv(data_path).to_numpy(dtype=np.float32).reshape(height, width, bands)
    y = pd.read_csv(label_path).to_numpy(dtype=np.int32).reshape(height, width)

    x_norm = np.empty_like(x, dtype=np.float32)
    for b in range(bands):
        band     = x[:, :, b]
        band_min = np.min(band)
        band_max = np.max(band)
        denom    = max(band_max - band_min, 1e-8)
        x_norm[:, :, b] = (band - band_min) / denom

    return x_norm, y


def extract_labeled_patches(x, y, patch_size=9):
    """Extract (patch_size × patch_size) spatial patches around every labelled pixel."""
    pad   = patch_size // 2
    x_pad = np.pad(x, ((pad, pad), (pad, pad), (0, 0)), mode="edge")

    coords  = np.argwhere(y > 0)
    patches = np.empty((coords.shape[0], patch_size, patch_size, x.shape[-1]), dtype=np.float32)
    labels  = np.empty((coords.shape[0],), dtype=np.int32)

    for i, (r, c) in enumerate(coords):
        patches[i] = x_pad[r:r + patch_size, c:c + patch_size, :]
        labels[i]  = int(y[r, c]) - 1  # convert class IDs to 0..C-1

    return patches, labels, coords

# %% [markdown]
# ## 3.2 — Load data and create splits

# %%
x_img, y_img = load_multispectral_6band(DATA_FILE, LABEL_FILE, H, W, B)
X, y, coords = extract_labeled_patches(x_img, y_img, PATCH_SIZE)

num_classes = int(np.unique(y).size)
input_shape = (PATCH_SIZE, PATCH_SIZE, B)

print("x_img:", x_img.shape, "  y_img:", y_img.shape)
print("Labelled samples:", X.shape[0])
print("Patch tensor:    ", X.shape)
print("Num classes:     ", num_classes)
# Out:
# x_img: (330, 307, 6)   y_img: (330, 307)
# Labelled samples: 17239
# Patch tensor:     (17239, 9, 9, 6)
# Num classes:      7

# %%
# Primary stratified split used by GFNet and ViT
x_train_full, x_test, y_train_full, y_test = train_test_split(
    X, y,
    train_size=TRAIN_PERCENT,
    random_state=SEED,
    stratify=y,
)
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full,
    test_size=VAL_SPLIT_FROM_TRAIN,
    random_state=SEED,
    stratify=y_train_full,
)

y_train_cat = keras.utils.to_categorical(y_train, num_classes)
y_val_cat   = keras.utils.to_categorical(y_val,   num_classes)
y_test_cat  = keras.utils.to_categorical(y_test,  num_classes)

print("Train:", x_train.shape, y_train.shape)
print("Val:  ", x_val.shape,   y_val.shape)
print("Test: ", x_test.shape,  y_test.shape)
# Out:
# Train: (10343, 9, 9, 6) (10343,)
# Val:   (2586, 9, 9, 6) (2586,)
# Test:  (4310, 9, 9, 6) (4310,)

# %%
# AlexNet legacy split — matches the original single-head notebook for
# uncertainty recovery (different seed and no val split)
x_train_alex, x_test_alex, y_train_alex, y_test_alex = train_test_split(
    X, y,
    train_size=ALEXNET_LEGACY_TRAIN_PERCENT,
    random_state=ALEXNET_LEGACY_SPLIT_SEED,
    stratify=y,
)
y_train_alex_cat = keras.utils.to_categorical(y_train_alex, num_classes)
y_test_alex_cat  = keras.utils.to_categorical(y_test_alex,  num_classes)

print("AlexNet Train:", x_train_alex.shape, y_train_alex.shape)
print("AlexNet Test: ", x_test_alex.shape,  y_test_alex.shape)
# Out:
# AlexNet Train: (12929, 9, 9, 6) (12929,)
# AlexNet Test:  (4310, 9, 9, 6) (4310,)

# %% [markdown]
# # 4.0 — Model Definitions
# Defines three single-head architectures: AlexNet-based CNN, Global Filter Network (GFNet), and Vision Transformer (ViT with U-Net style skip connections). Custom Keras layers are registered for serialisation.

# %% [markdown]
# ## 4.1 — Shared custom Keras layers (PatchExtractor, PatchPositionEncoder, PatchEncoderWithCLS)

# %%
@tf.keras.utils.register_keras_serializable()
class PatchExtractor(layers.Layer):
    """Extract non-overlapping spatial patches from an image tensor."""

    def __init__(self, patch_size=3, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        patches     = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        batch       = tf.shape(images)[0]
        num_patches = tf.shape(patches)[1] * tf.shape(patches)[2]
        patch_dim   = tf.shape(patches)[-1]
        return tf.reshape(patches, [batch, num_patches, patch_dim])

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"patch_size": self.patch_size})
        return cfg


@tf.keras.utils.register_keras_serializable()
class PatchPositionEncoder(layers.Layer):
    """Project patches to embedding dim and add learned positional embeddings."""

    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches      = num_patches
        self.projection_dim   = projection_dim
        self.projection       = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)

    def call(self, patches):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        return self.projection(patches) + self.position_embedding(positions)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"num_patches": self.num_patches, "projection_dim": self.projection_dim})
        return cfg


@tf.keras.utils.register_keras_serializable()
class PatchEncoderWithCLS(layers.Layer):
    """Project patches and prepend a learnable [CLS] token with positional embeddings."""

    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches      = num_patches
        self.projection_dim   = projection_dim
        self.projection       = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(input_dim=num_patches + 1, output_dim=projection_dim)

    def build(self, input_shape):
        self.cls_token = self.add_weight(
            name="cls_token",
            shape=(1, 1, self.projection_dim),
            initializer="zeros",
            trainable=True,
        )
        super().build(input_shape)

    def call(self, patches):
        batch      = tf.shape(patches)[0]
        patch_proj = self.projection(patches)
        cls_tokens = tf.repeat(self.cls_token, repeats=batch, axis=0)
        x          = tf.concat([cls_tokens, patch_proj], axis=1)
        positions  = tf.range(start=0, limit=self.num_patches + 1, delta=1)
        return x + self.position_embedding(positions)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"num_patches": self.num_patches, "projection_dim": self.projection_dim})
        return cfg

# %% [markdown]
# ### Evidential output activation
# For Evidential Deep Learning the final layer must output non-negative *evidence* rather than a softmax probability. We keep the architecture otherwise identical (same single final `Dense` layer, same layer count, so penultimate-layer feature extraction used elsewhere is unaffected) and only swap the activation function: `alpha = softplus(logits) + 1`. `alpha` is the Dirichlet concentration parameter per class; it is always ≥ 1 and is *not* normalised to sum to 1 (unlike softmax).

# %%
@tf.keras.utils.register_keras_serializable()
def evidence_activation(logits):
    """Map raw logits to Dirichlet alpha parameters: alpha = softplus(logits) + 1.

    softplus(.) guarantees non-negative 'evidence'; adding 1 gives the alpha used to
    parameterise a Dirichlet distribution over the class-probability simplex (Sensoy et al., 2018).
    """
    return tf.math.softplus(logits) + 1.0

# %% [markdown]
# ## 4.2 — AlexNet-based CNN

# %%
def build_alexnet(input_shape, num_classes, dropout_rate=0.25, cfg=None):
    """Build an AlexNet-inspired CNN with five conv layers and four dense layers."""
    cfg = cfg or ALEXNET_CFG

    inputs = keras.Input(shape=input_shape)
    x      = inputs
    for i, filters in enumerate(cfg["conv_filters"], start=1):
        x = layers.Conv2D(filters, (3, 3), activation="relu", padding="same", name=f"alex_conv_{i}")(x)

    x = layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same", name="alex_pool")(x)
    x = layers.Flatten(name="alex_flatten")(x)

    dense_units = cfg["dense_units"]
    x = layers.Dense(dense_units[0], activation="relu", name="alex_fc1")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)
    x = layers.Dense(dense_units[1], activation="relu", name="alex_fc2")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_2")(x)
    x = layers.Dense(dense_units[2], activation="relu", name="alex_fc3")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(x)
    x = layers.Dense(dense_units[3], activation="relu", name="alex_fc4")(x)

    outputs = layers.Dense(num_classes, activation=evidence_activation, name="alex_logits")(x)
    return keras.Model(inputs, outputs, name="AlexNet_SingleHead")

# %% [markdown]
# ## 4.3 — Global Filter Network (GFNet)

# %%
@tf.keras.utils.register_keras_serializable()
class GlobalFilterLayer(layers.Layer):
    """Apply learnable complex-valued filters in the 2-D frequency domain."""

    def __init__(self, token_side, **kwargs):
        super().__init__(**kwargs)
        self.token_side = token_side

    def build(self, input_shape):
        channels    = int(input_shape[-1])
        self.w_real = self.add_weight(
            name="w_real",
            shape=(self.token_side, self.token_side, channels),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.w_imag = self.add_weight(
            name="w_imag",
            shape=(self.token_side, self.token_side, channels),
            initializer="zeros",
            trainable=True,
        )
        super().build(input_shape)

    def call(self, x):
        batch      = tf.shape(x)[0]
        channels   = tf.shape(x)[-1]
        x_2d       = tf.reshape(x, [batch, self.token_side, self.token_side, channels])
        x_fft      = tf.signal.fft2d(tf.cast(x_2d, tf.complex64))
        w_complex  = tf.complex(self.w_real, self.w_imag)
        x_filtered = x_fft * w_complex
        x_spatial  = tf.math.real(tf.signal.ifft2d(x_filtered))
        return tf.reshape(x_spatial, [batch, self.token_side * self.token_side, channels])

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"token_side": self.token_side})
        return cfg


def gf_block(x, token_side, dim, mlp_ratio=4, dropout_rate=0.25, name_prefix="gf"):
    """Single GFNet residual block: global filter followed by a two-layer MLP."""
    # Legacy block style: one residual add after filter + MLP branch
    y = layers.LayerNormalization(name=f"{name_prefix}_ln1")(x)
    y = GlobalFilterLayer(token_side, name=f"{name_prefix}_gfilter")(y)
    y = layers.LayerNormalization(name=f"{name_prefix}_ln2")(y)
    y = layers.Dense(dim * mlp_ratio, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp1")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop1")(y)
    y = layers.Dense(dim, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp2")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop2")(y)
    return layers.Add(name=f"{name_prefix}_add")([x, y])


def build_gfnet(input_shape, num_classes, inner_patch=3, hidden_dim=512,
                num_blocks=5, mlp_ratio=4, dropout_rate=0.25):
    """Build a Global Filter Network (GFNet) single-head classifier."""
    num_patches = (input_shape[0] // inner_patch) * (input_shape[1] // inner_patch)
    token_side  = int(np.sqrt(num_patches))

    inputs = keras.Input(shape=input_shape)
    x      = PatchExtractor(inner_patch, name="gf_patch_extractor")(inputs)
    x      = PatchPositionEncoder(num_patches, hidden_dim, name="gf_patch_encoder")(x)
    x      = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)

    for i in range(num_blocks):
        x = gf_block(x, token_side, hidden_dim, mlp_ratio, dropout_rate, name_prefix=f"gf_block_{i+1}")

    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_2")(x)
    x = layers.LayerNormalization(name="gf_final_ln")(x)
    x = layers.GlobalAveragePooling1D(name="gf_gap")(x)
    x = layers.Flatten(name="gf_flatten")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(x)

    outputs = layers.Dense(num_classes, activation=evidence_activation, name="gf_logits")(x)
    return keras.Model(inputs, outputs, name="GFNet_SingleHead")

# %% [markdown]
# ## 4.4 — Vision Transformer with U-Net style skip connections

# %%
def transformer_block(x, num_heads, projection_dim, mlp_dim, dropout_rate, name_prefix):
    """Standard pre-LN transformer block with multi-head attention and a GELU MLP."""
    y = layers.LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_ln1")(x)
    y = layers.MultiHeadAttention(
        num_heads=num_heads, key_dim=projection_dim,
        dropout=dropout_rate, name=f"{name_prefix}_mha",
    )(y, y)
    x = layers.Add(name=f"{name_prefix}_add1")([y, x])

    y = layers.LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_ln2")(x)
    y = layers.Dense(mlp_dim, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp1")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop1")(y)
    y = layers.Dense(projection_dim, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp2")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop2")(y)
    return layers.Add(name=f"{name_prefix}_add2")([y, x])


def build_vit_unet_singlehead(
    input_shape, num_classes, inner_patch=3,
    projection_dim=256, num_heads=4, transformer_layers=12,
    mlp_multiplier=2, dropout_rate=0.25, head_units=(512, 256, 128, 64),
):
    """Build a ViT single-head classifier with U-Net style encoder–decoder skip connections."""
    num_patches = (input_shape[0] // inner_patch) * (input_shape[1] // inner_patch)

    inputs = keras.Input(shape=input_shape)
    x      = PatchExtractor(inner_patch, name="vit_patch_extractor")(inputs)
    x      = PatchEncoderWithCLS(num_patches, projection_dim, name="vit_patch_encoder")(x)

    block_list = []
    for i in range(transformer_layers):
        x = transformer_block(
            x, num_heads=num_heads, projection_dim=projection_dim,
            mlp_dim=projection_dim * mlp_multiplier,
            dropout_rate=0.1, name_prefix=f"vit_block_{i+1}",
        )
        if i <= transformer_layers // 2:
            block_list.append(x)
        else:
            x = layers.Add(name=f"vit_skip_add_{i+1}")([x, block_list[transformer_layers - i - 1]])

    x         = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)
    x         = layers.LayerNormalization(epsilon=1e-6, name="vit_cls_norm")(x)
    cls_token = layers.Lambda(lambda t: t[:, 0, :], name="vit_cls_token")(x)

    y = layers.Dense(head_units[0], activation=tf.keras.activations.gelu, name="vit_head_1")(cls_token)
    y = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(y)
    y = layers.Dense(head_units[1], activation=tf.keras.activations.gelu, name="vit_head_2")(y)
    y = layers.Dense(head_units[2], activation=tf.keras.activations.gelu, name="vit_head_3")(y)
    y = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_5")(y)
    y = layers.Dense(head_units[3], activation=tf.keras.activations.gelu, name="vit_head_4")(y)
    y = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_6")(y)

    outputs = layers.Dense(num_classes, activation=evidence_activation, name="vit_logits")(y)
    return keras.Model(inputs, outputs, name="ViT_UNet_SingleHead")

# %% [markdown]
# # 5.0 — Training & Evaluation Helpers
# Optimiser factory, learning-rate schedule, calibration metrics (Brier score, ECE), and the main `train_save_evaluate` function.

# %% [markdown]
# ## 5.1 — Evidential Deep Learning (EDL) loss
# Trains the model to output Dirichlet concentration parameters (`alpha`, produced by the `evidence_activation` final layer above) instead of a plain softmax distribution. The loss has two parts: an expected cross-entropy term that pushes `alpha` of the *correct* class up, and a KL-divergence regulariser that penalises the model for accumulating evidence on *incorrect* classes -- gradually phased in via an epoch-based annealing coefficient so early training is not destabilised (Sensoy et al., 2018). Because a standard `loss=...` argument to `model.compile()` has no way to see the current epoch number, `EDLAnnealer` is a small callback that writes the epoch into a shared `tf.Variable` that the loss closure reads from.

# %%
class EDLAnnealer(keras.callbacks.Callback):
    """Writes the current epoch number into a shared tf.Variable each epoch, so the EDL loss's
    KL-annealing coefficient can be computed inside a standard compile()-style loss function."""

    def __init__(self, epoch_variable):
        super().__init__()
        self.epoch_variable = epoch_variable

    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_variable.assign(float(epoch))


def make_edl_loss(epoch_variable, total_epochs, num_classes, sparse=False):
    """Build an EDL loss closure. `y_pred` here is `alpha` (see evidence_activation above),
    NOT a softmax probability vector."""
    total_epochs_f = tf.cast(total_epochs, tf.float32)

    def loss_fn(y_true, y_pred):
        alpha = y_pred
        S     = tf.reduce_sum(alpha, axis=-1, keepdims=True)

        if sparse:
            y_true_oh = tf.one_hot(tf.cast(y_true, tf.int32), depth=num_classes)
        else:
            y_true_oh = y_true

        # Expected cross-entropy: pushes alpha of the true class up
        loss_ce = tf.reduce_sum(y_true_oh * (tf.math.log(S) - tf.math.log(alpha)), axis=-1)

        # KL-divergence term: penalises evidence accumulated on incorrect classes.
        # alpha_tilde 'removes' the true class's evidence (sets it to 1) so only
        # non-target evidence is penalised.
        alpha_tilde     = y_true_oh + (1.0 - y_true_oh) * alpha
        annealing_coef  = tf.minimum(1.0, epoch_variable / (total_epochs_f / 2.0))
        kl_div = annealing_coef * tf.reduce_sum(
            tf.math.lgamma(alpha_tilde) - tf.math.lgamma(tf.ones_like(alpha_tilde)), axis=-1
        )
        return loss_ce + kl_div

    return loss_fn


def alpha_to_probs(alpha):
    """Convert Dirichlet alpha output to the expected class probabilities: p_hat = alpha / S."""
    alpha = np.asarray(alpha, dtype=np.float64)
    return alpha / alpha.sum(axis=-1, keepdims=True)

# %% [markdown]
# ## 5.2 — Calibration metrics

# %%
def multiclass_brier_score(y_onehot, y_prob):
    """Compute the multiclass Brier score (mean squared error over probability vectors)."""
    return float(np.mean(np.sum((y_prob - y_onehot) ** 2, axis=1)))


def expected_calibration_error(y_true, y_prob, n_bins=15):
    """Compute Expected Calibration Error (ECE) with equal-width confidence bins."""
    confidences = np.max(y_prob, axis=1)
    predictions = np.argmax(y_prob, axis=1)
    correct     = (predictions == y_true).astype(np.float32)
    bin_edges   = np.linspace(0.0, 1.0, n_bins + 1)
    ece         = 0.0

    for i in range(n_bins):
        lo, hi = bin_edges[i], bin_edges[i + 1]
        in_bin = (confidences >= lo) & (confidences <= hi if i == n_bins - 1 else confidences < hi)
        prop   = np.mean(in_bin)
        if prop > 0:
            ece += np.abs(np.mean(correct[in_bin]) - np.mean(confidences[in_bin])) * prop

    return float(ece)

# %% [markdown]
# ## 5.3 — Optimiser factory

# %%
def make_optimizer(num_train_samples):
    """Build an AdamW optimiser with a cosine-decay learning-rate schedule."""
    steps_per_epoch = int(np.ceil(num_train_samples / BATCH_SIZE))
    decay_steps     = max(1, steps_per_epoch * EPOCHS)
    lr_schedule     = keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=LEARNING_RATE,
        decay_steps=decay_steps,
        alpha=TRAIN_CFG["cosine_alpha"],
    )
    return keras.optimizers.AdamW(
        learning_rate=lr_schedule,
        weight_decay=TRAIN_CFG["weight_decay"],
        clipnorm=TRAIN_CFG["clipnorm"],
    )


def _alexnet_legacy_lr(epoch):
    """Cosine LR schedule for AlexNet, matching the original single-head script."""
    if EPOCHS <= 1:
        return ALEXNET_LR_START
    phase        = np.pi * epoch / (EPOCHS - 1)
    cosine_decay = 0.5 * (1.0 + np.cos(phase))
    return float((ALEXNET_LR_MAX - ALEXNET_LR_MIN) * cosine_decay + ALEXNET_LR_MIN)

# %% [markdown]
# ## 5.4 — Main training, saving, and evaluation function

# %%
def train_save_evaluate(model_name, model_builder, capacity_tag="max"):
    """Compile, train, save (best + final), and evaluate a single-head model.

    Returns a metrics dict, per-class classification report, confusion matrix,
    and the raw Keras history dict.
    """
    tf.keras.backend.clear_session()
    model     = model_builder()
    best_path  = MODEL_DIR / f"{model_name}_best.keras"
    final_path = MODEL_DIR / f"{model_name}_final.keras"

    # Shared epoch counter for the EDL loss's KL-annealing coefficient (see 5.1 above)
    edl_epoch_var = tf.Variable(0.0, trainable=False, dtype=tf.float32, name=f"{model_name}_edl_epoch")

    # AlexNet uses a legacy Adagrad + cosine LR schedule to match the original
    # single-head script for downstream uncertainty analysis.
    if model_name == "AlexNet_CNN":
        model.compile(
            optimizer=keras.optimizers.Adagrad(learning_rate=ALEXNET_LR_START),
            loss=make_edl_loss(edl_epoch_var, EPOCHS, num_classes, sparse=True),
            metrics=["accuracy"],
        )
        callbacks = [
            keras.callbacks.ModelCheckpoint(
                filepath=str(best_path), monitor="val_accuracy",
                mode="max", save_best_only=True, verbose=1,
            ),
            keras.callbacks.LearningRateScheduler(_alexnet_legacy_lr, verbose=0),
            EDLAnnealer(edl_epoch_var),
        ]
        x_tr, y_tr         = x_train_alex, y_train_alex
        x_va, y_va         = x_test_alex,  y_test_alex
        x_te, y_te, y_te_cat = x_test_alex, y_test_alex, y_test_alex_cat
        x_eval, y_eval, y_eval_cat = x_test_alex, y_test_alex, y_test_alex_cat
        fit_shuffle        = False
    else:
        # GFNet and ViT use AdamW + cosine decay with label smoothing
        model.compile(
            optimizer=make_optimizer(len(x_train)),
            loss=make_edl_loss(edl_epoch_var, EPOCHS, num_classes, sparse=False),
            metrics=["accuracy"],
        )
        callbacks = [
            keras.callbacks.ModelCheckpoint(
                filepath=str(best_path), monitor="val_loss",
                mode="min", save_best_only=True, verbose=1,
            ),
            EDLAnnealer(edl_epoch_var),
        ]
        x_tr, y_tr         = x_train, y_train_cat
        x_va, y_va         = x_val,   y_val_cat
        x_te, y_te, y_te_cat = x_test, y_test, y_test_cat
        x_eval, y_eval, y_eval_cat = x_val, y_val, y_val_cat
        fit_shuffle        = True

    train_start = time.perf_counter()
    history_obj = model.fit(
        x_tr, y_tr,
        validation_data=(x_va, y_va),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=callbacks,
        verbose=1,
        shuffle=fit_shuffle,
    )
    train_time_sec = float(time.perf_counter() - train_start)

    epochs_ran = int(len(history_obj.history.get("loss", [])))
    if epochs_ran != EPOCHS:
        print(f"WARNING: {model_name} ran {epochs_ran} epochs, expected {EPOCHS}.")
    else:
        print(f"{model_name} completed full training: {epochs_ran}/{EPOCHS} epochs.")

    model.save(final_path)

    # Model output is alpha (Dirichlet concentration), not a softmax probability --
    # convert to the expected probability p_hat = alpha / S before any downstream metric
    # (log-loss, Brier score, ECE, classification report) touches it.
    y_eval_prob = alpha_to_probs(model.predict(x_eval, batch_size=BATCH_SIZE, verbose=0))
    y_test_prob = alpha_to_probs(model.predict(x_te,   batch_size=BATCH_SIZE, verbose=0))
    y_test_pred = np.argmax(y_test_prob, axis=1)

    report = classification_report(y_te, y_test_pred, output_dict=True, zero_division=0)
    cm     = confusion_matrix(y_te, y_test_pred)

    row = {
        "model":            model_name,
        "capacity_tag":     capacity_tag,
        "test_accuracy":    float(accuracy_score(y_te, y_test_pred)),
        "kappa":            float(cohen_kappa_score(y_te, y_test_pred)),
        "macro_f1":         float(f1_score(y_te, y_test_pred, average="macro")),
        "weighted_f1":      float(f1_score(y_te, y_test_pred, average="weighted")),
        "val_nll":          float(log_loss(y_eval, y_eval_prob, labels=np.arange(num_classes))),
        "test_nll":         float(log_loss(y_te,   y_test_prob, labels=np.arange(num_classes))),
        "val_brier":        multiclass_brier_score(y_eval_cat, y_eval_prob),
        "test_brier":       multiclass_brier_score(y_te_cat,   y_test_prob),
        "test_ece_15bin":   expected_calibration_error(y_te, y_test_prob, n_bins=15),
        "epochs_configured": int(EPOCHS),
        "epochs_ran":       epochs_ran,
        "train_time_sec":   train_time_sec,
        "best_model_path":  str(best_path),
        "final_model_path": str(final_path),
    }
    return row, report, cm, history_obj.history

# %% [markdown]
# # 6.0 — Model Training
# Build factory lambdas, then loop over all three architectures. OOM errors on GFNet and ViT automatically retry with reduced fallback configs.

# %%
def build_gfnet_with_cfg(cfg):
    """Instantiate GFNet from a config dict."""
    return build_gfnet(
        input_shape, num_classes,
        inner_patch=INNER_PATCH,
        hidden_dim=cfg["hidden_dim"],
        num_blocks=cfg["num_blocks"],
        mlp_ratio=cfg["mlp_ratio"],
        dropout_rate=DROPOUT_RATE,
    )


def build_vit_with_cfg(cfg):
    """Instantiate ViT-UNet from a config dict."""
    return build_vit_unet_singlehead(
        input_shape, num_classes,
        inner_patch=INNER_PATCH,
        projection_dim=cfg["projection_dim"],
        num_heads=cfg["num_heads"],
        transformer_layers=cfg["transformer_layers"],
        mlp_multiplier=cfg["mlp_multiplier"],
        dropout_rate=DROPOUT_RATE,
        head_units=tuple(cfg["head_units"]),
    )


model_builders = {
    "AlexNet_CNN": lambda: build_alexnet(input_shape, num_classes,
                                         dropout_rate=DROPOUT_RATE, cfg=ALEXNET_CFG),
    "GFNet":       lambda: build_gfnet_with_cfg(GFNET_CFG),
    "ViT_UNet":    lambda: build_vit_with_cfg(VIT_CFG),
}

# %%
results_rows   = []
model_artifacts = {}

for model_name, builder in model_builders.items():
    print(f"\n{'=' * 25} Training {model_name} ({CAPACITY_PRESET}) {'=' * 25}")

    try:
        row, report, cm, history = train_save_evaluate(model_name, builder,
                                                       capacity_tag=CAPACITY_PRESET)
    except tf.errors.ResourceExhaustedError:
        # Automatically retry with a smaller fallback config to handle Colab OOM
        if model_name == "GFNet":
            print("OOM on GFNet legacy config. Retrying with fallback config.")
            tf.keras.backend.clear_session()
            row, report, cm, history = train_save_evaluate(
                model_name, lambda: build_gfnet_with_cfg(GFNET_FALLBACK_CFG),
                capacity_tag="fallback",
            )
        elif model_name == "ViT_UNet":
            print("OOM on ViT_UNet legacy config. Retrying with fallback config.")
            tf.keras.backend.clear_session()
            row, report, cm, history = train_save_evaluate(
                model_name, lambda: build_vit_with_cfg(VIT_FALLBACK_CFG),
                capacity_tag="fallback",
            )
        else:
            raise

    results_rows.append(row)
    model_artifacts[model_name] = {"report": report, "confusion_matrix": cm, "history": history}

summary_df = (
    pd.DataFrame(results_rows)
    .sort_values("test_accuracy", ascending=False)
    .reset_index(drop=True)
)
summary_df
# Out:
# ========================= Training AlexNet_CNN (legacy_arch) =========================
# Epoch 1/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.3764 - loss: 1.9129
# Epoch 1: val_accuracy improved from None to 0.42413, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 31s 159ms/step - accuracy: 0.4153 - loss: 1.8312 - val_accuracy: 0.4241 - val_loss: 1.6654 - learning_rate: 0.0200
# Epoch 2/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4321 - loss: 1.5644
# Epoch 2: val_accuracy improved from 0.42413 to 0.51299, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.4827 - loss: 1.4631 - val_accuracy: 0.5130 - val_loss: 1.5449 - learning_rate: 0.0200
# Epoch 3/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5406 - loss: 1.3912
# Epoch 3: val_accuracy improved from 0.51299 to 0.57169, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.5668 - loss: 1.3068 - val_accuracy: 0.5717 - val_loss: 1.3074 - learning_rate: 0.0200
# Epoch 4/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5652 - loss: 1.2833
# Epoch 4: val_accuracy improved from 0.57169 to 0.61995, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.5895 - loss: 1.2230 - val_accuracy: 0.6200 - val_loss: 1.1681 - learning_rate: 0.0200
# Epoch 5/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6293 - loss: 1.1666
# Epoch 5: val_accuracy improved from 0.61995 to 0.66357, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.6321 - loss: 1.1564 - val_accuracy: 0.6636 - val_loss: 1.1528 - learning_rate: 0.0199
# Epoch 6/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6563 - loss: 1.1401
# Epoch 6: val_accuracy improved from 0.66357 to 0.69234, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.6578 - loss: 1.1255 - val_accuracy: 0.6923 - val_loss: 1.1199 - learning_rate: 0.0199
# Epoch 7/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6735 - loss: 1.1226
# Epoch 7: val_accuracy improved from 0.69234 to 0.70348, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.6757 - loss: 1.1074 - val_accuracy: 0.7035 - val_loss: 1.1077 - learning_rate: 0.0199
# Epoch 8/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7021 - loss: 1.1014
# Epoch 8: val_accuracy improved from 0.70348 to 0.74339, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.7043 - loss: 1.0810 - val_accuracy: 0.7434 - val_loss: 1.0639 - learning_rate: 0.0198
# Epoch 9/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7273 - loss: 1.0641
# Epoch 9: val_accuracy improved from 0.74339 to 0.76682, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.7285 - loss: 1.0400 - val_accuracy: 0.7668 - val_loss: 0.9779 - learning_rate: 0.0198
# Epoch 10/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7402 - loss: 1.0219
# Epoch 10: val_accuracy did not improve from 0.76682
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.7434 - loss: 0.9958 - val_accuracy: 0.7278 - val_loss: 0.9950 - learning_rate: 0.0197
# Epoch 11/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7286 - loss: 1.0126
# Epoch 11: val_accuracy improved from 0.76682 to 0.77517, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 107ms/step - accuracy: 0.7458 - loss: 0.9731 - val_accuracy: 0.7752 - val_loss: 0.9178 - learning_rate: 0.0196
# Epoch 12/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7605 - loss: 0.9361
# Epoch 12: val_accuracy improved from 0.77517 to 0.79977, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.7677 - loss: 0.9080 - val_accuracy: 0.7998 - val_loss: 0.8243 - learning_rate: 0.0195
# Epoch 13/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7695 - loss: 0.8949
# Epoch 13: val_accuracy did not improve from 0.79977
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.7746 - loss: 0.8798 - val_accuracy: 0.7949 - val_loss: 0.8335 - learning_rate: 0.0195
# Epoch 14/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7902 - loss: 0.8494
# Epoch 14: val_accuracy improved from 0.79977 to 0.80070, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.7902 - loss: 0.8430 - val_accuracy: 0.8007 - val_loss: 0.8333 - learning_rate: 0.0194
# Epoch 15/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7952 - loss: 0.8515
# Epoch 15: val_accuracy did not improve from 0.80070
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.7494 - loss: 0.9441 - val_accuracy: 0.7420 - val_loss: 0.9437 - learning_rate: 0.0193
# Epoch 16/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7523 - loss: 0.9173
# Epoch 16: val_accuracy did not improve from 0.80070
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.7718 - loss: 0.8757 - val_accuracy: 0.7870 - val_loss: 0.8567 - learning_rate: 0.0192
# Epoch 17/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7941 - loss: 0.8340
# Epoch 17: val_accuracy improved from 0.80070 to 0.83828, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 17: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 84ms/step - accuracy: 0.8080 - loss: 0.7978 - val_accuracy: 0.8383 - val_loss: 0.8282 - learning_rate: 0.0191
# Epoch 18/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8335 - loss: 0.7637
# Epoch 18: val_accuracy improved from 0.83828 to 0.87471, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 18: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.8373 - loss: 0.7358 - val_accuracy: 0.8747 - val_loss: 0.7613 - learning_rate: 0.0189
# Epoch 19/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8526 - loss: 0.7124
# Epoch 19: val_accuracy did not improve from 0.87471
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.8537 - loss: 0.6960 - val_accuracy: 0.8645 - val_loss: 0.7142 - learning_rate: 0.0188
# Epoch 20/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8690 - loss: 0.6496
# Epoch 20: val_accuracy improved from 0.87471 to 0.89582, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 20: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 122ms/step - accuracy: 0.8749 - loss: 0.6325 - val_accuracy: 0.8958 - val_loss: 0.7092 - learning_rate: 0.0187
# Epoch 21/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8811 - loss: 0.6225
# Epoch 21: val_accuracy improved from 0.89582 to 0.91740, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 21: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.8868 - loss: 0.5880 - val_accuracy: 0.9174 - val_loss: 0.8236 - learning_rate: 0.0185
# Epoch 22/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8915 - loss: 0.5891
# Epoch 22: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.8960 - loss: 0.5546 - val_accuracy: 0.9125 - val_loss: 0.7422 - learning_rate: 0.0184
# Epoch 23/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8503 - loss: 107.0759
# Epoch 23: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.6522 - loss: 262.1414 - val_accuracy: 0.2107 - val_loss: 1.6599 - learning_rate: 0.0182
# Epoch 24/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3350 - loss: 1.5746
# Epoch 24: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.3949 - loss: 1.5336 - val_accuracy: 0.4241 - val_loss: 1.5996 - learning_rate: 0.0181
# Epoch 25/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4386 - loss: 1.3955
# Epoch 25: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.5037 - loss: 1.2631 - val_accuracy: 0.5984 - val_loss: 1.0617 - learning_rate: 0.0179
# Epoch 26/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5900 - loss: 1.0726
# Epoch 26: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.5948 - loss: 1.0369 - val_accuracy: 0.6044 - val_loss: 0.9854 - learning_rate: 0.0178
# Epoch 27/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5939 - loss: 1.0217
# Epoch 27: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.5963 - loss: 0.9939 - val_accuracy: 0.6032 - val_loss: 0.9543 - learning_rate: 0.0176
# Epoch 28/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5973 - loss: 0.9669
# Epoch 28: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.6018 - loss: 0.9405 - val_accuracy: 0.6121 - val_loss: 0.9221 - learning_rate: 0.0174
# Epoch 29/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6035 - loss: 0.9283
# Epoch 29: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.6058 - loss: 0.9047 - val_accuracy: 0.6114 - val_loss: 0.9090 - learning_rate: 0.0172
# Epoch 30/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6061 - loss: 0.8980
# Epoch 30: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.6096 - loss: 0.8766 - val_accuracy: 0.6139 - val_loss: 0.9306 - learning_rate: 0.0170
# Epoch 31/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6149 - loss: 0.8588
# Epoch 31: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.6212 - loss: 0.8378 - val_accuracy: 0.6188 - val_loss: 0.8139 - learning_rate: 0.0169
# Epoch 32/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6338 - loss: 0.8205
# Epoch 32: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.6332 - loss: 0.8135 - val_accuracy: 0.6432 - val_loss: 0.7972 - learning_rate: 0.0167
# Epoch 33/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6590 - loss: 0.7870
# Epoch 33: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.6671 - loss: 0.7741 - val_accuracy: 0.6900 - val_loss: 0.8408 - learning_rate: 0.0165
# Epoch 34/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6843 - loss: 0.7623
# Epoch 34: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.6896 - loss: 0.7439 - val_accuracy: 0.7251 - val_loss: 0.9734 - learning_rate: 0.0162
# Epoch 35/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7085 - loss: 0.7370
# Epoch 35: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7088 - loss: 0.7193 - val_accuracy: 0.7362 - val_loss: 0.7041 - learning_rate: 0.0160
# Epoch 36/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7189 - loss: 0.7101
# Epoch 36: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.7253 - loss: 0.6889 - val_accuracy: 0.7369 - val_loss: 0.6666 - learning_rate: 0.0158
# Epoch 37/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7308 - loss: 0.6671
# Epoch 37: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7348 - loss: 0.6494 - val_accuracy: 0.7534 - val_loss: 0.8106 - learning_rate: 0.0156
# Epoch 38/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7378 - loss: 0.6517
# Epoch 38: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.7430 - loss: 0.6238 - val_accuracy: 0.7599 - val_loss: 0.6645 - learning_rate: 0.0154
# Epoch 39/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7464 - loss: 0.6194
# Epoch 39: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.7470 - loss: 0.6065 - val_accuracy: 0.7661 - val_loss: 0.6249 - learning_rate: 0.0152
# Epoch 40/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7338 - loss: 0.6152
# Epoch 40: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.7427 - loss: 0.5883 - val_accuracy: 0.7650 - val_loss: 0.5583 - learning_rate: 0.0150
# Epoch 41/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7561 - loss: 0.5622
# Epoch 41: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7514 - loss: 0.5583 - val_accuracy: 0.7432 - val_loss: 0.6420 - learning_rate: 0.0147
# Epoch 42/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7585 - loss: 0.5525
# Epoch 42: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7649 - loss: 0.5228 - val_accuracy: 0.7712 - val_loss: 0.5136 - learning_rate: 0.0145
# Epoch 43/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7634 - loss: 0.5138
# Epoch 43: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7667 - loss: 0.4957 - val_accuracy: 0.7766 - val_loss: 0.5371 - learning_rate: 0.0143
# Epoch 44/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7615 - loss: 0.4978
# Epoch 44: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7694 - loss: 0.4747 - val_accuracy: 0.7770 - val_loss: 0.8041 - learning_rate: 0.0140
# Epoch 45/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7482 - loss: 0.5301
# Epoch 45: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.7679 - loss: 0.4715 - val_accuracy: 0.7726 - val_loss: 0.4731 - learning_rate: 0.0138
# Epoch 46/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7710 - loss: 0.4577
# Epoch 46: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7742 - loss: 0.4424 - val_accuracy: 0.7861 - val_loss: 0.4508 - learning_rate: 0.0136
# Epoch 47/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7654 - loss: 0.4629
# Epoch 47: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.7757 - loss: 0.4312 - val_accuracy: 0.7886 - val_loss: 0.4299 - learning_rate: 0.0133
# Epoch 48/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7753 - loss: 0.4070
# Epoch 48: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7806 - loss: 0.3939 - val_accuracy: 0.8023 - val_loss: 0.3859 - learning_rate: 0.0131
# Epoch 49/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7805 - loss: 0.3919
# Epoch 49: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.7885 - loss: 0.3703 - val_accuracy: 0.8165 - val_loss: 0.5277 - learning_rate: 0.0129
# Epoch 50/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7605 - loss: 0.4326
# Epoch 50: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7804 - loss: 0.3773 - val_accuracy: 0.8107 - val_loss: 0.4060 - learning_rate: 0.0126
# Epoch 51/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7877 - loss: 0.3456
# Epoch 51: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.7956 - loss: 0.3209 - val_accuracy: 0.8186 - val_loss: 0.3669 - learning_rate: 0.0124
# Epoch 52/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7891 - loss: 0.3397
# Epoch 52: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7942 - loss: 0.3173 - val_accuracy: 0.8309 - val_loss: 0.2931 - learning_rate: 0.0121
# Epoch 53/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7953 - loss: 0.3112
# Epoch 53: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8033 - loss: 0.2892 - val_accuracy: 0.8281 - val_loss: 0.4394 - learning_rate: 0.0119
# Epoch 54/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7994 - loss: 0.3137
# Epoch 54: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8078 - loss: 0.2830 - val_accuracy: 0.8360 - val_loss: 0.5767 - learning_rate: 0.0117
# Epoch 55/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8066 - loss: 0.3078
# Epoch 55: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8111 - loss: 0.2788 - val_accuracy: 0.8415 - val_loss: 0.2807 - learning_rate: 0.0114
# Epoch 56/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8136 - loss: 0.2709
# Epoch 56: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8237 - loss: 0.2416 - val_accuracy: 0.8564 - val_loss: 0.3041 - learning_rate: 0.0112
# Epoch 57/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8178 - loss: 0.2724
# Epoch 57: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8240 - loss: 0.2496 - val_accuracy: 0.8520 - val_loss: 0.2165 - learning_rate: 0.0110
# Epoch 58/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8294 - loss: 0.2434
# Epoch 58: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8358 - loss: 0.2236 - val_accuracy: 0.8756 - val_loss: 0.1935 - learning_rate: 0.0107
# Epoch 59/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8193 - loss: 0.2515
# Epoch 59: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8322 - loss: 0.2211 - val_accuracy: 0.8794 - val_loss: 0.1793 - learning_rate: 0.0105
# Epoch 60/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8428 - loss: 0.2061
# Epoch 60: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8512 - loss: 0.1836 - val_accuracy: 0.8940 - val_loss: 0.2861 - learning_rate: 0.0103
# Epoch 61/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8443 - loss: 0.2025
# Epoch 61: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.8521 - loss: 0.1740 - val_accuracy: 0.8977 - val_loss: 0.3035 - learning_rate: 0.0100
# Epoch 62/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8042 - loss: 0.3266
# Epoch 62: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8325 - loss: 0.2430 - val_accuracy: 0.8974 - val_loss: 0.2200 - learning_rate: 0.0098
# Epoch 63/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8404 - loss: 0.2175
# Epoch 63: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8489 - loss: 0.1907 - val_accuracy: 0.8905 - val_loss: 0.1278 - learning_rate: 0.0096
# Epoch 64/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8557 - loss: 0.1796
# Epoch 64: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8653 - loss: 0.1494 - val_accuracy: 0.8949 - val_loss: 0.4525 - learning_rate: 0.0094
# Epoch 65/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8681 - loss: 0.1662
# Epoch 65: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8752 - loss: 0.1292 - val_accuracy: 0.8898 - val_loss: 0.0974 - learning_rate: 0.0092
# Epoch 66/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8697 - loss: 0.1444
# Epoch 66: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8415 - loss: 0.2474 - val_accuracy: 0.7044 - val_loss: 0.4802 - learning_rate: 0.0090
# Epoch 67/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7113 - loss: 0.4213
# Epoch 67: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7482 - loss: 0.3547 - val_accuracy: 0.8125 - val_loss: 0.2773 - learning_rate: 0.0088
# Epoch 68/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8146 - loss: 0.1885
# Epoch 68: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8295 - loss: 0.1504 - val_accuracy: 0.8589 - val_loss: 0.1935 - learning_rate: 0.0085
# Epoch 69/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8415 - loss: 0.1466
# Epoch 69: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8483 - loss: 0.1213 - val_accuracy: 0.8596 - val_loss: 0.1649 - learning_rate: 0.0083
# Epoch 70/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8523 - loss: 0.1207
# Epoch 70: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8568 - loss: 0.1033 - val_accuracy: 0.8891 - val_loss: 0.2310 - learning_rate: 0.0081
# Epoch 71/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8564 - loss: 0.1181
# Epoch 71: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8629 - loss: 0.0999 - val_accuracy: 0.8993 - val_loss: 0.1317 - learning_rate: 0.0080
# Epoch 72/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8674 - loss: 0.1119
# Epoch 72: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8720 - loss: 0.0915 - val_accuracy: 0.9007 - val_loss: 0.0534 - learning_rate: 0.0078
# Epoch 73/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8675 - loss: 0.1190
# Epoch 73: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8771 - loss: 0.0893 - val_accuracy: 0.9053 - val_loss: 0.0664 - learning_rate: 0.0076
# Epoch 74/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8737 - loss: 0.0972
# Epoch 74: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8793 - loss: 0.0748 - val_accuracy: 0.9074 - val_loss: 0.2695 - learning_rate: 0.0074
# Epoch 75/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8792 - loss: 0.0834
# Epoch 75: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.8848 - loss: 0.0542 - val_accuracy: 0.9058 - val_loss: 0.0218 - learning_rate: 0.0072
# Epoch 76/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8877 - loss: 0.0679
# Epoch 76: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8918 - loss: 0.0473 - val_accuracy: 0.9109 - val_loss: 0.0194 - learning_rate: 0.0071
# Epoch 77/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8872 - loss: 0.0526
# Epoch 77: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.8934 - loss: 0.0367 - val_accuracy: 0.9053 - val_loss: 0.0186 - learning_rate: 0.0069
# Epoch 78/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8913 - loss: 0.0388
# Epoch 78: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8926 - loss: 0.0244 - val_accuracy: 0.9081 - val_loss: 0.2123 - learning_rate: 0.0068
# Epoch 79/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8916 - loss: 0.0582
# Epoch 79: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.8948 - loss: 0.0313 - val_accuracy: 0.9151 - val_loss: 0.0053 - learning_rate: 0.0066
# Epoch 80/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8963 - loss: 0.0281
# Epoch 80: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9034 - loss: 0.0054 - val_accuracy: 0.9139 - val_loss: 0.0249 - learning_rate: 0.0065
# Epoch 81/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9008 - loss: 0.0157
# Epoch 81: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9074 - loss: -0.0066 - val_accuracy: 0.9125 - val_loss: 0.0481 - learning_rate: 0.0063
# Epoch 82/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9019 - loss: 0.0208
# Epoch 82: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9030 - loss: 0.0050 - val_accuracy: 0.8884 - val_loss: 0.0119 - learning_rate: 0.0062
# Epoch 83/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8981 - loss: 0.0171
# Epoch 83: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9036 - loss: -0.0042 - val_accuracy: 0.9109 - val_loss: 0.0482 - learning_rate: 0.0061
# Epoch 84/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9072 - loss: 0.0065
# Epoch 84: val_accuracy did not improve from 0.91740
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9111 - loss: -0.0168 - val_accuracy: 0.9148 - val_loss: 0.0227 - learning_rate: 0.0059
# Epoch 85/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9051 - loss: -0.0098
# Epoch 85: val_accuracy improved from 0.91740 to 0.92552, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 85: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 13s 131ms/step - accuracy: 0.9100 - loss: -0.0270 - val_accuracy: 0.9255 - val_loss: 0.0325 - learning_rate: 0.0058
# Epoch 86/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9054 - loss: -0.0135
# Epoch 86: val_accuracy did not improve from 0.92552
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.9105 - loss: -0.0375 - val_accuracy: 0.9165 - val_loss: -0.0098 - learning_rate: 0.0057
# Epoch 87/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9076 - loss: -0.0220
# Epoch 87: val_accuracy improved from 0.92552 to 0.92784, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 87: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 118ms/step - accuracy: 0.9124 - loss: -0.0413 - val_accuracy: 0.9278 - val_loss: 0.1749 - learning_rate: 0.0056
# Epoch 88/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9081 - loss: -0.0252
# Epoch 88: val_accuracy improved from 0.92784 to 0.92970, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 88: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 84ms/step - accuracy: 0.9126 - loss: -0.0518 - val_accuracy: 0.9297 - val_loss: -0.0512 - learning_rate: 0.0055
# Epoch 89/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9111 - loss: -0.0258
# Epoch 89: val_accuracy did not improve from 0.92970
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - accuracy: 0.9145 - loss: -0.0465 - val_accuracy: 0.9100 - val_loss: 0.0335 - learning_rate: 0.0055
# Epoch 90/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9032 - loss: -0.0047
# Epoch 90: val_accuracy did not improve from 0.92970
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9117 - loss: -0.0353 - val_accuracy: 0.9262 - val_loss: -0.0751 - learning_rate: 0.0054
# Epoch 91/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9180 - loss: -0.0516
# Epoch 91: val_accuracy improved from 0.92970 to 0.93202, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 91: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.9209 - loss: -0.0681 - val_accuracy: 0.9320 - val_loss: -0.0469 - learning_rate: 0.0053
# Epoch 92/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9143 - loss: -0.0445
# Epoch 92: val_accuracy did not improve from 0.93202
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9189 - loss: -0.0669 - val_accuracy: 0.9262 - val_loss: -0.0543 - learning_rate: 0.0052
# Epoch 93/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9185 - loss: -0.0652
# Epoch 93: val_accuracy improved from 0.93202 to 0.93271, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 93: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step - accuracy: 0.9199 - loss: -0.0829 - val_accuracy: 0.9327 - val_loss: -0.0666 - learning_rate: 0.0052
# Epoch 94/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9189 - loss: -0.0592
# Epoch 94: val_accuracy did not improve from 0.93271
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9177 - loss: -0.0772 - val_accuracy: 0.9323 - val_loss: -0.0780 - learning_rate: 0.0051
# Epoch 95/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9240 - loss: -0.0818
# Epoch 95: val_accuracy did not improve from 0.93271
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9262 - loss: -0.0960 - val_accuracy: 0.9276 - val_loss: -0.0690 - learning_rate: 0.0051
# Epoch 96/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9168 - loss: -0.0699
# Epoch 96: val_accuracy improved from 0.93271 to 0.93411, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 96: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.9186 - loss: -0.0858 - val_accuracy: 0.9341 - val_loss: -0.0452 - learning_rate: 0.0051
# Epoch 97/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9190 - loss: -0.0562
# Epoch 97: val_accuracy did not improve from 0.93411
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9227 - loss: -0.0851 - val_accuracy: 0.9320 - val_loss: -0.0810 - learning_rate: 0.0050
# Epoch 98/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9175 - loss: -0.0832
# Epoch 98: val_accuracy did not improve from 0.93411
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9224 - loss: -0.1034 - val_accuracy: 0.9329 - val_loss: -0.0742 - learning_rate: 0.0050
# Epoch 99/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9200 - loss: -0.0775
# Epoch 99: val_accuracy did not improve from 0.93411
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9246 - loss: -0.1036 - val_accuracy: 0.9334 - val_loss: -0.0173 - learning_rate: 0.0050
# Epoch 100/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9211 - loss: -0.0894
# Epoch 100: val_accuracy improved from 0.93411 to 0.93875, saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
#
# Epoch 100: finished saving model to /content/drive/My Drive/Classification/edl/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.9254 - loss: -0.1105 - val_accuracy: 0.9387 - val_loss: -0.0640 - learning_rate: 0.0050
# AlexNet_CNN completed full training: 100/100 epochs.
#
# ========================= Training GFNet (legacy_arch) =========================
# Epoch 1/100
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.5109 - loss: 1.3005
# Epoch 1: val_loss improved from None to 0.81839, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 64s 379ms/step - accuracy: 0.5881 - loss: 1.1272 - val_accuracy: 0.7138 - val_loss: 0.8184
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7380 - loss: 0.9456
# Epoch 2: val_loss improved from 0.81839 to 0.69335, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.7619 - loss: 0.8796 - val_accuracy: 0.8310 - val_loss: 0.6933
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8186 - loss: 0.7966
# Epoch 3: val_loss did not improve from 0.69335
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8091 - loss: 0.8149 - val_accuracy: 0.8329 - val_loss: 0.7346
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8417 - loss: 0.7415
# Epoch 4: val_loss improved from 0.69335 to 0.64028, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 103ms/step - accuracy: 0.8455 - loss: 0.7415 - val_accuracy: 0.8794 - val_loss: 0.6403
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8793 - loss: 0.6705
# Epoch 5: val_loss improved from 0.64028 to 0.57798, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.8784 - loss: 0.6721 - val_accuracy: 0.9014 - val_loss: 0.5780
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8923 - loss: 0.6305
# Epoch 6: val_loss improved from 0.57798 to 0.54948, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 97ms/step - accuracy: 0.8887 - loss: 0.6402 - val_accuracy: 0.9142 - val_loss: 0.5495
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9067 - loss: 0.6027
# Epoch 7: val_loss improved from 0.54948 to 0.50307, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step - accuracy: 0.9069 - loss: 0.6092 - val_accuracy: 0.9258 - val_loss: 0.5031
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9136 - loss: 0.5774
# Epoch 8: val_loss did not improve from 0.50307
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.9093 - loss: 0.5929 - val_accuracy: 0.9215 - val_loss: 0.5739
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9201 - loss: 0.5573
# Epoch 9: val_loss improved from 0.50307 to 0.44369, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.9225 - loss: 0.5532 - val_accuracy: 0.9470 - val_loss: 0.4437
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9296 - loss: 0.5056
# Epoch 10: val_loss did not improve from 0.44369
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9268 - loss: 0.5200 - val_accuracy: 0.9385 - val_loss: 0.4695
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9325 - loss: 0.4981
# Epoch 11: val_loss improved from 0.44369 to 0.42792, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 117ms/step - accuracy: 0.9343 - loss: 0.4872 - val_accuracy: 0.9424 - val_loss: 0.4279
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9403 - loss: 0.4702
# Epoch 12: val_loss did not improve from 0.42792
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 85ms/step - accuracy: 0.9394 - loss: 0.4768 - val_accuracy: 0.9447 - val_loss: 0.4373
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9449 - loss: 0.4503
# Epoch 13: val_loss improved from 0.42792 to 0.37486, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 13: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.9430 - loss: 0.4571 - val_accuracy: 0.9517 - val_loss: 0.3749
# Epoch 14/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9415 - loss: 0.4623
# Epoch 14: val_loss did not improve from 0.37486
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.9402 - loss: 0.4720 - val_accuracy: 0.9490 - val_loss: 0.5491
# Epoch 15/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9502 - loss: 0.4154
# Epoch 15: val_loss improved from 0.37486 to 0.35193, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 15: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.9481 - loss: 0.4167 - val_accuracy: 0.9594 - val_loss: 0.3519
# Epoch 16/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9603 - loss: 0.3690
# Epoch 16: val_loss did not improve from 0.35193
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9557 - loss: 0.3867 - val_accuracy: 0.9652 - val_loss: 0.3565
# Epoch 17/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9600 - loss: 0.3582
# Epoch 17: val_loss did not improve from 0.35193
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - accuracy: 0.9547 - loss: 0.3749 - val_accuracy: 0.9517 - val_loss: 0.3794
# Epoch 18/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9606 - loss: 0.3739
# Epoch 18: val_loss improved from 0.35193 to 0.28591, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 18: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 11s 101ms/step - accuracy: 0.9616 - loss: 0.3593 - val_accuracy: 0.9714 - val_loss: 0.2859
# Epoch 19/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9654 - loss: 0.3066
# Epoch 19: val_loss improved from 0.28591 to 0.23281, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 19: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.9608 - loss: 0.3296 - val_accuracy: 0.9780 - val_loss: 0.2328
# Epoch 20/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9710 - loss: 0.2910
# Epoch 20: val_loss did not improve from 0.23281
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.9669 - loss: 0.3080 - val_accuracy: 0.9687 - val_loss: 0.3009
# Epoch 21/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9716 - loss: 0.2718
# Epoch 21: val_loss improved from 0.23281 to 0.20593, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 21: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - accuracy: 0.9690 - loss: 0.2775 - val_accuracy: 0.9780 - val_loss: 0.2059
# Epoch 22/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9713 - loss: 0.2478
# Epoch 22: val_loss did not improve from 0.20593
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.9683 - loss: 0.2669 - val_accuracy: 0.9675 - val_loss: 0.2879
# Epoch 23/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9705 - loss: 0.2561
# Epoch 23: val_loss improved from 0.20593 to 0.19117, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 23: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 96ms/step - accuracy: 0.9685 - loss: 0.2676 - val_accuracy: 0.9803 - val_loss: 0.1912
# Epoch 24/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9719 - loss: 0.2230
# Epoch 24: val_loss did not improve from 0.19117
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 91ms/step - accuracy: 0.9707 - loss: 0.2327 - val_accuracy: 0.9714 - val_loss: 0.2761
# Epoch 25/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9739 - loss: 0.2214
# Epoch 25: val_loss did not improve from 0.19117
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.9711 - loss: 0.2287 - val_accuracy: 0.9783 - val_loss: 0.1960
# Epoch 26/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9780 - loss: 0.1723
# Epoch 26: val_loss improved from 0.19117 to 0.13503, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 26: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 103ms/step - accuracy: 0.9766 - loss: 0.1788 - val_accuracy: 0.9826 - val_loss: 0.1350
# Epoch 27/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9768 - loss: 0.1656
# Epoch 27: val_loss did not improve from 0.13503
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.9772 - loss: 0.1700 - val_accuracy: 0.9722 - val_loss: 0.3663
# Epoch 28/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9705 - loss: 0.1924
# Epoch 28: val_loss did not improve from 0.13503
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9663 - loss: 0.2218 - val_accuracy: 0.9772 - val_loss: 0.1565
# Epoch 29/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9769 - loss: 0.1690
# Epoch 29: val_loss did not improve from 0.13503
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.9757 - loss: 0.1719 - val_accuracy: 0.9841 - val_loss: 0.1497
# Epoch 30/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9821 - loss: 0.1119
# Epoch 30: val_loss did not improve from 0.13503
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.9795 - loss: 0.1246 - val_accuracy: 0.9791 - val_loss: 0.1587
# Epoch 31/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9792 - loss: 0.1262
# Epoch 31: val_loss improved from 0.13503 to 0.10020, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 31: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - accuracy: 0.9798 - loss: 0.1235 - val_accuracy: 0.9845 - val_loss: 0.1002
# Epoch 32/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9824 - loss: 0.0964
# Epoch 32: val_loss did not improve from 0.10020
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.9798 - loss: 0.1122 - val_accuracy: 0.9834 - val_loss: 0.1218
# Epoch 33/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9825 - loss: 0.0786
# Epoch 33: val_loss did not improve from 0.10020
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 95ms/step - accuracy: 0.9833 - loss: 0.0768 - val_accuracy: 0.9834 - val_loss: 0.2470
# Epoch 34/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9783 - loss: 0.0926
# Epoch 34: val_loss improved from 0.10020 to 0.07226, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 34: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 100ms/step - accuracy: 0.9747 - loss: 0.1088 - val_accuracy: 0.9849 - val_loss: 0.0723
# Epoch 35/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9799 - loss: 0.0542
# Epoch 35: val_loss did not improve from 0.07226
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 93ms/step - accuracy: 0.9811 - loss: 0.0589 - val_accuracy: 0.9814 - val_loss: 0.2026
# Epoch 36/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9845 - loss: 0.0273
# Epoch 36: val_loss did not improve from 0.07226
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 92ms/step - accuracy: 0.9825 - loss: 0.0414 - val_accuracy: 0.9845 - val_loss: 0.0870
# Epoch 37/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9853 - loss: 0.0200
# Epoch 37: val_loss improved from 0.07226 to -0.00434, saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
#
# Epoch 37: finished saving model to /content/drive/My Drive/Classification/edl/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 100ms/step - accuracy: 0.9831 - loss: 0.0370 - val_accuracy: 0.9857 - val_loss: -0.0043
# Epoch 38/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9835 - loss: 0.0091
# Epoch 38: val_loss did not improve from -0.00434
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 90ms/step - accuracy: 0.9836 - loss: 0.0107 - val_accuracy: 0.9869 - val_loss: 0.0495
# Epoch 39/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9839 - loss: 2.7960e-04
# ...
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 169ms/step - accuracy: 0.9358 - loss: 0.2256 - val_accuracy: 0.9420 - val_loss: 0.1558
# Epoch 53/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9308 - loss: 0.2427
# Epoch 53: val_loss did not improve from 0.15583
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9299 - loss: 0.2446 - val_accuracy: 0.9466 - val_loss: 0.1887
# Epoch 54/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.9349 - loss: 0.2510
# Epoch 54: val_loss did not improve from 0.15583
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.9287 - loss: 0.2697 - val_accuracy: 0.9370 - val_loss: 0.2211
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9359 - loss: 0.2565
# Epoch 55: val_loss did not improve from 0.15583
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.9344 - loss: 0.2533 - val_accuracy: 0.9412 - val_loss: 0.1811
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9367 - loss: 0.2261
# Epoch 56: val_loss did not improve from 0.15583
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9362 - loss: 0.2135 - val_accuracy: 0.9462 - val_loss: 0.1718
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9445 - loss: 0.1778
# Epoch 57: val_loss did not improve from 0.15583
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9425 - loss: 0.1808 - val_accuracy: 0.9493 - val_loss: 0.1966
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9524 - loss: 0.1621
# Epoch 58: val_loss improved from 0.15583 to 0.14557, saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
#
# Epoch 58: finished saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 167ms/step - accuracy: 0.9488 - loss: 0.1744 - val_accuracy: 0.9319 - val_loss: 0.1456
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9470 - loss: 0.1713
# Epoch 59: val_loss did not improve from 0.14557
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9423 - loss: 0.2028 - val_accuracy: 0.9462 - val_loss: 0.1565
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9479 - loss: 0.1689
# Epoch 60: val_loss improved from 0.14557 to 0.10039, saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
#
# Epoch 60: finished saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 179ms/step - accuracy: 0.9482 - loss: 0.1551 - val_accuracy: 0.9497 - val_loss: 0.1004
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9451 - loss: 0.2066
# Epoch 61: val_loss did not improve from 0.10039
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9437 - loss: 0.2092 - val_accuracy: 0.9528 - val_loss: 0.1907
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9485 - loss: 0.1834
# Epoch 62: val_loss improved from 0.10039 to 0.07393, saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
#
# Epoch 62: finished saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 229ms/step - accuracy: 0.9475 - loss: 0.1763 - val_accuracy: 0.9609 - val_loss: 0.0739
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9533 - loss: 0.1161
# Epoch 63: val_loss did not improve from 0.07393
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.9505 - loss: 0.1273 - val_accuracy: 0.9501 - val_loss: 0.1104
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9455 - loss: 0.1642
# Epoch 64: val_loss did not improve from 0.07393
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 162ms/step - accuracy: 0.9437 - loss: 0.1731 - val_accuracy: 0.9559 - val_loss: 0.0916
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9484 - loss: 0.1459
# Epoch 65: val_loss did not improve from 0.07393
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.9458 - loss: 0.1477 - val_accuracy: 0.9505 - val_loss: 0.2179
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9456 - loss: 0.1498
# Epoch 66: val_loss did not improve from 0.07393
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.9455 - loss: 0.1511 - val_accuracy: 0.9443 - val_loss: 0.1223
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9498 - loss: 0.1648
# Epoch 67: val_loss did not improve from 0.07393
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9512 - loss: 0.1508 - val_accuracy: 0.9567 - val_loss: 0.1017
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9507 - loss: 0.1698
# Epoch 68: val_loss improved from 0.07393 to 0.07344, saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
#
# Epoch 68: finished saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 170ms/step - accuracy: 0.9506 - loss: 0.1839 - val_accuracy: 0.9606 - val_loss: 0.0734
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9552 - loss: 0.1103
# Epoch 69: val_loss improved from 0.07344 to 0.06537, saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
#
# Epoch 69: finished saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 237ms/step - accuracy: 0.9535 - loss: 0.1217 - val_accuracy: 0.9582 - val_loss: 0.0654
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9551 - loss: 0.1189
# Epoch 70: val_loss did not improve from 0.06537
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9533 - loss: 0.1153 - val_accuracy: 0.9586 - val_loss: 0.0823
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9554 - loss: 0.1101
# Epoch 71: val_loss improved from 0.06537 to 0.04971, saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
#
# Epoch 71: finished saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 17s 212ms/step - accuracy: 0.9548 - loss: 0.1141 - val_accuracy: 0.9602 - val_loss: 0.0497
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9581 - loss: 0.0990
# Epoch 72: val_loss did not improve from 0.04971
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 16s 153ms/step - accuracy: 0.9563 - loss: 0.1099 - val_accuracy: 0.9606 - val_loss: 0.1006
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9551 - loss: 0.0998
# Epoch 73: val_loss improved from 0.04971 to 0.04725, saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
#
# Epoch 73: finished saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 172ms/step - accuracy: 0.9524 - loss: 0.1054 - val_accuracy: 0.9602 - val_loss: 0.0473
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9551 - loss: 0.1031
# Epoch 74: val_loss improved from 0.04725 to 0.04466, saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
#
# Epoch 74: finished saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 18s 228ms/step - accuracy: 0.9550 - loss: 0.1021 - val_accuracy: 0.9644 - val_loss: 0.0447
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9564 - loss: 0.0738
# Epoch 75: val_loss did not improve from 0.04466
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.9535 - loss: 0.0950 - val_accuracy: 0.9551 - val_loss: 0.0562
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9580 - loss: 0.0798
# Epoch 76: val_loss did not improve from 0.04466
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.9571 - loss: 0.0945 - val_accuracy: 0.9640 - val_loss: 0.0504
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9561 - loss: 0.0883
# Epoch 77: val_loss improved from 0.04466 to 0.02173, saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
#
# Epoch 77: finished saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 169ms/step - accuracy: 0.9557 - loss: 0.0981 - val_accuracy: 0.9625 - val_loss: 0.0217
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9617 - loss: 0.0826
# Epoch 78: val_loss did not improve from 0.02173
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9571 - loss: 0.0917 - val_accuracy: 0.9544 - val_loss: 0.0566
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9553 - loss: 0.1582
# Epoch 79: val_loss did not improve from 0.02173
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - accuracy: 0.9548 - loss: 0.1654 - val_accuracy: 0.9621 - val_loss: 0.0457
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9565 - loss: 0.1409
# Epoch 80: val_loss improved from 0.02173 to 0.01788, saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
#
# Epoch 80: finished saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 177ms/step - accuracy: 0.9563 - loss: 0.1072 - val_accuracy: 0.9629 - val_loss: 0.0179
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9618 - loss: 0.0662
# Epoch 81: val_loss did not improve from 0.01788
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 159ms/step - accuracy: 0.9602 - loss: 0.0765 - val_accuracy: 0.9602 - val_loss: 0.0350
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9584 - loss: 0.0724
# Epoch 82: val_loss did not improve from 0.01788
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9561 - loss: 0.0847 - val_accuracy: 0.9594 - val_loss: 0.0218
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9617 - loss: 0.0818
# Epoch 83: val_loss did not improve from 0.01788
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9583 - loss: 0.0933 - val_accuracy: 0.9621 - val_loss: 0.0193
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9631 - loss: 0.0622
# Epoch 84: val_loss improved from 0.01788 to 0.00953, saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
#
# Epoch 84: finished saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 171ms/step - accuracy: 0.9593 - loss: 0.0636 - val_accuracy: 0.9648 - val_loss: 0.0095
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9629 - loss: 0.0507
# Epoch 85: val_loss did not improve from 0.00953
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9607 - loss: 0.0563 - val_accuracy: 0.9644 - val_loss: 0.0333
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9629 - loss: 0.0868
# Epoch 86: val_loss did not improve from 0.00953
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.9592 - loss: 0.0942 - val_accuracy: 0.9667 - val_loss: 0.0277
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9597 - loss: 0.0684
# Epoch 87: val_loss did not improve from 0.00953
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - accuracy: 0.9590 - loss: 0.0694 - val_accuracy: 0.9667 - val_loss: 0.0307
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9611 - loss: 0.0865
# Epoch 88: val_loss did not improve from 0.00953
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9599 - loss: 0.0799 - val_accuracy: 0.9644 - val_loss: 0.0139
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9609 - loss: 0.0509
# Epoch 89: val_loss did not improve from 0.00953
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9584 - loss: 0.0543 - val_accuracy: 0.9640 - val_loss: 0.0132
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9645 - loss: 0.0580
# Epoch 90: val_loss did not improve from 0.00953
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 150ms/step - accuracy: 0.9630 - loss: 0.0565 - val_accuracy: 0.9652 - val_loss: 0.0141
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9633 - loss: 0.0945
# Epoch 91: val_loss did not improve from 0.00953
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9633 - loss: 0.1263 - val_accuracy: 0.9648 - val_loss: 0.0327
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9570 - loss: 0.0916
# Epoch 92: val_loss did not improve from 0.00953
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9582 - loss: 0.0770 - val_accuracy: 0.9667 - val_loss: 0.0188
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9639 - loss: 0.0453
# Epoch 93: val_loss did not improve from 0.00953
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9608 - loss: 0.0576 - val_accuracy: 0.9687 - val_loss: 0.0695
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9655 - loss: 0.0353
# Epoch 94: val_loss did not improve from 0.00953
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 148ms/step - accuracy: 0.9625 - loss: 0.0427 - val_accuracy: 0.9656 - val_loss: 0.0326
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9642 - loss: 0.0447
# Epoch 95: val_loss improved from 0.00953 to -0.00079, saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
#
# Epoch 95: finished saving model to /content/drive/My Drive/Classification/edl/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 168ms/step - accuracy: 0.9617 - loss: 0.0414 - val_accuracy: 0.9671 - val_loss: -7.9450e-04
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9648 - loss: 0.0549
# Epoch 96: val_loss did not improve from -0.00079
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9627 - loss: 0.0852 - val_accuracy: 0.9648 - val_loss: 0.0040
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9620 - loss: 0.0357
# Epoch 97: val_loss did not improve from -0.00079
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 160ms/step - accuracy: 0.9617 - loss: 0.0389 - val_accuracy: 0.9675 - val_loss: 0.0051
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9665 - loss: 0.0615
# Epoch 98: val_loss did not improve from -0.00079
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9645 - loss: 0.0541 - val_accuracy: 0.9675 - val_loss: 1.0585e-04
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9646 - loss: 0.0233
# Epoch 99: val_loss did not improve from -0.00079
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9635 - loss: 0.0334 - val_accuracy: 0.9644 - val_loss: 0.0098
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9641 - loss: 0.0259
# Epoch 100: val_loss did not improve from -0.00079
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 149ms/step - accuracy: 0.9625 - loss: 0.0306 - val_accuracy: 0.9660 - val_loss: 0.0078
# ViT_UNet completed full training: 100/100 epochs.
#          model capacity_tag  test_accuracy     kappa  macro_f1  weighted_f1  \
# 0        GFNet  legacy_arch       0.993735  0.991501  0.992037     0.993725
# 1     ViT_UNet  legacy_arch       0.965197  0.952735  0.941083     0.965220
# 2  AlexNet_CNN  legacy_arch       0.938747  0.917127  0.862809     0.937466
#
#     val_nll  test_nll  val_brier  test_brier  test_ece_15bin  \
# 0  0.137324  0.139894   0.027896    0.029123        0.112659
# 1  0.307830  0.301866   0.116492    0.112962        0.161056
# 2  0.519391  0.519391   0.215491    0.215491        0.239744
#
#    epochs_configured  epochs_ran  train_time_sec  \
# 0                100         100      813.671996
# 1                100         100     1555.846021
# 2                100         100      728.545241
#
#                                      best_model_path  \
# 0  /content/drive/My Drive/Classification/edl/mod...
# 1  /content/drive/My Drive/Classification/edl/mod...
# 2  /content/drive/My Drive/Classification/edl/mod...
#
#                                     final_model_path
# 0  /content/drive/My Drive/Classification/edl/mod...
# 1  /content/drive/My Drive/Classification/edl/mod...
# 2  /content/drive/My Drive/Classification/edl/mod...

# %% [markdown]
# # 7.0 — Results & Metrics
# Save classification summaries to CSV / JSON, then plot training curves, cross-model bar charts, calibration proxies, and confusion matrices.

# %% [markdown]
# ## 7.1 — Save summary CSV and per-model JSON reports

# %%
summary_path = RESULTS_DIR / "classification_summary.csv"
summary_df.to_csv(summary_path, index=False)
print("Saved summary:", summary_path)

for model_name, artifact in model_artifacts.items():
    report_path = RESULTS_DIR / f"{model_name}_classification_report.json"
    with open(report_path, "w", encoding="utf-8") as f:
        json.dump(artifact["report"], f, indent=2)

print("Per-model classification reports saved to:", RESULTS_DIR)
summary_df
# Out:
# Saved summary: /content/drive/My Drive/Classification/edl/results/classification_summary.csv
# Per-model classification reports saved to: /content/drive/My Drive/Classification/edl/results
#          model capacity_tag  test_accuracy     kappa  macro_f1  weighted_f1  \
# 0        GFNet  legacy_arch       0.993735  0.991501  0.992037     0.993725
# 1     ViT_UNet  legacy_arch       0.965197  0.952735  0.941083     0.965220
# 2  AlexNet_CNN  legacy_arch       0.938747  0.917127  0.862809     0.937466
#
#     val_nll  test_nll  val_brier  test_brier  test_ece_15bin  \
# 0  0.137324  0.139894   0.027896    0.029123        0.112659
# 1  0.307830  0.301866   0.116492    0.112962        0.161056
# 2  0.519391  0.519391   0.215491    0.215491        0.239744
#
#    epochs_configured  epochs_ran  train_time_sec  \
# 0                100         100      813.671996
# 1                100         100     1555.846021
# 2                100         100      728.545241
#
#                                      best_model_path  \
# 0  /content/drive/My Drive/Classification/edl/mod...
# 1  /content/drive/My Drive/Classification/edl/mod...
# 2  /content/drive/My Drive/Classification/edl/mod...
#
#                                     final_model_path
# 0  /content/drive/My Drive/Classification/edl/mod...
# 1  /content/drive/My Drive/Classification/edl/mod...
# 2  /content/drive/My Drive/Classification/edl/mod...

# %% [markdown]
# ## 7.2 — Training curves (accuracy and loss per epoch)

# %%
for model_name, artifact in model_artifacts.items():
    hist   = artifact["history"]
    epochs = np.arange(1, len(hist["loss"]) + 1)

    fig, ax1 = plt.subplots(figsize=(12, 5))
    ax1.plot(epochs, hist["accuracy"],     color="#1f77b4", linewidth=2,   label="Train Accuracy")
    ax1.plot(epochs, hist["val_accuracy"], color="#2ca02c", linewidth=2, linestyle="--", label="Val Accuracy")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Accuracy")
    ax1.set_ylim(0, 1.0)
    ax1.grid(True, alpha=0.25)

    ax2 = ax1.twinx()
    ax2.plot(epochs, hist["loss"],     color="#111111", linewidth=1.8,   label="Train Loss")
    ax2.plot(epochs, hist["val_loss"], color="#d62728", linewidth=1.8, linestyle="--", label="Val Loss")
    ax2.set_ylabel("Loss")

    lines  = ax1.get_lines() + ax2.get_lines()
    labels = [ln.get_label() for ln in lines]
    ax1.legend(lines, labels, loc="upper right", frameon=True)
    plt.title(f"{model_name}: Accuracy / Loss vs Epoch")
    plt.tight_layout()

    curve_path = PLOT_DIR / f"{model_name}_training_curves.png"
    plt.savefig(curve_path, dpi=200, bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## 7.3 — Cross-model comparison bar charts

# %%
plot_df = summary_df[[
    "model", "test_accuracy", "macro_f1", "kappa", "train_time_sec",
    "test_nll", "test_brier", "test_ece_15bin",
]].copy()

fig, axes = plt.subplots(2, 2, figsize=(15, 9))
axes    = axes.flatten()
palette = ["#4c72b0", "#55a868", "#c44e52"]

metric_specs = [
    ("test_accuracy",  "Test Accuracy",   (0.0, 1.0), "{:.3f}"),
    ("macro_f1",       "Macro F1",        (0.0, 1.0), "{:.3f}"),
    ("kappa",          "Cohen Kappa",     (0.0, 1.0), "{:.3f}"),
    ("train_time_sec", "Train Time (sec)", None,       "{:.1f}"),
]

for ax, (col, title, ylim, fmt) in zip(axes, metric_specs):
    local = plot_df[["model", col]].copy()
    bars  = ax.bar(local["model"], local[col], color=palette[:len(local)])
    ax.set_title(title)
    ax.set_xlabel("Model")
    ax.set_ylabel(title)
    if ylim is not None:
        ax.set_ylim(*ylim)
    ax.grid(axis="y", alpha=0.25)
    for patch in bars:
        height = patch.get_height()
        xpos   = patch.get_x() + patch.get_width() / 2
        offset = (ylim[1] - ylim[0]) * 0.02 if ylim else max(local[col].max() * 0.02, 0.05)
        ax.text(xpos, height + offset, fmt.format(height), ha="center", va="bottom", fontsize=9)

plt.suptitle("Single-Head Model Comparison", y=1.02, fontsize=14)
plt.tight_layout()
comparison_path = PLOT_DIR / "model_comparison_metrics.png"
plt.savefig(comparison_path, dpi=200, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 7.4 — Calibration proxy metrics and confusion matrices

# %%
# Calibration proxy chart (lower is better for all three metrics)
fig, ax     = plt.subplots(figsize=(12, 5))
calib_cols  = ["test_nll", "test_brier", "test_ece_15bin"]
calib_df    = plot_df[["model"] + calib_cols].set_index("model")
calib_df.plot(kind="bar", ax=ax, rot=0)
ax.set_title("Uncertainty Proxy Metrics (Lower is Better)")
ax.set_ylabel("Metric Value")
ax.grid(axis="y", alpha=0.25)
plt.tight_layout()
calib_path = PLOT_DIR / "uncertainty_proxy_metrics.png"
plt.savefig(calib_path, dpi=200, bbox_inches="tight")
plt.show()

# Side-by-side confusion matrices
class_ticks = [str(i + 1) for i in range(num_classes)]
fig, axes   = plt.subplots(1, len(model_artifacts), figsize=(7 * len(model_artifacts), 5.5))
if len(model_artifacts) == 1:
    axes = [axes]

for ax, (model_name, artifact) in zip(axes, model_artifacts.items()):
    sns.heatmap(
        artifact["confusion_matrix"],
        annot=True, fmt="d", cmap="Blues",
        xticklabels=class_ticks, yticklabels=class_ticks,
        cbar=False, ax=ax,
    )
    ax.set_title(f"{model_name} Confusion Matrix")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("True")

plt.tight_layout()
cm_path = PLOT_DIR / "confusion_matrices_side_by_side.png"
plt.savefig(cm_path, dpi=220, bbox_inches="tight")
plt.show()
print("Saved confusion matrix figure:", cm_path)
print("All training plots saved to:", PLOT_DIR)
# Out:
# Saved confusion matrix figure: /content/drive/My Drive/Classification/edl/results/training_plots/confusion_matrices_side_by_side.png
# All training plots saved to: /content/drive/My Drive/Classification/edl/results/training_plots

# %% [markdown]
# # 8.0 — Scene Visualisation
# Load the saved best models, run dense patch-by-patch inference over the entire scene, and save classified maps as PNGs and an Excel workbook.

# %% [markdown]
# ## 8.1 — Visualisation helpers

# %%
CUSTOM_OBJECTS = {
    "PatchExtractor":      PatchExtractor,
    "PatchPositionEncoder": PatchPositionEncoder,
    "GlobalFilterLayer":   GlobalFilterLayer,
    "PatchEncoderWithCLS": PatchEncoderWithCLS,
}


def get_scene_rgb(x_img, bands):
    """Select three bands as an approximate RGB composite; clip to [0, 1]."""
    if bands >= 6:
        rgb_idx = [bands // 2 - 1, bands // 2, bands // 2 + 1]
    elif bands >= 3:
        rgb_idx = [0, 1, 2]
    else:
        raise ValueError(f"Need at least 3 bands to form RGB, got {bands}.")
    return np.clip(x_img[:, :, rgb_idx], 0.0, 1.0)


def get_display_cmap(num_classes):
    """Build a ListedColormap: index 0 = background black, 1..K = class colours."""
    return ListedColormap([BACKGROUND_COLOR] + CLASS_COLOR_BASE[:num_classes])


def predict_full_scene_labels(model, x_img, patch_size=9, batch_size=256):
    """Run dense sliding-window inference row-by-row; returns a (H, W) label map."""
    pad   = patch_size // 2
    x_pad = np.pad(x_img, ((pad, pad), (pad, pad), (0, 0)), mode="edge")
    preds = np.zeros((x_img.shape[0], x_img.shape[1]), dtype=np.int32)

    for r in range(x_img.shape[0]):
        row_patches = np.empty(
            (x_img.shape[1], patch_size, patch_size, x_img.shape[-1]),
            dtype=np.float32,
        )
        for c in range(x_img.shape[1]):
            row_patches[c] = x_pad[r:r + patch_size, c:c + patch_size, :]

        row_prob  = model.predict(row_patches, batch_size=batch_size, verbose=0)
        preds[r]  = np.argmax(row_prob, axis=1) + 1  # back to 1..K

    return preds


def load_saved_models_for_visualization(model_dir, custom_objects):
    """Attempt to load all three best models; return dicts of loaded and missing."""
    model_files = {
        "AlexNet_CNN": model_dir / "AlexNet_CNN_best.keras",
        "GFNet":       model_dir / "GFNet_best.keras",
        "ViT_UNet":    model_dir / "ViT_UNet_best.keras",
    }
    loaded, missing = {}, {}
    for model_key, model_path in model_files.items():
        if not model_path.exists():
            missing[model_key] = f"Missing file: {model_path}"
            continue
        try:
            loaded[model_key] = keras.models.load_model(
                model_path, custom_objects=custom_objects,
                compile=False, safe_mode=False,
            )
        except Exception as exc:
            missing[model_key] = f"Load failed: {exc}"
    return loaded, missing


def save_single_panel(image, title, save_path, cmap=None, vmin=None, vmax=None):
    """Save a single image panel as a high-DPI PNG."""
    fig, ax = plt.subplots(figsize=(8, 6))
    if cmap is None:
        ax.imshow(image)
    else:
        ax.imshow(image, cmap=cmap, vmin=vmin, vmax=vmax)
    ax.set_title(title, fontsize=14)
    ax.axis("off")
    fig.tight_layout()
    fig.savefig(save_path, dpi=220, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print("Saved:", save_path)


def save_combined_overview(rgb_image, y_true, pred_maps, missing_info, num_classes, save_path):
    """Save a five-panel side-by-side overview: RGB, GT, and one panel per model."""
    cmap   = get_display_cmap(num_classes)
    panels = [
        ("Approximate RGB",             rgb_image,               "rgb"),
        ("True Label Map",              y_true,                  "label"),
        ("AlexNet Initial Classification", pred_maps.get("AlexNet_CNN"), "label"),
        ("GFNet Initial Classification",   pred_maps.get("GFNet"),       "label"),
        ("ViT Initial Classification",     pred_maps.get("ViT_UNet"),    "label"),
    ]

    fig, axes = plt.subplots(1, len(panels), figsize=(30, 7), sharex=True, sharey=True)
    for ax, (title, img, kind) in zip(axes, panels):
        ax.set_title(title, fontsize=13)
        if kind == "rgb":
            ax.imshow(img)
        elif img is None:
            ax.imshow(np.zeros_like(y_true), cmap=cmap, vmin=0, vmax=num_classes)
            key = {"AlexNet": "AlexNet_CNN", "GFNet": "GFNet", "ViT": "ViT_UNet"}.get(
                next((k for k in ("AlexNet", "GFNet", "ViT") if k in title), None)
            )
            ax.text(0.5, 0.5, missing_info.get(key, "Unavailable"),
                    ha="center", va="center", fontsize=10, wrap=True, transform=ax.transAxes)
        else:
            ax.imshow(img, cmap=cmap, vmin=0, vmax=num_classes)
        ax.axis("off")

    handles = [plt.Rectangle((0, 0), 1, 1, color=BACKGROUND_COLOR, label="Background")]
    for i in range(num_classes):
        handles.append(plt.Rectangle((0, 0), 1, 1, color=CLASS_COLOR_BASE[i], label=f"Class {i+1}"))
    fig.legend(handles=handles, loc="lower center", ncol=min(num_classes + 1, 8),
               bbox_to_anchor=(0.5, -0.02), frameon=True)
    fig.tight_layout(rect=[0, 0.05, 1, 1])
    fig.savefig(save_path, dpi=220, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print("Saved:", save_path)


def save_images_to_excel(excel_path, image_paths, sheet_name="Initial_Classification_Maps"):
    """Embed PNG images into an Excel workbook at fixed anchor positions."""
    if excel_path.exists():
        wb = load_workbook(excel_path)
        if sheet_name in wb.sheetnames:
            del wb[sheet_name]
        ws = wb.create_sheet(title=sheet_name)
    else:
        wb = Workbook()
        ws = wb.active
        ws.title = sheet_name

    anchors = ["A1", "J1", "A25", "J25", "A49", "J49"]
    for path, anchor in zip(image_paths, anchors):
        if path.exists():
            img        = XLImage(str(path))
            img.anchor = anchor
            ws.add_image(img)

    wb.save(excel_path)
    print("Saved Excel workbook:", excel_path)

# %% [markdown]
# ## 8.2 — Generate and save all scene maps

# %%
scene_rgb    = get_scene_rgb(x_img, B)
display_cmap = get_display_cmap(num_classes)

loaded_models, missing_models = load_saved_models_for_visualization(MODEL_DIR, CUSTOM_OBJECTS)
prediction_maps = {}

for model_key, loaded_model in loaded_models.items():
    print(f"Generating full-scene classified image for {model_key}...")
    prediction_maps[model_key] = predict_full_scene_labels(
        loaded_model, x_img, patch_size=PATCH_SIZE, batch_size=BATCH_SIZE,
    )
    print(f"{model_key} map shape:", prediction_maps[model_key].shape)

if missing_models:
    print("Some models could not be loaded:")
    for model_key, reason in missing_models.items():
        print(f"  - {model_key}: {reason}")

# Individual PNG paths
rgb_png      = VIS_DIR / "scene_rgb.png"
gt_png       = VIS_DIR / "ground_truth_label_map.png"
alex_png     = VIS_DIR / "AlexNet_CNN_initial_classification.png"
gfnet_png    = VIS_DIR / "GFNet_initial_classification.png"
vit_png      = VIS_DIR / "ViT_UNet_initial_classification.png"
overview_png = VIS_DIR / "combined_initial_classification_overview.png"

save_single_panel(scene_rgb, "Approximate RGB", rgb_png)
save_single_panel(y_img, "Ground Truth Label Map", gt_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("AlexNet_CNN") is not None:
    save_single_panel(prediction_maps["AlexNet_CNN"], "AlexNet Initial Classification",
                      alex_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("GFNet") is not None:
    save_single_panel(prediction_maps["GFNet"], "GFNet Initial Classification",
                      gfnet_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("ViT_UNet") is not None:
    save_single_panel(prediction_maps["ViT_UNet"], "ViT Initial Classification",
                      vit_png, cmap=display_cmap, vmin=0, vmax=num_classes)

save_combined_overview(
    rgb_image=scene_rgb, y_true=y_img, pred_maps=prediction_maps,
    missing_info=missing_models, num_classes=num_classes, save_path=overview_png,
)

image_paths_for_excel = [rgb_png, gt_png, alex_png, gfnet_png, vit_png, overview_png]
save_images_to_excel(VIS_EXCEL_PATH, image_paths_for_excel, sheet_name="Initial_Classification_Maps")

print("All visualisation outputs saved to:", VIS_DIR)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:424: UserWarning: `build()` was called on layer 'gf_patch_encoder', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Generating full-scene classified image for AlexNet_CNN...
# AlexNet_CNN map shape: (330, 307)
# Generating full-scene classified image for GFNet...
# GFNet map shape: (330, 307)
# Generating full-scene classified image for ViT_UNet...
# ViT_UNet map shape: (330, 307)
# Saved: /content/drive/My Drive/Classification/edl/results/scene_visualizations/scene_rgb.png
# Saved: /content/drive/My Drive/Classification/edl/results/scene_visualizations/ground_truth_label_map.png
# Saved: /content/drive/My Drive/Classification/edl/results/scene_visualizations/AlexNet_CNN_initial_classification.png
# Saved: /content/drive/My Drive/Classification/edl/results/scene_visualizations/GFNet_initial_classification.png
# Saved: /content/drive/My Drive/Classification/edl/results/scene_visualizations/ViT_UNet_initial_classification.png
# Saved: /content/drive/My Drive/Classification/edl/results/scene_visualizations/combined_initial_classification_overview.png
# Saved Excel workbook: /content/drive/My Drive/Classification/edl/results/scene_visualizations/initial_classification_maps.xlsx
# All visualisation outputs saved to: /content/drive/My Drive/Classification/edl/results/scene_visualizations
