# %% [markdown]
# # 1.0 — Setup & Imports
# Mount Google Drive and import all required standard, third-party, and ML libraries.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Standard library
import io
import json
import os
import random
import time
from pathlib import Path

# Third-party – data / viz
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib.colors import ListedColormap
from openpyxl import Workbook, load_workbook
from openpyxl.drawing.image import Image as XLImage
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    cohen_kappa_score,
    confusion_matrix,
    f1_score,
    log_loss,
)
from sklearn.model_selection import train_test_split

# TensorFlow / Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers

sns.set_style("whitegrid")
print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.20.0

# %% [markdown]
# # 2.0 — Configuration
# All hyper-parameters, paths, and architecture configs are defined here. Change values in this single cell to reconfigure the whole notebook.

# %%
# ── Reproducibility ──────────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# ── Paths ─────────────────────────────────────────────────────────────
MODEL_DIR   = Path("/content/drive/My Drive/Classification/focal_loss/models")
RESULTS_DIR = Path("/content/drive/My Drive/Classification/focal_loss/results")
MODEL_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
PLOT_DIR    = RESULTS_DIR / "training_plots"
PLOT_DIR.mkdir(parents=True, exist_ok=True)
VIS_DIR     = RESULTS_DIR / "scene_visualizations"
VIS_DIR.mkdir(parents=True, exist_ok=True)

DATA_DIR   = Path("/content/drive/My Drive/Classification/data")
DATA_FILE  = DATA_DIR / "data.csv"
LABEL_FILE = DATA_DIR / "ref.csv"

# ── Dataset geometry ──────────────────────────────────────────────────
H, W, B    = 330, 307, 6          # height, width, bands
PATCH_SIZE  = 9
INNER_PATCH = 3                   # tokenisation patch size for GFNet / ViT

# ── Train / val / test splits ─────────────────────────────────────────
TRAIN_PERCENT          = 0.75
VAL_SPLIT_FROM_TRAIN   = 0.20

# ── Training ──────────────────────────────────────────────────────────
BATCH_SIZE    = 128
EPOCHS        = 100
LEARNING_RATE = 3e-4
DROPOUT_RATE  = 0.25
CAPACITY_PRESET = "legacy_arch"

TRAIN_CFG = {
    "label_smoothing": 0.05,   # retained for reference only; unused now that focal loss is active
    "weight_decay":    1e-4,
    "clipnorm":        1.0,
    "cosine_alpha":    0.05,
}

# ── Focal loss hyper-parameters ────────────────────────────────────────────────
# gamma: focusing parameter -- higher values down-weight easy, well-classified
#        pixels more and put relatively more training signal on hard / ambiguous ones
# alpha: balancing weight applied uniformly across all classes
FOCAL_GAMMA = 2.0
FOCAL_ALPHA = 0.25

# ── AlexNet legacy recipe (reproduces original single-head results) ────
ALEXNET_LEGACY_SPLIT_SEED   = 10
ALEXNET_LEGACY_TRAIN_PERCENT = 0.75
ALEXNET_LR_START = 0.01
ALEXNET_LR_MAX   = 0.02
ALEXNET_LR_MIN   = 0.005

# ── Architecture configs ──────────────────────────────────────────────
ALEXNET_CFG = {
    "conv_filters": [96, 256, 384, 384, 256],
    "dense_units":  [4096, 1024, 256, 32],
}

GFNET_CFG = {"hidden_dim": 512, "num_blocks": 5, "mlp_ratio": 4}
VIT_CFG   = {
    "projection_dim":    256,
    "num_heads":         4,
    "transformer_layers": 12,
    "mlp_multiplier":    2,
    "head_units":        [512, 256, 128, 64],
}

# Fallback configs used when Colab runs out of memory
GFNET_FALLBACK_CFG = {"hidden_dim": 384, "num_blocks": 4, "mlp_ratio": 4}
VIT_FALLBACK_CFG   = {
    "projection_dim":    192,
    "num_heads":         4,
    "transformer_layers": 8,
    "mlp_multiplier":    2,
    "head_units":        [384, 192, 96, 64],
}

# ── Visualisation palette ─────────────────────────────────────────────
CLASS_COLOR_BASE = [
    "#0000FF", "#00FF00", "#FF0000", "#00FFFF", "#FF00FF",
    "#FFFF00", "#A52A2A", "#FFA500", "#7FFF00", "#8A2BE2",
]
BACKGROUND_COLOR  = "#000000"
VIS_EXCEL_PATH    = VIS_DIR / "initial_classification_maps.xlsx"

print("Data file:    ", DATA_FILE)
print("Label file:   ", LABEL_FILE)
print("Model dir:    ", MODEL_DIR)
print("Results dir:  ", RESULTS_DIR)
print("Plot dir:     ", PLOT_DIR)
print("Arch preset:  ", CAPACITY_PRESET)
# Out:
# Data file:     /content/drive/My Drive/Classification/data/data.csv
# Label file:    /content/drive/My Drive/Classification/data/ref.csv
# Model dir:     /content/drive/My Drive/Classification/focal_loss/models
# Results dir:   /content/drive/My Drive/Classification/focal_loss/results
# Plot dir:      /content/drive/My Drive/Classification/focal_loss/results/training_plots
# Arch preset:   legacy_arch

# %% [markdown]
# # 3.0 — Data Loading & Preprocessing
# Load the raw multispectral CSV files, apply per-band min-max normalisation, extract labelled patches, and create stratified train / val / test splits.

# %% [markdown]
# ## 3.1 — Loading and patch extraction helpers

# %%
def load_multispectral_6band(data_path, label_path, height, width, bands):
    """Load multispectral data and reference labels; normalise each band to [0, 1]."""
    x = pd.read_csv(data_path).to_numpy(dtype=np.float32).reshape(height, width, bands)
    y = pd.read_csv(label_path).to_numpy(dtype=np.int32).reshape(height, width)

    x_norm = np.empty_like(x, dtype=np.float32)
    for b in range(bands):
        band     = x[:, :, b]
        band_min = np.min(band)
        band_max = np.max(band)
        denom    = max(band_max - band_min, 1e-8)
        x_norm[:, :, b] = (band - band_min) / denom

    return x_norm, y


def extract_labeled_patches(x, y, patch_size=9):
    """Extract (patch_size × patch_size) spatial patches around every labelled pixel."""
    pad   = patch_size // 2
    x_pad = np.pad(x, ((pad, pad), (pad, pad), (0, 0)), mode="edge")

    coords  = np.argwhere(y > 0)
    patches = np.empty((coords.shape[0], patch_size, patch_size, x.shape[-1]), dtype=np.float32)
    labels  = np.empty((coords.shape[0],), dtype=np.int32)

    for i, (r, c) in enumerate(coords):
        patches[i] = x_pad[r:r + patch_size, c:c + patch_size, :]
        labels[i]  = int(y[r, c]) - 1  # convert class IDs to 0..C-1

    return patches, labels, coords

# %% [markdown]
# ## 3.2 — Load data and create splits

# %%
x_img, y_img = load_multispectral_6band(DATA_FILE, LABEL_FILE, H, W, B)
X, y, coords = extract_labeled_patches(x_img, y_img, PATCH_SIZE)

num_classes = int(np.unique(y).size)
input_shape = (PATCH_SIZE, PATCH_SIZE, B)

print("x_img:", x_img.shape, "  y_img:", y_img.shape)
print("Labelled samples:", X.shape[0])
print("Patch tensor:    ", X.shape)
print("Num classes:     ", num_classes)
# Out:
# x_img: (330, 307, 6)   y_img: (330, 307)
# Labelled samples: 17239
# Patch tensor:     (17239, 9, 9, 6)
# Num classes:      7

# %%
# Primary stratified split used by GFNet and ViT
x_train_full, x_test, y_train_full, y_test = train_test_split(
    X, y,
    train_size=TRAIN_PERCENT,
    random_state=SEED,
    stratify=y,
)
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full,
    test_size=VAL_SPLIT_FROM_TRAIN,
    random_state=SEED,
    stratify=y_train_full,
)

y_train_cat = keras.utils.to_categorical(y_train, num_classes)
y_val_cat   = keras.utils.to_categorical(y_val,   num_classes)
y_test_cat  = keras.utils.to_categorical(y_test,  num_classes)

print("Train:", x_train.shape, y_train.shape)
print("Val:  ", x_val.shape,   y_val.shape)
print("Test: ", x_test.shape,  y_test.shape)
# Out:
# Train: (10343, 9, 9, 6) (10343,)
# Val:   (2586, 9, 9, 6) (2586,)
# Test:  (4310, 9, 9, 6) (4310,)

# %%
# AlexNet legacy split — matches the original single-head notebook for
# uncertainty recovery (different seed and no val split)
x_train_alex, x_test_alex, y_train_alex, y_test_alex = train_test_split(
    X, y,
    train_size=ALEXNET_LEGACY_TRAIN_PERCENT,
    random_state=ALEXNET_LEGACY_SPLIT_SEED,
    stratify=y,
)
y_train_alex_cat = keras.utils.to_categorical(y_train_alex, num_classes)
y_test_alex_cat  = keras.utils.to_categorical(y_test_alex,  num_classes)

print("AlexNet Train:", x_train_alex.shape, y_train_alex.shape)
print("AlexNet Test: ", x_test_alex.shape,  y_test_alex.shape)
# Out:
# AlexNet Train: (12929, 9, 9, 6) (12929,)
# AlexNet Test:  (4310, 9, 9, 6) (4310,)

# %% [markdown]
# # 4.0 — Model Definitions
# Defines three single-head architectures: AlexNet-based CNN, Global Filter Network (GFNet), and Vision Transformer (ViT with U-Net style skip connections). Custom Keras layers are registered for serialisation.

# %% [markdown]
# ## 4.1 — Shared custom Keras layers (PatchExtractor, PatchPositionEncoder, PatchEncoderWithCLS)

# %%
@tf.keras.utils.register_keras_serializable()
class PatchExtractor(layers.Layer):
    """Extract non-overlapping spatial patches from an image tensor."""

    def __init__(self, patch_size=3, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        patches     = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        batch       = tf.shape(images)[0]
        num_patches = tf.shape(patches)[1] * tf.shape(patches)[2]
        patch_dim   = tf.shape(patches)[-1]
        return tf.reshape(patches, [batch, num_patches, patch_dim])

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"patch_size": self.patch_size})
        return cfg


@tf.keras.utils.register_keras_serializable()
class PatchPositionEncoder(layers.Layer):
    """Project patches to embedding dim and add learned positional embeddings."""

    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches      = num_patches
        self.projection_dim   = projection_dim
        self.projection       = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(input_dim=num_patches, output_dim=projection_dim)

    def call(self, patches):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        return self.projection(patches) + self.position_embedding(positions)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"num_patches": self.num_patches, "projection_dim": self.projection_dim})
        return cfg


@tf.keras.utils.register_keras_serializable()
class PatchEncoderWithCLS(layers.Layer):
    """Project patches and prepend a learnable [CLS] token with positional embeddings."""

    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches      = num_patches
        self.projection_dim   = projection_dim
        self.projection       = layers.Dense(projection_dim)
        self.position_embedding = layers.Embedding(input_dim=num_patches + 1, output_dim=projection_dim)

    def build(self, input_shape):
        self.cls_token = self.add_weight(
            name="cls_token",
            shape=(1, 1, self.projection_dim),
            initializer="zeros",
            trainable=True,
        )
        super().build(input_shape)

    def call(self, patches):
        batch      = tf.shape(patches)[0]
        patch_proj = self.projection(patches)
        cls_tokens = tf.repeat(self.cls_token, repeats=batch, axis=0)
        x          = tf.concat([cls_tokens, patch_proj], axis=1)
        positions  = tf.range(start=0, limit=self.num_patches + 1, delta=1)
        return x + self.position_embedding(positions)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"num_patches": self.num_patches, "projection_dim": self.projection_dim})
        return cfg

# %% [markdown]
# ## 4.2 — AlexNet-based CNN

# %%
def build_alexnet(input_shape, num_classes, dropout_rate=0.25, cfg=None):
    """Build an AlexNet-inspired CNN with five conv layers and four dense layers."""
    cfg = cfg or ALEXNET_CFG

    inputs = keras.Input(shape=input_shape)
    x      = inputs
    for i, filters in enumerate(cfg["conv_filters"], start=1):
        x = layers.Conv2D(filters, (3, 3), activation="relu", padding="same", name=f"alex_conv_{i}")(x)

    x = layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding="same", name="alex_pool")(x)
    x = layers.Flatten(name="alex_flatten")(x)

    dense_units = cfg["dense_units"]
    x = layers.Dense(dense_units[0], activation="relu", name="alex_fc1")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)
    x = layers.Dense(dense_units[1], activation="relu", name="alex_fc2")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_2")(x)
    x = layers.Dense(dense_units[2], activation="relu", name="alex_fc3")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(x)
    x = layers.Dense(dense_units[3], activation="relu", name="alex_fc4")(x)

    outputs = layers.Dense(num_classes, activation="softmax", name="alex_logits")(x)
    return keras.Model(inputs, outputs, name="AlexNet_SingleHead")

# %% [markdown]
# ## 4.3 — Global Filter Network (GFNet)

# %%
@tf.keras.utils.register_keras_serializable()
class GlobalFilterLayer(layers.Layer):
    """Apply learnable complex-valued filters in the 2-D frequency domain."""

    def __init__(self, token_side, **kwargs):
        super().__init__(**kwargs)
        self.token_side = token_side

    def build(self, input_shape):
        channels    = int(input_shape[-1])
        self.w_real = self.add_weight(
            name="w_real",
            shape=(self.token_side, self.token_side, channels),
            initializer="glorot_uniform",
            trainable=True,
        )
        self.w_imag = self.add_weight(
            name="w_imag",
            shape=(self.token_side, self.token_side, channels),
            initializer="zeros",
            trainable=True,
        )
        super().build(input_shape)

    def call(self, x):
        batch      = tf.shape(x)[0]
        channels   = tf.shape(x)[-1]
        x_2d       = tf.reshape(x, [batch, self.token_side, self.token_side, channels])
        x_fft      = tf.signal.fft2d(tf.cast(x_2d, tf.complex64))
        w_complex  = tf.complex(self.w_real, self.w_imag)
        x_filtered = x_fft * w_complex
        x_spatial  = tf.math.real(tf.signal.ifft2d(x_filtered))
        return tf.reshape(x_spatial, [batch, self.token_side * self.token_side, channels])

    def get_config(self):
        cfg = super().get_config()
        cfg.update({"token_side": self.token_side})
        return cfg


def gf_block(x, token_side, dim, mlp_ratio=4, dropout_rate=0.25, name_prefix="gf"):
    """Single GFNet residual block: global filter followed by a two-layer MLP."""
    # Legacy block style: one residual add after filter + MLP branch
    y = layers.LayerNormalization(name=f"{name_prefix}_ln1")(x)
    y = GlobalFilterLayer(token_side, name=f"{name_prefix}_gfilter")(y)
    y = layers.LayerNormalization(name=f"{name_prefix}_ln2")(y)
    y = layers.Dense(dim * mlp_ratio, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp1")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop1")(y)
    y = layers.Dense(dim, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp2")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop2")(y)
    return layers.Add(name=f"{name_prefix}_add")([x, y])


def build_gfnet(input_shape, num_classes, inner_patch=3, hidden_dim=512,
                num_blocks=5, mlp_ratio=4, dropout_rate=0.25):
    """Build a Global Filter Network (GFNet) single-head classifier."""
    num_patches = (input_shape[0] // inner_patch) * (input_shape[1] // inner_patch)
    token_side  = int(np.sqrt(num_patches))

    inputs = keras.Input(shape=input_shape)
    x      = PatchExtractor(inner_patch, name="gf_patch_extractor")(inputs)
    x      = PatchPositionEncoder(num_patches, hidden_dim, name="gf_patch_encoder")(x)
    x      = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)

    for i in range(num_blocks):
        x = gf_block(x, token_side, hidden_dim, mlp_ratio, dropout_rate, name_prefix=f"gf_block_{i+1}")

    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_2")(x)
    x = layers.LayerNormalization(name="gf_final_ln")(x)
    x = layers.GlobalAveragePooling1D(name="gf_gap")(x)
    x = layers.Flatten(name="gf_flatten")(x)
    x = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(x)

    outputs = layers.Dense(num_classes, activation="softmax", name="gf_logits")(x)
    return keras.Model(inputs, outputs, name="GFNet_SingleHead")

# %% [markdown]
# ## 4.4 — Vision Transformer with U-Net style skip connections

# %%
def transformer_block(x, num_heads, projection_dim, mlp_dim, dropout_rate, name_prefix):
    """Standard pre-LN transformer block with multi-head attention and a GELU MLP."""
    y = layers.LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_ln1")(x)
    y = layers.MultiHeadAttention(
        num_heads=num_heads, key_dim=projection_dim,
        dropout=dropout_rate, name=f"{name_prefix}_mha",
    )(y, y)
    x = layers.Add(name=f"{name_prefix}_add1")([y, x])

    y = layers.LayerNormalization(epsilon=1e-6, name=f"{name_prefix}_ln2")(x)
    y = layers.Dense(mlp_dim, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp1")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop1")(y)
    y = layers.Dense(projection_dim, activation=tf.keras.activations.gelu, name=f"{name_prefix}_mlp2")(y)
    y = layers.Dropout(dropout_rate, name=f"{name_prefix}_drop2")(y)
    return layers.Add(name=f"{name_prefix}_add2")([y, x])


def build_vit_unet_singlehead(
    input_shape, num_classes, inner_patch=3,
    projection_dim=256, num_heads=4, transformer_layers=12,
    mlp_multiplier=2, dropout_rate=0.25, head_units=(512, 256, 128, 64),
):
    """Build a ViT single-head classifier with U-Net style encoder–decoder skip connections."""
    num_patches = (input_shape[0] // inner_patch) * (input_shape[1] // inner_patch)

    inputs = keras.Input(shape=input_shape)
    x      = PatchExtractor(inner_patch, name="vit_patch_extractor")(inputs)
    x      = PatchEncoderWithCLS(num_patches, projection_dim, name="vit_patch_encoder")(x)

    block_list = []
    for i in range(transformer_layers):
        x = transformer_block(
            x, num_heads=num_heads, projection_dim=projection_dim,
            mlp_dim=projection_dim * mlp_multiplier,
            dropout_rate=0.1, name_prefix=f"vit_block_{i+1}",
        )
        if i <= transformer_layers // 2:
            block_list.append(x)
        else:
            x = layers.Add(name=f"vit_skip_add_{i+1}")([x, block_list[transformer_layers - i - 1]])

    x         = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_1")(x)
    x         = layers.LayerNormalization(epsilon=1e-6, name="vit_cls_norm")(x)
    cls_token = layers.Lambda(lambda t: t[:, 0, :], name="vit_cls_token")(x)

    y = layers.Dense(head_units[0], activation=tf.keras.activations.gelu, name="vit_head_1")(cls_token)
    y = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_3")(y)
    y = layers.Dense(head_units[1], activation=tf.keras.activations.gelu, name="vit_head_2")(y)
    y = layers.Dense(head_units[2], activation=tf.keras.activations.gelu, name="vit_head_3")(y)
    y = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_5")(y)
    y = layers.Dense(head_units[3], activation=tf.keras.activations.gelu, name="vit_head_4")(y)
    y = layers.Dropout(dropout_rate, name="TRAIN_DROPOUT_6")(y)

    outputs = layers.Dense(num_classes, activation="softmax", name="vit_logits")(y)
    return keras.Model(inputs, outputs, name="ViT_UNet_SingleHead")

# %% [markdown]
# # 5.0 — Training & Evaluation Helpers
# Optimiser factory, learning-rate schedule, calibration metrics (Brier score, ECE), and the main `train_save_evaluate` function.

# %% [markdown]
# ## 5.1 — Focal loss functions
# Categorical and sparse-categorical focal loss (Lin et al., 2017). Down-weights the contribution of easy, high-confidence pixels during training so the optimiser spends relatively more effort on hard / ambiguous / minority-class pixels, in place of plain (possibly label-smoothed) cross-entropy.

# %%
def categorical_focal_loss(gamma=2.0, alpha=0.25):
    """Multi-class focal loss for one-hot targets (used by GFNet and ViT).

    FL(p_t) = -alpha * (1 - p_t)^gamma * log(p_t)
    """
    def loss_fn(y_true, y_pred):
        eps    = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, eps, 1.0 - eps)
        cross_entropy = -y_true * tf.math.log(y_pred)
        weight        = alpha * tf.pow(1.0 - y_pred, gamma)
        return tf.reduce_sum(weight * cross_entropy, axis=-1)
    return loss_fn


def sparse_categorical_focal_loss(gamma=2.0, alpha=0.25):
    """Multi-class focal loss for integer targets (used by AlexNet legacy path)."""
    def loss_fn(y_true, y_pred):
        eps           = tf.keras.backend.epsilon()
        y_pred        = tf.clip_by_value(y_pred, eps, 1.0 - eps)
        y_true        = tf.cast(y_true, tf.int32)
        y_true_onehot = tf.one_hot(y_true, depth=tf.shape(y_pred)[-1])
        cross_entropy = -y_true_onehot * tf.math.log(y_pred)
        weight        = alpha * tf.pow(1.0 - y_pred, gamma)
        return tf.reduce_sum(weight * cross_entropy, axis=-1)
    return loss_fn

# %% [markdown]
# ## 5.2 — Calibration metrics

# %%
def multiclass_brier_score(y_onehot, y_prob):
    """Compute the multiclass Brier score (mean squared error over probability vectors)."""
    return float(np.mean(np.sum((y_prob - y_onehot) ** 2, axis=1)))


def expected_calibration_error(y_true, y_prob, n_bins=15):
    """Compute Expected Calibration Error (ECE) with equal-width confidence bins."""
    confidences = np.max(y_prob, axis=1)
    predictions = np.argmax(y_prob, axis=1)
    correct     = (predictions == y_true).astype(np.float32)
    bin_edges   = np.linspace(0.0, 1.0, n_bins + 1)
    ece         = 0.0

    for i in range(n_bins):
        lo, hi = bin_edges[i], bin_edges[i + 1]
        in_bin = (confidences >= lo) & (confidences <= hi if i == n_bins - 1 else confidences < hi)
        prop   = np.mean(in_bin)
        if prop > 0:
            ece += np.abs(np.mean(correct[in_bin]) - np.mean(confidences[in_bin])) * prop

    return float(ece)

# %% [markdown]
# ## 5.3 — Optimiser factory

# %%
def make_optimizer(num_train_samples):
    """Build an AdamW optimiser with a cosine-decay learning-rate schedule."""
    steps_per_epoch = int(np.ceil(num_train_samples / BATCH_SIZE))
    decay_steps     = max(1, steps_per_epoch * EPOCHS)
    lr_schedule     = keras.optimizers.schedules.CosineDecay(
        initial_learning_rate=LEARNING_RATE,
        decay_steps=decay_steps,
        alpha=TRAIN_CFG["cosine_alpha"],
    )
    return keras.optimizers.AdamW(
        learning_rate=lr_schedule,
        weight_decay=TRAIN_CFG["weight_decay"],
        clipnorm=TRAIN_CFG["clipnorm"],
    )


def _alexnet_legacy_lr(epoch):
    """Cosine LR schedule for AlexNet, matching the original single-head script."""
    if EPOCHS <= 1:
        return ALEXNET_LR_START
    phase        = np.pi * epoch / (EPOCHS - 1)
    cosine_decay = 0.5 * (1.0 + np.cos(phase))
    return float((ALEXNET_LR_MAX - ALEXNET_LR_MIN) * cosine_decay + ALEXNET_LR_MIN)

# %% [markdown]
# ## 5.4 — Main training, saving, and evaluation function

# %%
def train_save_evaluate(model_name, model_builder, capacity_tag="max"):
    """Compile, train, save (best + final), and evaluate a single-head model.

    Returns a metrics dict, per-class classification report, confusion matrix,
    and the raw Keras history dict.
    """
    tf.keras.backend.clear_session()
    model     = model_builder()
    best_path  = MODEL_DIR / f"{model_name}_best.keras"
    final_path = MODEL_DIR / f"{model_name}_final.keras"

    # AlexNet uses a legacy Adagrad + cosine LR schedule to match the original
    # single-head script for downstream uncertainty analysis.
    if model_name == "AlexNet_CNN":
        model.compile(
            optimizer=keras.optimizers.Adagrad(learning_rate=ALEXNET_LR_START),
            loss=sparse_categorical_focal_loss(gamma=FOCAL_GAMMA, alpha=FOCAL_ALPHA),
            metrics=["accuracy"],
        )
        callbacks = [
            keras.callbacks.ModelCheckpoint(
                filepath=str(best_path), monitor="val_accuracy",
                mode="max", save_best_only=True, verbose=1,
            ),
            keras.callbacks.LearningRateScheduler(_alexnet_legacy_lr, verbose=0),
        ]
        x_tr, y_tr         = x_train_alex, y_train_alex
        x_va, y_va         = x_test_alex,  y_test_alex
        x_te, y_te, y_te_cat = x_test_alex, y_test_alex, y_test_alex_cat
        x_eval, y_eval, y_eval_cat = x_test_alex, y_test_alex, y_test_alex_cat
        fit_shuffle        = False
    else:
        # GFNet and ViT use AdamW + cosine decay with label smoothing
        model.compile(
            optimizer=make_optimizer(len(x_train)),
            loss=categorical_focal_loss(gamma=FOCAL_GAMMA, alpha=FOCAL_ALPHA),
            metrics=["accuracy"],
        )
        callbacks = [
            keras.callbacks.ModelCheckpoint(
                filepath=str(best_path), monitor="val_loss",
                mode="min", save_best_only=True, verbose=1,
            ),
        ]
        x_tr, y_tr         = x_train, y_train_cat
        x_va, y_va         = x_val,   y_val_cat
        x_te, y_te, y_te_cat = x_test, y_test, y_test_cat
        x_eval, y_eval, y_eval_cat = x_val, y_val, y_val_cat
        fit_shuffle        = True

    train_start = time.perf_counter()
    history_obj = model.fit(
        x_tr, y_tr,
        validation_data=(x_va, y_va),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=callbacks,
        verbose=1,
        shuffle=fit_shuffle,
    )
    train_time_sec = float(time.perf_counter() - train_start)

    epochs_ran = int(len(history_obj.history.get("loss", [])))
    if epochs_ran != EPOCHS:
        print(f"WARNING: {model_name} ran {epochs_ran} epochs, expected {EPOCHS}.")
    else:
        print(f"{model_name} completed full training: {epochs_ran}/{EPOCHS} epochs.")

    model.save(final_path)

    y_eval_prob = model.predict(x_eval, batch_size=BATCH_SIZE, verbose=0)
    y_test_prob = model.predict(x_te,   batch_size=BATCH_SIZE, verbose=0)
    y_test_pred = np.argmax(y_test_prob, axis=1)

    report = classification_report(y_te, y_test_pred, output_dict=True, zero_division=0)
    cm     = confusion_matrix(y_te, y_test_pred)

    row = {
        "model":            model_name,
        "capacity_tag":     capacity_tag,
        "test_accuracy":    float(accuracy_score(y_te, y_test_pred)),
        "kappa":            float(cohen_kappa_score(y_te, y_test_pred)),
        "macro_f1":         float(f1_score(y_te, y_test_pred, average="macro")),
        "weighted_f1":      float(f1_score(y_te, y_test_pred, average="weighted")),
        "val_nll":          float(log_loss(y_eval, y_eval_prob, labels=np.arange(num_classes))),
        "test_nll":         float(log_loss(y_te,   y_test_prob, labels=np.arange(num_classes))),
        "val_brier":        multiclass_brier_score(y_eval_cat, y_eval_prob),
        "test_brier":       multiclass_brier_score(y_te_cat,   y_test_prob),
        "test_ece_15bin":   expected_calibration_error(y_te, y_test_prob, n_bins=15),
        "epochs_configured": int(EPOCHS),
        "epochs_ran":       epochs_ran,
        "train_time_sec":   train_time_sec,
        "best_model_path":  str(best_path),
        "final_model_path": str(final_path),
    }
    return row, report, cm, history_obj.history

# %% [markdown]
# # 6.0 — Model Training
# Build factory lambdas, then loop over all three architectures. OOM errors on GFNet and ViT automatically retry with reduced fallback configs.

# %%
def build_gfnet_with_cfg(cfg):
    """Instantiate GFNet from a config dict."""
    return build_gfnet(
        input_shape, num_classes,
        inner_patch=INNER_PATCH,
        hidden_dim=cfg["hidden_dim"],
        num_blocks=cfg["num_blocks"],
        mlp_ratio=cfg["mlp_ratio"],
        dropout_rate=DROPOUT_RATE,
    )


def build_vit_with_cfg(cfg):
    """Instantiate ViT-UNet from a config dict."""
    return build_vit_unet_singlehead(
        input_shape, num_classes,
        inner_patch=INNER_PATCH,
        projection_dim=cfg["projection_dim"],
        num_heads=cfg["num_heads"],
        transformer_layers=cfg["transformer_layers"],
        mlp_multiplier=cfg["mlp_multiplier"],
        dropout_rate=DROPOUT_RATE,
        head_units=tuple(cfg["head_units"]),
    )


model_builders = {
    "AlexNet_CNN": lambda: build_alexnet(input_shape, num_classes,
                                         dropout_rate=DROPOUT_RATE, cfg=ALEXNET_CFG),
    "GFNet":       lambda: build_gfnet_with_cfg(GFNET_CFG),
    "ViT_UNet":    lambda: build_vit_with_cfg(VIT_CFG),
}

# %%
results_rows   = []
model_artifacts = {}

for model_name, builder in model_builders.items():
    print(f"\n{'=' * 25} Training {model_name} ({CAPACITY_PRESET}) {'=' * 25}")

    try:
        row, report, cm, history = train_save_evaluate(model_name, builder,
                                                       capacity_tag=CAPACITY_PRESET)
    except tf.errors.ResourceExhaustedError:
        # Automatically retry with a smaller fallback config to handle Colab OOM
        if model_name == "GFNet":
            print("OOM on GFNet legacy config. Retrying with fallback config.")
            tf.keras.backend.clear_session()
            row, report, cm, history = train_save_evaluate(
                model_name, lambda: build_gfnet_with_cfg(GFNET_FALLBACK_CFG),
                capacity_tag="fallback",
            )
        elif model_name == "ViT_UNet":
            print("OOM on ViT_UNet legacy config. Retrying with fallback config.")
            tf.keras.backend.clear_session()
            row, report, cm, history = train_save_evaluate(
                model_name, lambda: build_vit_with_cfg(VIT_FALLBACK_CFG),
                capacity_tag="fallback",
            )
        else:
            raise

    results_rows.append(row)
    model_artifacts[model_name] = {"report": report, "confusion_matrix": cm, "history": history}

summary_df = (
    pd.DataFrame(results_rows)
    .sort_values("test_accuracy", ascending=False)
    .reset_index(drop=True)
)
summary_df
# Out:
# ========================= Training AlexNet_CNN (legacy_arch) =========================
# Epoch 1/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.3768 - loss: 0.3363
# Epoch 1: val_accuracy improved from None to 0.42413, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 29s 162ms/step - accuracy: 0.4154 - loss: 0.3134 - val_accuracy: 0.4241 - val_loss: 0.2702 - learning_rate: 0.0200
# Epoch 2/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4522 - loss: 0.2411
# Epoch 2: val_accuracy improved from 0.42413 to 0.55986, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.4965 - loss: 0.2221 - val_accuracy: 0.5599 - val_loss: 0.1864 - learning_rate: 0.0200
# Epoch 3/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5579 - loss: 0.1829
# Epoch 3: val_accuracy improved from 0.55986 to 0.59002, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.5628 - loss: 0.1772 - val_accuracy: 0.5900 - val_loss: 0.1669 - learning_rate: 0.0200
# Epoch 4/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5658 - loss: 0.1656
# Epoch 4: val_accuracy improved from 0.59002 to 0.60093, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.5697 - loss: 0.1610 - val_accuracy: 0.6009 - val_loss: 0.1434 - learning_rate: 0.0200
# Epoch 5/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5728 - loss: 0.1505
# Epoch 5: val_accuracy did not improve from 0.60093
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.5791 - loss: 0.1492 - val_accuracy: 0.5991 - val_loss: 0.1402 - learning_rate: 0.0199
# Epoch 6/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5820 - loss: 0.1454
# Epoch 6: val_accuracy improved from 0.60093 to 0.60974, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.5868 - loss: 0.1438 - val_accuracy: 0.6097 - val_loss: 0.1393 - learning_rate: 0.0199
# Epoch 7/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5907 - loss: 0.1398
# Epoch 7: val_accuracy improved from 0.60974 to 0.63086, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.5956 - loss: 0.1376 - val_accuracy: 0.6309 - val_loss: 0.1272 - learning_rate: 0.0199
# Epoch 8/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5971 - loss: 0.1345
# Epoch 8: val_accuracy improved from 0.63086 to 0.64060, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 74ms/step - accuracy: 0.6066 - loss: 0.1331 - val_accuracy: 0.6406 - val_loss: 0.1216 - learning_rate: 0.0198
# Epoch 9/100
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6129 - loss: 0.1301
# Epoch 9: val_accuracy improved from 0.64060 to 0.64733, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 9: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.6167 - loss: 0.1290 - val_accuracy: 0.6473 - val_loss: 0.1203 - learning_rate: 0.0198
# Epoch 10/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6157 - loss: 0.1274
# Epoch 10: val_accuracy improved from 0.64733 to 0.65963, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 10: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.6226 - loss: 0.1254 - val_accuracy: 0.6596 - val_loss: 0.1149 - learning_rate: 0.0197
# Epoch 11/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6332 - loss: 0.1224
# Epoch 11: val_accuracy improved from 0.65963 to 0.66381, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.6359 - loss: 0.1208 - val_accuracy: 0.6638 - val_loss: 0.1164 - learning_rate: 0.0196
# Epoch 12/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6311 - loss: 0.1197
# Epoch 12: val_accuracy did not improve from 0.66381
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.6431 - loss: 0.1171 - val_accuracy: 0.6633 - val_loss: 0.1078 - learning_rate: 0.0195
# Epoch 13/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6484 - loss: 0.1145
# Epoch 13: val_accuracy improved from 0.66381 to 0.67262, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 13: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.6540 - loss: 0.1132 - val_accuracy: 0.6726 - val_loss: 0.1052 - learning_rate: 0.0195
# Epoch 14/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6665 - loss: 0.1098
# Epoch 14: val_accuracy improved from 0.67262 to 0.67912, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 14: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.6655 - loss: 0.1092 - val_accuracy: 0.6791 - val_loss: 0.1007 - learning_rate: 0.0194
# Epoch 15/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6728 - loss: 0.1068
# Epoch 15: val_accuracy improved from 0.67912 to 0.69606, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 15: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.6739 - loss: 0.1060 - val_accuracy: 0.6961 - val_loss: 0.0964 - learning_rate: 0.0193
# Epoch 16/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6810 - loss: 0.1021
# Epoch 16: val_accuracy improved from 0.69606 to 0.72506, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 16: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.6854 - loss: 0.1008 - val_accuracy: 0.7251 - val_loss: 0.0901 - learning_rate: 0.0192
# Epoch 17/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7020 - loss: 0.0958
# Epoch 17: val_accuracy improved from 0.72506 to 0.76891, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 17: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - accuracy: 0.7124 - loss: 0.0929 - val_accuracy: 0.7689 - val_loss: 0.0787 - learning_rate: 0.0191
# Epoch 18/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7308 - loss: 0.0867
# Epoch 18: val_accuracy improved from 0.76891 to 0.79281, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 18: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.7334 - loss: 0.0858 - val_accuracy: 0.7928 - val_loss: 0.0679 - learning_rate: 0.0189
# Epoch 19/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7553 - loss: 0.0776
# Epoch 19: val_accuracy improved from 0.79281 to 0.81485, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 19: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.7566 - loss: 0.0778 - val_accuracy: 0.8148 - val_loss: 0.0595 - learning_rate: 0.0188
# Epoch 20/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7647 - loss: 0.0728
# Epoch 20: val_accuracy improved from 0.81485 to 0.82019, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 20: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.7708 - loss: 0.0703 - val_accuracy: 0.8202 - val_loss: 0.0543 - learning_rate: 0.0187
# Epoch 21/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7774 - loss: 0.0659
# Epoch 21: val_accuracy did not improve from 0.82019
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7864 - loss: 0.0639 - val_accuracy: 0.8109 - val_loss: 0.0554 - learning_rate: 0.0185
# Epoch 22/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7987 - loss: 0.0579
# Epoch 22: val_accuracy did not improve from 0.82019
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.7991 - loss: 0.0582 - val_accuracy: 0.8058 - val_loss: 0.0551 - learning_rate: 0.0184
# Epoch 23/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7990 - loss: 0.0582
# Epoch 23: val_accuracy improved from 0.82019 to 0.83318, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 23: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.8118 - loss: 0.0548 - val_accuracy: 0.8332 - val_loss: 0.0464 - learning_rate: 0.0182
# Epoch 24/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8109 - loss: 0.0531
# Epoch 24: val_accuracy improved from 0.83318 to 0.83712, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 24: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.8136 - loss: 0.0529 - val_accuracy: 0.8371 - val_loss: 0.0442 - learning_rate: 0.0181
# Epoch 25/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8293 - loss: 0.0483
# Epoch 25: val_accuracy improved from 0.83712 to 0.84501, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 25: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.8275 - loss: 0.0482 - val_accuracy: 0.8450 - val_loss: 0.0411 - learning_rate: 0.0179
# Epoch 26/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8246 - loss: 0.0485
# Epoch 26: val_accuracy improved from 0.84501 to 0.85963, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 26: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.8254 - loss: 0.0477 - val_accuracy: 0.8596 - val_loss: 0.0381 - learning_rate: 0.0178
# Epoch 27/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8357 - loss: 0.0445
# Epoch 27: val_accuracy improved from 0.85963 to 0.86195, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 27: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.8375 - loss: 0.0439 - val_accuracy: 0.8619 - val_loss: 0.0366 - learning_rate: 0.0176
# Epoch 28/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8450 - loss: 0.0425
# Epoch 28: val_accuracy improved from 0.86195 to 0.87401, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 28: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 84ms/step - accuracy: 0.8448 - loss: 0.0422 - val_accuracy: 0.8740 - val_loss: 0.0334 - learning_rate: 0.0174
# Epoch 29/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8503 - loss: 0.0397
# Epoch 29: val_accuracy improved from 0.87401 to 0.88051, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 29: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.8534 - loss: 0.0395 - val_accuracy: 0.8805 - val_loss: 0.0316 - learning_rate: 0.0172
# Epoch 30/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8560 - loss: 0.0386
# Epoch 30: val_accuracy did not improve from 0.88051
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.8557 - loss: 0.0383 - val_accuracy: 0.8761 - val_loss: 0.0311 - learning_rate: 0.0170
# Epoch 31/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8621 - loss: 0.0354
# Epoch 31: val_accuracy did not improve from 0.88051
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.8661 - loss: 0.0347 - val_accuracy: 0.8796 - val_loss: 0.0297 - learning_rate: 0.0169
# Epoch 32/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8613 - loss: 0.0352
# Epoch 32: val_accuracy improved from 0.88051 to 0.89490, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 32: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.8667 - loss: 0.0339 - val_accuracy: 0.8949 - val_loss: 0.0259 - learning_rate: 0.0167
# Epoch 33/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8775 - loss: 0.0316
# Epoch 33: val_accuracy did not improve from 0.89490
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.8751 - loss: 0.0319 - val_accuracy: 0.8796 - val_loss: 0.0290 - learning_rate: 0.0165
# Epoch 34/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8812 - loss: 0.0298
# Epoch 34: val_accuracy did not improve from 0.89490
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.8831 - loss: 0.0289 - val_accuracy: 0.8926 - val_loss: 0.0245 - learning_rate: 0.0162
# Epoch 35/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8796 - loss: 0.0304
# Epoch 35: val_accuracy improved from 0.89490 to 0.90534, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 35: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.8837 - loss: 0.0300 - val_accuracy: 0.9053 - val_loss: 0.0217 - learning_rate: 0.0160
# Epoch 36/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8885 - loss: 0.0275
# Epoch 36: val_accuracy improved from 0.90534 to 0.91021, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 36: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - accuracy: 0.8909 - loss: 0.0275 - val_accuracy: 0.9102 - val_loss: 0.0212 - learning_rate: 0.0158
# Epoch 37/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9041 - loss: 0.0253
# Epoch 37: val_accuracy did not improve from 0.91021
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.8991 - loss: 0.0251 - val_accuracy: 0.9023 - val_loss: 0.0222 - learning_rate: 0.0156
# Epoch 38/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8957 - loss: 0.0254
# Epoch 38: val_accuracy improved from 0.91021 to 0.91717, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 38: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 104ms/step - accuracy: 0.8997 - loss: 0.0243 - val_accuracy: 0.9172 - val_loss: 0.0187 - learning_rate: 0.0154
# Epoch 39/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9023 - loss: 0.0236
# Epoch 39: val_accuracy improved from 0.91717 to 0.92413, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 39: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9068 - loss: 0.0230 - val_accuracy: 0.9241 - val_loss: 0.0169 - learning_rate: 0.0152
# Epoch 40/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9049 - loss: 0.0221
# Epoch 40: val_accuracy improved from 0.92413 to 0.92970, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 40: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9073 - loss: 0.0222 - val_accuracy: 0.9297 - val_loss: 0.0162 - learning_rate: 0.0150
# Epoch 41/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9101 - loss: 0.0210
# Epoch 41: val_accuracy did not improve from 0.92970
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9106 - loss: 0.0208 - val_accuracy: 0.9276 - val_loss: 0.0165 - learning_rate: 0.0147
# Epoch 42/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9155 - loss: 0.0206
# Epoch 42: val_accuracy improved from 0.92970 to 0.93109, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 42: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.9171 - loss: 0.0202 - val_accuracy: 0.9311 - val_loss: 0.0153 - learning_rate: 0.0145
# Epoch 43/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9177 - loss: 0.0191
# Epoch 43: val_accuracy improved from 0.93109 to 0.93411, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 43: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.9191 - loss: 0.0190 - val_accuracy: 0.9341 - val_loss: 0.0147 - learning_rate: 0.0143
# Epoch 44/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9217 - loss: 0.0182
# Epoch 44: val_accuracy did not improve from 0.93411
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9223 - loss: 0.0179 - val_accuracy: 0.9339 - val_loss: 0.0145 - learning_rate: 0.0140
# Epoch 45/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9214 - loss: 0.0184
# Epoch 45: val_accuracy improved from 0.93411 to 0.94153, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 45: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 11s 106ms/step - accuracy: 0.9212 - loss: 0.0191 - val_accuracy: 0.9415 - val_loss: 0.0130 - learning_rate: 0.0138
# Epoch 46/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9276 - loss: 0.0166
# Epoch 46: val_accuracy improved from 0.94153 to 0.94316, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 46: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 83ms/step - accuracy: 0.9315 - loss: 0.0158 - val_accuracy: 0.9432 - val_loss: 0.0126 - learning_rate: 0.0136
# Epoch 47/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9275 - loss: 0.0160
# Epoch 47: val_accuracy improved from 0.94316 to 0.94455, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 47: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.9316 - loss: 0.0159 - val_accuracy: 0.9445 - val_loss: 0.0127 - learning_rate: 0.0133
# Epoch 48/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9317 - loss: 0.0151
# Epoch 48: val_accuracy did not improve from 0.94455
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9356 - loss: 0.0147 - val_accuracy: 0.9432 - val_loss: 0.0122 - learning_rate: 0.0131
# Epoch 49/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9320 - loss: 0.0149
# Epoch 49: val_accuracy improved from 0.94455 to 0.94988, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 49: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 86ms/step - accuracy: 0.9372 - loss: 0.0141 - val_accuracy: 0.9499 - val_loss: 0.0108 - learning_rate: 0.0129
# Epoch 50/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9335 - loss: 0.0152
# Epoch 50: val_accuracy improved from 0.94988 to 0.95151, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 50: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9368 - loss: 0.0146 - val_accuracy: 0.9515 - val_loss: 0.0116 - learning_rate: 0.0126
# Epoch 51/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9393 - loss: 0.0139
# Epoch 51: val_accuracy improved from 0.95151 to 0.95220, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 51: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step - accuracy: 0.9416 - loss: 0.0135 - val_accuracy: 0.9522 - val_loss: 0.0113 - learning_rate: 0.0124
# Epoch 52/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9395 - loss: 0.0136
# Epoch 52: val_accuracy improved from 0.95220 to 0.95290, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 52: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.9417 - loss: 0.0130 - val_accuracy: 0.9529 - val_loss: 0.0103 - learning_rate: 0.0121
# Epoch 53/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9413 - loss: 0.0124
# Epoch 53: val_accuracy improved from 0.95290 to 0.95986, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 53: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.9438 - loss: 0.0123 - val_accuracy: 0.9599 - val_loss: 0.0093 - learning_rate: 0.0119
# Epoch 54/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9456 - loss: 0.0124
# Epoch 54: val_accuracy did not improve from 0.95986
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9478 - loss: 0.0120 - val_accuracy: 0.9599 - val_loss: 0.0096 - learning_rate: 0.0117
# Epoch 55/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9452 - loss: 0.0120
# Epoch 55: val_accuracy improved from 0.95986 to 0.96195, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 55: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.9474 - loss: 0.0119 - val_accuracy: 0.9619 - val_loss: 0.0092 - learning_rate: 0.0114
# Epoch 56/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9490 - loss: 0.0115
# Epoch 56: val_accuracy improved from 0.96195 to 0.96357, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 56: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - accuracy: 0.9496 - loss: 0.0112 - val_accuracy: 0.9636 - val_loss: 0.0090 - learning_rate: 0.0112
# Epoch 57/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9500 - loss: 0.0111
# Epoch 57: val_accuracy did not improve from 0.96357
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9499 - loss: 0.0111 - val_accuracy: 0.9624 - val_loss: 0.0085 - learning_rate: 0.0110
# Epoch 58/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9504 - loss: 0.0110
# Epoch 58: val_accuracy improved from 0.96357 to 0.96705, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 58: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.9510 - loss: 0.0109 - val_accuracy: 0.9671 - val_loss: 0.0082 - learning_rate: 0.0107
# Epoch 59/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9551 - loss: 0.0101
# Epoch 59: val_accuracy did not improve from 0.96705
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9568 - loss: 0.0097 - val_accuracy: 0.9610 - val_loss: 0.0084 - learning_rate: 0.0105
# Epoch 60/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9457 - loss: 0.0114
# Epoch 60: val_accuracy did not improve from 0.96705
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.9508 - loss: 0.0107 - val_accuracy: 0.9666 - val_loss: 0.0081 - learning_rate: 0.0103
# Epoch 61/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9540 - loss: 0.0102
# Epoch 61: val_accuracy did not improve from 0.96705
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9564 - loss: 0.0099 - val_accuracy: 0.9659 - val_loss: 0.0083 - learning_rate: 0.0100
# Epoch 62/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9587 - loss: 0.0096
# Epoch 62: val_accuracy improved from 0.96705 to 0.96868, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 62: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 114ms/step - accuracy: 0.9599 - loss: 0.0092 - val_accuracy: 0.9687 - val_loss: 0.0075 - learning_rate: 0.0098
# Epoch 63/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9574 - loss: 0.0091
# Epoch 63: val_accuracy improved from 0.96868 to 0.97100, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 63: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9578 - loss: 0.0092 - val_accuracy: 0.9710 - val_loss: 0.0071 - learning_rate: 0.0096
# Epoch 64/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9553 - loss: 0.0094
# Epoch 64: val_accuracy improved from 0.97100 to 0.97146, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 64: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.9595 - loss: 0.0085 - val_accuracy: 0.9715 - val_loss: 0.0069 - learning_rate: 0.0094
# Epoch 65/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9600 - loss: 0.0091
# Epoch 65: val_accuracy did not improve from 0.97146
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9614 - loss: 0.0087 - val_accuracy: 0.9691 - val_loss: 0.0073 - learning_rate: 0.0092
# Epoch 66/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9615 - loss: 0.0085
# Epoch 66: val_accuracy did not improve from 0.97146
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9623 - loss: 0.0083 - val_accuracy: 0.9715 - val_loss: 0.0069 - learning_rate: 0.0090
# Epoch 67/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9646 - loss: 0.0079
# Epoch 67: val_accuracy improved from 0.97146 to 0.97471, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 67: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 15s 143ms/step - accuracy: 0.9644 - loss: 0.0077 - val_accuracy: 0.9747 - val_loss: 0.0063 - learning_rate: 0.0088
# Epoch 68/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9602 - loss: 0.0085
# Epoch 68: val_accuracy did not improve from 0.97471
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9623 - loss: 0.0082 - val_accuracy: 0.9722 - val_loss: 0.0067 - learning_rate: 0.0085
# Epoch 69/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9611 - loss: 0.0081
# Epoch 69: val_accuracy did not improve from 0.97471
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9627 - loss: 0.0079 - val_accuracy: 0.9747 - val_loss: 0.0061 - learning_rate: 0.0083
# Epoch 70/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9623 - loss: 0.0079
# Epoch 70: val_accuracy improved from 0.97471 to 0.97657, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 70: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 114ms/step - accuracy: 0.9651 - loss: 0.0077 - val_accuracy: 0.9766 - val_loss: 0.0059 - learning_rate: 0.0081
# Epoch 71/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9645 - loss: 0.0073
# Epoch 71: val_accuracy did not improve from 0.97657
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9667 - loss: 0.0074 - val_accuracy: 0.9749 - val_loss: 0.0059 - learning_rate: 0.0080
# Epoch 72/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9647 - loss: 0.0071
# Epoch 72: val_accuracy did not improve from 0.97657
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9657 - loss: 0.0068 - val_accuracy: 0.9761 - val_loss: 0.0058 - learning_rate: 0.0078
# Epoch 73/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9687 - loss: 0.0068
# Epoch 73: val_accuracy did not improve from 0.97657
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9708 - loss: 0.0067 - val_accuracy: 0.9759 - val_loss: 0.0057 - learning_rate: 0.0076
# Epoch 74/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9683 - loss: 0.0070
# Epoch 74: val_accuracy did not improve from 0.97657
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9695 - loss: 0.0066 - val_accuracy: 0.9766 - val_loss: 0.0055 - learning_rate: 0.0074
# Epoch 75/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9657 - loss: 0.0071
# Epoch 75: val_accuracy improved from 0.97657 to 0.97773, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 75: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.9688 - loss: 0.0068 - val_accuracy: 0.9777 - val_loss: 0.0056 - learning_rate: 0.0072
# Epoch 76/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9671 - loss: 0.0070
# Epoch 76: val_accuracy improved from 0.97773 to 0.97819, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 76: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.9684 - loss: 0.0067 - val_accuracy: 0.9782 - val_loss: 0.0054 - learning_rate: 0.0071
# Epoch 77/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9688 - loss: 0.0066
# Epoch 77: val_accuracy did not improve from 0.97819
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9697 - loss: 0.0064 - val_accuracy: 0.9770 - val_loss: 0.0055 - learning_rate: 0.0069
# Epoch 78/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9683 - loss: 0.0062
# Epoch 78: val_accuracy improved from 0.97819 to 0.97889, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 78: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 12s 122ms/step - accuracy: 0.9702 - loss: 0.0063 - val_accuracy: 0.9789 - val_loss: 0.0053 - learning_rate: 0.0068
# Epoch 79/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9691 - loss: 0.0065
# Epoch 79: val_accuracy did not improve from 0.97889
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9722 - loss: 0.0061 - val_accuracy: 0.9773 - val_loss: 0.0052 - learning_rate: 0.0066
# Epoch 80/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9673 - loss: 0.0063
# Epoch 80: val_accuracy did not improve from 0.97889
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9700 - loss: 0.0060 - val_accuracy: 0.9773 - val_loss: 0.0052 - learning_rate: 0.0065
# Epoch 81/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9672 - loss: 0.0067
# Epoch 81: val_accuracy did not improve from 0.97889
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9695 - loss: 0.0064 - val_accuracy: 0.9770 - val_loss: 0.0055 - learning_rate: 0.0063
# Epoch 82/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9688 - loss: 0.0063
# Epoch 82: val_accuracy did not improve from 0.97889
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9715 - loss: 0.0059 - val_accuracy: 0.9775 - val_loss: 0.0051 - learning_rate: 0.0062
# Epoch 83/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9715 - loss: 0.0059
# Epoch 83: val_accuracy improved from 0.97889 to 0.97935, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 83: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 9s 86ms/step - accuracy: 0.9742 - loss: 0.0055 - val_accuracy: 0.9794 - val_loss: 0.0048 - learning_rate: 0.0061
# Epoch 84/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9699 - loss: 0.0059
# Epoch 84: val_accuracy improved from 0.97935 to 0.98028, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 84: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9731 - loss: 0.0057 - val_accuracy: 0.9803 - val_loss: 0.0047 - learning_rate: 0.0059
# Epoch 85/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9699 - loss: 0.0059
# Epoch 85: val_accuracy improved from 0.98028 to 0.98051, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 85: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 13s 132ms/step - accuracy: 0.9738 - loss: 0.0056 - val_accuracy: 0.9805 - val_loss: 0.0047 - learning_rate: 0.0058
# Epoch 86/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9708 - loss: 0.0058
# Epoch 86: val_accuracy did not improve from 0.98051
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9735 - loss: 0.0055 - val_accuracy: 0.9796 - val_loss: 0.0046 - learning_rate: 0.0057
# Epoch 87/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9734 - loss: 0.0054
# Epoch 87: val_accuracy did not improve from 0.98051
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9760 - loss: 0.0052 - val_accuracy: 0.9803 - val_loss: 0.0043 - learning_rate: 0.0056
# Epoch 88/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9737 - loss: 0.0058
# Epoch 88: val_accuracy did not improve from 0.98051
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9762 - loss: 0.0055 - val_accuracy: 0.9798 - val_loss: 0.0047 - learning_rate: 0.0055
# Epoch 89/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9765 - loss: 0.0052
# Epoch 89: val_accuracy improved from 0.98051 to 0.98144, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 89: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9774 - loss: 0.0050 - val_accuracy: 0.9814 - val_loss: 0.0043 - learning_rate: 0.0055
# Epoch 90/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9743 - loss: 0.0053
# Epoch 90: val_accuracy did not improve from 0.98144
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9753 - loss: 0.0052 - val_accuracy: 0.9800 - val_loss: 0.0046 - learning_rate: 0.0054
# Epoch 91/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9755 - loss: 0.0053
# Epoch 91: val_accuracy did not improve from 0.98144
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 73ms/step - accuracy: 0.9767 - loss: 0.0051 - val_accuracy: 0.9796 - val_loss: 0.0045 - learning_rate: 0.0053
# Epoch 92/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9736 - loss: 0.0057
# Epoch 92: val_accuracy did not improve from 0.98144
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9764 - loss: 0.0052 - val_accuracy: 0.9805 - val_loss: 0.0046 - learning_rate: 0.0052
# Epoch 93/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9741 - loss: 0.0058
# Epoch 93: val_accuracy did not improve from 0.98144
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9763 - loss: 0.0051 - val_accuracy: 0.9807 - val_loss: 0.0043 - learning_rate: 0.0052
# Epoch 94/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9731 - loss: 0.0055
# Epoch 94: val_accuracy improved from 0.98144 to 0.98283, saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
#
# Epoch 94: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/AlexNet_CNN_best.keras
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 14s 102ms/step - accuracy: 0.9753 - loss: 0.0052 - val_accuracy: 0.9828 - val_loss: 0.0041 - learning_rate: 0.0051
# Epoch 95/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9756 - loss: 0.0051
# Epoch 95: val_accuracy did not improve from 0.98283
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9769 - loss: 0.0049 - val_accuracy: 0.9828 - val_loss: 0.0040 - learning_rate: 0.0051
# Epoch 96/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9778 - loss: 0.0047
# Epoch 96: val_accuracy did not improve from 0.98283
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9793 - loss: 0.0044 - val_accuracy: 0.9810 - val_loss: 0.0044 - learning_rate: 0.0051
# Epoch 97/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9767 - loss: 0.0050
# Epoch 97: val_accuracy did not improve from 0.98283
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9784 - loss: 0.0046 - val_accuracy: 0.9817 - val_loss: 0.0040 - learning_rate: 0.0050
# Epoch 98/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9778 - loss: 0.0045
# Epoch 98: val_accuracy did not improve from 0.98283
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9804 - loss: 0.0045 - val_accuracy: 0.9814 - val_loss: 0.0044 - learning_rate: 0.0050
# Epoch 99/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9770 - loss: 0.0049
# Epoch 99: val_accuracy did not improve from 0.98283
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9790 - loss: 0.0044 - val_accuracy: 0.9819 - val_loss: 0.0040 - learning_rate: 0.0050
# Epoch 100/100
# 101/102 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9768 - loss: 0.0048
# Epoch 100: val_accuracy did not improve from 0.98283
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9778 - loss: 0.0047 - val_accuracy: 0.9828 - val_loss: 0.0038 - learning_rate: 0.0050
# AlexNet_CNN completed full training: 100/100 epochs.
#
# ========================= Training GFNet (legacy_arch) =========================
# Epoch 1/100
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# WARNING:tensorflow:You are casting an input of type complex64 to an incompatible dtype float32.  This will discard the imaginary part and may not be what you intended.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.4501 - loss: 0.3604
# Epoch 1: val_loss improved from None to 0.12856, saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
#
# Epoch 1: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 62s 362ms/step - accuracy: 0.5304 - loss: 0.2270 - val_accuracy: 0.6442 - val_loss: 0.1286
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6778 - loss: 0.1119
# Epoch 2: val_loss improved from 0.12856 to 0.07468, saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
#
# Epoch 2: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 100ms/step - accuracy: 0.7046 - loss: 0.1038 - val_accuracy: 0.7916 - val_loss: 0.0747
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7591 - loss: 0.0811
# Epoch 3: val_loss improved from 0.07468 to 0.07035, saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
#
# Epoch 3: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.7711 - loss: 0.0772 - val_accuracy: 0.8067 - val_loss: 0.0704
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8275 - loss: 0.0571
# Epoch 4: val_loss improved from 0.07035 to 0.04541, saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
#
# Epoch 4: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 9s 109ms/step - accuracy: 0.8253 - loss: 0.0569 - val_accuracy: 0.8689 - val_loss: 0.0454
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8557 - loss: 0.0455
# Epoch 5: val_loss improved from 0.04541 to 0.03361, saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
#
# Epoch 5: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.8527 - loss: 0.0469 - val_accuracy: 0.8817 - val_loss: 0.0336
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8736 - loss: 0.0387
# Epoch 6: val_loss improved from 0.03361 to 0.02897, saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
#
# Epoch 6: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - accuracy: 0.8692 - loss: 0.0399 - val_accuracy: 0.9022 - val_loss: 0.0290
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8785 - loss: 0.0363
# Epoch 7: val_loss improved from 0.02897 to 0.02748, saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
#
# Epoch 7: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 98ms/step - accuracy: 0.8793 - loss: 0.0365 - val_accuracy: 0.8979 - val_loss: 0.0275
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8933 - loss: 0.0320
# Epoch 8: val_loss improved from 0.02748 to 0.01864, saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
#
# Epoch 8: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - accuracy: 0.8962 - loss: 0.0313 - val_accuracy: 0.9304 - val_loss: 0.0186
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9080 - loss: 0.0265
# Epoch 9: val_loss did not improve from 0.01864
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.9045 - loss: 0.0285 - val_accuracy: 0.9203 - val_loss: 0.0218
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9147 - loss: 0.0249
# Epoch 10: val_loss did not improve from 0.01864
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 89ms/step - accuracy: 0.9160 - loss: 0.0241 - val_accuracy: 0.9288 - val_loss: 0.0192
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9218 - loss: 0.0221
# Epoch 11: val_loss improved from 0.01864 to 0.01501, saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
#
# Epoch 11: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step - accuracy: 0.9249 - loss: 0.0211 - val_accuracy: 0.9420 - val_loss: 0.0150
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9385 - loss: 0.0162
# Epoch 12: val_loss improved from 0.01501 to 0.01480, saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
#
# Epoch 12: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - accuracy: 0.9369 - loss: 0.0165 - val_accuracy: 0.9401 - val_loss: 0.0148
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9417 - loss: 0.0149
# Epoch 13: val_loss improved from 0.01480 to 0.01109, saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
#
# Epoch 13: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/GFNet_best.keras
# ...
# Epoch 48: val_loss did not improve from 0.00454
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.9872 - loss: 0.0029 - val_accuracy: 0.9822 - val_loss: 0.0062
# Epoch 49/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9856 - loss: 0.0034
# Epoch 49: val_loss did not improve from 0.00454
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9833 - loss: 0.0042 - val_accuracy: 0.9838 - val_loss: 0.0060
# Epoch 50/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9826 - loss: 0.0052
# Epoch 50: val_loss improved from 0.00454 to 0.00386, saving model to /content/drive/My Drive/Classification/focal_loss/models/ViT_UNet_best.keras
#
# Epoch 50: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 178ms/step - accuracy: 0.9840 - loss: 0.0044 - val_accuracy: 0.9869 - val_loss: 0.0039
# Epoch 51/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9866 - loss: 0.0027
# Epoch 51: val_loss did not improve from 0.00386
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 154ms/step - accuracy: 0.9886 - loss: 0.0024 - val_accuracy: 0.9869 - val_loss: 0.0055
# Epoch 52/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9898 - loss: 0.0026
# Epoch 52: val_loss did not improve from 0.00386
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 158ms/step - accuracy: 0.9894 - loss: 0.0023 - val_accuracy: 0.9838 - val_loss: 0.0057
# Epoch 53/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9898 - loss: 0.0023
# Epoch 53: val_loss did not improve from 0.00386
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.9862 - loss: 0.0033 - val_accuracy: 0.9783 - val_loss: 0.0076
# Epoch 54/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9885 - loss: 0.0024
# Epoch 54: val_loss did not improve from 0.00386
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9890 - loss: 0.0025 - val_accuracy: 0.9795 - val_loss: 0.0055
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9925 - loss: 0.0016
# Epoch 55: val_loss did not improve from 0.00386
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9925 - loss: 0.0018 - val_accuracy: 0.9838 - val_loss: 0.0039
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9944 - loss: 0.0013
# Epoch 56: val_loss did not improve from 0.00386
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9928 - loss: 0.0017 - val_accuracy: 0.9892 - val_loss: 0.0042
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9916 - loss: 0.0016
# Epoch 57: val_loss did not improve from 0.00386
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9903 - loss: 0.0019 - val_accuracy: 0.9857 - val_loss: 0.0064
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9931 - loss: 0.0018
# Epoch 58: val_loss improved from 0.00386 to 0.00300, saving model to /content/drive/My Drive/Classification/focal_loss/models/ViT_UNet_best.keras
#
# Epoch 58: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9930 - loss: 0.0017 - val_accuracy: 0.9888 - val_loss: 0.0030
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9944 - loss: 0.0013
# Epoch 59: val_loss improved from 0.00300 to 0.00243, saving model to /content/drive/My Drive/Classification/focal_loss/models/ViT_UNet_best.keras
#
# Epoch 59: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 19s 232ms/step - accuracy: 0.9948 - loss: 0.0013 - val_accuracy: 0.9919 - val_loss: 0.0024
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9955 - loss: 7.7837e-04
# Epoch 60: val_loss did not improve from 0.00243
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 15s 161ms/step - accuracy: 0.9961 - loss: 9.1145e-04 - val_accuracy: 0.9938 - val_loss: 0.0028
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9955 - loss: 0.0011
# Epoch 61: val_loss did not improve from 0.00243
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 164ms/step - accuracy: 0.9961 - loss: 0.0010 - val_accuracy: 0.9880 - val_loss: 0.0035
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9929 - loss: 0.0017
# Epoch 62: val_loss did not improve from 0.00243
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.9912 - loss: 0.0022 - val_accuracy: 0.9899 - val_loss: 0.0029
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9937 - loss: 0.0015
# Epoch 63: val_loss did not improve from 0.00243
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.9944 - loss: 0.0015 - val_accuracy: 0.9869 - val_loss: 0.0029
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9953 - loss: 0.0012
# Epoch 64: val_loss did not improve from 0.00243
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - accuracy: 0.9955 - loss: 0.0013 - val_accuracy: 0.9880 - val_loss: 0.0029
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9964 - loss: 5.6640e-04
# Epoch 65: val_loss did not improve from 0.00243
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9970 - loss: 6.2342e-04 - val_accuracy: 0.9923 - val_loss: 0.0026
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9917 - loss: 0.0014
# Epoch 66: val_loss improved from 0.00243 to 0.00242, saving model to /content/drive/My Drive/Classification/focal_loss/models/ViT_UNet_best.keras
#
# Epoch 66: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 175ms/step - accuracy: 0.9946 - loss: 0.0012 - val_accuracy: 0.9923 - val_loss: 0.0024
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.9961 - loss: 9.3135e-04
# Epoch 67: val_loss did not improve from 0.00242
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.9933 - loss: 0.0015 - val_accuracy: 0.9845 - val_loss: 0.0054
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9962 - loss: 0.0012
# Epoch 68: val_loss did not improve from 0.00242
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 157ms/step - accuracy: 0.9963 - loss: 8.8383e-04 - val_accuracy: 0.9899 - val_loss: 0.0036
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9953 - loss: 0.0012
# Epoch 69: val_loss did not improve from 0.00242
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9931 - loss: 0.0018 - val_accuracy: 0.9888 - val_loss: 0.0037
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9921 - loss: 0.0022
# Epoch 70: val_loss did not improve from 0.00242
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9933 - loss: 0.0018 - val_accuracy: 0.9915 - val_loss: 0.0030
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9946 - loss: 0.0010
# Epoch 71: val_loss did not improve from 0.00242
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9955 - loss: 9.6370e-04 - val_accuracy: 0.9927 - val_loss: 0.0026
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9983 - loss: 6.1735e-04
# Epoch 72: val_loss did not improve from 0.00242
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9979 - loss: 5.8824e-04 - val_accuracy: 0.9934 - val_loss: 0.0026
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9975 - loss: 5.0513e-04
# Epoch 73: val_loss improved from 0.00242 to 0.00224, saving model to /content/drive/My Drive/Classification/focal_loss/models/ViT_UNet_best.keras
#
# Epoch 73: finished saving model to /content/drive/My Drive/Classification/focal_loss/models/ViT_UNet_best.keras
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 14s 170ms/step - accuracy: 0.9981 - loss: 4.3534e-04 - val_accuracy: 0.9942 - val_loss: 0.0022
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9984 - loss: 3.9898e-04
# Epoch 74: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 156ms/step - accuracy: 0.9977 - loss: 4.5535e-04 - val_accuracy: 0.9938 - val_loss: 0.0027
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9980 - loss: 3.0653e-04
# Epoch 75: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 13s 166ms/step - accuracy: 0.9985 - loss: 2.9518e-04 - val_accuracy: 0.9942 - val_loss: 0.0025
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9979 - loss: 5.6775e-04
# Epoch 76: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9979 - loss: 5.7166e-04 - val_accuracy: 0.9911 - val_loss: 0.0034
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9980 - loss: 4.8752e-04
# Epoch 77: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9981 - loss: 5.2526e-04 - val_accuracy: 0.9919 - val_loss: 0.0026
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9973 - loss: 4.3246e-04
# Epoch 78: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9980 - loss: 3.9883e-04 - val_accuracy: 0.9888 - val_loss: 0.0043
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9977 - loss: 6.5106e-04
# Epoch 79: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9978 - loss: 5.1079e-04 - val_accuracy: 0.9927 - val_loss: 0.0035
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9964 - loss: 8.9262e-04
# Epoch 80: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9964 - loss: 8.2817e-04 - val_accuracy: 0.9915 - val_loss: 0.0032
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9969 - loss: 8.7525e-04
# Epoch 81: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9980 - loss: 6.2717e-04 - val_accuracy: 0.9919 - val_loss: 0.0028
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9979 - loss: 6.0685e-04
# Epoch 82: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9984 - loss: 4.3659e-04 - val_accuracy: 0.9938 - val_loss: 0.0032
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9976 - loss: 3.6518e-04
# Epoch 83: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9985 - loss: 2.8618e-04 - val_accuracy: 0.9930 - val_loss: 0.0037
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9984 - loss: 3.8516e-04
# Epoch 84: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9988 - loss: 2.8294e-04 - val_accuracy: 0.9938 - val_loss: 0.0031
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9987 - loss: 4.3424e-04
# Epoch 85: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9990 - loss: 3.1686e-04 - val_accuracy: 0.9927 - val_loss: 0.0034
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9994 - loss: 1.9580e-04
# Epoch 86: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9991 - loss: 2.4426e-04 - val_accuracy: 0.9934 - val_loss: 0.0033
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9985 - loss: 3.1246e-04
# Epoch 87: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9988 - loss: 2.1546e-04 - val_accuracy: 0.9930 - val_loss: 0.0032
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9997 - loss: 1.1569e-04
# Epoch 88: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9995 - loss: 1.4965e-04 - val_accuracy: 0.9915 - val_loss: 0.0035
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9992 - loss: 1.6560e-04
# Epoch 89: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9993 - loss: 1.3624e-04 - val_accuracy: 0.9934 - val_loss: 0.0036
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9992 - loss: 3.6335e-04
# Epoch 90: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9994 - loss: 2.5392e-04 - val_accuracy: 0.9942 - val_loss: 0.0032
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9993 - loss: 1.6999e-04
# Epoch 91: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9992 - loss: 1.5999e-04 - val_accuracy: 0.9930 - val_loss: 0.0040
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9993 - loss: 2.7362e-04
# Epoch 92: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9994 - loss: 2.6862e-04 - val_accuracy: 0.9915 - val_loss: 0.0041
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9997 - loss: 8.4500e-05
# Epoch 93: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9996 - loss: 1.3178e-04 - val_accuracy: 0.9907 - val_loss: 0.0038
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9998 - loss: 8.9131e-05
# Epoch 94: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9996 - loss: 1.1962e-04 - val_accuracy: 0.9927 - val_loss: 0.0036
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9995 - loss: 1.1884e-04
# Epoch 95: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9995 - loss: 1.2356e-04 - val_accuracy: 0.9950 - val_loss: 0.0031
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9995 - loss: 1.2773e-04
# Epoch 96: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9995 - loss: 1.7254e-04 - val_accuracy: 0.9930 - val_loss: 0.0035
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9998 - loss: 1.1501e-04
# Epoch 97: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 151ms/step - accuracy: 0.9996 - loss: 1.3912e-04 - val_accuracy: 0.9942 - val_loss: 0.0032
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9994 - loss: 2.1785e-04
# Epoch 98: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9995 - loss: 1.6496e-04 - val_accuracy: 0.9950 - val_loss: 0.0031
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9996 - loss: 2.0809e-04
# Epoch 99: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 152ms/step - accuracy: 0.9996 - loss: 1.6009e-04 - val_accuracy: 0.9946 - val_loss: 0.0032
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9993 - loss: 1.3938e-04
# Epoch 100: val_loss did not improve from 0.00224
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.9995 - loss: 1.1287e-04 - val_accuracy: 0.9919 - val_loss: 0.0041
# ViT_UNet completed full training: 100/100 epochs.
#          model capacity_tag  test_accuracy     kappa  macro_f1  weighted_f1  \
# 0        GFNet  legacy_arch       0.996520  0.995280  0.995653     0.996519
# 1     ViT_UNet  legacy_arch       0.991647  0.988676  0.987395     0.991654
# 2  AlexNet_CNN  legacy_arch       0.982831  0.976711  0.974353     0.982827
#
#     val_nll  test_nll  val_brier  test_brier  test_ece_15bin  \
# 0  0.005116  0.012082   0.002220    0.005062        0.001669
# 1  0.024554  0.024530   0.012760    0.012344        0.002517
# 2  0.088724  0.088724   0.037515    0.037515        0.050411
#
#    epochs_configured  epochs_ran  train_time_sec  \
# 0                100         100      823.158964
# 1                100         100     1482.774212
# 2                100         100      818.103117
#
#                                      best_model_path  \
# 0  /content/drive/My Drive/Classification/focal_l...
# 1  /content/drive/My Drive/Classification/focal_l...
# 2  /content/drive/My Drive/Classification/focal_l...
#
#                                     final_model_path
# 0  /content/drive/My Drive/Classification/focal_l...
# 1  /content/drive/My Drive/Classification/focal_l...
# 2  /content/drive/My Drive/Classification/focal_l...

# %% [markdown]
# # 7.0 — Results & Metrics
# Save classification summaries to CSV / JSON, then plot training curves, cross-model bar charts, calibration proxies, and confusion matrices.

# %% [markdown]
# ## 7.1 — Save summary CSV and per-model JSON reports

# %%
summary_path = RESULTS_DIR / "classification_summary.csv"
summary_df.to_csv(summary_path, index=False)
print("Saved summary:", summary_path)

for model_name, artifact in model_artifacts.items():
    report_path = RESULTS_DIR / f"{model_name}_classification_report.json"
    with open(report_path, "w", encoding="utf-8") as f:
        json.dump(artifact["report"], f, indent=2)

print("Per-model classification reports saved to:", RESULTS_DIR)
summary_df
# Out:
# Saved summary: /content/drive/My Drive/Classification/focal_loss/results/classification_summary.csv
# Per-model classification reports saved to: /content/drive/My Drive/Classification/focal_loss/results
#          model capacity_tag  test_accuracy     kappa  macro_f1  weighted_f1  \
# 0        GFNet  legacy_arch       0.996520  0.995280  0.995653     0.996519
# 1     ViT_UNet  legacy_arch       0.991647  0.988676  0.987395     0.991654
# 2  AlexNet_CNN  legacy_arch       0.982831  0.976711  0.974353     0.982827
#
#     val_nll  test_nll  val_brier  test_brier  test_ece_15bin  \
# 0  0.005116  0.012082   0.002220    0.005062        0.001669
# 1  0.024554  0.024530   0.012760    0.012344        0.002517
# 2  0.088724  0.088724   0.037515    0.037515        0.050411
#
#    epochs_configured  epochs_ran  train_time_sec  \
# 0                100         100      823.158964
# 1                100         100     1482.774212
# 2                100         100      818.103117
#
#                                      best_model_path  \
# 0  /content/drive/My Drive/Classification/focal_l...
# 1  /content/drive/My Drive/Classification/focal_l...
# 2  /content/drive/My Drive/Classification/focal_l...
#
#                                     final_model_path
# 0  /content/drive/My Drive/Classification/focal_l...
# 1  /content/drive/My Drive/Classification/focal_l...
# 2  /content/drive/My Drive/Classification/focal_l...

# %% [markdown]
# ## 7.2 — Training curves (accuracy and loss per epoch)

# %%
for model_name, artifact in model_artifacts.items():
    hist   = artifact["history"]
    epochs = np.arange(1, len(hist["loss"]) + 1)

    fig, ax1 = plt.subplots(figsize=(12, 5))
    ax1.plot(epochs, hist["accuracy"],     color="#1f77b4", linewidth=2,   label="Train Accuracy")
    ax1.plot(epochs, hist["val_accuracy"], color="#2ca02c", linewidth=2, linestyle="--", label="Val Accuracy")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Accuracy")
    ax1.set_ylim(0, 1.0)
    ax1.grid(True, alpha=0.25)

    ax2 = ax1.twinx()
    ax2.plot(epochs, hist["loss"],     color="#111111", linewidth=1.8,   label="Train Loss")
    ax2.plot(epochs, hist["val_loss"], color="#d62728", linewidth=1.8, linestyle="--", label="Val Loss")
    ax2.set_ylabel("Loss")

    lines  = ax1.get_lines() + ax2.get_lines()
    labels = [ln.get_label() for ln in lines]
    ax1.legend(lines, labels, loc="upper right", frameon=True)
    plt.title(f"{model_name}: Accuracy / Loss vs Epoch")
    plt.tight_layout()

    curve_path = PLOT_DIR / f"{model_name}_training_curves.png"
    plt.savefig(curve_path, dpi=200, bbox_inches="tight")
    plt.show()

# %% [markdown]
# ## 7.3 — Cross-model comparison bar charts

# %%
plot_df = summary_df[[
    "model", "test_accuracy", "macro_f1", "kappa", "train_time_sec",
    "test_nll", "test_brier", "test_ece_15bin",
]].copy()

fig, axes = plt.subplots(2, 2, figsize=(15, 9))
axes    = axes.flatten()
palette = ["#4c72b0", "#55a868", "#c44e52"]

metric_specs = [
    ("test_accuracy",  "Test Accuracy",   (0.0, 1.0), "{:.3f}"),
    ("macro_f1",       "Macro F1",        (0.0, 1.0), "{:.3f}"),
    ("kappa",          "Cohen Kappa",     (0.0, 1.0), "{:.3f}"),
    ("train_time_sec", "Train Time (sec)", None,       "{:.1f}"),
]

for ax, (col, title, ylim, fmt) in zip(axes, metric_specs):
    local = plot_df[["model", col]].copy()
    bars  = ax.bar(local["model"], local[col], color=palette[:len(local)])
    ax.set_title(title)
    ax.set_xlabel("Model")
    ax.set_ylabel(title)
    if ylim is not None:
        ax.set_ylim(*ylim)
    ax.grid(axis="y", alpha=0.25)
    for patch in bars:
        height = patch.get_height()
        xpos   = patch.get_x() + patch.get_width() / 2
        offset = (ylim[1] - ylim[0]) * 0.02 if ylim else max(local[col].max() * 0.02, 0.05)
        ax.text(xpos, height + offset, fmt.format(height), ha="center", va="bottom", fontsize=9)

plt.suptitle("Single-Head Model Comparison", y=1.02, fontsize=14)
plt.tight_layout()
comparison_path = PLOT_DIR / "model_comparison_metrics.png"
plt.savefig(comparison_path, dpi=200, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 7.4 — Calibration proxy metrics and confusion matrices

# %%
# Calibration proxy chart (lower is better for all three metrics)
fig, ax     = plt.subplots(figsize=(12, 5))
calib_cols  = ["test_nll", "test_brier", "test_ece_15bin"]
calib_df    = plot_df[["model"] + calib_cols].set_index("model")
calib_df.plot(kind="bar", ax=ax, rot=0)
ax.set_title("Uncertainty Proxy Metrics (Lower is Better)")
ax.set_ylabel("Metric Value")
ax.grid(axis="y", alpha=0.25)
plt.tight_layout()
calib_path = PLOT_DIR / "uncertainty_proxy_metrics.png"
plt.savefig(calib_path, dpi=200, bbox_inches="tight")
plt.show()

# Side-by-side confusion matrices
class_ticks = [str(i + 1) for i in range(num_classes)]
fig, axes   = plt.subplots(1, len(model_artifacts), figsize=(7 * len(model_artifacts), 5.5))
if len(model_artifacts) == 1:
    axes = [axes]

for ax, (model_name, artifact) in zip(axes, model_artifacts.items()):
    sns.heatmap(
        artifact["confusion_matrix"],
        annot=True, fmt="d", cmap="Blues",
        xticklabels=class_ticks, yticklabels=class_ticks,
        cbar=False, ax=ax,
    )
    ax.set_title(f"{model_name} Confusion Matrix")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("True")

plt.tight_layout()
cm_path = PLOT_DIR / "confusion_matrices_side_by_side.png"
plt.savefig(cm_path, dpi=220, bbox_inches="tight")
plt.show()
print("Saved confusion matrix figure:", cm_path)
print("All training plots saved to:", PLOT_DIR)
# Out:
# Saved confusion matrix figure: /content/drive/My Drive/Classification/focal_loss/results/training_plots/confusion_matrices_side_by_side.png
# All training plots saved to: /content/drive/My Drive/Classification/focal_loss/results/training_plots

# %% [markdown]
# # 8.0 — Scene Visualisation
# Load the saved best models, run dense patch-by-patch inference over the entire scene, and save classified maps as PNGs and an Excel workbook.

# %% [markdown]
# ## 8.1 — Visualisation helpers

# %%
CUSTOM_OBJECTS = {
    "PatchExtractor":      PatchExtractor,
    "PatchPositionEncoder": PatchPositionEncoder,
    "GlobalFilterLayer":   GlobalFilterLayer,
    "PatchEncoderWithCLS": PatchEncoderWithCLS,
}


def get_scene_rgb(x_img, bands):
    """Select three bands as an approximate RGB composite; clip to [0, 1]."""
    if bands >= 6:
        rgb_idx = [bands // 2 - 1, bands // 2, bands // 2 + 1]
    elif bands >= 3:
        rgb_idx = [0, 1, 2]
    else:
        raise ValueError(f"Need at least 3 bands to form RGB, got {bands}.")
    return np.clip(x_img[:, :, rgb_idx], 0.0, 1.0)


def get_display_cmap(num_classes):
    """Build a ListedColormap: index 0 = background black, 1..K = class colours."""
    return ListedColormap([BACKGROUND_COLOR] + CLASS_COLOR_BASE[:num_classes])


def predict_full_scene_labels(model, x_img, patch_size=9, batch_size=256):
    """Run dense sliding-window inference row-by-row; returns a (H, W) label map."""
    pad   = patch_size // 2
    x_pad = np.pad(x_img, ((pad, pad), (pad, pad), (0, 0)), mode="edge")
    preds = np.zeros((x_img.shape[0], x_img.shape[1]), dtype=np.int32)

    for r in range(x_img.shape[0]):
        row_patches = np.empty(
            (x_img.shape[1], patch_size, patch_size, x_img.shape[-1]),
            dtype=np.float32,
        )
        for c in range(x_img.shape[1]):
            row_patches[c] = x_pad[r:r + patch_size, c:c + patch_size, :]

        row_prob  = model.predict(row_patches, batch_size=batch_size, verbose=0)
        preds[r]  = np.argmax(row_prob, axis=1) + 1  # back to 1..K

    return preds


def load_saved_models_for_visualization(model_dir, custom_objects):
    """Attempt to load all three best models; return dicts of loaded and missing."""
    model_files = {
        "AlexNet_CNN": model_dir / "AlexNet_CNN_best.keras",
        "GFNet":       model_dir / "GFNet_best.keras",
        "ViT_UNet":    model_dir / "ViT_UNet_best.keras",
    }
    loaded, missing = {}, {}
    for model_key, model_path in model_files.items():
        if not model_path.exists():
            missing[model_key] = f"Missing file: {model_path}"
            continue
        try:
            loaded[model_key] = keras.models.load_model(
                model_path, custom_objects=custom_objects,
                compile=False, safe_mode=False,
            )
        except Exception as exc:
            missing[model_key] = f"Load failed: {exc}"
    return loaded, missing


def save_single_panel(image, title, save_path, cmap=None, vmin=None, vmax=None):
    """Save a single image panel as a high-DPI PNG."""
    fig, ax = plt.subplots(figsize=(8, 6))
    if cmap is None:
        ax.imshow(image)
    else:
        ax.imshow(image, cmap=cmap, vmin=vmin, vmax=vmax)
    ax.set_title(title, fontsize=14)
    ax.axis("off")
    fig.tight_layout()
    fig.savefig(save_path, dpi=220, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print("Saved:", save_path)


def save_combined_overview(rgb_image, y_true, pred_maps, missing_info, num_classes, save_path):
    """Save a five-panel side-by-side overview: RGB, GT, and one panel per model."""
    cmap   = get_display_cmap(num_classes)
    panels = [
        ("Approximate RGB",             rgb_image,               "rgb"),
        ("True Label Map",              y_true,                  "label"),
        ("AlexNet Initial Classification", pred_maps.get("AlexNet_CNN"), "label"),
        ("GFNet Initial Classification",   pred_maps.get("GFNet"),       "label"),
        ("ViT Initial Classification",     pred_maps.get("ViT_UNet"),    "label"),
    ]

    fig, axes = plt.subplots(1, len(panels), figsize=(30, 7), sharex=True, sharey=True)
    for ax, (title, img, kind) in zip(axes, panels):
        ax.set_title(title, fontsize=13)
        if kind == "rgb":
            ax.imshow(img)
        elif img is None:
            ax.imshow(np.zeros_like(y_true), cmap=cmap, vmin=0, vmax=num_classes)
            key = {"AlexNet": "AlexNet_CNN", "GFNet": "GFNet", "ViT": "ViT_UNet"}.get(
                next((k for k in ("AlexNet", "GFNet", "ViT") if k in title), None)
            )
            ax.text(0.5, 0.5, missing_info.get(key, "Unavailable"),
                    ha="center", va="center", fontsize=10, wrap=True, transform=ax.transAxes)
        else:
            ax.imshow(img, cmap=cmap, vmin=0, vmax=num_classes)
        ax.axis("off")

    handles = [plt.Rectangle((0, 0), 1, 1, color=BACKGROUND_COLOR, label="Background")]
    for i in range(num_classes):
        handles.append(plt.Rectangle((0, 0), 1, 1, color=CLASS_COLOR_BASE[i], label=f"Class {i+1}"))
    fig.legend(handles=handles, loc="lower center", ncol=min(num_classes + 1, 8),
               bbox_to_anchor=(0.5, -0.02), frameon=True)
    fig.tight_layout(rect=[0, 0.05, 1, 1])
    fig.savefig(save_path, dpi=220, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print("Saved:", save_path)


def save_images_to_excel(excel_path, image_paths, sheet_name="Initial_Classification_Maps"):
    """Embed PNG images into an Excel workbook at fixed anchor positions."""
    if excel_path.exists():
        wb = load_workbook(excel_path)
        if sheet_name in wb.sheetnames:
            del wb[sheet_name]
        ws = wb.create_sheet(title=sheet_name)
    else:
        wb = Workbook()
        ws = wb.active
        ws.title = sheet_name

    anchors = ["A1", "J1", "A25", "J25", "A49", "J49"]
    for path, anchor in zip(image_paths, anchors):
        if path.exists():
            img        = XLImage(str(path))
            img.anchor = anchor
            ws.add_image(img)

    wb.save(excel_path)
    print("Saved Excel workbook:", excel_path)

# %% [markdown]
# ## 8.2 — Generate and save all scene maps

# %%
scene_rgb    = get_scene_rgb(x_img, B)
display_cmap = get_display_cmap(num_classes)

loaded_models, missing_models = load_saved_models_for_visualization(MODEL_DIR, CUSTOM_OBJECTS)
prediction_maps = {}

for model_key, loaded_model in loaded_models.items():
    print(f"Generating full-scene classified image for {model_key}...")
    prediction_maps[model_key] = predict_full_scene_labels(
        loaded_model, x_img, patch_size=PATCH_SIZE, batch_size=BATCH_SIZE,
    )
    print(f"{model_key} map shape:", prediction_maps[model_key].shape)

if missing_models:
    print("Some models could not be loaded:")
    for model_key, reason in missing_models.items():
        print(f"  - {model_key}: {reason}")

# Individual PNG paths
rgb_png      = VIS_DIR / "scene_rgb.png"
gt_png       = VIS_DIR / "ground_truth_label_map.png"
alex_png     = VIS_DIR / "AlexNet_CNN_initial_classification.png"
gfnet_png    = VIS_DIR / "GFNet_initial_classification.png"
vit_png      = VIS_DIR / "ViT_UNet_initial_classification.png"
overview_png = VIS_DIR / "combined_initial_classification_overview.png"

save_single_panel(scene_rgb, "Approximate RGB", rgb_png)
save_single_panel(y_img, "Ground Truth Label Map", gt_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("AlexNet_CNN") is not None:
    save_single_panel(prediction_maps["AlexNet_CNN"], "AlexNet Initial Classification",
                      alex_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("GFNet") is not None:
    save_single_panel(prediction_maps["GFNet"], "GFNet Initial Classification",
                      gfnet_png, cmap=display_cmap, vmin=0, vmax=num_classes)

if prediction_maps.get("ViT_UNet") is not None:
    save_single_panel(prediction_maps["ViT_UNet"], "ViT Initial Classification",
                      vit_png, cmap=display_cmap, vmin=0, vmax=num_classes)

save_combined_overview(
    rgb_image=scene_rgb, y_true=y_img, pred_maps=prediction_maps,
    missing_info=missing_models, num_classes=num_classes, save_path=overview_png,
)

image_paths_for_excel = [rgb_png, gt_png, alex_png, gfnet_png, vit_png, overview_png]
save_images_to_excel(VIS_EXCEL_PATH, image_paths_for_excel, sheet_name="Initial_Classification_Maps")

print("All visualisation outputs saved to:", VIS_DIR)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
